# %%
import pandas as pd
from enum import Enum, auto

# FILENAME = "future_taobao_ssMain_tick"
FILENAME = "future_taobao_ss2401"
# FILENAME = "tianqin_ss"



class open_interest_delta_forward_enum(Enum):
    NONE = auto()
    UNKNOWN = auto()
    EXCHANGE = auto()
    OPENFWDOUBLE = auto()
    OPEN = auto()
    CLOSEFWDOUBLE = auto()
    CLOSE = auto()

class order_forward_enum(Enum):
    UP = auto()
    DOWN = auto()
    MIDDLE = auto()

class tick_type_key_enum(Enum):
    TICKTYPE = auto()
    TICKCOLOR = auto()

class tick_type_enum(Enum):
    NOCHANGE = '无交易'
    UNKNOWN = '未知'
    EXCHANGELONG = '多换'
    EXCHANGESHORT = '空换'
    EXCHANGEUNKOWN = '未知换'
    OPENDOUBLE = '双开'
    OPENLONG = '多开'
    OPENSHORT = '空开'
    OPENUNKOWN = '未知开'
    CLOSEDOUBLE = '双平'
    CLOSESHORT = '空平'
    CLOSELONG = '多平'
    CLOSEUNKOWN = '未知平'

class tick_color_enum(Enum):
    WHITE = '白色'
    RED = '红色'
    GREEN = '绿色'

tick_type_cal_dict = {
    open_interest_delta_forward_enum.NONE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.EXCHANGE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGELONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGESHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPENFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPEN:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENLONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENSHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSEFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSESHORT,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSELONG,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
}

 # Mapping of openclose and price_direction to open_interest_delta_forward_enum and order_forward_enum
openclose_mapping = {
    '换手': open_interest_delta_forward_enum.EXCHANGE,
    '双开': open_interest_delta_forward_enum.OPENFWDOUBLE,
    '开仓': open_interest_delta_forward_enum.OPEN,
    '双平': open_interest_delta_forward_enum.CLOSEFWDOUBLE,  # Assuming definition for 双平
    '平仓': open_interest_delta_forward_enum.CLOSE,
    '无交易': open_interest_delta_forward_enum.NONE,
    '未知':open_interest_delta_forward_enum.UNKNOWN
}

price_direction_mapping = {
    '向上': order_forward_enum.UP,
    '向下': order_forward_enum.DOWN,
    '不变': order_forward_enum.MIDDLE
}

# 枚举到中文的映射
tick_type_to_chinese = {
    tick_type_enum.NOCHANGE: '无交易',
    tick_type_enum.UNKNOWN: '未知',
    tick_type_enum.EXCHANGELONG: '多换',
    tick_type_enum.EXCHANGESHORT: '空换',
    tick_type_enum.EXCHANGEUNKOWN: '未知换',
    tick_type_enum.OPENDOUBLE: '双开',
    tick_type_enum.OPENLONG: '开多',
    tick_type_enum.OPENSHORT: '开空',
    tick_type_enum.OPENUNKOWN: '未知开',
    tick_type_enum.CLOSEDOUBLE: '双平',
    tick_type_enum.CLOSESHORT: '空平',
    tick_type_enum.CLOSELONG: '多平',
    tick_type_enum.CLOSEUNKOWN: '未知平',
}

tick_color_to_chinese = {
    tick_color_enum.WHITE: '白色',
    tick_color_enum.RED: '红色',
    tick_color_enum.GREEN: '绿色',
}


# Load the tick data
df = pd.read_csv(FILENAME+".csv")

# Calculate the deltas for volume and open interest
df['volume_delta'] = df['volume'].diff()
df['open_interest_delta'] = df['open_interest'].diff()

# Initialize columns for open/close position
df['trade_openclose'] = None
df['trade_color'] = None 
df['close_count'] = df['volume_delta']

# Iterate over the DataFrame to assign open/close positions
for i in range(1, len(df)):
    volume_delta = df.loc[i, 'volume_delta']
    open_interest_delta = df.loc[i, 'open_interest_delta']
    last_price = df.loc[i, 'last_price']
    ask_price1 = df.loc[i, 'ask_price1']
    bid_price1 = df.loc[i, 'bid_price1']
    pre_last_price = df.loc[i-1,'last_price']
    pre_ask_price1 = df.loc[i-1, 'ask_price1']
    pre_bid_price1 = df.loc[i-1, 'bid_price1']
    openclose = ''
    price_direction = ''

    # Determine the open/close position
    if volume_delta == open_interest_delta > 0:
        openclose = '双开'
    elif volume_delta > open_interest_delta > 0:
        openclose = '开仓'
    elif volume_delta > abs(open_interest_delta) > 0 and open_interest_delta < 0:
        openclose = '平仓'
    elif volume_delta > 0 and open_interest_delta == 0:
        openclose = '换手'
    elif volume_delta + open_interest_delta == 0 and volume_delta>0:
        openclose = '双平'
    elif volume_delta == 0 and  open_interest_delta == 0:
        openclose = '无交易'
    else:
        openclose = '未知'
    
    # 判断价格方向
    if last_price >= pre_ask_price1:
        price_direction = '向上'
    elif last_price <= pre_bid_price1:
        price_direction = '向下'
    elif last_price >= ask_price1:
        price_direction = '向上'
    elif last_price <= bid_price1:
        price_direction = '向下'
    else:
        price_direction = '不变'
        
   

    # Convert openclose and price_direction to their corresponding enum values
    delta_enum = openclose_mapping.get(openclose, open_interest_delta_forward_enum.NONE)
    direction_enum = price_direction_mapping.get(price_direction, order_forward_enum.MIDDLE)

    # Retrieve the tick type and color based on the mappings
    tick_info = tick_type_cal_dict.get(delta_enum, {}).get(direction_enum, {})
    tick_type = tick_info.get(tick_type_key_enum.TICKTYPE, tick_type_enum.UNKNOWN)
    tick_color = tick_info.get(tick_type_key_enum.TICKCOLOR, tick_color_enum.WHITE)
    

    # 使用映射转换为中文描述
    tick_type_chinese = tick_type_to_chinese[tick_type]
    tick_color_chinese = tick_color_to_chinese[tick_color]

    # 更新DataFrame
    df.at[i, 'trade_openclose'] = tick_type_chinese
    df.at[i, 'trade_color'] = tick_color_chinese

# Save the modified DataFrame to a new CSV file
df.to_csv(FILENAME+"_withopenclose.csv", index=False)

# %%
import pandas as pd

# FILENAME = "future_taobao_ssMain_tick"
FILENAME = "future_taobao_ss2401"


# 假设已加载并准备好DataFrame df
df = pd.read_csv(FILENAME+"_withopenclose.csv")

df = df.loc[df['volume_delta'] > 0]
# 重置索引以确保从0开始
df.reset_index(drop=True, inplace=True)


guess_tick=100

# 初始化列用于标记交易机会
df['buy_opportunity'] = 0
df['sell_opportunity'] = 0
trade_hand=1
trade_slippy = 0

# 为每个tick计算未来100个tick内与当前挂单价格相匹配的成交量
for i in range(len(df)):
    if i + guess_tick >= len(df):  # 确保未来有足够的tick进行分析
        break

    # 当前的买一和卖一价
    current_ask_price1 = df.loc[i, 'ask_price1']
    current_bid_price1 = df.loc[i, 'bid_price1']

    # 初始化对应价格的成交量计数
    matching_buy_volume = 0
    matching_sell_volume = 0
    
    buy_done = 0
    sell_done = 0

    # 遍历未来100个tick
    for j in range(i+1, i+guess_tick+1):
        if df.loc[j, 'bid_price1']<current_bid_price1:
            buy_done = 1 
        if df.loc[j, 'ask_price1']>current_ask_price1:
            sell_done = 1 
        # 如果未来tick的买一价等于当前tick的买一价，累加成交量
        if df.loc[j, 'bid_price1'] == current_bid_price1 and df.loc[j, 'bid_price1'] == df.loc[j, 'last_price']:
            matching_buy_volume += df.loc[j, 'volume_delta']
        # 如果未来tick的卖一价等于当前tick的卖一价，累加成交量
        if df.loc[j, 'ask_price1'] == current_ask_price1 and df.loc[j, 'ask_price1'] == df.loc[j, 'last_price']:
            matching_sell_volume += df.loc[j, 'volume_delta']

   # 判断是否存在买卖机会
    if buy_done==1 or matching_buy_volume >= df.loc[i, 'bid_volume1']+trade_hand+trade_slippy:
        df.loc[i, 'buy_opportunity'] = 1
    if sell_done==1 or matching_sell_volume >= df.loc[i, 'ask_volume1']+trade_hand+trade_slippy:
        df.loc[i, 'sell_opportunity'] = 1


# 创建一个新列来标记同时为买卖机会的tick
df['dual_opportunity'] = ((df['buy_opportunity'] == 1) & (df['sell_opportunity'] == 1)).astype(int)

# 计算同时为买卖机会的总数
dual_opportunities_count = df['dual_opportunity'].sum()

# 计算比例
total_ticks_analyzed = len(df) - guess_tick
dual_opportunities_ratio = dual_opportunities_count / total_ticks_analyzed

print(f"Dual opportunities count: {dual_opportunities_count}")
print(f"Dual opportunities ratio: {dual_opportunities_ratio:.4f}")

# 保存到新的CSV文件
df.to_csv(FILENAME+"_with_opportunities.csv", index=False)
# df.to_csv(FILENAME+"_120_with_opportunities.csv", index=False)
# Out:
# Dual opportunities count: 282503
# Dual opportunities ratio: 0.5630

# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score,precision_score

# FILENAME = "future_taobao_ssMain_tick"
FILENAME = "future_taobao_ss2401"


# 加载数据
data = pd.read_csv(FILENAME+"_with_opportunities.csv")

data_clean = data.dropna().copy()  # 创建一个副本以避免警告

data_clean =  pd.get_dummies(data_clean, columns=['trade_color', 'trade_openclose'])

features = [
    'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
    'bid_price1', 'ask_price1', 'bid_price2', 'ask_price2', 'bid_price3', 'ask_price3',
    'bid_price4', 'ask_price4', 'bid_price5', 'ask_price5', 'bid_volume1', 'bid_volume2',
    'bid_volume3', 'bid_volume4', 'bid_volume5', 'ask_volume1', 'ask_volume2', 'ask_volume3',
    'ask_volume4', 'ask_volume5'
]
# 获取所有列名
all_columns = data_clean.columns.tolist()
# 筛选出以"trade_color_"和"trade_openclose_"开头的列名
# 并将它们添加到features列表中
for column in all_columns:
    if column.startswith('trade_color_') or column.startswith('trade_openclose_'):
        features.append(column)

window_size = 200  # 用于特征计算的窗口大小
# 特征生成
data_clean['rolling_mean'] = data_clean['last_price'].rolling(window=window_size).mean()
data_clean['rolling_std'] = data_clean['last_price'].rolling(window=window_size).std()
data_clean['ask_rolling_mean'] = data_clean['ask_price1'].rolling(window=window_size).mean()
data_clean['ask_rolling_std'] = data_clean['ask_price1'].rolling(window=window_size).std()
data_clean['bid_rolling_mean'] = data_clean['bid_price1'].rolling(window=window_size).mean()
data_clean['bid_rolling_std'] = data_clean['bid_price1'].rolling(window=window_size).std()
# RSI计算
delta = data_clean['last_price'].diff()
gain = (delta.where(delta > 0, 0)).fillna(0)
loss = (-delta.where(delta < 0, 0)).fillna(0)
avg_gain = gain.rolling(window=window_size).mean()
avg_loss = loss.rolling(window=window_size).mean()
rs = avg_gain / avg_loss
data_clean['RSI'] = 100 - (100 / (1 + rs))
# MACD计算
short_ema = data_clean['last_price'].ewm(span=int(window_size/2), adjust=False).mean()  # 使用窗口大小的一半作为短期EMA
long_ema = data_clean['last_price'].ewm(span=window_size, adjust=False).mean()  # 使用整个窗口大小作为长期EMA
data_clean['MACD'] = short_ema - long_ema
data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=int(window_size/3), adjust=False).mean()  # 使用窗口大小的三分之一作为信号线
# 删除因计算滚动特征而产生的NaN值
data_clean.dropna(inplace=True)
# 添加新特征到特征列表
features.extend(['rolling_mean', 'rolling_std','ask_rolling_mean', 'ask_rolling_std','bid_rolling_mean', 'bid_rolling_std', 'RSI', 'MACD', 'MACD_signal'])

X = data_clean[['datetime'] + features]
y = data_clean['dual_opportunity']

# 数据切分
split_start = int(len(data_clean) * 0.5)
split_point = int(len(data_clean) * 1)
split_end = int(len(data_clean) * 1)
X_train = X.iloc[split_start:split_point]
y_train = y.iloc[split_start:split_point]
X_test = X.iloc[split_point:split_end]
y_test = y.iloc[split_point:split_end]
X_train_features = X_train.drop(columns=['datetime'])
X_test_features = X_test.drop(columns=['datetime'])



# 创建XGBoost模型并调整参数
model = xgb.XGBClassifier(
    n_estimators=40,  # 树的个数
    max_depth=3,  # 树的深度
    learning_rate=0.1,  # 学习率
    subsample=0.8,  # 训练每棵树时使用的样本比例
    colsample_bytree=0.8,  # 构建树时的列采样比例
    random_state=42,  # 随机种子
    use_label_encoder=False,  # 避免使用标签编码器的警告
    eval_metric='logloss',  # 评估指标
    scale_pos_weight=1
)
# print(X_train_features)
# 模型训练
model.fit(X_train_features, y_train)

# # 获取属于类别1的概率
# y_pred_proba = model.predict_proba(X_test_features)[:, 1]

# # 设置交易阈值
# trade_threshold = 0.65
# # 根据阈值生成预测结果，大于等于阈值预测为1，否则为0
# y_pred_threshold = (y_pred_proba >= trade_threshold).astype(int)
# # 计算查准率
# precision = precision_score(y_test, y_pred_threshold)
# print(f"Precision: {precision}")
# predicted_ones_count = np.sum(y_pred_threshold == 1)
# total_count = len(y_pred_threshold)
# print(f"Predicted as 1: {predicted_ones_count} / Total: {total_count}")

# # 对照组评估（全1预测）
# predictions_all_ones = [1] * len(y_test)
# print("All Ones Accuracy:", precision_score(y_test, predictions_all_ones))
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/laplace/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [14:29:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1748292887431/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=40, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
import pandas as pd
from datetime import datetime, time

guess_tick = 100
profit = 0  # 盈利
trade_threshold = 0.65 # 交易阈值
trade_hand = 1
trade_slippy = 0

trade_gap = 5 #每跳多少钱
hand_volume = 5  # 不锈钢1手5吨，1手开仓2元，平今0元
hand_fee = 2
done_count = 0
count = 0
daily_profit = {}  # 新增：用于存储每日盈利
daily_trade = {}

last_date_str=''
stop = False

def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False

# # 加载数据
data = pd.read_csv("future_taobao_ss2401_with_opportunities.csv")
data = data.dropna().copy() 

data =  pd.get_dummies(data, columns=['trade_color', 'trade_openclose'])
# 检查这些列是否存在于data中，如果不存在，则添加并赋值为0
for col in features:
    if col not in data.columns:
        data[col] = 0

data['volume_delta'] = data['volume'].diff()
data['open_interest_delta'] = data['open_interest'].diff()
data = data.loc[data['volume_delta'] > 0]


# 更新滚动平均值和滚动标准差
window_size = 200
data['rolling_mean'] = data['last_price'].rolling(window=window_size).mean()
data['rolling_std'] = data['last_price'].rolling(window=window_size).std()
data['ask_rolling_mean'] = data['ask_price1'].rolling(window=window_size).mean()
data['ask_rolling_std'] = data['ask_price1'].rolling(window=window_size).std()
data['bid_rolling_mean'] = data['bid_price1'].rolling(window=window_size).mean()
data['bid_rolling_std'] = data['bid_price1'].rolling(window=window_size).std()

# 更新RSI
delta = data['last_price'].diff()
gain = delta.where(delta > 0, 0).fillna(0)
loss = -delta.where(delta < 0, 0).fillna(0)
avg_gain = gain.rolling(window=window_size).mean()
avg_loss = loss.rolling(window=window_size).mean()
rs = avg_gain / avg_loss
data['RSI'] = 100 - (100 / (1 + rs))

# 更新MACD和MACD信号线
short_window = int(window_size/2)
long_window = window_size
signal_window = int(window_size/3)
data['short_ema'] = data['last_price'].ewm(span=short_window, adjust=False).mean()
data['long_ema'] = data['last_price'].ewm(span=long_window, adjust=False).mean()
data['MACD'] = data['short_ema'] - data['long_ema']
data['MACD_signal'] = data['MACD'].ewm(span=signal_window, adjust=False).mean()

# 预处理测试数据以匹配训练时的特征
X_test = data[['datetime'] + features].dropna()
X_test_features = X_test.drop(columns=['datetime'])

# 检查datetime列的数据类型并进行相应处理
if X_test['datetime'].dtype == 'object':
    # 如果是字符串格式，直接转换为datetime
    X_test['datetime'] = pd.to_datetime(X_test['datetime'])
else:
    # 如果是数值格式，按原来的方式处理
    X_test['datetime'] = pd.to_datetime(X_test['datetime'].astype(float), unit='ns')
    # 本地化为UTC时间，然后转换为目标时区
    X_test['datetime'] = X_test['datetime'].dt.tz_localize('UTC').dt.tz_convert('Asia/Shanghai')

# 将时间格式化为标准日期时间字符串，去除时区信息
X_test['datetime'] = X_test['datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')
# 保存处理后的DataFrame到新文件
X_test.to_csv("tianqin_test.csv", index=False)
# X_test = pd.read_csv("tianqin_test.csv")
# X_test_features = X_test.drop(columns=['datetime'])

y_pred_proba = model.predict_proba(X_test_features)[:, 1]
# print(X_test_features)

# 定义时间范围数组
notrade_time = ["11:25-11:30","14:55-15:00","0:50-1:00"]


i = guess_tick
while i < len(X_test) - guess_tick:  # 留出100个tick进行预测
    
    datetime_str = X_test.iloc[i]['datetime']
    date_str = datetime_str.split(' ')[0]  # 新增：提取日期字符串
    
    if last_date_str!= date_str: 
        daily_fail_count = 0
        daily_count = 0
        last_date_str = date_str
        stop = False
 
    
    if daily_profit.get(date_str, 0)  < -120:
        last_date_str = date_str
        stop = True
   
    if stop:
        i = i + 1
        continue
    
    
    if '.' in datetime_str:
        # 如果有小数点，分割为主时间部分和纳秒部分
        time, nano_part = datetime_str.split('.')
    else:
        # 如果没有小数点，则没有纳秒部分
        time = datetime_str
        nano_part = '0'
    if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S").time(), notrade_time):
        i = i+1
        continue
    
    
    current_ask_price1 = X_test.iloc[i]['ask_price1']
    current_bid_price1 = X_test.iloc[i]['bid_price1']
    if current_ask_price1-current_bid_price1!=trade_gap:
        i = i+1
        continue

    proba = y_pred_proba[i]
    # print(datetime_str)
    # print(proba)
    if proba < trade_threshold:
        i = i+1
        continue
    
    matching_buy_volume = 0
    matching_sell_volume = 0
    buy_done = 0
    sell_done = 0
    
    buy_index = 0
    sell_index = 0
    buy_stop_index = 0
    sell_stop_index = 0
    
    for j in range(i + 1, i + guess_tick + 1): 
        future_tick = X_test.iloc[j]
        if future_tick['bid_price1'] < current_bid_price1:
            buy_done = 1
            if buy_index==0:
                buy_index = j
        if future_tick['ask_price1'] > current_ask_price1:
            sell_done = 1
            if sell_index==0:
                sell_index = j
        if future_tick['bid_price1'] == current_bid_price1 and future_tick['last_price'] == current_bid_price1:
            matching_buy_volume += future_tick['volume_delta']
            if matching_buy_volume >= X_test.iloc[i]['bid_volume1']+trade_hand+trade_slippy and buy_index==0:
                buy_index = j
        if future_tick['ask_price1'] == current_ask_price1 and future_tick['last_price'] == current_ask_price1:
            matching_sell_volume += future_tick['volume_delta']
            if matching_sell_volume >= X_test.iloc[i]['ask_volume1']+trade_hand+trade_slippy and sell_index==0:
                sell_index = j
        if buy_index>0 and sell_index>0:
            break
        if buy_index>0 and buy_stop_index==0 and future_tick['bid_price1']<current_bid_price1:
            buy_stop_index = j
            break
        if sell_index>0 and sell_stop_index==0 and future_tick['ask_price1']>current_ask_price1:
            sell_stop_index = j
            break
        

    # print(buy_index)
    # print(sell_index)
    # print(buy_stop_index)
    # print(sell_stop_index)
    stop_loss_tick = i + guess_tick
    stop_loss_price_bid = X_test.iloc[stop_loss_tick]['bid_price1']
    stop_loss_price_ask = X_test.iloc[stop_loss_tick]['ask_price1']
    count = count + 1
    daily_trade[date_str] = daily_trade.get(date_str,0)+1
    
    # 判断是否存在买卖机会
    if buy_index>0 and sell_index>0:
        trade_profit = (current_ask_price1 - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        done_count += 1
        print(f"🎯 【双边成交】交易时间: {X_test.iloc[i]['datetime']}")
        print(f"💰 交易盈利: {trade_profit:.2f}元 (买价:{current_bid_price1}, 卖价:{current_ask_price1}, 价差:{current_ask_price1-current_bid_price1})")
        print(f"📈 买入成交时间: {X_test.iloc[buy_index]['datetime']}")
        print(f"📉 卖出成交时间: {X_test.iloc[sell_index]['datetime']}")
        print("-" * 50)
    elif buy_index>0:
        if buy_stop_index>0:
            trade_profit = (X_test.iloc[buy_stop_index]['bid_price1'] - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            exit_price = X_test.iloc[buy_stop_index]['bid_price1']
            exit_time = X_test.iloc[buy_stop_index]['datetime']
            exit_reason = "价格下跌止损"
        else:
            trade_profit = (stop_loss_price_bid - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            exit_price = stop_loss_price_bid
            exit_time = X_test.iloc[stop_loss_tick]['datetime']
            exit_reason = "时间止损"
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        print(f"📈 【仅买入成交】交易时间: {X_test.iloc[i]['datetime']}")
        print(f"💰 交易盈利: {trade_profit:.2f}元 (买入价:{current_bid_price1}, 平仓价:{exit_price})")
        print(f"📈 买入成交时间: {X_test.iloc[buy_index]['datetime']}")
        print(f"🛑 平仓时间: {exit_time} ({exit_reason})")
        print("-" * 50)
    elif sell_index>0:
        if sell_stop_index>0:
            trade_profit = (current_ask_price1 - X_test.iloc[sell_stop_index]['ask_price1'] ) * trade_hand * hand_volume-hand_fee*trade_hand
            exit_price = X_test.iloc[sell_stop_index]['ask_price1']
            exit_time = X_test.iloc[sell_stop_index]['datetime']
            exit_reason = "价格上涨止损"
        else:
            trade_profit = (current_ask_price1 - stop_loss_price_ask) * trade_hand * hand_volume-hand_fee*trade_hand
            exit_price = stop_loss_price_ask
            exit_time = X_test.iloc[stop_loss_tick]['datetime']
            exit_reason = "时间止损"
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        print(f"📉 【仅卖出成交】交易时间: {X_test.iloc[i]['datetime']}")
        print(f"💰 交易盈利: {trade_profit:.2f}元 (卖出价:{current_ask_price1}, 平仓价:{exit_price})")
        print(f"📉 卖出成交时间: {X_test.iloc[sell_index]['datetime']}")
        print(f"🛑 平仓时间: {exit_time} ({exit_reason})")
        print("-" * 50)
    else:
        i = i + 1
    i = stop_loss_tick

# 打印交易汇总统计
print("\n" + "="*60)
print("📊 交易回测结果汇总")
print("="*60)

print("\n📅 每日盈亏统计:")
print("-" * 40)
total_profit_days = 0
total_loss_days = 0
for date, daily_profit_value in daily_profit.items():
    daily_trades = daily_trade.get(date, 0)
    status = "📈 盈利" if daily_profit_value > 0 else "📉 亏损" if daily_profit_value < 0 else "⚖️ 持平"
    if daily_profit_value > 0:
        total_profit_days += 1
    elif daily_profit_value < 0:
        total_loss_days += 1
    print(f"{date}: {status} {daily_profit_value:>8.2f}元 (交易{daily_trades}次)")

print("\n💰 总体统计:")
print("-" * 40)
print(f"总盈亏: {profit:.2f}元")
print(f"双边成交次数: {done_count}次")
print(f"总交易信号次数: {count}次")
print(f"双边成交率: {done_count/count*100:.2f}%")
print(f"盈利天数: {total_profit_days}天")
print(f"亏损天数: {total_loss_days}天")
print(f"总交易天数: {len(daily_profit)}天")
if len(daily_profit) > 0:
    print(f"平均每日盈亏: {profit/len(daily_profit):.2f}元")
    print(f"胜率: {total_profit_days/(total_profit_days+total_loss_days)*100:.2f}%")

print("\n🎯 交易参数:")
print("-" * 40)
print(f"交易阈值: {trade_threshold}")
print(f"交易手数: {trade_hand}手")
print(f"每手吨数: {hand_volume}吨")
print(f"手续费: {hand_fee}元/手")
print(f"价格跳动: {trade_gap}元")
print("="*60)
# Out:
# 📉 【仅卖出成交】交易时间: 2023-10-31 21:06:05
# 💰 交易盈利: -27.00元 (卖出价:14500.0, 平仓价:14505.0)
# 📉 卖出成交时间: 2023-10-31 21:06:05
# 🛑 平仓时间: 2023-10-31 21:06:05 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-10-31 21:08:35
# 💰 交易盈利: -27.00元 (买入价:14445.0, 平仓价:14440.0)
# 📈 买入成交时间: 2023-10-31 21:08:38
# 🛑 平仓时间: 2023-10-31 21:08:38 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-10-31 21:10:01
# 💰 交易盈利: -52.00元 (买入价:14430.0, 平仓价:14420.0)
# 📈 买入成交时间: 2023-10-31 21:10:02
# 🛑 平仓时间: 2023-10-31 21:10:02 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-10-31 21:11:11
# 💰 交易盈利: -27.00元 (卖出价:14410.0, 平仓价:14415.0)
# 📉 卖出成交时间: 2023-10-31 21:11:14
# 🛑 平仓时间: 2023-10-31 21:11:14 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-01 00:01:52
# 💰 交易盈利: -27.00元 (卖出价:14455.0, 平仓价:14460.0)
# 📉 卖出成交时间: 2023-11-01 00:02:57
# 🛑 平仓时间: 2023-11-01 00:02:57 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-01 00:35:33
# 💰 交易盈利: -27.00元 (买入价:14445.0, 平仓价:14440.0)
# 📈 买入成交时间: 2023-11-01 00:35:33
# 🛑 平仓时间: 2023-11-01 00:35:33 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-01 00:49:15
# 💰 交易盈利: -27.00元 (买入价:14445.0, 平仓价:14440.0)
# 📈 买入成交时间: 2023-11-01 00:51:01
# 🛑 平仓时间: 2023-11-01 00:53:08 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-01 09:00:38
# 💰 交易盈利: -27.00元 (买入价:14425.0, 平仓价:14420.0)
# 📈 买入成交时间: 2023-11-01 09:00:39
# 🛑 平仓时间: 2023-11-01 09:00:39 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-01 09:02:40
# 💰 交易盈利: -27.00元 (卖出价:14415.0, 平仓价:14420.0)
# 📉 卖出成交时间: 2023-11-01 09:02:53
# 🛑 平仓时间: 2023-11-01 09:02:53 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-02 00:01:02
# 💰 交易盈利: -27.00元 (卖出价:14340.0, 平仓价:14345.0)
# 📉 卖出成交时间: 2023-11-02 00:02:03
# 🛑 平仓时间: 2023-11-02 00:02:03 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-02 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:14330.0, 平仓价:14335.0)
# 📉 卖出成交时间: 2023-11-02 09:00:01
# 🛑 平仓时间: 2023-11-02 09:00:01 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-02 09:02:44
# 💰 交易盈利: -27.00元 (卖出价:14355.0, 平仓价:14360.0)
# 📉 卖出成交时间: 2023-11-02 09:02:46
# 🛑 平仓时间: 2023-11-02 09:02:46 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-02 09:04:40
# 💰 交易盈利: -27.00元 (卖出价:14365.0, 平仓价:14370.0)
# 📉 卖出成交时间: 2023-11-02 09:04:44
# 🛑 平仓时间: 2023-11-02 09:04:44 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-02 09:07:46
# 💰 交易盈利: -27.00元 (卖出价:14350.0, 平仓价:14355.0)
# 📉 卖出成交时间: 2023-11-02 09:07:52
# 🛑 平仓时间: 2023-11-02 09:08:01 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-03 00:07:02
# 💰 交易盈利: -27.00元 (买入价:14420.0, 平仓价:14415.0)
# 📈 买入成交时间: 2023-11-03 00:07:03
# 🛑 平仓时间: 2023-11-03 00:07:03 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-03 08:59:00
# 💰 交易盈利: -52.00元 (卖出价:14430.0, 平仓价:14440.0)
# 📉 卖出成交时间: 2023-11-03 09:00:00
# 🛑 平仓时间: 2023-11-03 09:00:00 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-03 09:02:11
# 💰 交易盈利: -27.00元 (卖出价:14410.0, 平仓价:14415.0)
# 📉 卖出成交时间: 2023-11-03 09:02:11
# 🛑 平仓时间: 2023-11-03 09:02:11 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-03 09:05:43
# 💰 交易盈利: 23.00元 (买价:14410.0, 卖价:14415.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-03 09:05:44
# 📉 卖出成交时间: 2023-11-03 09:06:32
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-03 09:11:28
# 💰 交易盈利: -27.00元 (买入价:14405.0, 平仓价:14400.0)
# 📈 买入成交时间: 2023-11-03 09:11:37
# 🛑 平仓时间: 2023-11-03 09:11:37 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-03 09:15:25
# 💰 交易盈利: -27.00元 (卖出价:14400.0, 平仓价:14405.0)
# 📉 卖出成交时间: 2023-11-03 09:15:26
# 🛑 平仓时间: 2023-11-03 09:15:26 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-04 00:01:48
# 💰 交易盈利: -27.00元 (卖出价:14500.0, 平仓价:14505.0)
# 📉 卖出成交时间: 2023-11-04 00:02:34
# 🛑 平仓时间: 2023-11-04 00:02:34 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-06 09:00:01
# 💰 交易盈利: -27.00元 (卖出价:14495.0, 平仓价:14500.0)
# 📉 卖出成交时间: 2023-11-06 09:00:02
# 🛑 平仓时间: 2023-11-06 09:00:02 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-06 09:01:30
# 💰 交易盈利: -27.00元 (买入价:14460.0, 平仓价:14455.0)
# 📈 买入成交时间: 2023-11-06 09:01:31
# 🛑 平仓时间: 2023-11-06 09:01:33 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-06 09:02:48
# 💰 交易盈利: -27.00元 (买入价:14440.0, 平仓价:14435.0)
# 📈 买入成交时间: 2023-11-06 09:02:52
# 🛑 平仓时间: 2023-11-06 09:02:52 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-06 09:04:17
# 💰 交易盈利: -27.00元 (卖出价:14450.0, 平仓价:14455.0)
# 📉 卖出成交时间: 2023-11-06 09:04:23
# 🛑 平仓时间: 2023-11-06 09:04:23 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-06 09:06:57
# 💰 交易盈利: -27.00元 (买入价:14455.0, 平仓价:14450.0)
# 📈 买入成交时间: 2023-11-06 09:06:58
# 🛑 平仓时间: 2023-11-06 09:06:58 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-07 00:00:00
# 💰 交易盈利: -27.00元 (买入价:14590.0, 平仓价:14585.0)
# 📈 买入成交时间: 2023-11-07 00:01:12
# 🛑 平仓时间: 2023-11-07 00:01:12 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-07 09:00:01
# 💰 交易盈利: -27.00元 (买入价:14580.0, 平仓价:14575.0)
# 📈 买入成交时间: 2023-11-07 09:00:02
# 🛑 平仓时间: 2023-11-07 09:00:02 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-07 09:04:01
# 💰 交易盈利: -27.00元 (买入价:14575.0, 平仓价:14570.0)
# 📈 买入成交时间: 2023-11-07 09:04:10
# 🛑 平仓时间: 2023-11-07 09:04:10 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-07 09:06:19
# 💰 交易盈利: 23.00元 (买价:14570.0, 卖价:14575.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-07 09:06:47
# 📉 卖出成交时间: 2023-11-07 09:06:50
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-07 09:09:03
# 💰 交易盈利: 23.00元 (买价:14555.0, 卖价:14560.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-07 09:09:09
# 📉 卖出成交时间: 2023-11-07 09:09:11
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-07 09:13:36
# 💰 交易盈利: -27.00元 (买入价:14580.0, 平仓价:14575.0)
# 📈 买入成交时间: 2023-11-07 09:13:54
# 🛑 平仓时间: 2023-11-07 09:13:54 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-07 09:17:45
# 💰 交易盈利: -27.00元 (卖出价:14600.0, 平仓价:14605.0)
# 📉 卖出成交时间: 2023-11-07 09:17:53
# 🛑 平仓时间: 2023-11-07 09:17:53 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-07 09:22:02
# 💰 交易盈利: -27.00元 (买入价:14600.0, 平仓价:14595.0)
# 📈 买入成交时间: 2023-11-07 09:22:49
# 🛑 平仓时间: 2023-11-07 09:22:49 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-07 09:27:13
# 💰 交易盈利: -27.00元 (卖出价:14605.0, 平仓价:14610.0)
# 📉 卖出成交时间: 2023-11-07 09:27:14
# 🛑 平仓时间: 2023-11-07 09:27:14 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-08 00:01:09
# 💰 交易盈利: -27.00元 (卖出价:14360.0, 平仓价:14365.0)
# 📉 卖出成交时间: 2023-11-08 00:01:10
# 🛑 平仓时间: 2023-11-08 00:01:10 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-08 00:17:58
# 💰 交易盈利: -27.00元 (买入价:14375.0, 平仓价:14370.0)
# 📈 买入成交时间: 2023-11-08 00:18:12
# 🛑 平仓时间: 2023-11-08 00:18:12 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-08 00:42:34
# 💰 交易盈利: -27.00元 (卖出价:14400.0, 平仓价:14405.0)
# 📉 卖出成交时间: 2023-11-08 00:43:19
# 🛑 平仓时间: 2023-11-08 00:43:19 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-08 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:14395.0, 平仓价:14400.0)
# 📉 卖出成交时间: 2023-11-08 09:00:01
# 🛑 平仓时间: 2023-11-08 09:00:01 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-08 09:01:39
# 💰 交易盈利: -27.00元 (卖出价:14380.0, 平仓价:14385.0)
# 📉 卖出成交时间: 2023-11-08 09:01:41
# 🛑 平仓时间: 2023-11-08 09:01:41 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-09 00:00:29
# 💰 交易盈利: -27.00元 (买入价:14490.0, 平仓价:14485.0)
# 📈 买入成交时间: 2023-11-09 00:06:01
# 🛑 平仓时间: 2023-11-09 00:06:01 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-09 00:36:15
# 💰 交易盈利: -27.00元 (卖出价:14500.0, 平仓价:14505.0)
# 📉 卖出成交时间: 2023-11-09 00:36:24
# 🛑 平仓时间: 2023-11-09 00:36:24 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-09 08:59:00
# 💰 交易盈利: 23.00元 (买价:14470.0, 卖价:14475.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-09 09:00:01
# 📉 卖出成交时间: 2023-11-09 09:00:01
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-09 09:01:05
# 💰 交易盈利: -27.00元 (卖出价:14450.0, 平仓价:14455.0)
# 📉 卖出成交时间: 2023-11-09 09:01:09
# 🛑 平仓时间: 2023-11-09 09:01:10 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-09 09:03:09
# 💰 交易盈利: -27.00元 (卖出价:14460.0, 平仓价:14465.0)
# 📉 卖出成交时间: 2023-11-09 09:03:41
# 🛑 平仓时间: 2023-11-09 09:03:50 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-09 09:06:03
# 💰 交易盈利: -27.00元 (买入价:14485.0, 平仓价:14480.0)
# 📈 买入成交时间: 2023-11-09 09:06:05
# 🛑 平仓时间: 2023-11-09 09:06:05 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-09 09:10:16
# 💰 交易盈利: -27.00元 (卖出价:14485.0, 平仓价:14490.0)
# 📉 卖出成交时间: 2023-11-09 09:10:38
# 🛑 平仓时间: 2023-11-09 09:10:38 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-10 00:02:20
# 💰 交易盈利: -27.00元 (卖出价:14510.0, 平仓价:14515.0)
# 📉 卖出成交时间: 2023-11-10 00:02:21
# 🛑 平仓时间: 2023-11-10 00:02:21 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-10 00:24:07
# 💰 交易盈利: -27.00元 (卖出价:14515.0, 平仓价:14520.0)
# 📉 卖出成交时间: 2023-11-10 00:25:59
# 🛑 平仓时间: 2023-11-10 00:25:59 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-10 00:41:44
# 💰 交易盈利: -27.00元 (卖出价:14520.0, 平仓价:14525.0)
# 📉 卖出成交时间: 2023-11-10 00:42:08
# 🛑 平仓时间: 2023-11-10 00:42:08 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-10 00:49:42
# 💰 交易盈利: -27.00元 (买入价:14510.0, 平仓价:14505.0)
# 📈 买入成交时间: 2023-11-10 00:49:49
# 🛑 平仓时间: 2023-11-10 00:49:49 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-10 08:59:00
# 💰 交易盈利: -52.00元 (买入价:14500.0, 平仓价:14490.0)
# 📈 买入成交时间: 2023-11-10 09:00:00
# 🛑 平仓时间: 2023-11-10 09:00:00 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-11 00:07:12
# 💰 交易盈利: -27.00元 (卖出价:14310.0, 平仓价:14315.0)
# 📉 卖出成交时间: 2023-11-11 00:07:21
# 🛑 平仓时间: 2023-11-11 00:07:22 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-11 00:17:38
# 💰 交易盈利: -27.00元 (买入价:14285.0, 平仓价:14280.0)
# 📈 买入成交时间: 2023-11-11 00:17:53
# 🛑 平仓时间: 2023-11-11 00:17:53 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-11 00:21:26
# 💰 交易盈利: -27.00元 (卖出价:14285.0, 平仓价:14290.0)
# 📉 卖出成交时间: 2023-11-11 00:21:56
# 🛑 平仓时间: 2023-11-11 00:22:17 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-11 00:26:05
# 💰 交易盈利: 23.00元 (买价:14295.0, 卖价:14300.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-11 00:26:25
# 📉 卖出成交时间: 2023-11-11 00:26:12
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-11 00:35:48
# 💰 交易盈利: -27.00元 (卖出价:14290.0, 平仓价:14295.0)
# 📉 卖出成交时间: 2023-11-11 00:35:49
# 🛑 平仓时间: 2023-11-11 00:35:49 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-11 00:48:44
# 💰 交易盈利: -27.00元 (卖出价:14295.0, 平仓价:14300.0)
# 📉 卖出成交时间: 2023-11-11 00:49:00
# 🛑 平仓时间: 2023-11-11 00:49:00 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-13 09:00:01
# 💰 交易盈利: -27.00元 (卖出价:14285.0, 平仓价:14290.0)
# 📉 卖出成交时间: 2023-11-13 09:00:01
# 🛑 平仓时间: 2023-11-13 09:00:01 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-13 09:01:04
# 💰 交易盈利: -27.00元 (买入价:14275.0, 平仓价:14270.0)
# 📈 买入成交时间: 2023-11-13 09:01:08
# 🛑 平仓时间: 2023-11-13 09:01:08 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-13 09:02:32
# 💰 交易盈利: -27.00元 (买入价:14260.0, 平仓价:14255.0)
# 📈 买入成交时间: 2023-11-13 09:02:33
# 🛑 平仓时间: 2023-11-13 09:02:33 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-13 09:04:01
# 💰 交易盈利: -27.00元 (卖出价:14280.0, 平仓价:14285.0)
# 📉 卖出成交时间: 2023-11-13 09:04:10
# 🛑 平仓时间: 2023-11-13 09:04:10 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-13 09:05:43
# 💰 交易盈利: 23.00元 (买价:14265.0, 卖价:14270.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-13 09:05:51
# 📉 卖出成交时间: 2023-11-13 09:05:48
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-13 09:06:40
# 💰 交易盈利: -27.00元 (卖出价:14210.0, 平仓价:14215.0)
# 📉 卖出成交时间: 2023-11-13 09:06:41
# 🛑 平仓时间: 2023-11-13 09:06:42 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-13 09:07:39
# 💰 交易盈利: -27.00元 (卖出价:14220.0, 平仓价:14225.0)
# 📉 卖出成交时间: 2023-11-13 09:07:43
# 🛑 平仓时间: 2023-11-13 09:07:43 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-14 00:00:02
# 💰 交易盈利: -27.00元 (卖出价:14140.0, 平仓价:14145.0)
# 📉 卖出成交时间: 2023-11-14 00:00:25
# 🛑 平仓时间: 2023-11-14 00:00:25 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-14 00:25:17
# 💰 交易盈利: -27.00元 (卖出价:14150.0, 平仓价:14155.0)
# 📉 卖出成交时间: 2023-11-14 00:29:22
# 🛑 平仓时间: 2023-11-14 00:29:22 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-14 00:48:54
# 💰 交易盈利: -27.00元 (卖出价:14155.0, 平仓价:14160.0)
# 📉 卖出成交时间: 2023-11-14 00:49:38
# 🛑 平仓时间: 2023-11-14 00:49:38 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-14 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:14155.0, 平仓价:14160.0)
# 📉 卖出成交时间: 2023-11-14 09:00:00
# 🛑 平仓时间: 2023-11-14 09:00:00 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-14 09:01:25
# 💰 交易盈利: -27.00元 (买入价:14155.0, 平仓价:14150.0)
# 📈 买入成交时间: 2023-11-14 09:01:25
# 🛑 平仓时间: 2023-11-14 09:01:25 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-15 00:08:53
# 💰 交易盈利: -27.00元 (卖出价:14100.0, 平仓价:14105.0)
# 📉 卖出成交时间: 2023-11-15 00:09:17
# 🛑 平仓时间: 2023-11-15 00:09:17 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-15 08:59:00
# 💰 交易盈利: -27.00元 (买入价:14100.0, 平仓价:14095.0)
# 📈 买入成交时间: 2023-11-15 09:00:00
# 🛑 平仓时间: 2023-11-15 09:00:00 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-15 09:00:59
# 💰 交易盈利: -27.00元 (买入价:14085.0, 平仓价:14080.0)
# 📈 买入成交时间: 2023-11-15 09:01:01
# 🛑 平仓时间: 2023-11-15 09:01:01 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-15 09:02:08
# 💰 交易盈利: -27.00元 (卖出价:14100.0, 平仓价:14105.0)
# 📉 卖出成交时间: 2023-11-15 09:02:09
# 🛑 平仓时间: 2023-11-15 09:02:09 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-15 09:03:28
# 💰 交易盈利: -27.00元 (买入价:14085.0, 平仓价:14080.0)
# 📈 买入成交时间: 2023-11-15 09:03:38
# 🛑 平仓时间: 2023-11-15 09:03:38 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-16 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:14080.0, 平仓价:14085.0)
# 📉 卖出成交时间: 2023-11-16 09:00:01
# 🛑 平仓时间: 2023-11-16 09:00:01 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-16 09:01:11
# 💰 交易盈利: -27.00元 (卖出价:14090.0, 平仓价:14095.0)
# 📉 卖出成交时间: 2023-11-16 09:01:12
# 🛑 平仓时间: 2023-11-16 09:01:12 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-16 09:05:20
# 💰 交易盈利: -27.00元 (买入价:14095.0, 平仓价:14090.0)
# 📈 买入成交时间: 2023-11-16 09:05:36
# 🛑 平仓时间: 2023-11-16 09:05:36 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-16 09:09:10
# 💰 交易盈利: -27.00元 (买入价:14090.0, 平仓价:14085.0)
# 📈 买入成交时间: 2023-11-16 09:09:20
# 🛑 平仓时间: 2023-11-16 09:09:20 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-16 09:27:07
# 💰 交易盈利: -27.00元 (买入价:14060.0, 平仓价:14055.0)
# 📈 买入成交时间: 2023-11-16 09:27:07
# 🛑 平仓时间: 2023-11-16 09:27:07 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-17 00:02:17
# 💰 交易盈利: -27.00元 (卖出价:14015.0, 平仓价:14020.0)
# 📉 卖出成交时间: 2023-11-17 00:02:17
# 🛑 平仓时间: 2023-11-17 00:02:18 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-17 00:15:31
# 💰 交易盈利: -27.00元 (卖出价:14020.0, 平仓价:14025.0)
# 📉 卖出成交时间: 2023-11-17 00:15:37
# 🛑 平仓时间: 2023-11-17 00:15:38 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-17 09:00:01
# 💰 交易盈利: -27.00元 (买入价:13995.0, 平仓价:13990.0)
# 📈 买入成交时间: 2023-11-17 09:00:02
# 🛑 平仓时间: 2023-11-17 09:00:02 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-17 09:00:54
# 💰 交易盈利: -27.00元 (买入价:13935.0, 平仓价:13930.0)
# 📈 买入成交时间: 2023-11-17 09:00:55
# 🛑 平仓时间: 2023-11-17 09:00:55 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-17 09:01:46
# 💰 交易盈利: -27.00元 (卖出价:13930.0, 平仓价:13935.0)
# 📉 卖出成交时间: 2023-11-17 09:01:47
# 🛑 平仓时间: 2023-11-17 09:01:47 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-20 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:13915.0, 平仓价:13920.0)
# 📉 卖出成交时间: 2023-11-20 09:00:00
# 🛑 平仓时间: 2023-11-20 09:00:00 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-20 09:00:52
# 💰 交易盈利: 23.00元 (买价:13940.0, 卖价:13945.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-20 09:00:59
# 📉 卖出成交时间: 2023-11-20 09:00:56
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-20 09:01:54
# 💰 交易盈利: -27.00元 (卖出价:13940.0, 平仓价:13945.0)
# 📉 卖出成交时间: 2023-11-20 09:01:54
# 🛑 平仓时间: 2023-11-20 09:01:54 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-20 09:03:00
# 💰 交易盈利: -27.00元 (买入价:13930.0, 平仓价:13925.0)
# 📈 买入成交时间: 2023-11-20 09:03:02
# 🛑 平仓时间: 2023-11-20 09:03:02 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-20 09:04:25
# 💰 交易盈利: -27.00元 (卖出价:13935.0, 平仓价:13940.0)
# 📉 卖出成交时间: 2023-11-20 09:04:25
# 🛑 平仓时间: 2023-11-20 09:04:25 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-20 09:06:52
# 💰 交易盈利: -27.00元 (买入价:13930.0, 平仓价:13925.0)
# 📈 买入成交时间: 2023-11-20 09:06:53
# 🛑 平仓时间: 2023-11-20 09:06:53 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-20 09:14:16
# 💰 交易盈利: -27.00元 (卖出价:13930.0, 平仓价:13935.0)
# 📉 卖出成交时间: 2023-11-20 09:14:16
# 🛑 平仓时间: 2023-11-20 09:14:16 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-21 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13865.0, 平仓价:13860.0)
# 📈 买入成交时间: 2023-11-21 09:00:00
# 🛑 平仓时间: 2023-11-21 09:00:00 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-21 09:00:59
# 💰 交易盈利: 23.00元 (买价:13850.0, 卖价:13855.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-21 09:00:59
# 📉 卖出成交时间: 2023-11-21 09:01:05
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-21 09:02:08
# 💰 交易盈利: -27.00元 (买入价:13880.0, 平仓价:13875.0)
# 📈 买入成交时间: 2023-11-21 09:02:11
# 🛑 平仓时间: 2023-11-21 09:02:11 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-21 09:03:00
# 💰 交易盈利: -27.00元 (买入价:13885.0, 平仓价:13880.0)
# 📈 买入成交时间: 2023-11-21 09:03:00
# 🛑 平仓时间: 2023-11-21 09:03:12 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-21 09:03:58
# 💰 交易盈利: -27.00元 (卖出价:13895.0, 平仓价:13900.0)
# 📉 卖出成交时间: 2023-11-21 09:03:59
# 🛑 平仓时间: 2023-11-21 09:03:59 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-21 09:04:54
# 💰 交易盈利: -27.00元 (买入价:13890.0, 平仓价:13885.0)
# 📈 买入成交时间: 2023-11-21 09:05:05
# 🛑 平仓时间: 2023-11-21 09:05:06 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-21 09:06:25
# 💰 交易盈利: -27.00元 (卖出价:13890.0, 平仓价:13895.0)
# 📉 卖出成交时间: 2023-11-21 09:06:26
# 🛑 平仓时间: 2023-11-21 09:06:26 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-22 09:00:00
# 💰 交易盈利: -27.00元 (买入价:13790.0, 平仓价:13785.0)
# 📈 买入成交时间: 2023-11-22 09:00:02
# 🛑 平仓时间: 2023-11-22 09:00:02 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-22 09:01:05
# 💰 交易盈利: -27.00元 (买入价:13780.0, 平仓价:13775.0)
# 📈 买入成交时间: 2023-11-22 09:01:08
# 🛑 平仓时间: 2023-11-22 09:01:08 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-22 09:02:54
# 💰 交易盈利: -27.00元 (买入价:13775.0, 平仓价:13770.0)
# 📈 买入成交时间: 2023-11-22 09:02:55
# 🛑 平仓时间: 2023-11-22 09:02:55 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-22 09:10:57
# 💰 交易盈利: -27.00元 (卖出价:13740.0, 平仓价:13745.0)
# 📉 卖出成交时间: 2023-11-22 09:10:57
# 🛑 平仓时间: 2023-11-22 09:11:01 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-22 09:29:44
# 💰 交易盈利: -27.00元 (卖出价:13675.0, 平仓价:13680.0)
# 📉 卖出成交时间: 2023-11-22 09:29:45
# 🛑 平仓时间: 2023-11-22 09:29:45 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-23 00:22:31
# 💰 交易盈利: -27.00元 (买入价:13585.0, 平仓价:13580.0)
# 📈 买入成交时间: 2023-11-23 00:22:56
# 🛑 平仓时间: 2023-11-23 00:22:56 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-23 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13615.0, 平仓价:13610.0)
# 📈 买入成交时间: 2023-11-23 09:00:00
# 🛑 平仓时间: 2023-11-23 09:00:00 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-23 09:01:09
# 💰 交易盈利: 23.00元 (买价:13605.0, 卖价:13610.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-23 09:01:10
# 📉 卖出成交时间: 2023-11-23 09:01:31
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-23 09:02:47
# 💰 交易盈利: -27.00元 (卖出价:13625.0, 平仓价:13630.0)
# 📉 卖出成交时间: 2023-11-23 09:02:48
# 🛑 平仓时间: 2023-11-23 09:02:48 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-23 09:04:05
# 💰 交易盈利: -27.00元 (买入价:13625.0, 平仓价:13620.0)
# 📈 买入成交时间: 2023-11-23 09:04:06
# 🛑 平仓时间: 2023-11-23 09:04:06 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-23 09:05:45
# 💰 交易盈利: -27.00元 (买入价:13620.0, 平仓价:13615.0)
# 📈 买入成交时间: 2023-11-23 09:06:01
# 🛑 平仓时间: 2023-11-23 09:06:01 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-23 09:09:38
# 💰 交易盈利: -27.00元 (买入价:13595.0, 平仓价:13590.0)
# 📈 买入成交时间: 2023-11-23 09:09:43
# 🛑 平仓时间: 2023-11-23 09:09:43 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-24 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13715.0, 平仓价:13710.0)
# 📈 买入成交时间: 2023-11-24 09:00:00
# 🛑 平仓时间: 2023-11-24 09:00:00 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-24 09:01:03
# 💰 交易盈利: -27.00元 (卖出价:13695.0, 平仓价:13700.0)
# 📉 卖出成交时间: 2023-11-24 09:01:06
# 🛑 平仓时间: 2023-11-24 09:01:09 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-24 09:01:57
# 💰 交易盈利: -27.00元 (卖出价:13675.0, 平仓价:13680.0)
# 📉 卖出成交时间: 2023-11-24 09:01:58
# 🛑 平仓时间: 2023-11-24 09:01:58 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-24 09:14:09
# 💰 交易盈利: -27.00元 (卖出价:13705.0, 平仓价:13710.0)
# 📉 卖出成交时间: 2023-11-24 09:14:12
# 🛑 平仓时间: 2023-11-24 09:14:12 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-24 09:16:11
# 💰 交易盈利: 23.00元 (买价:13710.0, 卖价:13715.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-24 09:16:57
# 📉 卖出成交时间: 2023-11-24 09:16:28
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-24 09:27:14
# 💰 交易盈利: -27.00元 (买入价:13720.0, 平仓价:13715.0)
# 📈 买入成交时间: 2023-11-24 09:27:25
# 🛑 平仓时间: 2023-11-24 09:27:25 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-24 09:59:47
# 💰 交易盈利: -27.00元 (卖出价:13750.0, 平仓价:13755.0)
# 📉 卖出成交时间: 2023-11-24 09:59:47
# 🛑 平仓时间: 2023-11-24 09:59:47 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-27 08:59:00
# 💰 交易盈利: 23.00元 (买价:13595.0, 卖价:13600.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-27 09:00:00
# 📉 卖出成交时间: 2023-11-27 09:00:00
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-27 09:00:56
# 💰 交易盈利: -27.00元 (买入价:13575.0, 平仓价:13570.0)
# 📈 买入成交时间: 2023-11-27 09:00:57
# 🛑 平仓时间: 2023-11-27 09:00:57 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-27 09:01:53
# 💰 交易盈利: -27.00元 (卖出价:13575.0, 平仓价:13580.0)
# 📉 卖出成交时间: 2023-11-27 09:02:01
# 🛑 平仓时间: 2023-11-27 09:02:01 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-27 09:03:04
# 💰 交易盈利: -27.00元 (卖出价:13585.0, 平仓价:13590.0)
# 📉 卖出成交时间: 2023-11-27 09:03:04
# 🛑 平仓时间: 2023-11-27 09:03:04 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-27 09:04:13
# 💰 交易盈利: -27.00元 (买入价:13610.0, 平仓价:13605.0)
# 📈 买入成交时间: 2023-11-27 09:04:15
# 🛑 平仓时间: 2023-11-27 09:04:15 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-27 09:05:47
# 💰 交易盈利: 23.00元 (买价:13620.0, 卖价:13625.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-27 09:05:48
# 📉 卖出成交时间: 2023-11-27 09:05:59
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-27 09:07:00
# 💰 交易盈利: -27.00元 (买入价:13630.0, 平仓价:13625.0)
# 📈 买入成交时间: 2023-11-27 09:07:00
# 🛑 平仓时间: 2023-11-27 09:07:00 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-27 09:08:15
# 💰 交易盈利: -27.00元 (卖出价:13655.0, 平仓价:13660.0)
# 📉 卖出成交时间: 2023-11-27 09:08:16
# 🛑 平仓时间: 2023-11-27 09:08:16 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-27 09:10:52
# 💰 交易盈利: -27.00元 (卖出价:13670.0, 平仓价:13675.0)
# 📉 卖出成交时间: 2023-11-27 09:10:54
# 🛑 平仓时间: 2023-11-27 09:10:54 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-28 00:08:16
# 💰 交易盈利: -27.00元 (买入价:13610.0, 平仓价:13605.0)
# 📈 买入成交时间: 2023-11-28 00:08:17
# 🛑 平仓时间: 2023-11-28 00:08:17 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-28 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13605.0, 平仓价:13600.0)
# 📈 买入成交时间: 2023-11-28 09:00:02
# 🛑 平仓时间: 2023-11-28 09:00:02 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-28 09:01:12
# 💰 交易盈利: -27.00元 (买入价:13595.0, 平仓价:13590.0)
# 📈 买入成交时间: 2023-11-28 09:01:13
# 🛑 平仓时间: 2023-11-28 09:01:13 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-28 09:02:36
# 💰 交易盈利: -27.00元 (卖出价:13605.0, 平仓价:13610.0)
# 📉 卖出成交时间: 2023-11-28 09:02:44
# 🛑 平仓时间: 2023-11-28 09:02:44 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-28 09:04:13
# 💰 交易盈利: -27.00元 (卖出价:13580.0, 平仓价:13585.0)
# 📉 卖出成交时间: 2023-11-28 09:04:13
# 🛑 平仓时间: 2023-11-28 09:04:17 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-29 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:13915.0, 平仓价:13920.0)
# 📉 卖出成交时间: 2023-11-29 09:00:00
# 🛑 平仓时间: 2023-11-29 09:00:00 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-29 09:01:01
# 💰 交易盈利: -27.00元 (买入价:13920.0, 平仓价:13915.0)
# 📈 买入成交时间: 2023-11-29 09:01:02
# 🛑 平仓时间: 2023-11-29 09:01:02 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-29 09:02:46
# 💰 交易盈利: 23.00元 (买价:13890.0, 卖价:13895.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-29 09:03:05
# 📉 卖出成交时间: 2023-11-29 09:03:02
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-29 09:03:53
# 💰 交易盈利: -27.00元 (买入价:13885.0, 平仓价:13880.0)
# 📈 买入成交时间: 2023-11-29 09:03:57
# 🛑 平仓时间: 2023-11-29 09:03:58 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-29 09:05:01
# 💰 交易盈利: -27.00元 (卖出价:13885.0, 平仓价:13890.0)
# 📉 卖出成交时间: 2023-11-29 09:05:04
# 🛑 平仓时间: 2023-11-29 09:05:04 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-29 09:06:12
# 💰 交易盈利: -27.00元 (卖出价:13875.0, 平仓价:13880.0)
# 📉 卖出成交时间: 2023-11-29 09:06:15
# 🛑 平仓时间: 2023-11-29 09:06:15 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-29 09:09:08
# 💰 交易盈利: -27.00元 (买入价:13885.0, 平仓价:13880.0)
# 📈 买入成交时间: 2023-11-29 09:09:09
# 🛑 平仓时间: 2023-11-29 09:09:09 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-30 00:00:17
# 💰 交易盈利: -27.00元 (卖出价:14050.0, 平仓价:14055.0)
# 📉 卖出成交时间: 2023-11-30 00:01:17
# 🛑 平仓时间: 2023-11-30 00:01:20 (价格上涨止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-11-30 00:26:32
# 💰 交易盈利: 23.00元 (买价:14070.0, 卖价:14075.0, 价差:5.0)
# 📈 买入成交时间: 2023-11-30 00:28:44
# 📉 卖出成交时间: 2023-11-30 00:27:59
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-30 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:14075.0, 平仓价:14080.0)
# 📉 卖出成交时间: 2023-11-30 09:00:00
# 🛑 平仓时间: 2023-11-30 09:00:00 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-30 09:00:57
# 💰 交易盈利: -27.00元 (买入价:14080.0, 平仓价:14075.0)
# 📈 买入成交时间: 2023-11-30 09:00:59
# 🛑 平仓时间: 2023-11-30 09:00:59 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-11-30 09:02:01
# 💰 交易盈利: -27.00元 (卖出价:14070.0, 平仓价:14075.0)
# 📉 卖出成交时间: 2023-11-30 09:02:01
# 🛑 平仓时间: 2023-11-30 09:02:01 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-30 09:03:33
# 💰 交易盈利: -27.00元 (买入价:14055.0, 平仓价:14050.0)
# 📈 买入成交时间: 2023-11-30 09:03:39
# 🛑 平仓时间: 2023-11-30 09:03:52 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-11-30 09:04:47
# 💰 交易盈利: -27.00元 (买入价:14050.0, 平仓价:14045.0)
# 📈 买入成交时间: 2023-11-30 09:04:53
# 🛑 平仓时间: 2023-11-30 09:04:54 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-01 00:21:57
# 💰 交易盈利: -27.00元 (买入价:13810.0, 平仓价:13805.0)
# 📈 买入成交时间: 2023-12-01 00:21:57
# 🛑 平仓时间: 2023-12-01 00:21:57 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-01 00:41:45
# 💰 交易盈利: -27.00元 (买入价:13810.0, 平仓价:13805.0)
# 📈 买入成交时间: 2023-12-01 00:41:46
# 🛑 平仓时间: 2023-12-01 00:41:46 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-01 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13810.0, 平仓价:13805.0)
# 📈 买入成交时间: 2023-12-01 09:00:01
# 🛑 平仓时间: 2023-12-01 09:00:02 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-01 09:01:06
# 💰 交易盈利: -27.00元 (买入价:13830.0, 平仓价:13825.0)
# 📈 买入成交时间: 2023-12-01 09:01:06
# 🛑 平仓时间: 2023-12-01 09:01:08 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-01 09:02:21
# 💰 交易盈利: -27.00元 (卖出价:13840.0, 平仓价:13845.0)
# 📉 卖出成交时间: 2023-12-01 09:02:22
# 🛑 平仓时间: 2023-12-01 09:02:22 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-02 00:27:00
# 💰 交易盈利: -27.00元 (卖出价:13750.0, 平仓价:13755.0)
# 📉 卖出成交时间: 2023-12-02 00:27:45
# 🛑 平仓时间: 2023-12-02 00:27:45 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-04 09:00:00
# 💰 交易盈利: -52.00元 (买入价:13735.0, 平仓价:13725.0)
# 📈 买入成交时间: 2023-12-04 09:00:01
# 🛑 平仓时间: 2023-12-04 09:00:01 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-04 09:01:01
# 💰 交易盈利: -27.00元 (买入价:13710.0, 平仓价:13705.0)
# 📈 买入成交时间: 2023-12-04 09:01:02
# 🛑 平仓时间: 2023-12-04 09:01:02 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-04 09:01:56
# 💰 交易盈利: -27.00元 (买入价:13690.0, 平仓价:13685.0)
# 📈 买入成交时间: 2023-12-04 09:02:01
# 🛑 平仓时间: 2023-12-04 09:02:01 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-04 09:03:01
# 💰 交易盈利: -27.00元 (卖出价:13725.0, 平仓价:13730.0)
# 📉 卖出成交时间: 2023-12-04 09:03:04
# 🛑 平仓时间: 2023-12-04 09:03:04 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-05 00:02:26
# 💰 交易盈利: -27.00元 (买入价:13600.0, 平仓价:13595.0)
# 📈 买入成交时间: 2023-12-05 00:02:28
# 🛑 平仓时间: 2023-12-05 00:02:28 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-05 00:42:00
# 💰 交易盈利: -27.00元 (买入价:13585.0, 平仓价:13580.0)
# 📈 买入成交时间: 2023-12-05 00:42:21
# 🛑 平仓时间: 2023-12-05 00:42:22 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-12-05 08:59:00
# 💰 交易盈利: 23.00元 (买价:13575.0, 卖价:13580.0, 价差:5.0)
# 📈 买入成交时间: 2023-12-05 09:00:01
# 📉 卖出成交时间: 2023-12-05 09:00:01
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-12-05 09:00:55
# 💰 交易盈利: 23.00元 (买价:13535.0, 卖价:13540.0, 价差:5.0)
# 📈 买入成交时间: 2023-12-05 09:01:03
# 📉 卖出成交时间: 2023-12-05 09:01:00
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-05 09:01:54
# 💰 交易盈利: -27.00元 (卖出价:13550.0, 平仓价:13555.0)
# 📉 卖出成交时间: 2023-12-05 09:01:58
# 🛑 平仓时间: 2023-12-05 09:01:58 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-05 09:03:17
# 💰 交易盈利: -27.00元 (卖出价:13495.0, 平仓价:13500.0)
# 📉 卖出成交时间: 2023-12-05 09:03:18
# 🛑 平仓时间: 2023-12-05 09:03:18 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-05 09:04:13
# 💰 交易盈利: -27.00元 (买入价:13495.0, 平仓价:13490.0)
# 📈 买入成交时间: 2023-12-05 09:04:15
# 🛑 平仓时间: 2023-12-05 09:04:15 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-05 09:05:55
# 💰 交易盈利: -27.00元 (买入价:13520.0, 平仓价:13515.0)
# 📈 买入成交时间: 2023-12-05 09:05:58
# 🛑 平仓时间: 2023-12-05 09:05:58 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-05 09:07:02
# 💰 交易盈利: -27.00元 (卖出价:13490.0, 平仓价:13495.0)
# 📉 卖出成交时间: 2023-12-05 09:07:03
# 🛑 平仓时间: 2023-12-05 09:07:03 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-06 00:09:18
# 💰 交易盈利: -27.00元 (买入价:13030.0, 平仓价:13025.0)
# 📈 买入成交时间: 2023-12-06 00:09:21
# 🛑 平仓时间: 2023-12-06 00:09:29 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-06 00:44:23
# 💰 交易盈利: -27.00元 (卖出价:13030.0, 平仓价:13035.0)
# 📉 卖出成交时间: 2023-12-06 00:47:06
# 🛑 平仓时间: 2023-12-06 00:47:06 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-06 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13045.0, 平仓价:13040.0)
# 📈 买入成交时间: 2023-12-06 09:00:00
# 🛑 平仓时间: 2023-12-06 09:00:01 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-12-06 09:01:10
# 💰 交易盈利: 23.00元 (买价:13020.0, 卖价:13025.0, 价差:5.0)
# 📈 买入成交时间: 2023-12-06 09:01:13
# 📉 卖出成交时间: 2023-12-06 09:01:14
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-06 09:02:37
# 💰 交易盈利: -27.00元 (卖出价:13060.0, 平仓价:13065.0)
# 📉 卖出成交时间: 2023-12-06 09:02:38
# 🛑 平仓时间: 2023-12-06 09:02:38 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-06 09:03:53
# 💰 交易盈利: -27.00元 (买入价:13055.0, 平仓价:13050.0)
# 📈 买入成交时间: 2023-12-06 09:03:55
# 🛑 平仓时间: 2023-12-06 09:03:55 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-06 09:05:18
# 💰 交易盈利: -27.00元 (卖出价:13035.0, 平仓价:13040.0)
# 📉 卖出成交时间: 2023-12-06 09:05:21
# 🛑 平仓时间: 2023-12-06 09:05:21 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-07 00:02:25
# 💰 交易盈利: -27.00元 (买入价:13260.0, 平仓价:13255.0)
# 📈 买入成交时间: 2023-12-07 00:02:25
# 🛑 平仓时间: 2023-12-07 00:02:25 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-07 00:15:38
# 💰 交易盈利: -27.00元 (卖出价:13255.0, 平仓价:13260.0)
# 📉 卖出成交时间: 2023-12-07 00:16:30
# 🛑 平仓时间: 2023-12-07 00:16:31 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-07 00:20:08
# 💰 交易盈利: -27.00元 (卖出价:13245.0, 平仓价:13250.0)
# 📉 卖出成交时间: 2023-12-07 00:20:13
# 🛑 平仓时间: 2023-12-07 00:20:13 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-07 00:25:42
# 💰 交易盈利: -27.00元 (买入价:13250.0, 平仓价:13245.0)
# 📈 买入成交时间: 2023-12-07 00:25:43
# 🛑 平仓时间: 2023-12-07 00:25:54 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-07 00:37:56
# 💰 交易盈利: -27.00元 (卖出价:13235.0, 平仓价:13240.0)
# 📉 卖出成交时间: 2023-12-07 00:37:56
# 🛑 平仓时间: 2023-12-07 00:37:56 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-08 00:01:53
# 💰 交易盈利: -27.00元 (买入价:13370.0, 平仓价:13365.0)
# 📈 买入成交时间: 2023-12-08 00:01:54
# 🛑 平仓时间: 2023-12-08 00:01:56 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-08 00:17:15
# 💰 交易盈利: -27.00元 (卖出价:13385.0, 平仓价:13390.0)
# 📉 卖出成交时间: 2023-12-08 00:17:15
# 🛑 平仓时间: 2023-12-08 00:17:15 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-08 00:33:12
# 💰 交易盈利: -27.00元 (买入价:13400.0, 平仓价:13395.0)
# 📈 买入成交时间: 2023-12-08 00:33:13
# 🛑 平仓时间: 2023-12-08 00:33:13 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-08 00:44:53
# 💰 交易盈利: -27.00元 (卖出价:13400.0, 平仓价:13405.0)
# 📉 卖出成交时间: 2023-12-08 00:44:54
# 🛑 平仓时间: 2023-12-08 00:44:54 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-08 08:59:00
# 💰 交易盈利: -27.00元 (买入价:13385.0, 平仓价:13380.0)
# 📈 买入成交时间: 2023-12-08 09:00:00
# 🛑 平仓时间: 2023-12-08 09:00:00 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-09 00:24:52
# 💰 交易盈利: -27.00元 (买入价:13465.0, 平仓价:13460.0)
# 📈 买入成交时间: 2023-12-09 00:25:01
# 🛑 平仓时间: 2023-12-09 00:25:01 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-09 00:45:27
# 💰 交易盈利: -27.00元 (买入价:13475.0, 平仓价:13470.0)
# 📈 买入成交时间: 2023-12-09 00:47:05
# 🛑 平仓时间: 2023-12-09 00:47:05 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-11 08:59:00
# 💰 交易盈利: -27.00元 (卖出价:13480.0, 平仓价:13485.0)
# 📉 卖出成交时间: 2023-12-11 09:00:00
# 🛑 平仓时间: 2023-12-11 09:00:00 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-11 09:00:56
# 💰 交易盈利: -27.00元 (买入价:13430.0, 平仓价:13425.0)
# 📈 买入成交时间: 2023-12-11 09:00:57
# 🛑 平仓时间: 2023-12-11 09:00:57 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-11 09:01:56
# 💰 交易盈利: -27.00元 (买入价:13435.0, 平仓价:13430.0)
# 📈 买入成交时间: 2023-12-11 09:01:57
# 🛑 平仓时间: 2023-12-11 09:01:57 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-11 09:03:08
# 💰 交易盈利: -27.00元 (买入价:13410.0, 平仓价:13405.0)
# 📈 买入成交时间: 2023-12-11 09:03:12
# 🛑 平仓时间: 2023-12-11 09:03:12 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-11 09:04:07
# 💰 交易盈利: -27.00元 (买入价:13360.0, 平仓价:13355.0)
# 📈 买入成交时间: 2023-12-11 09:04:07
# 🛑 平仓时间: 2023-12-11 09:04:08 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-12 00:01:23
# 💰 交易盈利: -27.00元 (卖出价:13440.0, 平仓价:13445.0)
# 📉 卖出成交时间: 2023-12-12 00:01:25
# 🛑 平仓时间: 2023-12-12 00:01:25 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-12 00:18:35
# 💰 交易盈利: -27.00元 (卖出价:13430.0, 平仓价:13435.0)
# 📉 卖出成交时间: 2023-12-12 00:18:58
# 🛑 平仓时间: 2023-12-12 00:18:58 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-12 00:38:59
# 💰 交易盈利: -27.00元 (买入价:13430.0, 平仓价:13425.0)
# 📈 买入成交时间: 2023-12-12 00:38:59
# 🛑 平仓时间: 2023-12-12 00:38:59 (价格下跌止损)
# --------------------------------------------------
# 🎯 【双边成交】交易时间: 2023-12-12 09:00:01
# 💰 交易盈利: 23.00元 (买价:13415.0, 卖价:13420.0, 价差:5.0)
# 📈 买入成交时间: 2023-12-12 09:00:01
# 📉 卖出成交时间: 2023-12-12 09:00:04
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-12 09:01:13
# 💰 交易盈利: -27.00元 (买入价:13435.0, 平仓价:13430.0)
# 📈 买入成交时间: 2023-12-12 09:01:17
# 🛑 平仓时间: 2023-12-12 09:01:17 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-12 09:02:55
# 💰 交易盈利: -27.00元 (卖出价:13440.0, 平仓价:13445.0)
# 📉 卖出成交时间: 2023-12-12 09:02:57
# 🛑 平仓时间: 2023-12-12 09:02:57 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-12 09:05:04
# 💰 交易盈利: -27.00元 (卖出价:13435.0, 平仓价:13440.0)
# 📉 卖出成交时间: 2023-12-12 09:05:06
# 🛑 平仓时间: 2023-12-12 09:05:07 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-13 00:00:11
# 💰 交易盈利: -27.00元 (卖出价:13500.0, 平仓价:13505.0)
# 📉 卖出成交时间: 2023-12-13 00:00:11
# 🛑 平仓时间: 2023-12-13 00:00:11 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-13 00:28:04
# 💰 交易盈利: -27.00元 (买入价:13515.0, 平仓价:13510.0)
# 📈 买入成交时间: 2023-12-13 00:28:05
# 🛑 平仓时间: 2023-12-13 00:28:05 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-13 09:00:07
# 💰 交易盈利: -27.00元 (买入价:13515.0, 平仓价:13510.0)
# 📈 买入成交时间: 2023-12-13 09:00:07
# 🛑 平仓时间: 2023-12-13 09:00:10 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-13 09:01:37
# 💰 交易盈利: -27.00元 (卖出价:13505.0, 平仓价:13510.0)
# 📉 卖出成交时间: 2023-12-13 09:01:38
# 🛑 平仓时间: 2023-12-13 09:01:38 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-13 09:04:20
# 💰 交易盈利: -27.00元 (买入价:13520.0, 平仓价:13515.0)
# 📈 买入成交时间: 2023-12-13 09:04:22
# 🛑 平仓时间: 2023-12-13 09:04:22 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-14 00:00:54
# 💰 交易盈利: -27.00元 (买入价:13450.0, 平仓价:13445.0)
# 📈 买入成交时间: 2023-12-14 00:00:55
# 🛑 平仓时间: 2023-12-14 00:00:55 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-14 00:29:18
# 💰 交易盈利: -27.00元 (卖出价:13430.0, 平仓价:13435.0)
# 📉 卖出成交时间: 2023-12-14 00:29:25
# 🛑 平仓时间: 2023-12-14 00:29:25 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-14 09:00:02
# 💰 交易盈利: -27.00元 (卖出价:13480.0, 平仓价:13485.0)
# 📉 卖出成交时间: 2023-12-14 09:00:04
# 🛑 平仓时间: 2023-12-14 09:00:04 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-14 09:01:22
# 💰 交易盈利: -27.00元 (买入价:13505.0, 平仓价:13500.0)
# 📈 买入成交时间: 2023-12-14 09:01:23
# 🛑 平仓时间: 2023-12-14 09:01:23 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-14 09:02:48
# 💰 交易盈利: -27.00元 (买入价:13505.0, 平仓价:13500.0)
# 📈 买入成交时间: 2023-12-14 09:02:49
# 🛑 平仓时间: 2023-12-14 09:02:49 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-15 00:00:55
# 💰 交易盈利: -27.00元 (卖出价:13560.0, 平仓价:13565.0)
# 📉 卖出成交时间: 2023-12-15 00:08:34
# 🛑 平仓时间: 2023-12-15 00:08:34 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-15 09:00:28
# 💰 交易盈利: -27.00元 (买入价:13555.0, 平仓价:13550.0)
# 📈 买入成交时间: 2023-12-15 09:00:32
# 🛑 平仓时间: 2023-12-15 09:00:32 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-15 09:03:44
# 💰 交易盈利: -27.00元 (卖出价:13535.0, 平仓价:13540.0)
# 📉 卖出成交时间: 2023-12-15 09:03:45
# 🛑 平仓时间: 2023-12-15 09:03:45 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-15 09:11:48
# 💰 交易盈利: -27.00元 (卖出价:13555.0, 平仓价:13560.0)
# 📉 卖出成交时间: 2023-12-15 09:11:48
# 🛑 平仓时间: 2023-12-15 09:11:48 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-15 09:19:16
# 💰 交易盈利: -27.00元 (卖出价:13585.0, 平仓价:13590.0)
# 📉 卖出成交时间: 2023-12-15 09:19:17
# 🛑 平仓时间: 2023-12-15 09:19:21 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-16 00:01:06
# 💰 交易盈利: -27.00元 (买入价:13565.0, 平仓价:13560.0)
# 📈 买入成交时间: 2023-12-16 00:04:31
# 🛑 平仓时间: 2023-12-16 00:04:31 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-18 09:00:38
# 💰 交易盈利: -27.00元 (买入价:13585.0, 平仓价:13580.0)
# 📈 买入成交时间: 2023-12-18 09:00:39
# 🛑 平仓时间: 2023-12-18 09:00:39 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-18 09:05:41
# 💰 交易盈利: -27.00元 (买入价:13580.0, 平仓价:13575.0)
# 📈 买入成交时间: 2023-12-18 09:05:45
# 🛑 平仓时间: 2023-12-18 09:05:45 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-18 09:18:56
# 💰 交易盈利: -27.00元 (卖出价:13585.0, 平仓价:13590.0)
# 📉 卖出成交时间: 2023-12-18 09:18:57
# 🛑 平仓时间: 2023-12-18 09:18:57 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-18 09:28:38
# 💰 交易盈利: -27.00元 (买入价:13600.0, 平仓价:13595.0)
# 📈 买入成交时间: 2023-12-18 09:29:00
# 🛑 平仓时间: 2023-12-18 09:29:00 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-18 09:38:03
# 💰 交易盈利: -27.00元 (卖出价:13600.0, 平仓价:13605.0)
# 📉 卖出成交时间: 2023-12-18 09:38:12
# 🛑 平仓时间: 2023-12-18 09:38:12 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-19 00:01:04
# 💰 交易盈利: -27.00元 (卖出价:13610.0, 平仓价:13615.0)
# 📉 卖出成交时间: 2023-12-19 00:01:16
# 🛑 平仓时间: 2023-12-19 00:01:16 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-19 09:00:00
# 💰 交易盈利: -77.00元 (买入价:13555.0, 平仓价:13540.0)
# 📈 买入成交时间: 2023-12-19 09:00:01
# 🛑 平仓时间: 2023-12-19 09:00:01 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-19 09:02:29
# 💰 交易盈利: -27.00元 (卖出价:13515.0, 平仓价:13520.0)
# 📉 卖出成交时间: 2023-12-19 09:02:32
# 🛑 平仓时间: 2023-12-19 09:02:32 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-20 00:03:54
# 💰 交易盈利: -27.00元 (卖出价:13695.0, 平仓价:13700.0)
# 📉 卖出成交时间: 2023-12-20 00:03:57
# 🛑 平仓时间: 2023-12-20 00:03:57 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-20 09:01:21
# 💰 交易盈利: -27.00元 (买入价:13715.0, 平仓价:13710.0)
# 📈 买入成交时间: 2023-12-20 09:01:24
# 🛑 平仓时间: 2023-12-20 09:01:24 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-20 09:10:31
# 💰 交易盈利: -27.00元 (买入价:13715.0, 平仓价:13710.0)
# 📈 买入成交时间: 2023-12-20 09:11:10
# 🛑 平仓时间: 2023-12-20 09:11:10 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-20 09:14:40
# 💰 交易盈利: -27.00元 (卖出价:13700.0, 平仓价:13705.0)
# 📉 卖出成交时间: 2023-12-20 09:14:43
# 🛑 平仓时间: 2023-12-20 09:14:43 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-20 09:29:09
# 💰 交易盈利: -27.00元 (买入价:13700.0, 平仓价:13695.0)
# 📈 买入成交时间: 2023-12-20 09:29:09
# 🛑 平仓时间: 2023-12-20 09:29:09 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-21 00:01:21
# 💰 交易盈利: -27.00元 (卖出价:13700.0, 平仓价:13705.0)
# 📉 卖出成交时间: 2023-12-21 00:01:51
# 🛑 平仓时间: 2023-12-21 00:01:51 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-21 09:01:02
# 💰 交易盈利: -77.00元 (卖出价:13630.0, 平仓价:13645.0)
# 📉 卖出成交时间: 2023-12-21 09:01:03
# 🛑 平仓时间: 2023-12-21 09:01:03 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-21 09:03:56
# 💰 交易盈利: -27.00元 (卖出价:13625.0, 平仓价:13630.0)
# 📉 卖出成交时间: 2023-12-21 09:03:59
# 🛑 平仓时间: 2023-12-21 09:03:59 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-22 00:01:13
# 💰 交易盈利: -27.00元 (卖出价:13685.0, 平仓价:13690.0)
# 📉 卖出成交时间: 2023-12-22 00:01:35
# 🛑 平仓时间: 2023-12-22 00:01:35 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-22 09:01:13
# 💰 交易盈利: -27.00元 (买入价:13735.0, 平仓价:13730.0)
# 📈 买入成交时间: 2023-12-22 09:01:13
# 🛑 平仓时间: 2023-12-22 09:01:13 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-22 09:18:36
# 💰 交易盈利: -27.00元 (买入价:13755.0, 平仓价:13750.0)
# 📈 买入成交时间: 2023-12-22 09:18:37
# 🛑 平仓时间: 2023-12-22 09:18:37 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-22 09:39:22
# 💰 交易盈利: -27.00元 (买入价:13735.0, 平仓价:13730.0)
# 📈 买入成交时间: 2023-12-22 09:40:04
# 🛑 平仓时间: 2023-12-22 09:40:04 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-22 09:55:58
# 💰 交易盈利: -27.00元 (买入价:13770.0, 平仓价:13765.0)
# 📈 买入成交时间: 2023-12-22 09:56:37
# 🛑 平仓时间: 2023-12-22 09:56:37 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-23 00:02:26
# 💰 交易盈利: -27.00元 (买入价:13705.0, 平仓价:13700.0)
# 📈 买入成交时间: 2023-12-23 00:02:27
# 🛑 平仓时间: 2023-12-23 00:02:27 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-25 09:00:05
# 💰 交易盈利: -52.00元 (买入价:13825.0, 平仓价:13815.0)
# 📈 买入成交时间: 2023-12-25 09:00:05
# 🛑 平仓时间: 2023-12-25 09:00:05 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-25 09:01:02
# 💰 交易盈利: -27.00元 (买入价:13935.0, 平仓价:13930.0)
# 📈 买入成交时间: 2023-12-25 09:01:03
# 🛑 平仓时间: 2023-12-25 09:01:03 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-25 09:02:55
# 💰 交易盈利: -27.00元 (卖出价:13895.0, 平仓价:13900.0)
# 📉 卖出成交时间: 2023-12-25 09:02:55
# 🛑 平仓时间: 2023-12-25 09:02:55 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-25 09:04:53
# 💰 交易盈利: -27.00元 (卖出价:13885.0, 平仓价:13890.0)
# 📉 卖出成交时间: 2023-12-25 09:04:54
# 🛑 平仓时间: 2023-12-25 09:04:54 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-26 00:11:30
# 💰 交易盈利: -27.00元 (卖出价:13835.0, 平仓价:13840.0)
# 📉 卖出成交时间: 2023-12-26 00:11:30
# 🛑 平仓时间: 2023-12-26 00:11:30 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-26 09:04:33
# 💰 交易盈利: -27.00元 (卖出价:13770.0, 平仓价:13775.0)
# 📉 卖出成交时间: 2023-12-26 09:04:34
# 🛑 平仓时间: 2023-12-26 09:04:34 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-26 09:13:49
# 💰 交易盈利: -27.00元 (买入价:13780.0, 平仓价:13775.0)
# 📈 买入成交时间: 2023-12-26 09:13:51
# 🛑 平仓时间: 2023-12-26 09:13:51 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-26 09:33:20
# 💰 交易盈利: -27.00元 (卖出价:13755.0, 平仓价:13760.0)
# 📉 卖出成交时间: 2023-12-26 09:33:21
# 🛑 平仓时间: 2023-12-26 09:33:21 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-26 09:57:18
# 💰 交易盈利: -27.00元 (卖出价:13785.0, 平仓价:13790.0)
# 📉 卖出成交时间: 2023-12-26 09:57:35
# 🛑 平仓时间: 2023-12-26 09:57:35 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-27 00:02:17
# 💰 交易盈利: -27.00元 (卖出价:13755.0, 平仓价:13760.0)
# 📉 卖出成交时间: 2023-12-27 00:06:25
# 🛑 平仓时间: 2023-12-27 00:06:25 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-27 09:11:36
# 💰 交易盈利: -27.00元 (买入价:13815.0, 平仓价:13810.0)
# 📈 买入成交时间: 2023-12-27 09:11:36
# 🛑 平仓时间: 2023-12-27 09:11:36 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-27 09:39:09
# 💰 交易盈利: -27.00元 (卖出价:13790.0, 平仓价:13795.0)
# 📉 卖出成交时间: 2023-12-27 09:39:09
# 🛑 平仓时间: 2023-12-27 09:39:09 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-27 10:03:29
# 💰 交易盈利: -27.00元 (卖出价:13790.0, 平仓价:13795.0)
# 📉 卖出成交时间: 2023-12-27 10:03:30
# 🛑 平仓时间: 2023-12-27 10:03:30 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-27 10:08:21
# 💰 交易盈利: -27.00元 (买入价:13775.0, 平仓价:13770.0)
# 📈 买入成交时间: 2023-12-27 10:08:22
# 🛑 平仓时间: 2023-12-27 10:08:22 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-28 00:21:55
# 💰 交易盈利: -27.00元 (买入价:13840.0, 平仓价:13835.0)
# 📈 买入成交时间: 2023-12-28 00:21:55
# 🛑 平仓时间: 2023-12-28 00:21:55 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-28 09:11:10
# 💰 交易盈利: -27.00元 (卖出价:13845.0, 平仓价:13850.0)
# 📉 卖出成交时间: 2023-12-28 09:11:10
# 🛑 平仓时间: 2023-12-28 09:11:10 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-28 09:38:25
# 💰 交易盈利: -27.00元 (卖出价:13830.0, 平仓价:13835.0)
# 📉 卖出成交时间: 2023-12-28 09:38:25
# 🛑 平仓时间: 2023-12-28 09:38:25 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-28 10:34:47
# 💰 交易盈利: -27.00元 (买入价:13800.0, 平仓价:13795.0)
# 📈 买入成交时间: 2023-12-28 10:37:25
# 🛑 平仓时间: 2023-12-28 10:37:25 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-28 13:33:04
# 💰 交易盈利: -52.00元 (卖出价:13785.0, 平仓价:13795.0)
# 📉 卖出成交时间: 2023-12-28 13:34:16
# 🛑 平仓时间: 2023-12-28 13:34:16 (价格上涨止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-29 09:04:03
# 💰 交易盈利: -27.00元 (卖出价:13755.0, 平仓价:13760.0)
# 📉 卖出成交时间: 2023-12-29 09:04:20
# 🛑 平仓时间: 2023-12-29 09:04:20 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-29 09:19:22
# 💰 交易盈利: -27.00元 (买入价:13765.0, 平仓价:13760.0)
# 📈 买入成交时间: 2023-12-29 09:19:51
# 🛑 平仓时间: 2023-12-29 09:19:51 (价格下跌止损)
# --------------------------------------------------
# 📉 【仅卖出成交】交易时间: 2023-12-29 09:47:21
# 💰 交易盈利: -52.00元 (卖出价:13735.0, 平仓价:13745.0)
# 📉 卖出成交时间: 2023-12-29 09:47:21
# 🛑 平仓时间: 2023-12-29 09:47:21 (价格上涨止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2023-12-29 10:34:15
# 💰 交易盈利: -52.00元 (买入价:13615.0, 平仓价:13605.0)
# 📈 买入成交时间: 2023-12-29 10:34:23
# 🛑 平仓时间: 2023-12-29 10:34:23 (价格下跌止损)
# --------------------------------------------------
# 📈 【仅买入成交】交易时间: 2024-01-02 13:40:03
# 💰 交易盈利: -227.00元 (买入价:13690.0, 平仓价:13645.0)
# 📈 买入成交时间: 2024-01-02 13:40:04
# 🛑 平仓时间: 2024-01-02 13:40:04 (价格下跌止损)
# --------------------------------------------------
#
# ============================================================
# 📊 交易回测结果汇总
# ============================================================
#
# 📅 每日盈亏统计:
# ----------------------------------------
# 2023-10-31: 📉 亏损  -133.00元 (交易4次)
# 2023-11-01: 📉 亏损  -135.00元 (交易5次)
# 2023-11-02: 📉 亏损  -135.00元 (交易5次)
# 2023-11-03: 📉 亏损  -137.00元 (交易6次)
# 2023-11-04: 📉 亏损   -27.00元 (交易1次)
# 2023-11-06: 📉 亏损  -135.00元 (交易5次)
# 2023-11-07: 📉 亏损  -143.00元 (交易9次)
# 2023-11-08: 📉 亏损  -135.00元 (交易5次)
# 2023-11-09: 📉 亏损  -139.00元 (交易7次)
# 2023-11-10: 📉 亏损  -160.00元 (交易5次)
# 2023-11-11: 📉 亏损  -112.00元 (交易6次)
# 2023-11-13: 📉 亏损  -139.00元 (交易7次)
# 2023-11-14: 📉 亏损  -135.00元 (交易5次)
# 2023-11-15: 📉 亏损  -135.00元 (交易5次)
# 2023-11-16: 📉 亏损  -135.00元 (交易5次)
# 2023-11-17: 📉 亏损  -135.00元 (交易5次)
# 2023-11-20: 📉 亏损  -139.00元 (交易7次)
# 2023-11-21: 📉 亏损  -139.00元 (交易7次)
# 2023-11-22: 📉 亏损  -135.00元 (交易5次)
# 2023-11-23: 📉 亏损  -139.00元 (交易7次)
# 2023-11-24: 📉 亏损  -139.00元 (交易7次)
# 2023-11-27: 📉 亏损  -143.00元 (交易9次)
# 2023-11-28: 📉 亏损  -135.00元 (交易5次)
# 2023-11-29: 📉 亏损  -139.00元 (交易7次)
# 2023-11-30: 📉 亏损  -139.00元 (交易7次)
# 2023-12-01: 📉 亏损  -135.00元 (交易5次)
# 2023-12-02: 📉 亏损   -27.00元 (交易1次)
# 2023-12-04: 📉 亏损  -133.00元 (交易4次)
# 2023-12-05: 📉 亏损  -143.00元 (交易9次)
# 2023-12-06: 📉 亏损  -139.00元 (交易7次)
# 2023-12-07: 📉 亏损  -135.00元 (交易5次)
# 2023-12-08: 📉 亏损  -135.00元 (交易5次)
# 2023-12-09: 📉 亏损   -54.00元 (交易2次)
# 2023-12-11: 📉 亏损  -135.00元 (交易5次)
# 2023-12-12: 📉 亏损  -139.00元 (交易7次)
# 2023-12-13: 📉 亏损  -135.00元 (交易5次)
# 2023-12-14: 📉 亏损  -135.00元 (交易5次)
# 2023-12-15: 📉 亏损  -135.00元 (交易5次)
# 2023-12-16: 📉 亏损   -27.00元 (交易1次)
# 2023-12-18: 📉 亏损  -135.00元 (交易5次)
# 2023-12-19: 📉 亏损  -131.00元 (交易3次)
# 2023-12-20: 📉 亏损  -135.00元 (交易5次)
# 2023-12-21: 📉 亏损  -131.00元 (交易3次)
# 2023-12-22: 📉 亏损  -135.00元 (交易5次)
# 2023-12-23: 📉 亏损   -27.00元 (交易1次)
# 2023-12-25: 📉 亏损  -133.00元 (交易4次)
# 2023-12-26: 📉 亏损  -135.00元 (交易5次)
# 2023-12-27: 📉 亏损  -135.00元 (交易5次)
# 2023-12-28: 📉 亏损  -160.00元 (交易5次)
# 2023-12-29: 📉 亏损  -158.00元 (交易4次)
# 2024-01-02: 📉 亏损  -227.00元 (交易1次)
#
# 💰 总体统计:
# ----------------------------------------
# 总盈亏: -6566.00元
# 双边成交次数: 18次
# 总交易信号次数: 258次
# 双边成交率: 6.98%
# 盈利天数: 0天
# 亏损天数: 51天
# 总交易天数: 51天
# 平均每日盈亏: -128.75元
# 胜率: 0.00%
#
# 🎯 交易参数:
# ----------------------------------------
# 交易阈值: 0.65
# 交易手数: 1手
# 每手吨数: 5吨
# 手续费: 2元/手
# 价格跳动: 5元
# ============================================================
