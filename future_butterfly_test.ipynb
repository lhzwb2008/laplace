# %%
import pandas as pd
from enum import Enum, auto

# FILENAME = "future_taobao_ssMain_tick"
FILENAME = "future_taobao_ss2401_tick"

class open_interest_delta_forward_enum(Enum):
    NONE = auto()
    UNKNOWN = auto()
    EXCHANGE = auto()
    OPENFWDOUBLE = auto()
    OPEN = auto()
    CLOSEFWDOUBLE = auto()
    CLOSE = auto()

class order_forward_enum(Enum):
    UP = auto()
    DOWN = auto()
    MIDDLE = auto()

class tick_type_key_enum(Enum):
    TICKTYPE = auto()
    TICKCOLOR = auto()

class tick_type_enum(Enum):
    NOCHANGE = '无交易'
    UNKNOWN = '未知'
    EXCHANGELONG = '多换'
    EXCHANGESHORT = '空换'
    EXCHANGEUNKOWN = '未知换'
    OPENDOUBLE = '双开'
    OPENLONG = '多开'
    OPENSHORT = '空开'
    OPENUNKOWN = '未知开'
    CLOSEDOUBLE = '双平'
    CLOSESHORT = '空平'
    CLOSELONG = '多平'
    CLOSEUNKOWN = '未知平'

class tick_color_enum(Enum):
    WHITE = '白色'
    RED = '红色'
    GREEN = '绿色'

tick_type_cal_dict = {
    open_interest_delta_forward_enum.NONE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.EXCHANGE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGELONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGESHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPENFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPEN:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENLONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENSHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSEFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSESHORT,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSELONG,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
}

 # Mapping of openclose and price_direction to open_interest_delta_forward_enum and order_forward_enum
openclose_mapping = {
    '换手': open_interest_delta_forward_enum.EXCHANGE,
    '双开': open_interest_delta_forward_enum.OPENFWDOUBLE,
    '开仓': open_interest_delta_forward_enum.OPEN,
    '双平': open_interest_delta_forward_enum.CLOSEFWDOUBLE,  # Assuming definition for 双平
    '平仓': open_interest_delta_forward_enum.CLOSE,
    '无交易': open_interest_delta_forward_enum.NONE,
    '未知':open_interest_delta_forward_enum.UNKNOWN
}

price_direction_mapping = {
    '向上': order_forward_enum.UP,
    '向下': order_forward_enum.DOWN,
    '不变': order_forward_enum.MIDDLE
}

# 枚举到中文的映射
tick_type_to_chinese = {
    tick_type_enum.NOCHANGE: '无交易',
    tick_type_enum.UNKNOWN: '未知',
    tick_type_enum.EXCHANGELONG: '多换',
    tick_type_enum.EXCHANGESHORT: '空换',
    tick_type_enum.EXCHANGEUNKOWN: '未知换',
    tick_type_enum.OPENDOUBLE: '双开',
    tick_type_enum.OPENLONG: '开多',
    tick_type_enum.OPENSHORT: '开空',
    tick_type_enum.OPENUNKOWN: '未知开',
    tick_type_enum.CLOSEDOUBLE: '双平',
    tick_type_enum.CLOSESHORT: '空平',
    tick_type_enum.CLOSELONG: '多平',
    tick_type_enum.CLOSEUNKOWN: '未知平',
}

tick_color_to_chinese = {
    tick_color_enum.WHITE: '白色',
    tick_color_enum.RED: '红色',
    tick_color_enum.GREEN: '绿色',
}


# Load the tick data
df = pd.read_csv(FILENAME+".csv")

# Calculate the deltas for volume and open interest
df['volume_delta'] = df['volume'].diff()
df['open_interest_delta'] = df['open_interest'].diff()

# Initialize columns for open/close position
df['trade_openclose'] = None
df['trade_color'] = None 
df['close_count'] = df['volume_delta']

# Iterate over the DataFrame to assign open/close positions
for i in range(1, len(df)):
    volume_delta = df.loc[i, 'volume_delta']
    open_interest_delta = df.loc[i, 'open_interest_delta']
    last_price = df.loc[i, 'last_price']
    ask_price1 = df.loc[i, 'ask_price1']
    bid_price1 = df.loc[i, 'bid_price1']
    pre_last_price = df.loc[i-1,'last_price']
    pre_ask_price1 = df.loc[i-1, 'ask_price1']
    pre_bid_price1 = df.loc[i-1, 'bid_price1']
    openclose = ''
    price_direction = ''

    # Determine the open/close position
    if volume_delta == open_interest_delta > 0:
        openclose = '双开'
    elif volume_delta > open_interest_delta > 0:
        openclose = '开仓'
    elif volume_delta > abs(open_interest_delta) > 0 and open_interest_delta < 0:
        openclose = '平仓'
    elif volume_delta > 0 and open_interest_delta == 0:
        openclose = '换手'
    elif volume_delta + open_interest_delta == 0 and volume_delta>0:
        openclose = '双平'
    elif volume_delta == 0 and  open_interest_delta == 0:
        openclose = '无交易'
    else:
        openclose = '未知'
    
    # 判断价格方向
    if last_price >= pre_ask_price1:
        price_direction = '向上'
    elif last_price <= pre_bid_price1:
        price_direction = '向下'
    elif last_price >= ask_price1:
        price_direction = '向上'
    elif last_price <= bid_price1:
        price_direction = '向下'
    else:
        price_direction = '不变'
        
   

    # Convert openclose and price_direction to their corresponding enum values
    delta_enum = openclose_mapping.get(openclose, open_interest_delta_forward_enum.NONE)
    direction_enum = price_direction_mapping.get(price_direction, order_forward_enum.MIDDLE)

    # Retrieve the tick type and color based on the mappings
    tick_info = tick_type_cal_dict.get(delta_enum, {}).get(direction_enum, {})
    tick_type = tick_info.get(tick_type_key_enum.TICKTYPE, tick_type_enum.UNKNOWN)
    tick_color = tick_info.get(tick_type_key_enum.TICKCOLOR, tick_color_enum.WHITE)
    

    # 使用映射转换为中文描述
    tick_type_chinese = tick_type_to_chinese[tick_type]
    tick_color_chinese = tick_color_to_chinese[tick_color]

    # 更新DataFrame
    df.at[i, 'trade_openclose'] = tick_type_chinese
    df.at[i, 'trade_color'] = tick_color_chinese

# Save the modified DataFrame to a new CSV file
df.to_csv(FILENAME+"_withopenclose.csv", index=False)

# %%
import pandas as pd

# FILENAME = "future_taobao_ssMain_tick"
FILENAME = "future_taobao_ss2401_tick"

# 假设已加载并准备好DataFrame df
df = pd.read_csv(FILENAME+"_withopenclose.csv")

df = df.loc[df['volume_delta'] > 0]
# 重置索引以确保从0开始
df.reset_index(drop=True, inplace=True)


guess_tick=100

# 初始化列用于标记交易机会
df['buy_opportunity'] = 0
df['sell_opportunity'] = 0
trade_hand = 1
trade_slippy = 0

# 为每个tick计算未来100个tick内与当前挂单价格相匹配的成交量
for i in range(len(df)):
    if i + guess_tick >= len(df):  # 确保未来有足够的tick进行分析
        break

    # 当前的买一和卖一价
    current_ask_price1 = df.loc[i, 'ask_price1']
    current_bid_price1 = df.loc[i, 'bid_price1']

    # 初始化对应价格的成交量计数
    matching_buy_volume = 0
    matching_sell_volume = 0
    
    buy_done = 0
    sell_done = 0

    # 遍历未来100个tick
    for j in range(i+1, i+guess_tick+1):
        if df.loc[j, 'bid_price1']<current_bid_price1:
            buy_done = 1 
        if df.loc[j, 'ask_price1']>current_ask_price1:
            sell_done = 1 
        # 如果未来tick的买一价等于当前tick的买一价，累加成交量
        if df.loc[j, 'bid_price1'] == current_bid_price1 and df.loc[j, 'bid_price1'] == df.loc[j, 'last_price']:
            matching_buy_volume += df.loc[j, 'volume_delta']
        # 如果未来tick的卖一价等于当前tick的卖一价，累加成交量
        if df.loc[j, 'ask_price1'] == current_ask_price1 and df.loc[j, 'ask_price1'] == df.loc[j, 'last_price']:
            matching_sell_volume += df.loc[j, 'volume_delta']

    # 判断是否存在买卖机会
    if buy_done==1 or matching_buy_volume >= df.loc[i, 'bid_volume1']+trade_hand+trade_slippy:
        df.loc[i, 'buy_opportunity'] = 1
    if sell_done==1 or matching_sell_volume >= df.loc[i, 'ask_volume1']+trade_hand+trade_slippy:
        df.loc[i, 'sell_opportunity'] = 1


# 创建一个新列来标记同时为买卖机会的tick
df['dual_opportunity'] = ((df['buy_opportunity'] == 1) & (df['sell_opportunity'] == 1)).astype(int)

# 计算同时为买卖机会的总数
dual_opportunities_count = df['dual_opportunity'].sum()

# 计算比例
total_ticks_analyzed = len(df) - guess_tick
dual_opportunities_ratio = dual_opportunities_count / total_ticks_analyzed

print(f"Dual opportunities count: {dual_opportunities_count}")
print(f"Dual opportunities ratio: {dual_opportunities_ratio:.4f}")

# 保存到新的CSV文件
df.to_csv(FILENAME+"_with_opportunities.csv", index=False)
# df.to_csv(FILENAME+"_80_with_opportunities.csv", index=False)
# Out:
# Dual opportunities count: 106925
# Dual opportunities ratio: 0.6365

# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score,precision_score

FILENAME = "future_taobao_ssMain_tick"
# FILENAME = "future_taobao_ss2401_tick"

# 加载数据
data = pd.read_csv(FILENAME+"_with_opportunities.csv")

data_clean = data.dropna().copy()  # 创建一个副本以避免警告

data_clean =  pd.get_dummies(data_clean, columns=['trade_color', 'trade_openclose'])

features = [
    'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
    'bid_price1', 'ask_price1', 'bid_price2', 'ask_price2', 'bid_price3', 'ask_price3',
    'bid_price4', 'ask_price4', 'bid_price5', 'ask_price5', 'bid_volume1', 'bid_volume2',
    'bid_volume3', 'bid_volume4', 'bid_volume5', 'ask_volume1', 'ask_volume2', 'ask_volume3',
    'ask_volume4', 'ask_volume5'
]
# 获取所有列名
all_columns = data_clean.columns.tolist()
# 筛选出以"trade_color_"和"trade_openclose_"开头的列名
# 并将它们添加到features列表中
for column in all_columns:
    if column.startswith('trade_color_') or column.startswith('trade_openclose_'):
        features.append(column)

window_size = 200  # 用于特征计算的窗口大小
# 特征生成
data_clean['rolling_mean'] = data_clean['last_price'].rolling(window=window_size).mean()
data_clean['rolling_std'] = data_clean['last_price'].rolling(window=window_size).std()
data_clean['ask_rolling_mean'] = data_clean['ask_price1'].rolling(window=window_size).mean()
data_clean['ask_rolling_std'] = data_clean['ask_price1'].rolling(window=window_size).std()
data_clean['bid_rolling_mean'] = data_clean['bid_price1'].rolling(window=window_size).mean()
data_clean['bid_rolling_std'] = data_clean['bid_price1'].rolling(window=window_size).std()
# RSI计算
delta = data_clean['last_price'].diff()
gain = (delta.where(delta > 0, 0)).fillna(0)
loss = (-delta.where(delta < 0, 0)).fillna(0)
avg_gain = gain.rolling(window=window_size).mean()
avg_loss = loss.rolling(window=window_size).mean()
rs = avg_gain / avg_loss
data_clean['RSI'] = 100 - (100 / (1 + rs))
# MACD计算
short_ema = data_clean['last_price'].ewm(span=int(window_size/2), adjust=False).mean()  # 使用窗口大小的一半作为短期EMA
long_ema = data_clean['last_price'].ewm(span=window_size, adjust=False).mean()  # 使用整个窗口大小作为长期EMA
data_clean['MACD'] = short_ema - long_ema
data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=int(window_size/3), adjust=False).mean()  # 使用窗口大小的三分之一作为信号线
# 删除因计算滚动特征而产生的NaN值
data_clean.dropna(inplace=True)
# 添加新特征到特征列表
features.extend(['rolling_mean', 'rolling_std','ask_rolling_mean', 'ask_rolling_std','bid_rolling_mean', 'bid_rolling_std', 'RSI', 'MACD', 'MACD_signal'])

X = data_clean[['datetime'] + features]
y = data_clean['dual_opportunity']

# 数据切分
split_start = int(len(data_clean) * 0)
split_point = int(len(data_clean) * 0.7)
split_end = int(len(data_clean) * 1)
X_train = X.iloc[split_start:split_point]
y_train = y.iloc[split_start:split_point]
X_test = X.iloc[split_point:split_end]
y_test = y.iloc[split_point:split_end]
X_train_features = X_train.drop(columns=['datetime'])
X_test_features = X_test.drop(columns=['datetime'])



# 创建XGBoost模型并调整参数
model = xgb.XGBClassifier(
    n_estimators=40,  # 树的个数
    max_depth=3,  # 树的深度
    learning_rate=0.1,  # 学习率
    subsample=0.8,  # 训练每棵树时使用的样本比例
    colsample_bytree=0.8,  # 构建树时的列采样比例
    random_state=42,  # 随机种子
    use_label_encoder=False,  # 避免使用标签编码器的警告
    eval_metric='logloss',  # 评估指标
    scale_pos_weight=1
)
# 模型训练
model.fit(X_train_features, y_train)

# 获取属于类别1的概率
y_pred_proba = model.predict_proba(X_test_features)[:, 1]

# 设置交易阈值
trade_threshold = 0.65
# 根据阈值生成预测结果，大于等于阈值预测为1，否则为0
y_pred_threshold = (y_pred_proba >= trade_threshold).astype(int)
# 计算查准率
precision = precision_score(y_test, y_pred_threshold)
print(f"Precision: {precision}")
predicted_ones_count = np.sum(y_pred_threshold == 1)
total_count = len(y_pred_threshold)
print(f"Predicted as 1: {predicted_ones_count} / Total: {total_count}")

# 对照组评估（全1预测）
predictions_all_ones = [1] * len(y_test)
print("All Ones Accuracy:", precision_score(y_test, predictions_all_ones))
# Out:
# Precision: 0.7312986235786954
# Predicted as 1: 5013 / Total: 202371
# All Ones Accuracy: 0.47734606242989364

# %%
from datetime import datetime, time
import numpy as np

guess_tick = 100
profit = 0  # 盈利
trade_threshold = 0.65 # 交易阈值
trade_hand = 1
trade_slippy = 0

trade_gap = 5 #每跳多少钱
hand_volume = 5  # 不锈钢1手5吨，1手开仓2元，平今0元
hand_fee = 2
done_count = 0
count = 0
daily_profit = {}  # 新增：用于存储每日盈利
daily_trade = {}

last_date_str=''
stop = False

# def check_trend_consistency(prices):
#     overall_trend_up = prices[-1] > prices[0]
#     for i in range(len(prices) - 1):
#         if overall_trend_up and prices[i + 1] < prices[i]:
#             return False
#         elif not overall_trend_up and prices[i + 1] > prices[i]:
#             return False
#     return True

def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False

# 定义时间范围数组
# notrade_time = ["08:30-09:20","10:00-10:40","11:20-11:30","13:30-13:40","14:50-15:00","21:00-21:10","0:00-1:00"]

i = guess_tick
while i < len(X_test) - guess_tick:  # 留出100个tick进行预测
    
    datetime_str = X_test.iloc[i]['datetime']
    date_str = datetime_str.split(' ')[0]  # 新增：提取日期字符串
    
    if last_date_str!= date_str: 
        last_date_str = date_str
        stop = False
    if stop:
        i = i + 1
        continue
    if daily_profit.get(date_str, 0)  < -100:
        last_date_str = date_str
        stop = True
    
    
    if '.' in datetime_str:
        # 如果有小数点，分割为主时间部分和纳秒部分
        time, nano_part = datetime_str.split('.')
    else:
        # 如果没有小数点，则没有纳秒部分
        time = datetime_str
        nano_part = '0'
    # if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S").time(), notrade_time):
    #     i = i+1
    #     continue
    
    proba = y_pred_proba[i]
    if proba < trade_threshold:
        i = i+1
        continue
    
    # prices = X_test['ask_price1'].iloc[i-50:i].values
    # # 检查整体趋势一致性和变化范围
    # if (check_trend_consistency(prices) and abs(prices[-1] - prices[0])> 5)or abs(prices[-1] - prices[0])>10 :
    #     i += 100  # 注意：在for循环中直接修改i的值不会改变下一个迭代的索引
    #     continue
    
    
    current_ask_price1 = X_test.iloc[i]['ask_price1']
    current_bid_price1 = X_test.iloc[i]['bid_price1']
    
    if current_ask_price1-current_bid_price1!=trade_gap:
        i = i + 1
        continue

    matching_buy_volume = 0
    matching_sell_volume = 0
    buy_done = 0
    sell_done = 0
    
    buy_index = 0
    sell_index = 0
    buy_stop_index = 0
    sell_stop_index = 0
    
    for j in range(i + 1, i + guess_tick + 1): 
        future_tick = X_test.iloc[j]
        if future_tick['bid_price1'] < current_bid_price1:
            buy_done = 1
            if buy_index==0:
                buy_index = j
        if future_tick['ask_price1'] > current_ask_price1:
            sell_done = 1
            if sell_index==0:
                sell_index = j
        if future_tick['bid_price1'] == current_bid_price1 and future_tick['last_price'] == current_bid_price1:
            matching_buy_volume += future_tick['volume_delta']
            if matching_buy_volume >= X_test.iloc[i]['bid_volume1']+trade_hand+trade_slippy and buy_index==0:
                buy_index = j
        if future_tick['ask_price1'] == current_ask_price1 and future_tick['last_price'] == current_ask_price1:
            matching_sell_volume += future_tick['volume_delta']
            if matching_sell_volume >= X_test.iloc[i]['ask_volume1']+trade_hand+trade_slippy and sell_index==0:
                sell_index = j
        if buy_index>0 and buy_stop_index==0 and future_tick['bid_price1']<current_bid_price1:
            buy_stop_index = j
        if sell_index>0 and sell_stop_index==0 and future_tick['ask_price1']>current_ask_price1:
            sell_stop_index = j

    stop_loss_tick = i + guess_tick
    stop_loss_price_bid = X_test.iloc[stop_loss_tick]['bid_price1']
    stop_loss_price_ask = X_test.iloc[stop_loss_tick]['ask_price1']
    count = count + 1
    daily_trade[date_str] = daily_trade.get(date_str,0)+1
    
    # 判断是否存在买卖机会
    if buy_index>0 and sell_index>0:
        trade_profit = (current_ask_price1 - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        done_count += 1
        print(X_test.iloc[i]['datetime'])
        print(trade_profit)
        print(X_test.iloc[buy_index]['datetime'])
        print(X_test.iloc[sell_index]['datetime'])
    elif buy_index>0:
        if buy_stop_index>0:
            trade_profit = (X_test.iloc[buy_stop_index]['bid_price1'] - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
        else:
            trade_profit = (stop_loss_price_bid - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand 
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        print(X_test.iloc[i]['datetime'])
        print(trade_profit)
        print(X_test.iloc[buy_index]['datetime'])
        print(X_test.iloc[buy_stop_index]['datetime'])
    elif sell_index>0:
        if sell_stop_index>0:
            trade_profit = (current_ask_price1 - X_test.iloc[sell_stop_index]['ask_price1'] ) * trade_hand * hand_volume-hand_fee*trade_hand
        else:
            trade_profit = (current_ask_price1 - stop_loss_price_ask) * trade_hand * hand_volume-hand_fee*trade_hand
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        print(X_test.iloc[i]['datetime'])
        print(trade_profit)
        print(X_test.iloc[sell_index]['datetime'])
        print(X_test.iloc[sell_stop_index]['datetime'])
    i = stop_loss_tick
        

# 打印每一天的盈利
for date, daily_profit in daily_profit.items():
    print(f"{date}: {daily_profit:.2f}")
for date, daily_trade in daily_trade.items():
    print(f"{date}: {daily_trade}")

print(f"Final profit: {profit:.2f}")
print(done_count)
print(count)
print(done_count/count)
# Out:
# 2024-01-30 10:03:13.000000
# 23.0
# 2024-01-30 10:03:16.500000
# 2024-01-30 10:03:13.500000
# 2024-01-30 11:29:58.000
# 23.0
# 2024-01-30 13:30:00.500
# 2024-01-30 13:30:21.000
# 2024-01-30 14:59:49.500000
# 23.0
# 2024-01-30 14:59:56.000000
# 2024-01-30 14:59:53.500000
# 2024-01-30 21:00:42.500000
# 23.0
# 2024-01-30 21:00:51.500000
# 2024-01-30 21:00:44.500000
# 2024-01-30 21:03:20.500000
# 23.0
# 2024-01-30 21:03:50.000000
# 2024-01-30 21:03:21.000000
# 2024-01-30 21:20:37.000000
# 23.0
# 2024-01-30 21:20:37.500000
# 2024-01-30 21:20:38.500000
# 2024-01-30 21:21:27.500000
# 23.0
# 2024-01-30 21:21:30.000000
# 2024-01-30 21:21:29.500000
# 2024-01-31 00:59:46.000000
# 23.0
# 2024-01-31 00:59:46.500000
# 2024-01-31 09:00:02.000000
# 2024-01-31 09:02:17.000
# 23.0
# 2024-01-31 09:02:19.000
# 2024-01-31 09:02:26.500
# 2024-01-31 09:03:16.500
# 23.0
# 2024-01-31 09:04:34.500
# 2024-01-31 09:03:18.500
# 2024-01-31 09:21:03.000
# 23.0
# 2024-01-31 09:21:03.500
# 2024-01-31 09:21:07.500
# 2024-01-31 10:30:29.500000
# 23.0
# 2024-01-31 10:30:30.000000
# 2024-01-31 10:30:46.500000
# 2024-01-31 13:30:02.000000
# -27.0
# 2024-01-31 13:30:03.500000
# 2024-01-31 13:30:03.500000
# 2024-01-31 21:00:01.000004
# 23.0
# 2024-01-31 21:00:01.500000
# 2024-01-31 21:00:15.500000
# 2024-01-31 21:00:53.500000
# 23.0
# 2024-01-31 21:00:59.500000
# 2024-01-31 21:00:58.500000
# 2024-01-31 21:02:00.000000
# -27.0
# 2024-01-31 21:02:00.500000
# 2024-01-31 21:02:00.500000
# 2024-02-01 09:00:06.000000
# 23.0
# 2024-02-01 09:00:14.500000
# 2024-02-01 09:00:07.500000
# 2024-02-01 09:01:01.500000
# 23.0
# 2024-02-01 09:01:02.500000
# 2024-02-01 09:01:02.000000
# 2024-02-01 09:01:54.000000
# 23.0
# 2024-02-01 09:02:01.000000
# 2024-02-01 09:01:57.000000
# 2024-02-01 09:02:50.000000
# 23.0
# 2024-02-01 09:02:52.000000
# 2024-02-01 09:02:55.500000
# 2024-02-01 09:04:01.000000
# 23.0
# 2024-02-01 09:04:03.000000
# 2024-02-01 09:04:01.500000
# 2024-02-01 09:05:28.000000
# 23.0
# 2024-02-01 09:05:31.000000
# 2024-02-01 09:05:32.000000
# 2024-02-01 09:06:31.500000
# 23.0
# 2024-02-01 09:06:46.500000
# 2024-02-01 09:06:52.500000
# 2024-02-01 09:10:43.000000
# 23.0
# 2024-02-01 09:11:00.500000
# 2024-02-01 09:10:46.500000
# 2024-02-01 09:19:06.500000
# 23.0
# 2024-02-01 09:19:13.000000
# 2024-02-01 09:19:07.000000
# 2024-02-01 09:23:49.500000
# -27.0
# 2024-02-01 09:23:52.500000
# 2024-02-01 09:23:52.500000
# 2024-02-01 09:26:28.500000
# 23.0
# 2024-02-01 09:26:42.000000
# 2024-02-01 09:28:08.000000
# 2024-02-01 09:35:25.000000
# 23.0
# 2024-02-01 09:35:31.500000
# 2024-02-01 09:35:54.000000
# 2024-02-01 10:14:34.500000
# 23.0
# 2024-02-01 10:14:38.500000
# 2024-02-01 10:14:37.500000
# 2024-02-01 14:02:34.500000
# 23.0
# 2024-02-01 14:02:54.500000
# 2024-02-01 14:02:50.500000
# 2024-02-01 14:20:03.500
# 23.0
# 2024-02-01 14:20:06.000
# 2024-02-01 14:20:04.000
# 2024-02-01 21:00:01.000002
# 23.0
# 2024-02-01 21:00:01.500000
# 2024-02-01 21:00:01.500000
# 2024-02-01 21:01:00.500000
# -27.0
# 2024-02-01 21:01:02.500000
# 2024-02-01 21:01:02.500000
# 2024-02-01 21:07:01.000000
# 23.0
# 2024-02-01 21:07:01.500000
# 2024-02-01 21:07:50.500000
# 2024-02-02 00:59:39.000000
# -27.0
# 2024-02-02 00:59:44.000000
# 2024-02-02 00:59:44.000000
# 2024-02-02 09:00:40.000000
# 23.0
# 2024-02-02 09:00:45.000000
# 2024-02-02 09:00:40.500000
# 2024-02-02 09:01:34.500000
# 23.0
# 2024-02-02 09:01:58.500000
# 2024-02-02 09:01:37.000000
# 2024-02-02 09:02:43.500000
# 23.0
# 2024-02-02 09:02:46.000000
# 2024-02-02 09:03:30.000000
# 2024-02-02 09:05:04.500000
# -27.0
# 2024-02-02 09:05:05.000000
# 2024-02-02 09:05:05.000000
# 2024-02-02 09:06:39.000000
# 23.0
# 2024-02-02 09:07:17.000000
# 2024-02-02 09:06:39.500000
# 2024-02-02 09:15:03.000
# -27.0
# 2024-02-02 09:15:07.500
# 2024-02-02 09:15:07.500
# 2024-02-02 09:18:55.000
# 23.0
# 2024-02-02 09:20:04.000
# 2024-02-02 09:19:12.500
# 2024-02-02 09:21:09.500
# 23.0
# 2024-02-02 09:21:13.500
# 2024-02-02 09:21:33.500
# 2024-02-02 09:29:28.500
# 23.0
# 2024-02-02 09:29:37.000
# 2024-02-02 09:30:09.000
# 2024-02-02 09:31:01.500
# -27.0
# 2024-02-02 09:31:08.000
# 2024-02-02 09:31:08.000
# 2024-02-02 09:39:41.500
# -27.0
# 2024-02-02 09:40:16.500
# 2024-02-02 09:40:16.500
# 2024-02-02 10:14:43.000000
# -27.0
# 2024-02-02 10:14:43.500000
# 2024-02-02 10:30:26.500000
# 2024-02-02 10:33:05.500000
# -27.0
# 2024-02-02 10:33:10.000000
# 2024-02-02 10:33:10.000000
# 2024-02-02 13:58:35.000000
# 23.0
# 2024-02-02 13:58:35.500000
# 2024-02-02 13:59:25.500000
# 2024-02-02 14:05:15.500000
# -27.0
# 2024-02-02 14:05:16.000000
# 2024-02-02 14:05:16.000000
# 2024-02-02 14:26:03.500000
# 23.0
# 2024-02-02 14:26:06.500000
# 2024-02-02 14:26:04.000000
# 2024-02-02 14:27:39.000000
# -27.0
# 2024-02-02 14:27:39.500000
# 2024-02-02 14:27:39.500000
# 2024-02-02 14:29:55.000000
# 23.0
# 2024-02-02 14:30:00.500000
# 2024-02-02 14:30:00.500000
# 2024-02-02 14:31:08.500000
# -27.0
# 2024-02-02 14:31:16.500000
# 2024-02-02 14:31:16.500000
# 2024-02-02 14:32:25.500000
# 23.0
# 2024-02-02 14:33:11.500000
# 2024-02-02 14:32:27.000000
# 2024-02-02 14:59:40.500000
# 23.0
# 2024-02-02 21:00:04.500001
# 2024-02-02 14:59:45.000000
# 2024-02-02 21:00:43.500000
# 23.0
# 2024-02-02 21:00:45.000000
# 2024-02-02 21:01:10.500000
# 2024-02-02 21:01:37.500000
# -27.0
# 2024-02-02 21:01:38.000000
# 2024-02-02 21:01:38.000000
# 2024-02-02 21:02:36.000000
# 23.0
# 2024-02-02 21:02:46.500000
# 2024-02-02 21:02:46.500000
# 2024-02-02 21:03:33.500000
# 23.0
# 2024-02-02 21:04:25.500000
# 2024-02-02 21:03:38.000000
# 2024-02-02 23:38:41.000
# 23.0
# 2024-02-02 23:39:00.500
# 2024-02-02 23:40:47.000
# 2024-02-03 00:59:22.500000
# 23.0
# 2024-02-03 00:59:55.500000
# 2024-02-03 00:59:23.000000
# 2024-02-05 09:01:30.500000
# 23.0
# 2024-02-05 09:01:49.000000
# 2024-02-05 09:01:31.500000
# 2024-02-05 09:03:04.000000
# -27.0
# 2024-02-05 09:03:05.000000
# 2024-02-05 09:03:05.000000
# 2024-02-05 09:21:31.500000
# 23.0
# 2024-02-05 09:21:32.000000
# 2024-02-05 09:21:41.000000
# 2024-02-05 09:35:52.500
# 23.0
# 2024-02-05 09:36:05.000
# 2024-02-05 09:35:58.000
# 2024-02-05 10:14:19.000000
# 23.0
# 2024-02-05 10:14:28.500000
# 2024-02-05 10:14:20.500000
# 2024-02-05 10:34:04.000000
# 23.0
# 2024-02-05 10:36:07.500000
# 2024-02-05 10:34:04.500000
# 2024-02-05 11:29:33.500
# -152.0
# 2024-02-05 13:30:00.500
# 2024-02-05 13:30:00.500
# 2024-02-05 13:30:58.000
# -27.0
# 2024-02-05 13:31:03.000
# 2024-02-05 13:31:03.000
# 2024-02-05 13:33:27.500
# -27.0
# 2024-02-05 13:33:39.000
# 2024-02-05 13:33:39.000
# 2024-02-05 13:35:52.000
# 23.0
# 2024-02-05 13:36:01.500
# 2024-02-05 13:35:53.500
# 2024-02-06 00:59:30.000000
# -27.0
# 2024-02-06 00:59:30.500000
# 2024-02-06 00:59:30.500000
# 2024-02-06 09:00:49.000000
# 23.0
# 2024-02-06 09:01:05.500000
# 2024-02-06 09:00:49.500000
# 2024-02-06 09:02:13.500000
# 23.0
# 2024-02-06 09:02:28.500000
# 2024-02-06 09:02:15.000000
# 2024-02-06 09:07:54.500000
# -27.0
# 2024-02-06 09:08:01.000000
# 2024-02-06 09:08:01.000000
# 2024-02-06 09:13:47.500000
# 23.0
# 2024-02-06 09:13:48.000000
# 2024-02-06 09:14:06.500000
# 2024-02-06 09:16:53.000000
# 23.0
# 2024-02-06 09:19:04.500000
# 2024-02-06 09:16:53.500000
# 2024-02-06 09:20:43.000000
# 23.0
# 2024-02-06 09:21:01.000000
# 2024-02-06 09:21:28.500000
# 2024-02-06 09:30:01.500000
# -27.0
# 2024-02-06 09:30:02.000000
# 2024-02-06 09:30:02.000000
# 2024-02-06 10:06:50.500000
# 23.0
# 2024-02-06 10:09:05.000000
# 2024-02-06 10:06:51.500000
# 2024-02-06 10:11:48.500000
# -27.0
# 2024-02-06 10:11:52.500000
# 2024-02-06 10:11:52.500000
# 2024-02-06 10:30:07.000000
# -27.0
# 2024-02-06 10:30:09.000000
# 2024-02-06 10:30:09.000000
# 2024-02-06 10:50:53.500000
# 23.0
# 2024-02-06 10:51:03.000000
# 2024-02-06 10:51:03.500000
# 2024-02-06 11:29:40.500000
# -27.0
# 2024-02-06 11:29:42.000000
# 2024-02-06 11:29:42.000000
# 2024-02-06 13:30:44.500000
# 23.0
# 2024-02-06 13:30:57.000000
# 2024-02-06 13:30:45.000000
# 2024-02-06 13:31:56.500000
# 23.0
# 2024-02-06 13:32:01.500000
# 2024-02-06 13:32:04.000000
# 2024-02-06 13:35:41.500000
# 23.0
# 2024-02-06 13:35:45.500000
# 2024-02-06 13:35:42.000000
# 2024-02-06 13:42:14.500
# 23.0
# 2024-02-06 13:42:30.500
# 2024-02-06 13:42:15.000
# 2024-02-06 13:44:27.500
# 23.0
# 2024-02-06 13:44:57.500
# 2024-02-06 13:44:28.000
# 2024-02-06 13:55:51.000
# 23.0
# 2024-02-06 13:56:31.500
# 2024-02-06 13:55:56.500
# 2024-02-06 14:59:08.000000
# 23.0
# 2024-02-06 21:00:05.500000
# 2024-02-06 14:59:08.500000
# 2024-02-06 21:00:20.500000
# -27.0
# 2024-02-06 21:00:22.000000
# 2024-02-06 21:00:22.000000
# 2024-02-06 21:01:19.000000
# 23.0
# 2024-02-06 21:01:24.500000
# 2024-02-06 21:01:19.500000
# 2024-02-06 21:02:38.500000
# 23.0
# 2024-02-06 21:03:05.000000
# 2024-02-06 21:02:39.000000
# 2024-02-06 21:04:35.000000
# 23.0
# 2024-02-06 21:04:52.500000
# 2024-02-06 21:04:46.500000
# 2024-02-06 21:08:07.000000
# 23.0
# 2024-02-06 21:08:11.500000
# 2024-02-06 21:08:07.500000
# 2024-02-07 00:59:28.500000
# 23.0
# 2024-02-07 09:00:23.000000
# 2024-02-07 00:59:52.000000
# 2024-02-07 09:01:37.000000
# 23.0
# 2024-02-07 09:01:49.500000
# 2024-02-07 09:01:38.500000
# 2024-02-07 09:06:51.500000
# 23.0
# 2024-02-07 09:06:52.000000
# 2024-02-07 09:09:09.500000
# 2024-02-07 09:40:45.500
# -27.0
# 2024-02-07 09:40:46.000
# 2024-02-07 09:40:46.000
# 2024-02-07 10:14:55.000
# 23.0
# 2024-02-07 10:30:36.500
# 2024-02-07 10:14:55.500
# 2024-02-07 10:57:23.000000
# -27.0
# 2024-02-07 10:57:25.500000
# 2024-02-07 10:57:25.500000
# 2024-02-07 10:59:12.000000
# 23.0
# 2024-02-07 10:59:17.000000
# 2024-02-07 10:59:17.500000
# 2024-02-07 11:27:02.500
# 23.0
# 2024-02-07 11:27:03.500
# 2024-02-07 11:27:12.000
# 2024-02-07 13:31:43.000
# 23.0
# 2024-02-07 13:32:10.000
# 2024-02-07 13:31:43.500
# 2024-02-07 13:35:20.000
# 23.0
# 2024-02-07 13:35:38.500
# 2024-02-07 13:36:02.500
# 2024-02-07 13:42:00.000
# 23.0
# 2024-02-07 13:42:16.500
# 2024-02-07 13:42:00.500
# 2024-02-07 13:43:29.500
# 23.0
# 2024-02-07 13:44:55.500
# 2024-02-07 13:43:32.500
# 2024-02-07 14:36:25.500000
# -27.0
# 2024-02-07 14:36:26.000000
# 2024-02-07 14:36:26.000000
# 2024-02-07 14:58:41.000000
# 23.0
# 2024-02-07 14:59:10.000000
# 2024-02-07 14:59:31.500000
# 2024-02-07 21:00:19.000000
# 23.0
# 2024-02-07 21:00:19.500000
# 2024-02-07 21:00:27.500000
# 2024-02-07 21:01:19.000000
# 23.0
# 2024-02-07 21:01:30.500000
# 2024-02-07 21:02:09.000000
# 2024-02-07 21:02:36.500000
# 23.0
# 2024-02-07 21:02:38.500000
# 2024-02-07 21:03:02.500000
# 2024-02-07 21:04:02.000000
# 23.0
# 2024-02-07 21:04:05.000000
# 2024-02-07 21:04:23.500000
# 2024-02-07 21:14:58.000000
# 23.0
# 2024-02-07 21:15:12.000000
# 2024-02-07 21:15:01.500000
# 2024-02-07 21:23:28.000000
# -27.0
# 2024-02-07 21:23:41.000000
# 2024-02-07 21:23:41.000000
# 2024-02-07 21:31:46.500000
# 23.0
# 2024-02-07 21:33:24.000000
# 2024-02-07 21:31:47.000000
# 2024-02-07 21:34:55.500000
# 23.0
# 2024-02-07 21:35:19.500000
# 2024-02-07 21:36:05.000000
# 2024-02-07 21:59:17.500
# 23.0
# 2024-02-07 21:59:21.500
# 2024-02-07 21:59:40.500
# 2024-02-07 22:10:06.000
# 23.0
# 2024-02-07 22:10:07.000
# 2024-02-07 22:11:24.000
# 2024-02-07 22:15:11.500
# 23.0
# 2024-02-07 22:20:14.500
# 2024-02-07 22:15:29.000
# 2024-02-07 22:26:21.000
# 23.0
# 2024-02-07 22:29:07.500
# 2024-02-07 22:26:21.500
# 2024-02-07 22:37:31.500
# -27.0
# 2024-02-07 22:37:32.000
# 2024-02-07 22:37:32.000
# 2024-02-07 22:44:55.500
# -27.0
# 2024-02-07 22:44:56.000
# 2024-02-07 22:44:56.000
# 2024-02-08 00:38:01.500000
# 23.0
# 2024-02-08 00:38:02.500000
# 2024-02-08 00:45:59.000000
# 2024-02-08 00:58:42.000000
# 23.0
# 2024-02-08 09:00:22.500000
# 2024-02-08 00:58:42.500000
# 2024-02-08 09:00:56.000000
# 23.0
# 2024-02-08 09:00:57.000000
# 2024-02-08 09:01:07.000000
# 2024-02-08 09:03:07.500000
# 23.0
# 2024-02-08 09:03:09.000000
# 2024-02-08 09:04:39.500000
# 2024-02-08 09:07:14.000000
# -27.0
# 2024-02-08 09:07:36.000000
# 2024-02-08 09:07:36.000000
# 2024-02-08 09:10:50.500000
# 23.0
# 2024-02-08 09:10:51.000000
# 2024-02-08 09:11:32.500000
# 2024-02-08 09:44:08.500000
# 23.0
# 2024-02-08 09:47:47.000000
# 2024-02-08 09:44:09.000000
# 2024-02-08 09:50:52.500000
# -27.0
# 2024-02-08 09:50:53.000000
# 2024-02-08 09:50:53.000000
# 2024-02-08 09:54:07.500000
# -27.0
# 2024-02-08 09:54:12.000000
# 2024-02-08 09:54:12.000000
# 2024-02-08 10:14:53.000000
# 23.0
# 2024-02-08 10:30:09.000000
# 2024-02-08 10:14:53.500000
# 2024-02-08 10:35:31.500
# 23.0
# 2024-02-08 10:36:22.000
# 2024-02-08 10:35:32.000
# 2024-02-08 10:47:18.500
# 23.0
# 2024-02-08 10:47:25.000
# 2024-02-08 10:49:37.000
# 2024-02-08 10:55:54.000
# 23.0
# 2024-02-08 10:56:56.000
# 2024-02-08 10:56:23.500
# 2024-02-08 11:00:32.500
# -27.0
# 2024-02-08 11:00:58.000
# 2024-02-08 11:01:02.000
# 2024-02-08 11:12:41.000
# -27.0
# 2024-02-08 11:12:46.500
# 2024-02-08 11:12:46.500
# 2024-02-08 11:20:51.000
# 23.0
# 2024-02-08 11:21:26.000
# 2024-02-08 11:21:12.500
# 2024-02-08 11:28:05.500000
# 23.0
# 2024-02-08 11:29:01.000000
# 2024-02-08 13:30:01.500000
# 2024-02-08 13:31:53.500000
# 23.0
# 2024-02-08 13:32:22.000000
# 2024-02-08 13:32:03.500000
# 2024-02-08 13:36:39.000000
# 23.0
# 2024-02-08 13:37:21.500000
# 2024-02-08 13:37:04.500000
# 2024-02-08 13:44:50.500000
# 23.0
# 2024-02-08 13:45:23.500000
# 2024-02-08 13:44:51.000000
# 2024-02-08 13:50:01.500000
# 23.0
# 2024-02-08 13:51:06.000000
# 2024-02-08 13:50:03.000000
# 2024-02-08 13:55:00.000000
# -27.0
# 2024-02-08 13:55:02.500000
# 2024-02-08 13:55:13.000000
# 2024-02-08 13:58:17.500000
# -27.0
# 2024-02-08 13:58:31.500000
# 2024-02-08 13:58:32.000000
# 2024-02-08 14:35:02.000
# -27.0
# 2024-02-08 14:35:02.500
# 2024-02-08 14:35:03.000
# 2024-02-08 14:38:47.000
# 23.0
# 2024-02-08 14:39:07.000
# 2024-02-08 14:39:54.000
# 2024-02-08 14:42:08.000
# 23.0
# 2024-02-08 14:42:11.500
# 2024-02-08 14:42:15.000
# 2024-02-08 14:44:28.000
# 23.0
# 2024-02-08 14:45:17.000
# 2024-02-08 14:44:32.000
# 2024-02-08 14:47:45.000
# -27.0
# 2024-02-08 14:47:56.500
# 2024-02-08 14:47:56.500
# 2024-02-08 14:59:18.500000
# -27.0
# 2024-02-08 14:59:19.500000
# 2024-02-08 14:59:19.500000
# 2024-02-19 09:00:24.000000
# 23.0
# 2024-02-19 09:00:28.500000
# 2024-02-19 09:00:24.500000
# 2024-02-19 09:01:14.000000
# -27.0
# 2024-02-19 09:01:14.500000
# 2024-02-19 09:01:16.000000
# 2024-02-19 09:02:07.000000
# 23.0
# 2024-02-19 09:02:11.000000
# 2024-02-19 09:02:10.500000
# 2024-02-19 09:03:03.500000
# -27.0
# 2024-02-19 09:03:06.500000
# 2024-02-19 09:03:06.500000
# 2024-02-19 09:13:38.000000
# 23.0
# 2024-02-19 09:14:09.000000
# 2024-02-19 09:13:39.500000
# 2024-02-19 09:32:57.500
# -27.0
# 2024-02-19 09:32:58.000
# 2024-02-19 09:32:58.500
# 2024-02-19 09:41:36.500
# -27.0
# 2024-02-19 09:41:37.500
# 2024-02-19 09:41:37.500
# 2024-02-19 10:31:30.000000
# -27.0
# 2024-02-19 10:31:34.000000
# 2024-02-19 10:31:36.500000
# 2024-02-19 10:34:23.500000
# 23.0
# 2024-02-19 10:35:55.000000
# 2024-02-19 10:34:36.000000
# 2024-02-19 10:38:11.000000
# 23.0
# 2024-02-19 10:38:21.000000
# 2024-02-19 10:38:12.500000
# 2024-02-19 13:34:12.000
# 23.0
# 2024-02-19 13:34:20.500
# 2024-02-19 13:34:13.500
# 2024-02-19 13:56:27.000
# -27.0
# 2024-02-19 13:56:27.500
# 2024-02-19 13:56:28.500
# 2024-02-19 14:06:36.500
# 23.0
# 2024-02-19 14:06:39.500
# 2024-02-19 14:06:42.500
# 2024-02-19 14:10:32.000
# 23.0
# 2024-02-19 14:10:53.500
# 2024-02-19 14:10:33.000
# 2024-02-19 14:22:33.500
# 23.0
# 2024-02-19 14:22:34.000
# 2024-02-19 14:23:40.500
# 2024-02-19 14:23:45.500
# -27.0
# 2024-02-19 14:23:49.000
# 2024-02-19 14:23:49.000
# 2024-02-19 14:46:58.000
# 23.0
# 2024-02-19 14:47:00.500
# 2024-02-19 14:47:02.500
# 2024-02-19 14:54:17.000
# 23.0
# 2024-02-19 14:55:04.000
# 2024-02-19 14:54:31.000
# 2024-02-19 14:59:46.500000
# 23.0
# 2024-02-19 14:59:50.000000
# 2024-02-19 14:59:51.000000
# 2024-02-19 21:00:41.000000
# 23.0
# 2024-02-19 21:00:41.500000
# 2024-02-19 21:01:10.500000
# 2024-02-19 21:01:32.500000
# 23.0
# 2024-02-19 21:01:36.000000
# 2024-02-19 21:01:55.000000
# 2024-02-19 21:02:31.000000
# -27.0
# 2024-02-19 21:02:32.000000
# 2024-02-19 21:02:33.000000
# 2024-02-19 21:03:25.500000
# 23.0
# 2024-02-19 21:03:35.000000
# 2024-02-19 21:03:26.000000
# 2024-02-20 09:00:03.500000
# 23.0
# 2024-02-20 09:00:04.500000
# 2024-02-20 09:00:28.500000
# 2024-02-20 09:01:05.000000
# 23.0
# 2024-02-20 09:01:09.500000
# 2024-02-20 09:01:10.000000
# 2024-02-20 09:02:25.000000
# -27.0
# 2024-02-20 09:02:26.000000
# 2024-02-20 09:02:26.000000
# 2024-02-20 10:09:06.500
# 23.0
# 2024-02-20 10:09:28.000
# 2024-02-20 10:10:07.500
# 2024-02-20 10:13:08.500000
# 23.0
# 2024-02-20 10:13:27.500000
# 2024-02-20 10:13:24.000000
# 2024-02-20 10:14:37.000000
# 23.0
# 2024-02-20 10:30:25.000000
# 2024-02-20 10:14:39.000000
# 2024-02-20 21:00:01.500002
# 23.0
# 2024-02-20 21:00:02.000001
# 2024-02-20 21:00:05.000000
# 2024-02-20 21:00:52.500000
# 23.0
# 2024-02-20 21:01:01.000000
# 2024-02-20 21:00:56.000000
# 2024-02-20 21:01:46.000000
# 23.0
# 2024-02-20 21:01:48.000000
# 2024-02-20 21:01:49.000000
# 2024-02-20 21:02:38.500000
# 23.0
# 2024-02-20 21:02:40.500000
# 2024-02-20 21:02:49.500000
# 2024-02-20 21:03:44.000000
# 23.0
# 2024-02-20 21:03:45.500000
# 2024-02-20 21:04:27.000000
# 2024-02-21 00:59:34.500000
# -27.0
# 2024-02-21 00:59:42.500000
# 2024-02-21 00:59:42.500000
# 2024-02-21 09:00:36.500000
# -27.0
# 2024-02-21 09:00:39.000000
# 2024-02-21 09:00:39.000000
# 2024-02-21 09:01:54.000000
# 23.0
# 2024-02-21 09:02:07.500000
# 2024-02-21 09:01:54.500000
# 2024-02-21 09:06:41.500
# 23.0
# 2024-02-21 09:07:01.500
# 2024-02-21 09:06:42.000
# 2024-02-21 09:41:20.000000
# -27.0
# 2024-02-21 09:41:20.500000
# 2024-02-21 09:41:23.000000
# 2024-02-21 13:30:00.500000
# -27.0
# 2024-02-21 13:30:01.000000
# 2024-02-21 13:30:01.000000
# 2024-02-21 13:31:51.500000
# -27.0
# 2024-02-21 13:31:52.500000
# 2024-02-21 13:31:52.500000
# 2024-02-21 13:33:07.500000
# -27.0
# 2024-02-21 13:33:08.000000
# 2024-02-21 13:33:08.000000
# 2024-02-22 09:00:13.500000
# -27.0
# 2024-02-22 09:00:16.000000
# 2024-02-22 09:00:16.000000
# 2024-02-22 09:07:09.000000
# 23.0
# 2024-02-22 09:07:28.000000
# 2024-02-22 09:07:12.000000
# 2024-02-22 10:12:18.500000
# 23.0
# 2024-02-22 10:12:23.500000
# 2024-02-22 10:12:21.000000
# 2024-02-22 21:00:00.500001
# 23.0
# 2024-02-22 21:00:01.000003
# 2024-02-22 21:00:02.500000
# 2024-02-22 21:00:51.000000
# 23.0
# 2024-02-22 21:01:00.500000
# 2024-02-22 21:00:55.000000
# 2024-02-22 21:03:02.000000
# -27.0
# 2024-02-22 21:03:03.500000
# 2024-02-22 21:03:05.000000
# 2024-02-23 00:59:54.500000
# 23.0
# 2024-02-23 00:59:59.500001
# 2024-02-23 00:59:58.000000
# 2024-02-23 09:01:24.500000
# 23.0
# 2024-02-23 09:01:59.500000
# 2024-02-23 09:01:33.500000
# 2024-02-23 09:57:05.000000
# 23.0
# 2024-02-23 09:57:06.000000
# 2024-02-23 09:57:05.500000
# 2024-02-23 11:16:51.500000
# 23.0
# 2024-02-23 11:16:52.500000
# 2024-02-23 11:17:04.500000
# 2024-02-23 21:00:00.500002
# 23.0
# 2024-02-23 21:00:12.500000
# 2024-02-23 21:00:01.000002
# 2024-02-23 21:00:54.000000
# 23.0
# 2024-02-23 21:00:56.000000
# 2024-02-23 21:01:33.000000
# 2024-02-24 00:59:31.500
# 23.0
# 2024-02-24 00:59:32.500
# 2024-02-24 00:59:58.500
# 2024-02-26 09:00:43.000
# -27.0
# 2024-02-26 09:00:45.000
# 2024-02-26 09:00:45.500
# 2024-02-26 09:05:00.000
# 23.0
# 2024-02-26 09:05:02.000
# 2024-02-26 09:05:06.000
# 2024-01-30: 161.00
# 2024-01-31: 107.00
# 2024-02-01: 314.00
# 2024-02-02: 71.00
# 2024-02-03: 23.00
# 2024-02-05: -95.00
# 2024-02-06: 225.00
# 2024-02-07: 344.00
# 2024-02-08: 167.00
# 2024-02-19: 129.00
# 2024-02-20: 203.00
# 2024-02-21: -116.00
# 2024-02-22: 38.00
# 2024-02-23: 138.00
# 2024-02-24: 23.00
# 2024-02-26: -4.00
# 2024-01-30: 7
# 2024-01-31: 9
# 2024-02-01: 18
# 2024-02-02: 27
# 2024-02-03: 1
# 2024-02-05: 10
# 2024-02-06: 25
# 2024-02-07: 28
# 2024-02-08: 29
# 2024-02-19: 23
# 2024-02-20: 11
# 2024-02-21: 8
# 2024-02-22: 6
# 2024-02-23: 6
# 2024-02-24: 1
# 2024-02-26: 2
# Final profit: 1728.00
# 151
# 211
# 0.7156398104265402
