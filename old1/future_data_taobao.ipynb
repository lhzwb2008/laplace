# %%
import os
import glob
import pandas as pd

def read_csv_with_encoding(file, encodings):
    for encoding in encodings:
        try:
            return pd.read_csv(file, encoding=encoding)
        except UnicodeDecodeError:
            continue
    raise ValueError(f"None of the encodings worked for file: {file}")

def combine_csv_in_folder(folder_path, file_pattern, combined_csv):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(file_pattern):
                file_path = os.path.join(root, file)
                df = read_csv_with_encoding(file_path, ['utf-8', 'gb2312', 'gbk'])
                combined_csv = combined_csv.append(df, ignore_index=True)
    return combined_csv

# List of root folders to start the search
root_folders = ['/Users/zhangwenbo/Downloads']  # Update with your folder paths
file_pattern = "ss2312.csv"

# Create an empty DataFrame to store combined data
combined_csv = pd.DataFrame()

# Process each root folder
for folder in root_folders:
    combined_csv = combine_csv_in_folder(folder, file_pattern, combined_csv)

# Save the combined data to a new CSV file
combined_csv.to_csv("/Users/zhangwenbo/testProjects/laplace/taobao_combined_csv.csv", index=False, encoding='utf-8', errors='ignore')

print("All files combined successfully!")
# Out:
# /var/folders/g3/764mx2lj2gs3qc7l4pz4v2n00000gp/T/ipykernel_74374/4041679392.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_csv = combined_csv.append(df, ignore_index=True)
# /var/folders/g3/764mx2lj2gs3qc7l4pz4v2n00000gp/T/ipykernel_74374/4041679392.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_csv = combined_csv.append(df, ignore_index=True)
# /var/folders/g3/764mx2lj2gs3qc7l4pz4v2n00000gp/T/ipykernel_74374/4041679392.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_csv = combined_csv.append(df, ignore_index=True)
# ...

# %%
import pandas as pd
data = pd.read_csv("/Users/zhangwenbo/testProjects/laplace/taobao_combined_csv.csv")
code = "SHFE.ss2312."

# 遍历所有列名并处理
new_columns = []
for col in data.columns:
    if col.startswith(code):
        new_columns.append(col.replace(code, ""))
    else:
        new_columns.append(col)
data.columns = new_columns
data = data.sort_values(by='datetime')
data.to_csv("future_taobao_ss2312_tick.csv",index=False)
