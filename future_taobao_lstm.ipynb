# %%
import os
os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense,GRU,Dropout, Bidirectional
from sklearn.preprocessing import MinMaxScaler
from keras.utils import Sequence
import warnings
warnings.filterwarnings('ignore')


data_clean = pd.read_csv("future_taobao_ss2401_tick.csv")


# 1. 数据加载和预处理
data_clean['last_price'] = pd.to_numeric(data_clean['last_price'], errors='coerce')

price_features = ['highest','lowest','bid_price1','ask_price1','bid_price2','ask_price2','bid_price3','ask_price3','bid_price4','ask_price4','bid_price5','ask_price5']
for feature in price_features:
    data_clean[feature + '_diff'] = data_clean['last_price'] - data_clean[feature]

data_clean['datetime'] = pd.to_datetime(data_clean['datetime'])

data_clean['last_price_diff'] = data_clean['last_price'].diff()

# Define label
data_clean['label'] = (data_clean['last_price'].shift(-100) > data_clean['last_price']).astype(int)


features = ['last_price_diff', 'volume','bid_volume1','bid_volume2','bid_volume3','bid_volume4','bid_volume5','ask_volume1','ask_volume2','ask_volume3','ask_volume4','ask_volume5'] + [f + '_diff' for f in price_features]

# 3. 分割数据

# Now you can filter the data between two dates
train_data = data_clean[(data_clean['datetime'] >= '2023-09-01 09:00:00') & 
                        (data_clean['datetime'] < '2023-11-10 09:00:00')]

test_data = data_clean[(data_clean['datetime'] >= '2023-11-10 09:00:00') & 
                        (data_clean['datetime'] < '2023-11-17 09:00:00')]


# 初始化归一化器
scaler = MinMaxScaler(feature_range=(0, 1))

train_data[features] = scaler.fit_transform(train_data[features])


# 将 DataFrame 转换为 NumPy 数组
X_train = np.array(train_data[features])
y_train = np.array(train_data['label'])

# 删除 NaN 值
mask = ~np.isnan(X_train).any(axis=1)
X_train = X_train[mask]
y_train = y_train[mask]

# 首先，确保 X_train 和 X_test 没有 NaN 值
X_train = X_train[~np.isnan(X_train).any(axis=1)]
y_train = y_train[~np.isnan(X_train).any(axis=1)]

class TimeseriesGenerator(Sequence):
    def __init__(self, data, labels, length, stride=1, batch_size=32):
        self.data = data
        self.labels = labels
        self.length = length
        self.stride = stride
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil((len(self.data) - self.length) / float(self.stride * self.batch_size)))

    def __getitem__(self, idx):
        batch_x = []
        batch_y = []

        start = idx * self.batch_size * self.stride
        end = start + self.batch_size * self.stride + self.length

        for i in range(start, min(end, len(self.data) - self.length), self.stride):
            batch_x.append(self.data[i: i + self.length])
            batch_y.append(self.labels[i + self.length])

        return np.array(batch_x), np.array(batch_y)

# 定义时间步长和步长
time_steps = 300
stride = 1  # 增加步长以减少内存使用

# 创建数据生成器
train_generator = TimeseriesGenerator(X_train, y_train, length=time_steps, stride=stride, batch_size=32)

model = Sequential()
model.add(LSTM(units=50, input_shape=(time_steps, X_train.shape[1])))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy')


# 使用生成器训练模型
model.fit_generator(train_generator, epochs=5)
model.save('model_taobao_lstm.h5')
# Out:
# Epoch 1/5
# 2023-11-29 14:46:26.285677: I tensorflow/core/common_runtime/executor.cc:1210] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
#  1393/20931 [>.............................] - ETA: 1:43:52 - loss: 0.6666
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/zhangwenbo/testProjects/laplace/future_taobao_lstm.ipynb 单元格 1 line <cell line: 103>()
#      <a href='vscode-notebook-cell:/Users/zhangwenbo/testProjects/laplace/future_taobao_lstm.ipynb#W0sZmlsZQ%3D%3D?line=98'>99</a> model.compile(optimizer='adam', loss='binary_crossentropy')
#     <a href='vscode-notebook-cell:/Users/zhangwenbo/testProjects/laplace/future_taobao_lstm.ipynb#W0sZmlsZQ%3D%3D?line=101'>102</a> # 使用生成器训练模型
# --> <a href='vscode-notebook-cell:/Users/zhangwenbo/testProjects/laplace/future_taobao_lstm.ipynb#W0sZmlsZQ%3D%3D?line=102'>103</a> model.fit_generator(train_generator, epochs=5)
#     <a href='vscode-notebook-cell:/Users/zhangwenbo/testProjects/laplace/future_taobao_lstm.ipynb#W0sZmlsZQ%3D%3D?line=103'>104</a> model.save('model_taobao_lstm.h5')
#
# File ~/miniforge3/lib/python3.10/site-packages/keras/src/engine/training.py:2810, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2798 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2799
#    2800 DEPRECATED:
#    2801   `Model.fit` now supports generators, so there is no longer any need to
#    2802   use this endpoint.
#    2803 """
#    2804 warnings.warn(
#    2805     "`Model.fit_generator` is deprecated and "
#    2806     "will be removed in a future version. "
#    2807     "Please use `Model.fit`, which supports generators.",
#    2808     stacklevel=2,
#    2809 )
# -> 2810 return self.fit(
#    2811     generator,
#    2812     steps_per_epoch=steps_per_epoch,
#    2813     epochs=epochs,
#    2814     verbose=verbose,
#    2815     callbacks=callbacks,
#    2816     validation_data=validation_data,
#    2817     validation_steps=validation_steps,
#    2818     validation_freq=validation_freq,
#    2819     class_weight=class_weight,
#    2820     max_queue_size=max_queue_size,
#    2821     workers=workers,
#    2822     use_multiprocessing=use_multiprocessing,
#    2823     shuffle=shuffle,
#    2824     initial_epoch=initial_epoch,
#    2825 )
#
# File ~/miniforge3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/lib/python3.10/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from keras.models import load_model
model = load_model('model_taobao_lstm.h5')

def predict_next_move(tick, model, time_steps,historical_data,scaler):
    # 将新的 tick 数据追加到历史数据中
    historical_data = pd.concat([historical_data, pd.DataFrame([tick])], ignore_index=True)

    # 检查是否有足够的数据来计算滚动和EWM特征
    if len(historical_data) >= time_steps+20:


        for feature in price_features:
            historical_data[feature + '_diff'] = historical_data['last_price'] - historical_data[feature]

        historical_data['last_price_diff'] = historical_data['last_price'].diff()


        data_for_scaling = historical_data[features].dropna()

        # 选择最近的time_steps行用于归一化
        data_to_scale = data_for_scaling.tail(time_steps)

        # 归一化
        scaled_data = scaler.fit_transform(data_to_scale)
        

        # 使用归一化的数据创建模型输入
        X_new = scaled_data.reshape(1, time_steps, len(features))


        # 检查X_new是否包含NaN值
        if np.isnan(X_new).any():
            return None, historical_data
        else:
            # 进行预测
            prediction_proba = model.predict(X_new,verbose=0)
            probability_of_one = prediction_proba[0][0]

            return probability_of_one, historical_data
    else:
        # 数据不足以进行预测
        return None, historical_data



# Initialize historical_data with the correct column names and types if necessary
historical_data = pd.DataFrame()
scaled_historical_data = pd.DataFrame()

initial_funds = 100000
funds = initial_funds
stock_quantity = 0
stock_price = 0
buy_threshold = 0.8
sold_threshold = 0.4
transactions = []
minute_count = 0

for idx, row in test_data.iterrows():
    current_probability, historical_data = predict_next_move(row, model,time_steps,historical_data,scaler) 
    # print(current_probability)
    # print(row['trade_time'])
    if current_probability is not None:
        current_price = row['last_price']
        minute_count = minute_count + 1
        if current_probability > buy_threshold and stock_quantity == 0 :
            print(current_probability)
            stock_quantity = funds // current_price
            funds -= stock_quantity * current_price
            fee = stock_quantity * 2
            funds -= fee
            stock_price = current_price
            buy_price = current_price  # 记录买入价格
            print(f"Time: {row['datetime']} - Action: BUY at {current_price}, Quantity: {stock_quantity},Funds:{funds}")
            transactions.append({
                'action': 'buy',
                'time': row['datetime'],
                'price': current_price,
                'quantity': stock_quantity,
                'funds_remaining': funds
            })
            minute_count = 0
        elif minute_count > 100 and stock_quantity > 0 and current_probability<sold_threshold:
            print(current_probability)
            funds += stock_quantity * current_price
            price_diff = current_price - buy_price  # 计算价格差异
            # 判断价格差异是涨、跌还是平
            if price_diff > 0:
                direction = '涨'
            elif price_diff < 0:
                direction = '跌'
            else:
                direction = '平'
            print(f"Time: {row['datetime']} - Action: SELL at {current_price}, Quantity: {stock_quantity},Funds:{funds}, Price Change: {direction}")
            transactions.append({
                'action': 'sell',
                'time': row['datetime'],
                'price': current_price,
                'quantity': stock_quantity,
                'funds_remaining': funds,
                'price_change': direction
            })
            stock_quantity = 0
            buy_price = 0  # 重置买入价格为0

    
if len(transactions)>0:
    transactions_df = pd.DataFrame(transactions)
    print(transactions_df['price_change'].value_counts())
transactions_df.to_csv('transactions_tick.csv')

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from keras.models import load_model
from datetime import datetime, time
model = load_model('model_taobao_lstm.h5')

def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False


def prepare_data_for_prediction(test_data, time_steps, scaler):

    # 使用归一化
    scaled_data = scaler.fit_transform(test_data[features].dropna())

    # 重塑数据以适应模型
    X = np.array([scaled_data[i:i+time_steps] for i in range(len(scaled_data)-time_steps+1)])
    return X


# 定义时间范围数组
notrade_time = ["11:20-11:30","14:50-15:00","0:30-1:00"]
# 准备数据
X_test = prepare_data_for_prediction(test_data, time_steps, scaler)
# 批量预测
predictions = model.predict(X_test, verbose=0)
# 确保test_data的索引与predictions对齐
aligned_test_data = test_data.iloc[time_steps - 1:]


initial_funds = 100000
funds = initial_funds
stock_quantity = 0
stock_price = 0
buy_threshold = 0.8
sold_threshold = 0.3
transactions = []
minute_count = 0
for prediction,  (index, row)  in zip(predictions, aligned_test_data.iterrows()):
    current_probability = prediction[0]
    time, nano_part = row['datetime'].split('.')
    if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S")
.time(),notrade_time):
            continue
    if current_probability is not None:
        current_price = row['last_price']
        buy1_price = row['bid_price1']
        sell1_price = row['ask_price1']
        minute_count = minute_count + 1
            
        if current_probability > buy_threshold and stock_quantity == 0 and current_price!=sell1_price :
            print(current_probability)
            stock_quantity = funds // current_price
            funds -= stock_quantity * current_price
            fee = stock_quantity * 2
            funds -= fee
            stock_price = current_price
            buy_price = current_price  # 记录买入价格
            print(f"Time: {row['datetime']} - Action: BUY at {current_price}, Quantity: {stock_quantity},Funds:{funds}")
            transactions.append({
                'action': 'buy',
                'time': row['datetime'],
                'price': current_price,
                'quantity': stock_quantity,
                'funds_remaining': funds
            })
            minute_count = 0
        elif minute_count > 100 and stock_quantity > 0 and current_probability<sold_threshold and current_price!=buy1_price:
            print(current_probability)
            funds += stock_quantity * current_price
            price_diff = current_price - buy_price  # 计算价格差异
            # 判断价格差异是涨、跌还是平
            if price_diff > 0:
                direction = '涨'
            elif price_diff < 0:
                direction = '跌'
            else:
                direction = '平'
            print(f"Time: {row['datetime']} - Action: SELL at {current_price}, Quantity: {stock_quantity},Funds:{funds}, Price Change: {direction}")
            transactions.append({
                'action': 'sell',
                'time': row['datetime'],
                'price': current_price,
                'quantity': stock_quantity,
                'funds_remaining': funds,
                'price_change': direction
            })
            stock_quantity = 0
            buy_price = 0  # 重置买入价格为0

    
if len(transactions)>0:
    transactions_df = pd.DataFrame(transactions)
    print(transactions_df['price_change'].value_counts())
transactions_df.to_csv('transactions_tick_lstm.csv')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 0.84668756
# Time: 2023-10-25 09:03:14 - Action: BUY at 14750.0, Quantity: 6.0,Funds:11488.0
# 0.27820057
# Time: 2023-10-25 09:04:58 - Action: SELL at 14770.0, Quantity: 6.0,Funds:100108.0, Price Change: 涨
# 0.9054644
# Time: 2023-10-25 09:05:04 - Action: BUY at 14765.0, Quantity: 6.0,Funds:11506.0
# 0.29193515
# Time: 2023-10-25 09:06:34 - Action: SELL at 14775.0, Quantity: 6.0,Funds:100156.0, Price Change: 涨
# 0.8477657
# Time: 2023-10-25 09:06:47 - Action: BUY at 14765.0, Quantity: 6.0,Funds:11554.0
# 0.27052036
# Time: 2023-10-25 09:09:12 - Action: SELL at 14770.0, Quantity: 6.0,Funds:100174.0, Price Change: 涨
# 0.85874116
# Time: 2023-10-25 09:09:17 - Action: BUY at 14760.0, Quantity: 6.0,Funds:11602.0
# 0.17200416
# Time: 2023-10-25 09:11:52 - Action: SELL at 14770.0, Quantity: 6.0,Funds:100222.0, Price Change: 涨
# 0.93956536
# Time: 2023-10-25 09:11:53 - Action: BUY at 14760.0, Quantity: 6.0,Funds:11650.0
# 0.1636614
# Time: 2023-10-25 09:13:54 - Action: SELL at 14765.0, Quantity: 6.0,Funds:100240.0, Price Change: 涨
# 0.8699575
# Time: 2023-10-25 09:13:57 - Action: BUY at 14760.0, Quantity: 6.0,Funds:11668.0
# 0.2778147
# Time: 2023-10-25 09:15:39 - Action: SELL at 14775.0, Quantity: 6.0,Funds:100318.0, Price Change: 涨
# 0.820508
# Time: 2023-10-25 09:16:01 - Action: BUY at 14765.0, Quantity: 6.0,Funds:11716.0
# 0.27457356
# Time: 2023-10-25 09:20:20 - Action: SELL at 14765.0, Quantity: 6.0,Funds:100306.0, Price Change: 平
# 0.84418774
# Time: 2023-10-25 09:20:42 - Action: BUY at 14755.0, Quantity: 6.0,Funds:11764.0
# 0.2644196
# Time: 2023-10-25 09:25:36 - Action: SELL at 14745.0, Quantity: 6.0,Funds:100234.0, Price Change: 跌
# 0.910791
# Time: 2023-10-25 09:25:54 - Action: BUY at 14735.0, Quantity: 6.0,Funds:11812.0
# 0.24748309
# Time: 2023-10-25 09:46:01 - Action: SELL at 14770.0, Quantity: 6.0,Funds:100432.0, Price Change: 涨
# 0.8699691
# Time: 2023-10-25 09:46:08 - Action: BUY at 14765.0, Quantity: 6.0,Funds:11830.0
# 0.16628532
# Time: 2023-10-25 09:50:01 - Action: SELL at 14790.0, Quantity: 6.0,Funds:100570.0, Price Change: 涨
# 0.8839802
# Time: 2023-10-25 09:50:01 - Action: BUY at 14780.0, Quantity: 6.0,Funds:11878.0
# 0.21566771
# Time: 2023-10-25 09:52:33 - Action: SELL at 14785.0, Quantity: 6.0,Funds:100588.0, Price Change: 涨
# 0.84719145
# Time: 2023-10-25 09:52:48 - Action: BUY at 14780.0, Quantity: 6.0,Funds:11896.0
# 0.27559674
# Time: 2023-10-25 10:00:02 - Action: SELL at 14790.0, Quantity: 6.0,Funds:100636.0, Price Change: 涨
# 0.8305845
# Time: 2023-10-25 10:00:04 - Action: BUY at 14785.0, Quantity: 6.0,Funds:11914.0
# 0.22236356
# Time: 2023-10-25 10:11:42 - Action: SELL at 14730.0, Quantity: 6.0,Funds:100294.0, Price Change: 跌
# 0.87592447
# Time: 2023-10-25 10:11:44 - Action: BUY at 14725.0, Quantity: 6.0,Funds:11932.0
# 0.03227567
# Time: 2023-10-25 10:13:23 - Action: SELL at 14720.0, Quantity: 6.0,Funds:100252.0, Price Change: 跌
# 0.90696526
# Time: 2023-10-25 10:13:24 - Action: BUY at 14700.0, Quantity: 6.0,Funds:12040.0
# 0.2699402
# Time: 2023-10-25 10:31:27 - Action: SELL at 14715.0, Quantity: 6.0,Funds:100330.0, Price Change: 涨
# 0.8043288
# Time: 2023-10-25 10:31:35 - Action: BUY at 14705.0, Quantity: 6.0,Funds:12088.0
# 0.28116712
# Time: 2023-10-25 10:46:49 - Action: SELL at 14695.0, Quantity: 6.0,Funds:100258.0, Price Change: 跌
# 0.89581645
# Time: 2023-10-25 10:46:53 - Action: BUY at 14685.0, Quantity: 6.0,Funds:12136.0
# 0.2150067
# Time: 2023-10-25 10:50:58 - Action: SELL at 14700.0, Quantity: 6.0,Funds:100336.0, Price Change: 涨
# 0.8625555
# Time: 2023-10-25 10:51:05 - Action: BUY at 14695.0, Quantity: 6.0,Funds:12154.0
# 0.14973599
# Time: 2023-10-25 10:56:06 - Action: SELL at 14665.0, Quantity: 6.0,Funds:100144.0, Price Change: 跌
# 0.9143978
# Time: 2023-10-25 10:56:07 - Action: BUY at 14655.0, Quantity: 6.0,Funds:12202.0
# 0.26690343
# Time: 2023-10-25 10:58:13 - Action: SELL at 14685.0, Quantity: 6.0,Funds:100312.0, Price Change: 涨
# 0.9178828
# Time: 2023-10-25 10:58:26 - Action: BUY at 14675.0, Quantity: 6.0,Funds:12250.0
# 0.25733042
# Time: 2023-10-25 11:01:23 - Action: SELL at 14685.0, Quantity: 6.0,Funds:100360.0, Price Change: 涨
# 0.8478942
# Time: 2023-10-25 11:01:24 - Action: BUY at 14680.0, Quantity: 6.0,Funds:12268.0
# 0.20371379
# Time: 2023-10-25 11:02:49 - Action: SELL at 14695.0, Quantity: 6.0,Funds:100438.0, Price Change: 涨
# 0.89832014
# Time: 2023-10-25 11:02:52 - Action: BUY at 14685.0, Quantity: 6.0,Funds:12316.0
# 0.24985754
# Time: 2023-10-25 11:12:36 - Action: SELL at 14690.0, Quantity: 6.0,Funds:100456.0, Price Change: 涨
# 0.8383645
# Time: 2023-10-25 11:12:56 - Action: BUY at 14685.0, Quantity: 6.0,Funds:12334.0
# 0.26962164
# Time: 2023-10-25 11:19:59 - Action: SELL at 14690.0, Quantity: 6.0,Funds:100474.0, Price Change: 涨
# 0.8175687
# Time: 2023-10-25 13:30:01 - Action: BUY at 14685.0, Quantity: 6.0,Funds:12352.0
# 0.21208751
# Time: 2023-10-25 13:36:01 - Action: SELL at 14675.0, Quantity: 6.0,Funds:100402.0, Price Change: 跌
# 0.8917975
# Time: 2023-10-25 13:36:12 - Action: BUY at 14665.0, Quantity: 6.0,Funds:12400.0
# 0.21813524
# Time: 2023-10-25 13:41:00 - Action: SELL at 14680.0, Quantity: 6.0,Funds:100480.0, Price Change: 涨
# 0.89782584
# Time: 2023-10-25 13:41:09 - Action: BUY at 14670.0, Quantity: 6.0,Funds:12448.0
# 0.22402169
# Time: 2023-10-25 13:48:48 - Action: SELL at 14670.0, Quantity: 6.0,Funds:100468.0, Price Change: 平
# 0.870939
# Time: 2023-10-25 13:48:49 - Action: BUY at 14670.0, Quantity: 6.0,Funds:12436.0
# 0.22263722
# Time: 2023-10-25 13:51:59 - Action: SELL at 14685.0, Quantity: 6.0,Funds:100546.0, Price Change: 涨
# 0.88035345
# Time: 2023-10-25 13:52:05 - Action: BUY at 14675.0, Quantity: 6.0,Funds:12484.0
# 0.2123812
# Time: 2023-10-25 13:53:51 - Action: SELL at 14690.0, Quantity: 6.0,Funds:100624.0, Price Change: 涨
# 0.8861132
# Time: 2023-10-25 13:54:07 - Action: BUY at 14680.0, Quantity: 6.0,Funds:12532.0
# 0.26797667
# Time: 2023-10-25 13:56:08 - Action: SELL at 14680.0, Quantity: 6.0,Funds:100612.0, Price Change: 平
# 0.87733155
# Time: 2023-10-25 13:56:09 - Action: BUY at 14670.0, Quantity: 6.0,Funds:12580.0
# 0.15477
# Time: 2023-10-25 13:58:03 - Action: SELL at 14680.0, Quantity: 6.0,Funds:100660.0, Price Change: 涨
# 0.845954
# Time: 2023-10-25 13:58:14 - Action: BUY at 14665.0, Quantity: 6.0,Funds:12658.0
# 0.2227655
# Time: 2023-10-25 14:00:35 - Action: SELL at 14665.0, Quantity: 6.0,Funds:100648.0, Price Change: 平
# 0.9193032
# Time: 2023-10-25 14:00:44 - Action: BUY at 14655.0, Quantity: 6.0,Funds:12706.0
# 0.26407483
# Time: 2023-10-25 14:02:59 - Action: SELL at 14670.0, Quantity: 6.0,Funds:100726.0, Price Change: 涨
# 0.8942453
# Time: 2023-10-25 14:03:07 - Action: BUY at 14660.0, Quantity: 6.0,Funds:12754.0
# 0.2553348
# Time: 2023-10-25 14:06:47 - Action: SELL at 14670.0, Quantity: 6.0,Funds:100774.0, Price Change: 涨
# 0.90038234
# Time: 2023-10-25 14:06:51 - Action: BUY at 14660.0, Quantity: 6.0,Funds:12802.0
# 0.263431
# Time: 2023-10-25 14:11:29 - Action: SELL at 14670.0, Quantity: 6.0,Funds:100822.0, Price Change: 涨
# 0.8316718
# Time: 2023-10-25 14:11:41 - Action: BUY at 14665.0, Quantity: 6.0,Funds:12820.0
# 0.19711405
# Time: 2023-10-25 14:13:54 - Action: SELL at 14665.0, Quantity: 6.0,Funds:100810.0, Price Change: 平
# 0.9025069
# Time: 2023-10-25 14:13:59 - Action: BUY at 14655.0, Quantity: 6.0,Funds:12868.0
# 0.22055884
# Time: 2023-10-25 14:17:18 - Action: SELL at 14680.0, Quantity: 6.0,Funds:100948.0, Price Change: 涨
# 0.920339
# Time: 2023-10-25 14:17:30 - Action: BUY at 14670.0, Quantity: 6.0,Funds:12916.0
# 0.28239384
# Time: 2023-10-25 14:19:12 - Action: SELL at 14685.0, Quantity: 6.0,Funds:101026.0, Price Change: 涨
# 0.9189731
# Time: 2023-10-25 14:19:27 - Action: BUY at 14675.0, Quantity: 6.0,Funds:12964.0
# 0.24499424
# Time: 2023-10-25 14:20:41 - Action: SELL at 14680.0, Quantity: 6.0,Funds:101044.0, Price Change: 涨
# 0.87017316
# Time: 2023-10-25 14:20:42 - Action: BUY at 14680.0, Quantity: 6.0,Funds:12952.0
# 0.1162926
# Time: 2023-10-25 14:25:06 - Action: SELL at 14695.0, Quantity: 6.0,Funds:101122.0, Price Change: 涨
# 0.86502063
# Time: 2023-10-25 14:25:07 - Action: BUY at 14690.0, Quantity: 6.0,Funds:12970.0
# 0.19448166
# Time: 2023-10-25 14:27:38 - Action: SELL at 14670.0, Quantity: 6.0,Funds:100990.0, Price Change: 跌
# 0.82654804
# Time: 2023-10-25 14:27:46 - Action: BUY at 14660.0, Quantity: 6.0,Funds:13018.0
# 0.21865024
# Time: 2023-10-25 14:32:03 - Action: SELL at 14660.0, Quantity: 6.0,Funds:100978.0, Price Change: 平
# 0.89140266
# Time: 2023-10-25 14:32:07 - Action: BUY at 14650.0, Quantity: 6.0,Funds:13066.0
# 0.22649062
# Time: 2023-10-25 14:40:05 - Action: SELL at 14665.0, Quantity: 6.0,Funds:101056.0, Price Change: 涨
# 0.89401275
# Time: 2023-10-25 14:40:15 - Action: BUY at 14655.0, Quantity: 6.0,Funds:13114.0
# 0.20460252
# Time: 2023-10-25 14:43:02 - Action: SELL at 14670.0, Quantity: 6.0,Funds:101134.0, Price Change: 涨
# 0.84462756
# Time: 2023-10-25 14:43:17 - Action: BUY at 14665.0, Quantity: 6.0,Funds:13132.0
# 0.18726926
# Time: 2023-10-25 14:46:03 - Action: SELL at 14675.0, Quantity: 6.0,Funds:101182.0, Price Change: 涨
# 0.89258355
# Time: 2023-10-25 14:46:15 - Action: BUY at 14665.0, Quantity: 6.0,Funds:13180.0
# 0.20224999
# Time: 2023-10-25 14:49:27 - Action: SELL at 14670.0, Quantity: 6.0,Funds:101200.0, Price Change: 涨
# 0.8454745
# Time: 2023-10-25 14:49:40 - Action: BUY at 14665.0, Quantity: 6.0,Funds:13198.0
# 0.24337924
# Time: 2023-10-25 21:00:44 - Action: SELL at 14640.0, Quantity: 6.0,Funds:101038.0, Price Change: 跌
# 0.92268395
# Time: 2023-10-25 21:00:45 - Action: BUY at 14635.0, Quantity: 6.0,Funds:13216.0
# 0.27127755
# Time: 2023-10-25 21:03:02 - Action: SELL at 14660.0, Quantity: 6.0,Funds:101176.0, Price Change: 涨
# 0.85167027
# Time: 2023-10-25 21:03:10 - Action: BUY at 14645.0, Quantity: 6.0,Funds:13294.0
# 0.21080354
# Time: 2023-10-25 21:07:44 - Action: SELL at 14635.0, Quantity: 6.0,Funds:101104.0, Price Change: 跌
# 0.8527147
# Time: 2023-10-25 21:07:45 - Action: BUY at 14635.0, Quantity: 6.0,Funds:13282.0
# 0.27184412
# Time: 2023-10-25 21:08:41 - Action: SELL at 14640.0, Quantity: 6.0,Funds:101122.0, Price Change: 涨
# 0.84813964
# Time: 2023-10-25 21:08:59 - Action: BUY at 14635.0, Quantity: 6.0,Funds:13300.0
# 0.25846314
# Time: 2023-10-25 21:23:00 - Action: SELL at 14640.0, Quantity: 6.0,Funds:101140.0, Price Change: 涨
# 0.8572121
# Time: 2023-10-25 21:24:03 - Action: BUY at 14635.0, Quantity: 6.0,Funds:13318.0
# 0.22748579
# Time: 2023-10-25 21:33:25 - Action: SELL at 14635.0, Quantity: 6.0,Funds:101128.0, Price Change: 平
# 0.8776395
# Time: 2023-10-25 21:33:45 - Action: BUY at 14630.0, Quantity: 6.0,Funds:13336.0
# 0.27694008
# Time: 2023-10-25 21:47:01 - Action: SELL at 14635.0, Quantity: 6.0,Funds:101146.0, Price Change: 涨
# 0.8063574
# Time: 2023-10-25 21:47:15 - Action: BUY at 14630.0, Quantity: 6.0,Funds:13354.0
# 0.2517018
# Time: 2023-10-25 21:59:44 - Action: SELL at 14660.0, Quantity: 6.0,Funds:101314.0, Price Change: 涨
# 0.829071
# Time: 2023-10-25 22:00:10 - Action: BUY at 14655.0, Quantity: 6.0,Funds:13372.0
# 0.29407856
# Time: 2023-10-25 22:15:18 - Action: SELL at 14695.0, Quantity: 6.0,Funds:101542.0, Price Change: 涨
# 0.822188
# Time: 2023-10-25 22:15:23 - Action: BUY at 14690.0, Quantity: 6.0,Funds:13390.0
# 0.2689243
# Time: 2023-10-25 22:17:42 - Action: SELL at 14695.0, Quantity: 6.0,Funds:101560.0, Price Change: 涨
# 0.8734965
# Time: 2023-10-25 22:18:14 - Action: BUY at 14695.0, Quantity: 6.0,Funds:13378.0
# 0.29653278
# Time: 2023-10-25 22:24:08 - Action: SELL at 14690.0, Quantity: 6.0,Funds:101518.0, Price Change: 跌
# 0.901318
# Time: 2023-10-25 22:26:53 - Action: BUY at 14680.0, Quantity: 6.0,Funds:13426.0
# 0.24153185
# Time: 2023-10-25 22:40:36 - Action: SELL at 14675.0, Quantity: 6.0,Funds:101476.0, Price Change: 跌
# 0.8043049
# Time: 2023-10-25 22:40:44 - Action: BUY at 14665.0, Quantity: 6.0,Funds:13474.0
# 0.25034022
# Time: 2023-10-25 22:50:31 - Action: SELL at 14690.0, Quantity: 6.0,Funds:101614.0, Price Change: 涨
# 0.8029051
# Time: 2023-10-25 22:50:32 - Action: BUY at 14685.0, Quantity: 6.0,Funds:13492.0
# 0.22482318
# Time: 2023-10-25 22:52:36 - Action: SELL at 14690.0, Quantity: 6.0,Funds:101632.0, Price Change: 涨
# 0.81872535
# Time: 2023-10-25 22:52:37 - Action: BUY at 14685.0, Quantity: 6.0,Funds:13510.0
# 0.29145443
# Time: 2023-10-25 22:55:46 - Action: SELL at 14690.0, Quantity: 6.0,Funds:101650.0, Price Change: 涨
# 0.8716326
# Time: 2023-10-25 22:56:19 - Action: BUY at 14685.0, Quantity: 6.0,Funds:13528.0
# 0.24998973
# Time: 2023-10-25 22:59:32 - Action: SELL at 14695.0, Quantity: 6.0,Funds:101698.0, Price Change: 涨
# 0.82924026
# Time: 2023-10-25 22:59:46 - Action: BUY at 14690.0, Quantity: 6.0,Funds:13546.0
# 0.24762928
# Time: 2023-10-25 23:04:27 - Action: SELL at 14695.0, Quantity: 6.0,Funds:101716.0, Price Change: 涨
# 0.8486716
# Time: 2023-10-25 23:05:44 - Action: BUY at 14685.0, Quantity: 6.0,Funds:13594.0
# 0.19184677
# Time: 2023-10-25 23:09:04 - Action: SELL at 14690.0, Quantity: 6.0,Funds:101734.0, Price Change: 涨
# 0.8432188
# Time: 2023-10-25 23:11:16 - Action: BUY at 14685.0, Quantity: 6.0,Funds:13612.0
# 0.29275206
# Time: 2023-10-25 23:37:35 - Action: SELL at 14700.0, Quantity: 6.0,Funds:101812.0, Price Change: 涨
# 0.84339064
# Time: 2023-10-25 23:38:01 - Action: BUY at 14695.0, Quantity: 6.0,Funds:13630.0
# 0.2317906
# Time: 2023-10-25 23:45:29 - Action: SELL at 14700.0, Quantity: 6.0,Funds:101830.0, Price Change: 涨
# 0.84581286
# Time: 2023-10-25 23:46:39 - Action: BUY at 14690.0, Quantity: 6.0,Funds:13678.0
# 0.2235429
# Time: 2023-10-25 23:58:02 - Action: SELL at 14700.0, Quantity: 6.0,Funds:101878.0, Price Change: 涨
# 0.8658386
# Time: 2023-10-25 23:58:28 - Action: BUY at 14690.0, Quantity: 6.0,Funds:13726.0
# 0.26182455
# Time: 2023-10-26 00:09:41 - Action: SELL at 14605.0, Quantity: 6.0,Funds:101356.0, Price Change: 跌
# 0.87929374
# Time: 2023-10-26 00:13:42 - Action: BUY at 14600.0, Quantity: 6.0,Funds:13744.0
# 0.25693613
# Time: 2023-10-26 09:00:07 - Action: SELL at 14615.0, Quantity: 6.0,Funds:101434.0, Price Change: 涨
# 0.890293
# Time: 2023-10-26 09:00:11 - Action: BUY at 14615.0, Quantity: 6.0,Funds:13732.0
# 0.24999054
# Time: 2023-10-26 09:05:07 - Action: SELL at 14620.0, Quantity: 6.0,Funds:101452.0, Price Change: 涨
# 0.8530832
# Time: 2023-10-26 09:05:24 - Action: BUY at 14610.0, Quantity: 6.0,Funds:13780.0
# 0.29490426
# Time: 2023-10-26 09:09:56 - Action: SELL at 14620.0, Quantity: 6.0,Funds:101500.0, Price Change: 涨
# 0.86090046
# Time: 2023-10-26 09:11:01 - Action: BUY at 14605.0, Quantity: 6.0,Funds:13858.0
# 0.16818057
# Time: 2023-10-26 09:14:06 - Action: SELL at 14625.0, Quantity: 6.0,Funds:101608.0, Price Change: 涨
# 0.8112412
# Time: 2023-10-26 09:14:09 - Action: BUY at 14615.0, Quantity: 6.0,Funds:13906.0
# 0.18096486
# Time: 2023-10-26 09:58:21 - Action: SELL at 14540.0, Quantity: 6.0,Funds:101146.0, Price Change: 跌
# 0.8506092
# Time: 2023-10-26 09:58:39 - Action: BUY at 14525.0, Quantity: 6.0,Funds:13984.0
# 0.29330695
# Time: 2023-10-26 10:00:00 - Action: SELL at 14540.0, Quantity: 6.0,Funds:101224.0, Price Change: 涨
# 0.84907067
# Time: 2023-10-26 10:00:01 - Action: BUY at 14530.0, Quantity: 6.0,Funds:14032.0
# 0.24879132
# Time: 2023-10-26 11:10:04 - Action: SELL at 14515.0, Quantity: 6.0,Funds:101122.0, Price Change: 跌
# 0.9026693
# Time: 2023-10-26 11:10:07 - Action: BUY at 14505.0, Quantity: 6.0,Funds:14080.0
# 0.1501097
# Time: 2023-10-26 13:50:40 - Action: SELL at 14545.0, Quantity: 6.0,Funds:101350.0, Price Change: 涨
# 0.8167567
# Time: 2023-10-26 13:50:43 - Action: BUY at 14535.0, Quantity: 6.0,Funds:14128.0
# 0.2200303
# Time: 2023-10-26 13:54:43 - Action: SELL at 14550.0, Quantity: 6.0,Funds:101428.0, Price Change: 涨
# 0.82391727
# Time: 2023-10-26 13:54:43 - Action: BUY at 14545.0, Quantity: 6.0,Funds:14146.0
# 0.2570243
# Time: 2023-10-26 14:05:38 - Action: SELL at 14540.0, Quantity: 6.0,Funds:101386.0, Price Change: 跌
# 0.84266394
# Time: 2023-10-26 14:05:42 - Action: BUY at 14540.0, Quantity: 6.0,Funds:14134.0
# 0.26025024
# Time: 2023-10-26 14:30:58 - Action: SELL at 14555.0, Quantity: 6.0,Funds:101464.0, Price Change: 涨
# 0.83694327
# Time: 2023-10-26 14:31:00 - Action: BUY at 14550.0, Quantity: 6.0,Funds:14152.0
# 0.0965931
# Time: 2023-10-26 14:38:00 - Action: SELL at 14560.0, Quantity: 6.0,Funds:101512.0, Price Change: 涨
# 0.8212899
# Time: 2023-10-26 14:38:01 - Action: BUY at 14555.0, Quantity: 6.0,Funds:14170.0
# 0.28736362
# Time: 2023-10-26 14:39:33 - Action: SELL at 14555.0, Quantity: 6.0,Funds:101500.0, Price Change: 平
# 0.8494043
# Time: 2023-10-26 14:39:40 - Action: BUY at 14550.0, Quantity: 6.0,Funds:14188.0
# 0.20057525
# Time: 2023-10-26 14:40:48 - Action: SELL at 14555.0, Quantity: 6.0,Funds:101518.0, Price Change: 涨
# 0.85874546
# Time: 2023-10-26 14:40:53 - Action: BUY at 14550.0, Quantity: 6.0,Funds:14206.0
# 0.29486796
# Time: 2023-10-26 14:44:08 - Action: SELL at 14560.0, Quantity: 6.0,Funds:101566.0, Price Change: 涨
# 0.8481468
# Time: 2023-10-26 14:44:12 - Action: BUY at 14550.0, Quantity: 6.0,Funds:14254.0
# 0.10129546
# Time: 2023-10-26 14:47:39 - Action: SELL at 14565.0, Quantity: 6.0,Funds:101644.0, Price Change: 涨
# 0.90318424
# Time: 2023-10-26 14:47:41 - Action: BUY at 14560.0, Quantity: 6.0,Funds:14272.0
# 0.16870585
# Time: 2023-10-26 21:00:08 - Action: SELL at 14690.0, Quantity: 6.0,Funds:102412.0, Price Change: 涨
# 0.8103676
# Time: 2023-10-26 21:00:11 - Action: BUY at 14685.0, Quantity: 6.0,Funds:14290.0
# 0.17248195
# Time: 2023-10-26 21:18:15 - Action: SELL at 14650.0, Quantity: 6.0,Funds:102190.0, Price Change: 跌
# 0.87703323
# Time: 2023-10-26 21:18:42 - Action: BUY at 14645.0, Quantity: 6.0,Funds:14308.0
# 0.14538309
# Time: 2023-10-26 21:33:22 - Action: SELL at 14640.0, Quantity: 6.0,Funds:102148.0, Price Change: 跌
# 0.87658006
# Time: 2023-10-26 21:33:41 - Action: BUY at 14635.0, Quantity: 6.0,Funds:14326.0
# 0.27152473
# Time: 2023-10-26 21:42:14 - Action: SELL at 14645.0, Quantity: 6.0,Funds:102196.0, Price Change: 涨
# 0.87497985
# Time: 2023-10-26 21:42:52 - Action: BUY at 14635.0, Quantity: 6.0,Funds:14374.0
# 0.26035
# Time: 2023-10-26 21:50:25 - Action: SELL at 14645.0, Quantity: 6.0,Funds:102244.0, Price Change: 涨
# 0.87609756
# Time: 2023-10-26 21:52:37 - Action: BUY at 14640.0, Quantity: 6.0,Funds:14392.0
# 0.2774445
# Time: 2023-10-26 22:11:48 - Action: SELL at 14605.0, Quantity: 6.0,Funds:102022.0, Price Change: 跌
# 0.95047116
# Time: 2023-10-26 22:11:57 - Action: BUY at 14600.0, Quantity: 6.0,Funds:14410.0
# 0.25699255
# Time: 2023-10-26 22:16:07 - Action: SELL at 14615.0, Quantity: 6.0,Funds:102100.0, Price Change: 涨
# 0.84856397
# Time: 2023-10-26 22:17:32 - Action: BUY at 14610.0, Quantity: 6.0,Funds:14428.0
# 0.27058926
# Time: 2023-10-26 22:21:09 - Action: SELL at 14625.0, Quantity: 6.0,Funds:102178.0, Price Change: 涨
# 0.83057976
# Time: 2023-10-26 22:21:45 - Action: BUY at 14620.0, Quantity: 6.0,Funds:14446.0
# 0.25187394
# Time: 2023-10-26 23:03:37 - Action: SELL at 14630.0, Quantity: 6.0,Funds:102226.0, Price Change: 涨
# 0.848577
# Time: 2023-10-26 23:04:08 - Action: BUY at 14620.0, Quantity: 6.0,Funds:14494.0
# 0.15525162
# Time: 2023-10-26 23:55:06 - Action: SELL at 14610.0, Quantity: 6.0,Funds:102154.0, Price Change: 跌
# 0.8497424
# Time: 2023-10-26 23:57:02 - Action: BUY at 14600.0, Quantity: 6.0,Funds:14542.0
# 0.2179562
# Time: 2023-10-27 08:59:00 - Action: SELL at 14520.0, Quantity: 6.0,Funds:101662.0, Price Change: 跌
# 0.84415364
# Time: 2023-10-27 09:00:01 - Action: BUY at 14505.0, Quantity: 7.0,Funds:113.0
# 0.2205537
# Time: 2023-10-27 09:02:38 - Action: SELL at 14495.0, Quantity: 7.0,Funds:101578.0, Price Change: 跌
# 0.8429762
# Time: 2023-10-27 09:02:41 - Action: BUY at 14490.0, Quantity: 7.0,Funds:134.0
# 0.27175447
# Time: 2023-10-27 09:04:15 - Action: SELL at 14490.0, Quantity: 7.0,Funds:101564.0, Price Change: 平
# 0.822563
# Time: 2023-10-27 09:04:18 - Action: BUY at 14485.0, Quantity: 7.0,Funds:155.0
# 0.27515516
# Time: 2023-10-27 09:11:04 - Action: SELL at 14465.0, Quantity: 7.0,Funds:101410.0, Price Change: 跌
# 0.83870023
# Time: 2023-10-27 09:11:05 - Action: BUY at 14460.0, Quantity: 7.0,Funds:176.0
# 0.16146134
# Time: 2023-10-27 09:12:19 - Action: SELL at 14450.0, Quantity: 7.0,Funds:101326.0, Price Change: 跌
# 0.885556
# Time: 2023-10-27 09:12:21 - Action: BUY at 14445.0, Quantity: 7.0,Funds:197.0
# 0.1477079
# Time: 2023-10-27 10:09:10 - Action: SELL at 14465.0, Quantity: 7.0,Funds:101452.0, Price Change: 涨
# 0.84627736
# Time: 2023-10-27 10:09:12 - Action: BUY at 14460.0, Quantity: 7.0,Funds:218.0
# 0.14294292
# Time: 2023-10-27 10:31:30 - Action: SELL at 14465.0, Quantity: 7.0,Funds:101473.0, Price Change: 涨
# 0.90247184
# Time: 2023-10-27 10:31:31 - Action: BUY at 14455.0, Quantity: 7.0,Funds:274.0
# 0.13049826
# Time: 2023-10-27 10:40:11 - Action: SELL at 14465.0, Quantity: 7.0,Funds:101529.0, Price Change: 涨
# 0.8081006
# Time: 2023-10-27 10:40:16 - Action: BUY at 14455.0, Quantity: 7.0,Funds:330.0
# 0.19607034
# Time: 2023-10-27 10:45:16 - Action: SELL at 14460.0, Quantity: 7.0,Funds:101550.0, Price Change: 涨
# 0.82070273
# Time: 2023-10-27 10:45:17 - Action: BUY at 14455.0, Quantity: 7.0,Funds:351.0
# 0.2514705
# Time: 2023-10-27 10:46:59 - Action: SELL at 14460.0, Quantity: 7.0,Funds:101571.0, Price Change: 涨
# 0.89403623
# Time: 2023-10-27 10:47:00 - Action: BUY at 14450.0, Quantity: 7.0,Funds:407.0
# 0.28985667
# Time: 2023-10-27 10:58:43 - Action: SELL at 14460.0, Quantity: 7.0,Funds:101627.0, Price Change: 涨
# 0.82709235
# Time: 2023-10-27 10:58:46 - Action: BUY at 14450.0, Quantity: 7.0,Funds:463.0
# 0.28969035
# Time: 2023-10-27 11:04:12 - Action: SELL at 14445.0, Quantity: 7.0,Funds:101578.0, Price Change: 跌
# 0.8838384
# Time: 2023-10-27 11:04:14 - Action: BUY at 14435.0, Quantity: 7.0,Funds:519.0
# 0.10533563
# Time: 2023-10-27 13:45:33 - Action: SELL at 14480.0, Quantity: 7.0,Funds:101879.0, Price Change: 涨
# 0.8175656
# Time: 2023-10-27 13:45:34 - Action: BUY at 14470.0, Quantity: 7.0,Funds:575.0
# 0.103279024
# Time: 2023-10-27 13:47:10 - Action: SELL at 14470.0, Quantity: 7.0,Funds:101865.0, Price Change: 平
# 0.8313038
# Time: 2023-10-27 13:47:13 - Action: BUY at 14465.0, Quantity: 7.0,Funds:596.0
# 0.25164798
# Time: 2023-10-27 13:50:19 - Action: SELL at 14470.0, Quantity: 7.0,Funds:101886.0, Price Change: 涨
# 0.87261355
# Time: 2023-10-27 13:50:20 - Action: BUY at 14465.0, Quantity: 7.0,Funds:617.0
# 0.15735042
# Time: 2023-10-27 13:52:53 - Action: SELL at 14470.0, Quantity: 7.0,Funds:101907.0, Price Change: 涨
# 0.87861186
# Time: 2023-10-27 13:52:54 - Action: BUY at 14465.0, Quantity: 7.0,Funds:638.0
# 0.19850816
# Time: 2023-10-27 14:00:33 - Action: SELL at 14475.0, Quantity: 7.0,Funds:101963.0, Price Change: 涨
# 0.8223865
# Time: 2023-10-27 14:00:39 - Action: BUY at 14465.0, Quantity: 7.0,Funds:694.0
# 0.16866976
# Time: 2023-10-27 14:02:51 - Action: SELL at 14485.0, Quantity: 7.0,Funds:102089.0, Price Change: 涨
# 0.822854
# Time: 2023-10-27 14:03:00 - Action: BUY at 14480.0, Quantity: 7.0,Funds:715.0
# 0.1265512
# Time: 2023-10-27 14:05:06 - Action: SELL at 14485.0, Quantity: 7.0,Funds:102110.0, Price Change: 涨
# 0.83724743
# Time: 2023-10-27 14:05:11 - Action: BUY at 14480.0, Quantity: 7.0,Funds:736.0
# 0.16870753
# Time: 2023-10-27 14:06:30 - Action: SELL at 14495.0, Quantity: 7.0,Funds:102201.0, Price Change: 涨
# 0.83280313
# Time: 2023-10-27 14:06:32 - Action: BUY at 14490.0, Quantity: 7.0,Funds:757.0
# 0.17174166
# Time: 2023-10-27 14:09:09 - Action: SELL at 14495.0, Quantity: 7.0,Funds:102222.0, Price Change: 涨
# 0.8254545
# Time: 2023-10-27 14:09:16 - Action: BUY at 14490.0, Quantity: 7.0,Funds:778.0
# 0.2585905
# Time: 2023-10-27 14:18:37 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102278.0, Price Change: 涨
# 0.82663065
# Time: 2023-10-27 14:18:56 - Action: BUY at 14490.0, Quantity: 7.0,Funds:834.0
# 0.1665224
# Time: 2023-10-27 14:24:00 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102334.0, Price Change: 涨
# 0.814313
# Time: 2023-10-27 14:24:01 - Action: BUY at 14495.0, Quantity: 7.0,Funds:855.0
# 0.23916322
# Time: 2023-10-27 14:26:36 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102355.0, Price Change: 涨
# 0.83149457
# Time: 2023-10-27 14:26:41 - Action: BUY at 14490.0, Quantity: 7.0,Funds:911.0
# 0.09987629
# Time: 2023-10-27 14:30:48 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102411.0, Price Change: 涨
# 0.8645043
# Time: 2023-10-27 14:30:54 - Action: BUY at 14495.0, Quantity: 7.0,Funds:932.0
# 0.18185152
# Time: 2023-10-27 14:33:41 - Action: SELL at 14485.0, Quantity: 7.0,Funds:102327.0, Price Change: 跌
# 0.8631333
# Time: 2023-10-27 14:33:43 - Action: BUY at 14480.0, Quantity: 7.0,Funds:953.0
# 0.15648651
# Time: 2023-10-27 14:35:57 - Action: SELL at 14490.0, Quantity: 7.0,Funds:102383.0, Price Change: 涨
# 0.8253651
# Time: 2023-10-27 14:36:16 - Action: BUY at 14485.0, Quantity: 7.0,Funds:974.0
# 0.20059443
# Time: 2023-10-27 14:39:12 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102474.0, Price Change: 涨
# 0.8032176
# Time: 2023-10-27 14:39:13 - Action: BUY at 14495.0, Quantity: 7.0,Funds:995.0
# 0.2028739
# Time: 2023-10-27 14:41:14 - Action: SELL at 14495.0, Quantity: 7.0,Funds:102460.0, Price Change: 平
# 0.8327686
# Time: 2023-10-27 14:41:28 - Action: BUY at 14495.0, Quantity: 7.0,Funds:981.0
# 0.22090098
# Time: 2023-10-27 14:45:55 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102481.0, Price Change: 涨
# 0.85221946
# Time: 2023-10-27 14:45:58 - Action: BUY at 14495.0, Quantity: 7.0,Funds:1002.0
# 0.25880367
# Time: 2023-10-27 21:01:03 - Action: SELL at 14530.0, Quantity: 7.0,Funds:102712.0, Price Change: 涨
# 0.87366587
# Time: 2023-10-27 21:01:09 - Action: BUY at 14525.0, Quantity: 7.0,Funds:1023.0
# 0.2834754
# Time: 2023-10-27 21:02:38 - Action: SELL at 14510.0, Quantity: 7.0,Funds:102593.0, Price Change: 跌
# 0.8575685
# Time: 2023-10-27 21:02:42 - Action: BUY at 14490.0, Quantity: 7.0,Funds:1149.0
# 0.2755761
# Time: 2023-10-27 21:06:05 - Action: SELL at 14520.0, Quantity: 7.0,Funds:102789.0, Price Change: 涨
# 0.8711796
# Time: 2023-10-27 21:06:06 - Action: BUY at 14510.0, Quantity: 7.0,Funds:1205.0
# 0.27071774
# Time: 2023-10-27 21:08:31 - Action: SELL at 14520.0, Quantity: 7.0,Funds:102845.0, Price Change: 涨
# 0.85627997
# Time: 2023-10-27 21:08:43 - Action: BUY at 14515.0, Quantity: 7.0,Funds:1226.0
# 0.26365563
# Time: 2023-10-27 21:13:33 - Action: SELL at 14515.0, Quantity: 7.0,Funds:102831.0, Price Change: 平
# 0.8471401
# Time: 2023-10-27 21:13:37 - Action: BUY at 14510.0, Quantity: 7.0,Funds:1247.0
# 0.26103744
# Time: 2023-10-27 21:25:22 - Action: SELL at 14530.0, Quantity: 7.0,Funds:102957.0, Price Change: 涨
# 0.8492908
# Time: 2023-10-27 21:26:04 - Action: BUY at 14520.0, Quantity: 7.0,Funds:1303.0
# 0.14910755
# Time: 2023-10-27 22:02:42 - Action: SELL at 14500.0, Quantity: 7.0,Funds:102803.0, Price Change: 跌
# 0.84975016
# Time: 2023-10-27 22:03:41 - Action: BUY at 14490.0, Quantity: 7.0,Funds:1359.0
# 0.29920655
# Time: 2023-10-27 22:49:27 - Action: SELL at 14535.0, Quantity: 7.0,Funds:103104.0, Price Change: 涨
# 0.8536374
# Time: 2023-10-27 22:50:12 - Action: BUY at 14525.0, Quantity: 7.0,Funds:1415.0
# 0.23330556
# Time: 2023-10-27 22:55:42 - Action: SELL at 14535.0, Quantity: 7.0,Funds:103160.0, Price Change: 涨
# 0.8013884
# Time: 2023-10-27 22:56:21 - Action: BUY at 14525.0, Quantity: 7.0,Funds:1471.0
# 0.2516941
# Time: 2023-10-30 09:02:07 - Action: SELL at 14655.0, Quantity: 7.0,Funds:104056.0, Price Change: 涨
# 0.84485555
# Time: 2023-10-30 09:02:09 - Action: BUY at 14650.0, Quantity: 7.0,Funds:1492.0
# 0.23572709
# Time: 2023-10-30 09:03:03 - Action: SELL at 14665.0, Quantity: 7.0,Funds:104147.0, Price Change: 涨
# 0.8384778
# Time: 2023-10-30 09:03:04 - Action: BUY at 14660.0, Quantity: 7.0,Funds:1513.0
# 0.20562495
# Time: 2023-10-30 09:04:05 - Action: SELL at 14665.0, Quantity: 7.0,Funds:104168.0, Price Change: 涨
# 0.8429686
# Time: 2023-10-30 09:04:12 - Action: BUY at 14660.0, Quantity: 7.0,Funds:1534.0
# 0.106671646
# Time: 2023-10-30 09:05:54 - Action: SELL at 14665.0, Quantity: 7.0,Funds:104189.0, Price Change: 涨
# 0.877595
# Time: 2023-10-30 09:05:55 - Action: BUY at 14660.0, Quantity: 7.0,Funds:1555.0
# 0.26238143
# Time: 2023-10-30 09:15:42 - Action: SELL at 14675.0, Quantity: 7.0,Funds:104280.0, Price Change: 涨
# 0.80144405
# Time: 2023-10-30 09:15:43 - Action: BUY at 14670.0, Quantity: 7.0,Funds:1576.0
# 0.23202948
# Time: 2023-10-30 09:18:02 - Action: SELL at 14665.0, Quantity: 7.0,Funds:104231.0, Price Change: 跌
# 0.840417
# Time: 2023-10-30 09:18:06 - Action: BUY at 14655.0, Quantity: 7.0,Funds:1632.0
# 0.2562326
# Time: 2023-10-30 09:21:40 - Action: SELL at 14660.0, Quantity: 7.0,Funds:104252.0, Price Change: 涨
# 0.8219917
# Time: 2023-10-30 09:21:45 - Action: BUY at 14655.0, Quantity: 7.0,Funds:1653.0
# 0.20986687
# Time: 2023-10-30 09:24:52 - Action: SELL at 14675.0, Quantity: 7.0,Funds:104378.0, Price Change: 涨
# 0.8290949
# Time: 2023-10-30 09:24:55 - Action: BUY at 14670.0, Quantity: 7.0,Funds:1674.0
# 0.14527823
# Time: 2023-10-30 09:31:03 - Action: SELL at 14710.0, Quantity: 7.0,Funds:104644.0, Price Change: 涨
# 0.86171985
# Time: 2023-10-30 09:31:07 - Action: BUY at 14700.0, Quantity: 7.0,Funds:1730.0
# 0.22830814
# Time: 2023-10-30 09:34:31 - Action: SELL at 14705.0, Quantity: 7.0,Funds:104665.0, Price Change: 涨
# 0.82594055
# Time: 2023-10-30 09:34:36 - Action: BUY at 14700.0, Quantity: 7.0,Funds:1751.0
# 0.28213936
# Time: 2023-10-30 09:40:40 - Action: SELL at 14705.0, Quantity: 7.0,Funds:104686.0, Price Change: 涨
# 0.8517313
# Time: 2023-10-30 09:40:43 - Action: BUY at 14700.0, Quantity: 7.0,Funds:1772.0
# 0.21170422
# Time: 2023-10-30 09:43:04 - Action: SELL at 14710.0, Quantity: 7.0,Funds:104742.0, Price Change: 涨
# 0.8223141
# Time: 2023-10-30 09:43:04 - Action: BUY at 14700.0, Quantity: 7.0,Funds:1828.0
# 0.20668976
# Time: 2023-10-30 10:02:32 - Action: SELL at 14705.0, Quantity: 7.0,Funds:104763.0, Price Change: 涨
# 0.845829
# Time: 2023-10-30 10:02:33 - Action: BUY at 14700.0, Quantity: 7.0,Funds:1849.0
# 0.21421565
# Time: 2023-10-30 10:05:32 - Action: SELL at 14685.0, Quantity: 7.0,Funds:104644.0, Price Change: 跌
# 0.8882847
# Time: 2023-10-30 10:05:34 - Action: BUY at 14675.0, Quantity: 7.0,Funds:1905.0
# 0.13110499
# Time: 2023-10-30 10:08:31 - Action: SELL at 14675.0, Quantity: 7.0,Funds:104630.0, Price Change: 平
# 0.8468241
# Time: 2023-10-30 10:08:36 - Action: BUY at 14665.0, Quantity: 7.0,Funds:1961.0
# 0.23549616
# Time: 2023-10-30 10:14:40 - Action: SELL at 14685.0, Quantity: 7.0,Funds:104756.0, Price Change: 涨
# 0.88749963
# Time: 2023-10-30 10:14:43 - Action: BUY at 14675.0, Quantity: 7.0,Funds:2017.0
# 0.22009338
# Time: 2023-10-30 10:37:58 - Action: SELL at 14690.0, Quantity: 7.0,Funds:104847.0, Price Change: 涨
# 0.884436
# Time: 2023-10-30 10:37:58 - Action: BUY at 14680.0, Quantity: 7.0,Funds:2073.0
# 0.116328135
# Time: 2023-10-30 10:42:03 - Action: SELL at 14690.0, Quantity: 7.0,Funds:104903.0, Price Change: 涨
# 0.82767093
# Time: 2023-10-30 10:42:06 - Action: BUY at 14680.0, Quantity: 7.0,Funds:2129.0
# 0.19259383
# Time: 2023-10-30 10:44:15 - Action: SELL at 14690.0, Quantity: 7.0,Funds:104959.0, Price Change: 涨
# 0.82186824
# Time: 2023-10-30 10:44:16 - Action: BUY at 14685.0, Quantity: 7.0,Funds:2150.0
# 0.27465004
# Time: 2023-10-30 10:45:53 - Action: SELL at 14695.0, Quantity: 7.0,Funds:105015.0, Price Change: 涨
# 0.8552666
# Time: 2023-10-30 10:45:53 - Action: BUY at 14690.0, Quantity: 7.0,Funds:2171.0
# 0.22075556
# Time: 2023-10-30 10:54:21 - Action: SELL at 14700.0, Quantity: 7.0,Funds:105071.0, Price Change: 涨
# 0.82106066
# Time: 2023-10-30 10:54:25 - Action: BUY at 14690.0, Quantity: 7.0,Funds:2227.0
# 0.20305026
# Time: 2023-10-30 10:56:59 - Action: SELL at 14700.0, Quantity: 7.0,Funds:105127.0, Price Change: 涨
# 0.86614335
# Time: 2023-10-30 10:57:01 - Action: BUY at 14695.0, Quantity: 7.0,Funds:2248.0
# 0.18734173
# Time: 2023-10-30 11:16:36 - Action: SELL at 14680.0, Quantity: 7.0,Funds:105008.0, Price Change: 跌
# 0.90046394
# Time: 2023-10-30 11:16:39 - Action: BUY at 14670.0, Quantity: 7.0,Funds:2304.0
# 0.2853169
# Time: 2023-10-30 13:30:40 - Action: SELL at 14700.0, Quantity: 7.0,Funds:105204.0, Price Change: 涨
# 0.9066073
# Time: 2023-10-30 13:30:41 - Action: BUY at 14690.0, Quantity: 7.0,Funds:2360.0
# 0.18815736
# Time: 2023-10-30 13:42:01 - Action: SELL at 14705.0, Quantity: 7.0,Funds:105295.0, Price Change: 涨
# 0.8601596
# Time: 2023-10-30 13:42:01 - Action: BUY at 14700.0, Quantity: 7.0,Funds:2381.0
# 0.18479216
# Time: 2023-10-30 13:48:06 - Action: SELL at 14695.0, Quantity: 7.0,Funds:105246.0, Price Change: 跌
# 0.84241235
# Time: 2023-10-30 13:48:10 - Action: BUY at 14690.0, Quantity: 7.0,Funds:2402.0
# 0.1550855
# Time: 2023-10-30 14:01:49 - Action: SELL at 14695.0, Quantity: 7.0,Funds:105267.0, Price Change: 涨
# 0.83553684
# Time: 2023-10-30 14:01:49 - Action: BUY at 14690.0, Quantity: 7.0,Funds:2423.0
# 0.18935269
# Time: 2023-10-30 14:03:42 - Action: SELL at 14700.0, Quantity: 7.0,Funds:105323.0, Price Change: 涨
# 0.80418235
# Time: 2023-10-30 14:03:44 - Action: BUY at 14690.0, Quantity: 7.0,Funds:2479.0
# 0.15910222
# Time: 2023-10-30 14:13:07 - Action: SELL at 14730.0, Quantity: 7.0,Funds:105589.0, Price Change: 涨
# 0.8373985
# Time: 2023-10-30 14:13:19 - Action: BUY at 14715.0, Quantity: 7.0,Funds:2570.0
# 0.16471949
# Time: 2023-10-30 14:16:15 - Action: SELL at 14725.0, Quantity: 7.0,Funds:105645.0, Price Change: 涨
# 0.8396812
# Time: 2023-10-30 14:16:28 - Action: BUY at 14720.0, Quantity: 7.0,Funds:2591.0
# 0.09831465
# Time: 2023-10-30 14:19:05 - Action: SELL at 14710.0, Quantity: 7.0,Funds:105561.0, Price Change: 跌
# 0.8440195
# Time: 2023-10-30 14:19:09 - Action: BUY at 14705.0, Quantity: 7.0,Funds:2612.0
# 0.24574727
# Time: 2023-10-30 14:33:59 - Action: SELL at 14710.0, Quantity: 7.0,Funds:105582.0, Price Change: 涨
# 0.84960926
# Time: 2023-10-30 14:34:22 - Action: BUY at 14700.0, Quantity: 7.0,Funds:2668.0
# 0.17319484
# Time: 2023-10-30 14:38:17 - Action: SELL at 14715.0, Quantity: 7.0,Funds:105673.0, Price Change: 涨
# 0.80583364
# Time: 2023-10-30 14:38:18 - Action: BUY at 14710.0, Quantity: 7.0,Funds:2689.0
# 0.20153782
# Time: 2023-10-30 14:40:18 - Action: SELL at 14710.0, Quantity: 7.0,Funds:105659.0, Price Change: 平
# 0.824752
# Time: 2023-10-30 14:40:58 - Action: BUY at 14700.0, Quantity: 7.0,Funds:2745.0
# 0.1906002
# Time: 2023-10-30 14:47:29 - Action: SELL at 14700.0, Quantity: 7.0,Funds:105645.0, Price Change: 平
# 0.8684594
# Time: 2023-10-30 14:48:21 - Action: BUY at 14705.0, Quantity: 7.0,Funds:2696.0
# 0.21978602
# Time: 2023-10-30 21:00:30 - Action: SELL at 14570.0, Quantity: 7.0,Funds:104686.0, Price Change: 跌
# 0.8348805
# Time: 2023-10-30 21:00:38 - Action: BUY at 14560.0, Quantity: 7.0,Funds:2752.0
# 0.2685105
# Time: 2023-10-30 21:01:47 - Action: SELL at 14565.0, Quantity: 7.0,Funds:104707.0, Price Change: 涨
# 0.8454063
# Time: 2023-10-30 21:01:50 - Action: BUY at 14560.0, Quantity: 7.0,Funds:2773.0
# 0.2537676
# Time: 2023-10-30 21:03:01 - Action: SELL at 14565.0, Quantity: 7.0,Funds:104728.0, Price Change: 涨
# 0.8435895
# Time: 2023-10-30 21:03:04 - Action: BUY at 14560.0, Quantity: 7.0,Funds:2794.0
# 0.2421079
# Time: 2023-10-30 21:04:15 - Action: SELL at 14560.0, Quantity: 7.0,Funds:104714.0, Price Change: 平
# 0.83991265
# Time: 2023-10-30 21:04:18 - Action: BUY at 14555.0, Quantity: 7.0,Funds:2815.0
# 0.29515287
# Time: 2023-10-30 21:07:25 - Action: SELL at 14555.0, Quantity: 7.0,Funds:104700.0, Price Change: 平
# 0.87029
# Time: 2023-10-30 21:07:36 - Action: BUY at 14550.0, Quantity: 7.0,Funds:2836.0
# 0.25467566
# Time: 2023-10-30 21:09:22 - Action: SELL at 14570.0, Quantity: 7.0,Funds:104826.0, Price Change: 涨
# 0.84454846
# Time: 2023-10-30 21:09:24 - Action: BUY at 14565.0, Quantity: 7.0,Funds:2857.0
# 0.28313422
# Time: 2023-10-30 21:10:39 - Action: SELL at 14565.0, Quantity: 7.0,Funds:104812.0, Price Change: 平
# 0.81145084
# Time: 2023-10-30 21:10:41 - Action: BUY at 14555.0, Quantity: 7.0,Funds:2913.0
# 0.23708916
# Time: 2023-10-30 21:12:21 - Action: SELL at 14555.0, Quantity: 7.0,Funds:104798.0, Price Change: 平
# 0.8685879
# Time: 2023-10-30 21:13:02 - Action: BUY at 14555.0, Quantity: 7.0,Funds:2899.0
# 0.2287873
# Time: 2023-10-30 21:15:38 - Action: SELL at 14565.0, Quantity: 7.0,Funds:104854.0, Price Change: 涨
# 0.8437741
# Time: 2023-10-30 21:16:02 - Action: BUY at 14560.0, Quantity: 7.0,Funds:2920.0
# 0.17463154
# Time: 2023-10-30 21:25:50 - Action: SELL at 14600.0, Quantity: 7.0,Funds:105120.0, Price Change: 涨
# 0.83943313
# Time: 2023-10-30 21:25:51 - Action: BUY at 14595.0, Quantity: 7.0,Funds:2941.0
# 0.2945536
# Time: 2023-10-30 21:35:28 - Action: SELL at 14605.0, Quantity: 7.0,Funds:105176.0, Price Change: 涨
# 0.8487067
# Time: 2023-10-30 21:35:35 - Action: BUY at 14600.0, Quantity: 7.0,Funds:2962.0
# 0.1691142
# Time: 2023-10-30 21:45:42 - Action: SELL at 14600.0, Quantity: 7.0,Funds:105162.0, Price Change: 平
# 0.88198256
# Time: 2023-10-30 21:45:48 - Action: BUY at 14590.0, Quantity: 7.0,Funds:3018.0
# 0.19742072
# Time: 2023-10-30 22:13:35 - Action: SELL at 14605.0, Quantity: 7.0,Funds:105253.0, Price Change: 涨
# 0.8166858
# Time: 2023-10-30 22:13:37 - Action: BUY at 14600.0, Quantity: 7.0,Funds:3039.0
# 0.20378278
# Time: 2023-10-30 22:15:54 - Action: SELL at 14600.0, Quantity: 7.0,Funds:105239.0, Price Change: 平
# 0.81005055
# Time: 2023-10-30 22:15:54 - Action: BUY at 14595.0, Quantity: 7.0,Funds:3060.0
# 0.25665718
# Time: 2023-10-30 22:53:53 - Action: SELL at 14600.0, Quantity: 7.0,Funds:105260.0, Price Change: 涨
# 0.8767439
# Time: 2023-10-30 22:54:47 - Action: BUY at 14595.0, Quantity: 7.0,Funds:3081.0
# 0.28178358
# Time: 2023-10-31 00:11:55 - Action: SELL at 14565.0, Quantity: 7.0,Funds:105036.0, Price Change: 跌
# 0.8737733
# Time: 2023-10-31 00:12:06 - Action: BUY at 14560.0, Quantity: 7.0,Funds:3102.0
# 涨    128
# 跌     34
# 平     21
# Name: price_change, dtype: int64
