# %%
import pandas as pd
from enum import Enum, auto

FILENAME = "future_taobao_ssMain_tick"

class open_interest_delta_forward_enum(Enum):
    NONE = auto()
    UNKNOWN = auto()
    EXCHANGE = auto()
    OPENFWDOUBLE = auto()
    OPEN = auto()
    CLOSEFWDOUBLE = auto()
    CLOSE = auto()

class order_forward_enum(Enum):
    UP = auto()
    DOWN = auto()
    MIDDLE = auto()

class tick_type_key_enum(Enum):
    TICKTYPE = auto()
    TICKCOLOR = auto()

class tick_type_enum(Enum):
    NOCHANGE = '无交易'
    UNKNOWN = '未知'
    EXCHANGELONG = '多换'
    EXCHANGESHORT = '空换'
    EXCHANGEUNKOWN = '未知换'
    OPENDOUBLE = '双开'
    OPENLONG = '多开'
    OPENSHORT = '空开'
    OPENUNKOWN = '未知开'
    CLOSEDOUBLE = '双平'
    CLOSESHORT = '空平'
    CLOSELONG = '多平'
    CLOSEUNKOWN = '未知平'

class tick_color_enum(Enum):
    WHITE = '白色'
    RED = '红色'
    GREEN = '绿色'

tick_type_cal_dict = {
    open_interest_delta_forward_enum.NONE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.EXCHANGE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGELONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGESHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPENFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPEN:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENLONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENSHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSEFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSESHORT,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSELONG,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
}

 # Mapping of openclose and price_direction to open_interest_delta_forward_enum and order_forward_enum
openclose_mapping = {
    '换手': open_interest_delta_forward_enum.EXCHANGE,
    '双开': open_interest_delta_forward_enum.OPENFWDOUBLE,
    '开仓': open_interest_delta_forward_enum.OPEN,
    '双平': open_interest_delta_forward_enum.CLOSEFWDOUBLE,  # Assuming definition for 双平
    '平仓': open_interest_delta_forward_enum.CLOSE,
    '无交易': open_interest_delta_forward_enum.NONE,
    '未知':open_interest_delta_forward_enum.UNKNOWN
}

price_direction_mapping = {
    '向上': order_forward_enum.UP,
    '向下': order_forward_enum.DOWN,
    '不变': order_forward_enum.MIDDLE
}

# 枚举到中文的映射
tick_type_to_chinese = {
    tick_type_enum.NOCHANGE: '无交易',
    tick_type_enum.UNKNOWN: '未知',
    tick_type_enum.EXCHANGELONG: '多换',
    tick_type_enum.EXCHANGESHORT: '空换',
    tick_type_enum.EXCHANGEUNKOWN: '未知换',
    tick_type_enum.OPENDOUBLE: '双开',
    tick_type_enum.OPENLONG: '开多',
    tick_type_enum.OPENSHORT: '开空',
    tick_type_enum.OPENUNKOWN: '未知开',
    tick_type_enum.CLOSEDOUBLE: '双平',
    tick_type_enum.CLOSESHORT: '空平',
    tick_type_enum.CLOSELONG: '多平',
    tick_type_enum.CLOSEUNKOWN: '未知平',
}

tick_color_to_chinese = {
    tick_color_enum.WHITE: '白色',
    tick_color_enum.RED: '红色',
    tick_color_enum.GREEN: '绿色',
}


# Load the tick data
df = pd.read_csv(FILENAME+".csv")

# Calculate the deltas for volume and open interest
df['volume_delta'] = df['volume'].diff()
df['open_interest_delta'] = df['open_interest'].diff()

# Initialize columns for open/close position
df['trade_openclose'] = None
df['trade_color'] = None 
df['close_count'] = df['volume_delta']

# Iterate over the DataFrame to assign open/close positions
for i in range(1, len(df)):
    volume_delta = df.loc[i, 'volume_delta']
    open_interest_delta = df.loc[i, 'open_interest_delta']
    last_price = df.loc[i, 'last_price']
    ask_price1 = df.loc[i, 'ask_price1']
    bid_price1 = df.loc[i, 'bid_price1']
    pre_last_price = df.loc[i-1,'last_price']
    pre_ask_price1 = df.loc[i-1, 'ask_price1']
    pre_bid_price1 = df.loc[i-1, 'bid_price1']
    openclose = ''
    price_direction = ''

    # Determine the open/close position
    if volume_delta == open_interest_delta > 0:
        openclose = '双开'
    elif volume_delta > open_interest_delta > 0:
        openclose = '开仓'
    elif volume_delta > abs(open_interest_delta) > 0 and open_interest_delta < 0:
        openclose = '平仓'
    elif volume_delta > 0 and open_interest_delta == 0:
        openclose = '换手'
    elif volume_delta + open_interest_delta == 0 and volume_delta>0:
        openclose = '双平'
    elif volume_delta == 0 and  open_interest_delta == 0:
        openclose = '无交易'
    else:
        openclose = '未知'
    
    # 判断价格方向
    if last_price >= pre_ask_price1:
        price_direction = '向上'
    elif last_price <= pre_bid_price1:
        price_direction = '向下'
    elif last_price >= ask_price1:
        price_direction = '向上'
    elif last_price <= bid_price1:
        price_direction = '向下'
    else:
        price_direction = '不变'
        
   

    # Convert openclose and price_direction to their corresponding enum values
    delta_enum = openclose_mapping.get(openclose, open_interest_delta_forward_enum.NONE)
    direction_enum = price_direction_mapping.get(price_direction, order_forward_enum.MIDDLE)

    # Retrieve the tick type and color based on the mappings
    tick_info = tick_type_cal_dict.get(delta_enum, {}).get(direction_enum, {})
    tick_type = tick_info.get(tick_type_key_enum.TICKTYPE, tick_type_enum.UNKNOWN)
    tick_color = tick_info.get(tick_type_key_enum.TICKCOLOR, tick_color_enum.WHITE)
    

    # 使用映射转换为中文描述
    tick_type_chinese = tick_type_to_chinese[tick_type]
    tick_color_chinese = tick_color_to_chinese[tick_color]

    # 更新DataFrame
    df.at[i, 'trade_openclose'] = tick_type_chinese
    df.at[i, 'trade_color'] = tick_color_chinese

# Save the modified DataFrame to a new CSV file
df.to_csv(FILENAME+"_withopenclose.csv", index=False)

# %%
import pandas as pd

# 假设已加载并准备好DataFrame df
df = pd.read_csv(FILENAME+"_withopenclose.csv")

df = df.loc[df['volume_delta'] > 0]
# 重置索引以确保从0开始
df.reset_index(drop=True, inplace=True)


guess_tick=100

# 初始化列用于标记交易机会
df['buy_opportunity'] = 0
df['sell_opportunity'] = 0
trade_hand=1

# 为每个tick计算未来100个tick内与当前挂单价格相匹配的成交量
for i in range(len(df)):
    if i + guess_tick >= len(df):  # 确保未来有足够的tick进行分析
        break

    # 当前的买一和卖一价
    current_ask_price1 = df.loc[i, 'ask_price1']
    current_bid_price1 = df.loc[i, 'bid_price1']

    # 初始化对应价格的成交量计数
    matching_buy_volume = 0
    matching_sell_volume = 0
    
    buy_done = 0
    sell_done = 0

    # 遍历未来100个tick
    for j in range(i+1, i+guess_tick+1):
        if df.loc[j, 'bid_price1']<current_bid_price1:
            buy_done = 1 
        if df.loc[j, 'ask_price1']>current_ask_price1:
            sell_done = 1 
        # 如果未来tick的买一价等于当前tick的买一价，累加成交量
        if df.loc[j, 'bid_price1'] == current_bid_price1 and df.loc[j, 'bid_price1'] == df.loc[j, 'last_price']:
            matching_buy_volume += df.loc[j, 'volume_delta']
        # 如果未来tick的卖一价等于当前tick的卖一价，累加成交量
        if df.loc[j, 'ask_price1'] == current_ask_price1 and df.loc[j, 'ask_price1'] == df.loc[j, 'last_price']:
            matching_sell_volume += df.loc[j, 'volume_delta']

    # 判断是否存在买卖机会
    if buy_done==1 or matching_buy_volume >= df.loc[i, 'ask_volume1']+trade_hand:
        df.loc[i, 'buy_opportunity'] = 1
    if sell_done==1 or matching_sell_volume >= df.loc[i, 'bid_volume1']+trade_hand:
        df.loc[i, 'sell_opportunity'] = 1


# 创建一个新列来标记同时为买卖机会的tick
df['dual_opportunity'] = ((df['buy_opportunity'] == 1) & (df['sell_opportunity'] == 1)).astype(int)

# 计算同时为买卖机会的总数
dual_opportunities_count = df['dual_opportunity'].sum()

# 计算比例
total_ticks_analyzed = len(df) - guess_tick
dual_opportunities_ratio = dual_opportunities_count / total_ticks_analyzed

print(f"Dual opportunities count: {dual_opportunities_count}")
print(f"Dual opportunities ratio: {dual_opportunities_ratio:.4f}")

# 保存到新的CSV文件
df.to_csv(FILENAME+"_with_opportunities.csv", index=False)
# Out:
# Dual opportunities count: 310773
# Dual opportunities ratio: 0.5481

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score,precision_score


# 加载数据
data = pd.read_csv(FILENAME+"_with_opportunities.csv")

data_clean = data.dropna().copy()  # 创建一个副本以避免警告

# features = [
#     'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
#     'bid_price1', 'ask_price1', 'bid_price2', 'ask_price2', 'bid_price3', 'ask_price3',
#     'bid_price4', 'ask_price4', 'bid_price5', 'ask_price5', 'bid_volume1', 'bid_volume2',
#     'bid_volume3', 'bid_volume4', 'bid_volume5', 'ask_volume1', 'ask_volume2', 'ask_volume3',
#     'ask_volume4', 'ask_volume5'
# ]
features = [
    'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
    'bid_price1', 'ask_price1', 'bid_volume1', 'ask_volume1'
]
# 计算短期量价特征

# window_size = 500  # 用于特征计算的窗口大小
# # 特征生成
# data_clean['rolling_mean'] = data_clean['last_price'].rolling(window=window_size).mean()
# data_clean['rolling_std'] = data_clean['last_price'].rolling(window=window_size).std()
# # RSI计算
# delta = data_clean['last_price'].diff()
# gain = (delta.where(delta > 0, 0)).fillna(0)
# loss = (-delta.where(delta < 0, 0)).fillna(0)
# avg_gain = gain.rolling(window=window_size).mean()
# avg_loss = loss.rolling(window=window_size).mean()
# rs = avg_gain / avg_loss
# data_clean['RSI'] = 100 - (100 / (1 + rs))
# # MACD计算
# short_ema = data_clean['last_price'].ewm(span=int(window_size/2), adjust=False).mean()  # 使用窗口大小的一半作为短期EMA
# long_ema = data_clean['last_price'].ewm(span=window_size, adjust=False).mean()  # 使用整个窗口大小作为长期EMA
# data_clean['MACD'] = short_ema - long_ema
# data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=int(window_size/3), adjust=False).mean()  # 使用窗口大小的三分之一作为信号线
# # 删除因计算滚动特征而产生的NaN值
# data_clean.dropna(inplace=True)
# # 添加新特征到特征列表
# features.extend(['rolling_mean', 'rolling_std', 'RSI', 'MACD', 'MACD_signal'])


# 目标列处理
data_clean['successful_trade'] = data_clean.apply(
    lambda row: 1 if row['buy_opportunity'] and row['sell_opportunity'] else 0, axis=1
)

X = data_clean[['datetime'] + features]
y = data_clean['successful_trade']

# 数据切分
split_start = int(len(data_clean) * 0)
split_point = int(len(data_clean) * 0.7)
X_train = X.iloc[split_start:split_point]
y_train = y.iloc[split_start:split_point]
X_test = X.iloc[split_point:]
y_test = y.iloc[split_point:]

# 模型训练
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# 注意：随机森林模型不能直接处理datetime类型的特征，所以在训练前需要去除或转换该特征
X_train_features = X_train.drop(columns=['datetime'])
X_test_features = X_test.drop(columns=['datetime'])
rf_model.fit(X_train_features, y_train)

# 获取属于类别1的概率
y_pred_proba = rf_model.predict_proba(X_test_features)[:, 1]
# 设置交易阈值
trade_threshold = 0.6
# 根据阈值生成预测结果，大于等于阈值预测为1，否则为0
y_pred_threshold = (y_pred_proba >= trade_threshold).astype(int)
# 计算查准率
precision = precision_score(y_test, y_pred_threshold)
print(f"Precision: {precision}")

# 对照组评估（全1预测）
predictions_all_ones = [1] * len(y_test)
print("All Ones Accuracy:", precision_score(y_test, predictions_all_ones))
# Out:
# Precision: 0.7385375029391018
# All Ones Accuracy: 0.5026569168008841

# %%
from datetime import datetime, time

guess_tick = 100
profit = 0  # 盈利
trade_threshold = 0.6 # 交易阈值
trade_hand = 1
trade_gap = 5 #每跳多少钱
hand_volume = 5  # 不锈钢1手5吨，1手开仓2元，平今0元
hand_fee = 2
done_count = 0
count = 0
daily_profit = {}  # 新增：用于存储每日盈利

def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False

# 定义时间范围数组
notrade_time = ["09:00-09:10","11:20-11:30","13:30-13:40","14:50-15:00","21:00-21:10","0:00-1:00"]

i = 0
while i < len(X_test) - guess_tick:
    datetime_str = str(X_test.iloc[i]['datetime'])
    date_str = datetime_str.split(' ')[0]  # 新增：提取日期字符串

    if '.' in datetime_str:
        # 如果有小数点，分割为主时间部分和纳秒部分
        time, nano_part = datetime_str.split('.')
    else:
        # 如果没有小数点，则没有纳秒部分
        time = datetime_str
        nano_part = '0'
    if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S").time(), notrade_time):
        i = i+1
        continue
    proba = y_pred_proba[i]
    if proba > trade_threshold:
        current_ask_price1 = X_test.iloc[i]['ask_price1']
        current_bid_price1 = X_test.iloc[i]['bid_price1']
        if current_ask_price1-current_bid_price1!=trade_gap:
            i = i+1
            continue

        matching_buy_volume = 0
        matching_sell_volume = 0
        buy_done = 0
        sell_done = 0
        for j in range(i + 1, i + guess_tick+1):
            future_tick = X_test.iloc[j]
            if future_tick['bid_price1'] < current_bid_price1:
                buy_done = 1
            if future_tick['ask_price1'] > current_ask_price1:
                sell_done = 1
            if future_tick['bid_price1'] == current_bid_price1 and future_tick['last_price'] == current_bid_price1:
                matching_sell_volume += future_tick['volume_delta']
            if future_tick['ask_price1'] == current_ask_price1 and future_tick['last_price'] == current_ask_price1:
                matching_buy_volume += future_tick['volume_delta']

        stop_loss_tick = i + guess_tick
        stop_loss_price_bid = X_test.iloc[stop_loss_tick]['bid_price1']
        stop_loss_price_ask = X_test.iloc[stop_loss_tick]['ask_price1']
        count = count +1
        # 判断是否存在买卖机会
        if (buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand) and \
        (sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand):
            trade_profit = (current_ask_price1 - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            done_count = done_count + 1
            print(datetime_str)
            print(trade_profit)
        elif buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand:
            trade_profit = (stop_loss_price_bid - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            print(datetime_str)
            print(trade_profit)
        elif sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand:
            trade_profit = (current_ask_price1 - stop_loss_price_ask) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            print(datetime_str)
            print(trade_profit)
        else:
            i = i + 1

        i = stop_loss_tick
    else:
        i = i + 1

# 打印每一天的盈利
for date, daily_profit in daily_profit.items():
    print(f"{date}: {daily_profit:.2f}")

print(f"Final profit: {profit:.2f}")
print(done_count/count)
print(count)
# Out:
# 2024-02-05 14:34:07.500000000
# 23
# 1
# 2024-02-05 14:39:22.000000000
# 23
# 2
# 2024-02-05 14:44:09.500000000
# 23
# 3
# 2024-02-05 14:47:14.500000000
# 23
# 4
# 2024-02-05 21:10:02.500000000
# 23
# 5
# 2024-02-05 21:11:33.000000000
# -52
# 6
# 2024-02-05 21:12:46.000000000
# 23
# 7
# 2024-02-05 21:15:07.000000000
# 23
# 8
# 2024-02-05 21:17:35.000000000
# 23
# 9
# 2024-02-05 21:21:52.000000000
# 23
# 10
# 2024-02-05 21:26:35.500000000
# 23
# 11
# 2024-02-05 21:28:01.000000000
# 23
# 12
# 2024-02-05 21:29:43.500000000
# 23
# 13
# 2024-02-05 21:34:39.000000000
# 23
# 14
# 2024-02-05 21:38:08.000000000
# 23
# 15
# 2024-02-05 21:43:14.000000000
# 23
# 16
# 2024-02-05 21:47:33.500000000
# 23
# 17
# 2024-02-05 21:51:33.000000000
# 23
# 18
# 2024-02-05 21:56:08.500000000
# -27
# 19
# 2024-02-05 21:59:57.500000000
# 23
# 20
# 2024-02-05 22:04:24.000000000
# -52
# 21
# 2024-02-05 22:10:45.500000000
# 23
# 22
# 2024-02-05 22:16:47.500000000
# 23
# 23
# 2024-02-05 22:22:05.000000000
# 23
# 24
# 2024-02-05 22:28:34.000000000
# -52
# 25
# 2024-02-05 22:35:59.500000000
# -52
# 26
# 2024-02-05 22:45:52.500000000
# -77
# 27
# 2024-02-05 22:53:55.500000000
# 23
# 28
# 2024-02-05 22:59:46.000000000
# 23
# 29
# 2024-02-05 23:04:27.500000000
# 23
# 30
# 2024-02-05 23:22:24.500000000
# 23
# 31
# 2024-02-05 23:38:20.000000000
# 23
# 32
# 2024-02-06 09:10:03.000000000
# 23
# 33
# 2024-02-06 09:13:10.000000000
# 23
# 34
# 2024-02-06 09:15:42.500000000
# 23
# 35
# 2024-02-06 09:18:23.000000000
# -77
# 36
# 2024-02-06 09:21:54.000000000
# -127
# 37
# 2024-02-06 09:23:40.000000000
# 23
# 38
# 2024-02-06 09:26:12.000000000
# -27
# 39
# 2024-02-06 09:28:20.500000000
# -52
# 40
# 2024-02-06 09:29:25.000000000
# 23
# 41
# 2024-02-06 09:31:04.000000000
# 23
# 42
# 2024-02-06 09:34:16.500000000
# 23
# 43
# 2024-02-06 09:37:45.500000000
# 23
# 44
# 2024-02-06 09:40:48.500000000
# 23
# 45
# 2024-02-06 09:46:02.500000000
# 23
# 46
# 2024-02-06 09:49:29.500000000
# 23
# 47
# 2024-02-06 09:52:34.500000000
# -77
# 48
# 2024-02-06 09:54:34.500000000
# 23
# 49
# 2024-02-06 10:00:40.000000000
# 23
# 50
# 2024-02-06 10:04:44.000000000
# 23
# 51
# 2024-02-06 10:10:18.000000000
# -77
# 52
# 2024-02-06 10:30:03.500000000
# 23
# 53
# 2024-02-06 10:35:36.000000000
# 23
# 54
# 2024-02-06 10:39:37.000000000
# 23
# 55
# 2024-02-06 10:46:51.000000000
# 23
# 56
# 2024-02-06 10:49:06.000000000
# 23
# 57
# 2024-02-06 10:50:39.000000000
# 23
# 58
# 2024-02-06 10:51:53.000000000
# 23
# 59
# 2024-02-06 10:57:08.000000000
# -52
# 60
# 2024-02-06 11:04:10.500000000
# 23
# 61
# 2024-02-06 11:10:06.500000000
# -77
# 62
# 2024-02-06 11:14:35.000000000
# 23
# 63
# 2024-02-06 13:40:19.000000000
# -177
# 64
# 2024-02-06 13:42:38.500000000
# 23
# 65
# 2024-02-06 13:44:28.000000000
# 23
# 66
# 2024-02-06 13:47:17.500000000
# 23
# 67
# 2024-02-06 13:50:20.000000000
# -52
# 68
# 2024-02-06 13:53:36.500000000
# 23
# 69
# 2024-02-06 13:56:48.500000000
# 23
# 70
# 2024-02-06 13:59:38.500000000
# 23
# 71
# 2024-02-06 14:04:07.000000000
# 23
# 72
# 2024-02-06 14:09:11.500000000
# 23
# 73
# 2024-02-06 14:13:40.500000000
# 23
# 74
# 2024-02-06 14:17:21.000000000
# 23
# 75
# 2024-02-06 14:22:26.000000000
# 23
# 76
# 2024-02-06 14:26:54.500000000
# 23
# 77
# 2024-02-06 14:32:01.000000000
# 23
# 78
# 2024-02-06 14:37:28.000000000
# 23
# 79
# 2024-02-06 14:44:47.500000000
# 23
# 80
# 2024-02-06 14:49:50.000000000
# 23
# 81
# 2024-02-06 21:10:06.000000000
# 23
# 82
# 2024-02-06 21:11:54.000000000
# 23
# 83
# 2024-02-06 21:13:54.000000000
# 23
# 84
# 2024-02-06 21:16:02.000000000
# 23
# 85
# 2024-02-06 21:18:06.000000000
# 23
# 86
# 2024-02-06 21:21:30.000000000
# 23
# 87
# 2024-02-06 21:25:52.000000000
# 23
# 88
# 2024-02-06 21:30:25.500000000
# 23
# 89
# 2024-02-06 21:38:01.000000000
# -52
# 90
# 2024-02-06 21:39:42.500000000
# -27
# 91
# 2024-02-06 21:42:06.500000000
# 23
# 92
# 2024-02-06 21:46:25.500000000
# -52
# 93
# 2024-02-06 21:51:25.000000000
# 23
# 94
# 2024-02-06 21:56:01.000000000
# 23
# 95
# 2024-02-06 22:01:40.000000000
# 23
# 96
# 2024-02-06 22:08:10.000000000
# 23
# 97
# 2024-02-06 22:16:55.000000000
# 23
# 98
# 2024-02-06 22:26:01.000000000
# -27
# 99
# 2024-02-06 22:28:51.500000000
# 23
# 100
# 2024-02-06 22:31:39.500000000
# -27
# 101
# 2024-02-06 22:35:56.000000000
# 23
# 102
# 2024-02-06 22:41:00.000000000
# 23
# 103
# 2024-02-06 22:45:46.000000000
# -2
# 104
# 2024-02-06 22:47:44.000000000
# 23
# 105
# 2024-02-06 22:49:54.000000000
# 23
# 106
# 2024-02-06 22:51:52.000000000
# 23
# 107
# 2024-02-06 22:56:02.000000000
# 23
# 108
# 2024-02-06 23:00:03.500000000
# 23
# 109
# 2024-02-06 23:06:11.500000000
# 23
# 110
# 2024-02-06 23:14:12.500000000
# 23
# 111
# 2024-02-06 23:30:03.000000000
# 23
# 112
# 2024-02-06 23:39:36.500000000
# 23
# 113
# 2024-02-06 23:58:38.000000000
# 23
# 114
# 2024-02-07 09:10:22.500000000
# 23
# 115
# 2024-02-07 09:13:31.000000000
# 23
# 116
# 2024-02-07 09:18:35.000000000
# 23
# 117
# 2024-02-07 09:26:32.500000000
# 23
# 118
# 2024-02-07 09:31:30.500000000
# 23
# 119
# 2024-02-07 09:34:27.000000000
# -127
# 120
# 2024-02-07 09:39:11.500000000
# 23
# 121
# 2024-02-07 09:42:52.000000000
# 23
# 122
# 2024-02-07 09:47:18.500000000
# 23
# 123
# 2024-02-07 09:51:15.500000000
# 23
# 124
# 2024-02-07 09:55:46.500000000
# 23
# 125
# 2024-02-07 10:03:51.000000000
# 23
# 126
# 2024-02-07 10:10:13.000000000
# 23
# 127
# 2024-02-07 10:32:07.500000000
# -77
# 128
# 2024-02-07 10:37:41.500000000
# 23
# 129
# 2024-02-07 10:42:34.000000000
# 23
# 130
# 2024-02-07 10:47:36.500000000
# 23
# 131
# 2024-02-07 10:57:05.000000000
# 23
# 132
# 2024-02-07 10:58:16.000000000
# 23
# 133
# 2024-02-07 10:59:36.000000000
# 23
# 134
# 2024-02-07 11:00:47.500000000
# -52
# 135
# 2024-02-07 11:02:52.000000000
# 23
# 136
# 2024-02-07 11:05:46.000000000
# 23
# 137
# 2024-02-07 11:09:16.000000000
# -52
# 138
# 2024-02-07 11:13:02.500000000
# -52
# 139
# 2024-02-07 11:17:19.000000000
# 23
# 140
# 2024-02-07 13:41:00.000000000
# 23
# 141
# 2024-02-07 13:43:02.500000000
# 23
# 142
# 2024-02-07 13:44:39.500000000
# 23
# 143
# 2024-02-07 13:47:09.000000000
# 23
# 144
# 2024-02-07 13:50:43.500000000
# 23
# 145
# 2024-02-07 13:54:48.000000000
# 23
# 146
# 2024-02-07 13:59:05.000000000
# -52
# 147
# 2024-02-07 14:03:07.500000000
# 23
# 148
# 2024-02-07 14:06:46.500000000
# 23
# 149
# 2024-02-07 14:12:01.500000000
# 23
# 150
# 2024-02-07 14:19:07.000000000
# 23
# 151
# 2024-02-07 14:24:49.500000000
# 23
# 152
# 2024-02-07 14:29:19.000000000
# 23
# 153
# 2024-02-07 14:33:26.000000000
# 23
# 154
# 2024-02-07 14:38:46.500000000
# 23
# 155
# 2024-02-07 14:42:43.500000000
# 23
# 156
# 2024-02-07 14:46:07.000000000
# 23
# 157
# 2024-02-07 14:49:47.500000000
# 23
# 158
# 2024-02-07 21:10:06.000000000
# 23
# 159
# 2024-02-07 21:12:43.500000000
# 23
# 160
# 2024-02-07 21:14:58.000000000
# 23
# 161
# 2024-02-07 21:17:18.000000000
# 23
# 162
# 2024-02-07 21:20:27.000000000
# 23
# 163
# 2024-02-07 21:23:23.000000000
# -27
# 164
# 2024-02-07 21:29:32.500000000
# 23
# 165
# 2024-02-07 21:32:41.000000000
# 23
# 166
# 2024-02-07 21:36:05.000000000
# 23
# 167
# 2024-02-07 21:43:48.500000000
# 23
# 168
# 2024-02-07 21:50:41.500000000
# 23
# 169
# 2024-02-07 21:55:18.500000000
# 23
# 170
# 2024-02-07 22:01:01.500000000
# -102
# 171
# 2024-02-07 22:08:34.000000000
# 23
# 172
# 2024-02-07 22:12:45.500000000
# 23
# 173
# 2024-02-07 22:20:42.500000000
# 23
# 174
# 2024-02-07 22:26:03.500000000
# -77
# 175
# 2024-02-07 22:30:22.500000000
# 23
# 176
# 2024-02-07 22:37:32.000000000
# 23
# 177
# 2024-02-07 22:43:44.500000000
# 23
# 178
# 2024-02-07 22:46:16.500000000
# 23
# 179
# 2024-02-07 22:51:27.000000000
# 23
# 180
# 2024-02-07 22:58:15.000000000
# 23
# 181
# 2024-02-07 23:00:47.000000000
# 23
# 182
# 2024-02-07 23:05:37.500000000
# 23
# 183
# 2024-02-07 23:13:45.000000000
# 23
# 184
# 2024-02-07 23:26:42.000000000
# 23
# 185
# 2024-02-07 23:47:12.500000000
# -52
# 186
# 2024-02-07 23:59:54.000000000
# 23
# 187
# 2024-02-08 09:10:04.500000000
# -52
# 188
# 2024-02-08 09:11:09.000000000
# -77
# 189
# 2024-02-08 09:12:35.000000000
# -52
# 190
# 2024-02-08 09:20:06.500000000
# 23
# 191
# 2024-02-08 09:29:06.000000000
# 23
# 192
# 2024-02-08 09:33:33.000000000
# -27
# 193
# 2024-02-08 09:37:03.000000000
# -102
# 194
# 2024-02-08 09:41:13.500000000
# 23
# 195
# 2024-02-08 09:45:07.500000000
# 23
# 196
# 2024-02-08 09:50:33.000000000
# 23
# 197
# 2024-02-08 09:54:25.000000000
# 23
# 198
# 2024-02-08 09:58:33.000000000
# 23
# 199
# 2024-02-08 10:05:26.500000000
# 23
# 200
# 2024-02-08 10:11:08.000000000
# 23
# 201
# 2024-02-08 10:31:49.500000000
# 23
# 202
# 2024-02-08 10:37:12.000000000
# 23
# 203
# 2024-02-08 10:46:00.500000000
# 23
# 204
# 2024-02-08 10:52:09.500000000
# -102
# 205
# 2024-02-08 10:57:17.000000000
# -77
# 206
# 2024-02-08 11:00:47.000000000
# 23
# 207
# 2024-02-08 11:05:03.500000000
# 23
# 208
# 2024-02-08 11:11:48.000000000
# 23
# 209
# 2024-02-08 13:40:01.000000000
# 23
# 210
# 2024-02-08 13:45:27.000000000
# 23
# 211
# 2024-02-08 13:51:05.000000000
# 23
# 212
# 2024-02-08 13:56:21.500000000
# 23
# 213
# 2024-02-08 14:00:01.000000000
# 23
# 214
# 2024-02-08 14:04:23.000000000
# 23
# 215
# 2024-02-08 14:10:17.500000000
# 23
# 216
# 2024-02-08 14:16:15.500000000
# 23
# 217
# 2024-02-08 14:24:03.500000000
# 23
# 218
# 2024-02-08 14:29:04.000000000
# 23
# 219
# 2024-02-08 14:33:47.000000000
# -102
# 220
# 2024-02-08 14:38:15.000000000
# -102
# 221
# 2024-02-08 14:41:53.500000000
# 23
# 222
# 2024-02-08 14:44:34.500000000
# 23
# 223
# 2024-02-08 14:47:55.000000000
# 23
# 224
# 2024-02-08 14:49:30.000000000
# -52
# 225
# 2024-02-19 09:10:25.500000000
# 23
# 226
# 2024-02-19 09:12:07.000000000
# 23
# 227
# 2024-02-19 09:13:37.500000000
# 23
# 228
# 2024-02-19 09:15:01.500000000
# 23
# 229
# 2024-02-19 09:16:22.000000000
# 23
# 230
# 2024-02-19 09:18:14.000000000
# 23
# 231
# 2024-02-19 09:21:06.000000000
# -52
# 232
# 2024-02-19 09:22:55.500000000
# 23
# 233
# 2024-02-19 09:24:38.500000000
# -27
# 234
# 2024-02-19 09:26:36.000000000
# 23
# 235
# 2024-02-19 09:29:24.500000000
# 23
# 236
# 2024-02-19 09:31:59.000000000
# 23
# 237
# 2024-02-19 09:33:39.000000000
# 23
# 238
# 2024-02-19 09:36:13.000000000
# 23
# 239
# 2024-02-19 09:38:28.000000000
# 23
# 240
# 2024-02-19 09:40:53.500000000
# 23
# 241
# 2024-02-19 09:42:55.000000000
# 23
# 242
# 2024-02-19 09:45:01.500000000
# 23
# 243
# 244
# 2024-02-19 09:55:55.000000000
# 23
# 245
# 2024-02-19 09:59:39.000000000
# 23
# 246
# 2024-02-19 10:02:30.500000000
# -52
# 247
# 2024-02-19 10:05:44.000000000
# 23
# 248
# 2024-02-19 10:10:10.500000000
# 23
# 249
# 2024-02-19 10:31:06.000000000
# 23
# 250
# 2024-02-19 10:34:17.000000000
# 23
# 251
# 2024-02-19 10:37:06.500000000
# 23
# 252
# 2024-02-19 10:39:57.500000000
# 23
# 253
# 2024-02-19 10:42:33.000000000
# -52
# 254
# 2024-02-19 10:47:11.500000000
# -27
# 255
# 2024-02-19 10:53:46.500000000
# 23
# 256
# 2024-02-19 10:57:28.500000000
# -52
# 257
# 2024-02-19 11:06:21.500000000
# 23
# 258
# 2024-02-19 11:11:26.500000000
# 23
# 259
# 2024-02-19 11:15:53.000000000
# 23
# 260
# 2024-02-19 13:40:03.000000000
# 23
# 261
# 2024-02-19 13:42:01.500000000
# 23
# 262
# 2024-02-19 13:45:23.500000000
# 23
# 263
# 2024-02-19 13:50:01.500000000
# 23
# 264
# 2024-02-19 13:54:16.000000000
# 23
# 265
# 2024-02-19 13:56:27.500000000
# 23
# 266
# 2024-02-19 13:59:06.000000000
# 23
# 267
# 2024-02-19 14:01:06.500000000
# 23
# 268
# 2024-02-19 14:03:52.000000000
# 23
# 269
# 2024-02-19 14:06:47.000000000
# 23
# 270
# 2024-02-19 14:09:27.000000000
# 23
# 271
# 2024-02-19 14:11:25.000000000
# 23
# 272
# 2024-02-19 14:13:44.500000000
# 23
# 273
# 2024-02-19 14:15:12.000000000
# 23
# 274
# 2024-02-19 14:17:51.500000000
# 23
# 275
# 2024-02-19 14:20:10.000000000
# -102
# 276
# 2024-02-19 14:21:55.000000000
# 23
# 277
# 2024-02-19 14:23:17.000000000
# -52
# 278
# 2024-02-19 14:25:00.000000000
# 23
# 279
# 2024-02-19 14:29:46.000000000
# 23
# 280
# 2024-02-19 14:32:30.000000000
# -27
# 281
# 2024-02-19 14:35:58.500000000
# 23
# 282
# 2024-02-19 14:40:33.000000000
# -77
# 283
# 2024-02-19 14:44:01.500000000
# -77
# 284
# 2024-02-19 14:46:15.500000000
# 23
# 285
# 2024-02-19 14:47:30.500000000
# -77
# 286
# 2024-02-19 14:49:41.000000000
# -27
# 287
# 2024-02-19 21:10:01.500000000
# 23
# 288
# 2024-02-19 21:11:50.000000000
# -52
# 289
# 2024-02-19 21:13:18.500000000
# 23
# 290
# 2024-02-19 21:16:48.000000000
# -27
# 291
# 2024-02-19 21:18:44.500000000
# 23
# 292
# 2024-02-19 21:20:54.500000000
# -27
# 293
# 2024-02-19 21:24:26.500000000
# 23
# 294
# 2024-02-19 21:30:36.000000000
# -52
# 295
# 2024-02-19 21:33:06.500000000
# 23
# 296
# 2024-02-19 21:34:49.500000000
# -77
# 297
# 2024-02-19 21:36:36.500000000
# 23
# 298
# 2024-02-19 21:38:11.000000000
# 23
# 299
# 2024-02-19 21:39:36.000000000
# -52
# 300
# 2024-02-19 21:41:18.500000000
# 23
# 301
# 2024-02-19 21:43:30.500000000
# -27
# 302
# 2024-02-19 21:45:58.500000000
# 23
# 303
# 2024-02-19 21:47:15.500000000
# 23
# 304
# 2024-02-19 21:51:21.000000000
# -2
# 305
# 2024-02-19 21:54:53.000000000
# 23
# 306
# 2024-02-19 21:58:41.500000000
# 23
# 307
# 2024-02-19 22:00:28.000000000
# -27
# 308
# 2024-02-19 22:04:01.500000000
# 23
# 309
# 2024-02-19 22:07:55.000000000
# 23
# 310
# 2024-02-19 22:11:39.500000000
# 23
# 311
# 2024-02-19 22:13:24.000000000
# 23
# 312
# 2024-02-19 22:15:01.500000000
# -52
# 313
# 2024-02-19 22:20:41.500000000
# 23
# 314
# 2024-02-19 22:23:55.000000000
# -52
# 315
# 2024-02-19 22:27:32.500000000
# 23
# 316
# 2024-02-19 22:30:06.500000000
# 23
# 317
# 2024-02-19 22:32:41.000000000
# -52
# 318
# 2024-02-19 22:35:37.500000000
# 23
# 319
# 2024-02-19 22:37:39.000000000
# 23
# 320
# 2024-02-19 22:45:07.500000000
# 23
# 321
# 2024-02-19 22:51:24.000000000
# 23
# 322
# 2024-02-19 22:58:28.000000000
# -52
# 323
# 2024-02-19 23:03:00.000000000
# -27
# 324
# 2024-02-19 23:06:09.000000000
# -27
# 325
# 2024-02-19 23:12:30.500000000
# -27
# 326
# 2024-02-19 23:15:23.500000000
# 23
# 327
# 2024-02-19 23:22:40.000000000
# -27
# 328
# 2024-02-19 23:35:02.000000000
# 23
# 329
# 2024-02-19 23:45:51.500000000
# 23
# 330
# 2024-02-20 09:10:23.000000000
# 23
# 331
# 2024-02-20 09:14:20.000000000
# 23
# 332
# 2024-02-20 09:15:58.500000000
# 23
# 333
# 2024-02-20 09:18:19.000000000
# 23
# 334
# 2024-02-20 09:21:30.500000000
# -77
# 335
# 2024-02-20 09:23:39.500000000
# 23
# 336
# 2024-02-20 09:27:05.000000000
# -52
# 337
# 2024-02-20 09:29:49.000000000
# 23
# 338
# 2024-02-20 09:31:53.000000000
# 23
# 339
# 2024-02-20 09:34:01.500000000
# 23
# 340
# 2024-02-20 09:36:54.500000000
# 23
# 341
# 2024-02-20 09:39:32.500000000
# -27
# 342
# 2024-02-20 09:45:05.000000000
# 23
# 343
# 2024-02-20 09:47:54.000000000
# 23
# 344
# 2024-02-20 09:53:03.000000000
# -52
# 345
# 2024-02-20 09:59:10.500000000
# 23
# 346
# 2024-02-20 10:04:41.000000000
# -127
# 347
# 2024-02-20 10:08:39.000000000
# 23
# 348
# 2024-02-20 10:10:57.500000000
# 23
# 349
# 2024-02-20 10:14:57.000000000
# 23
# 350
# 2024-02-20 10:36:25.500000000
# 23
# 351
# 2024-02-20 10:42:57.000000000
# 23
# 352
# 2024-02-20 10:49:48.000000000
# 23
# 353
# 2024-02-20 10:54:37.000000000
# 23
# 354
# 2024-02-20 10:56:42.500000000
# 23
# 355
# 2024-02-20 10:58:48.000000000
# 23
# 356
# 2024-02-20 11:00:42.000000000
# 23
# 357
# 2024-02-20 11:02:32.500000000
# 23
# 358
# 2024-02-20 11:03:48.500000000
# -27
# 359
# 2024-02-20 11:06:18.000000000
# -52
# 360
# 2024-02-20 11:11:15.000000000
# 23
# 361
# 2024-02-20 11:17:24.000000000
# 23
# 362
# 2024-02-20 11:19:41.000000000
# 23
# 363
# 2024-02-20 13:42:29.500000000
# -2
# 364
# 2024-02-20 13:45:55.500000000
# -27
# 365
# 2024-02-20 13:50:49.500000000
# -52
# 366
# 2024-02-20 13:53:41.000000000
# -27
# 367
# 2024-02-20 13:55:53.500000000
# -27
# 368
# 2024-02-20 13:58:14.000000000
# -2
# 369
# 2024-02-20 14:04:52.000000000
# -52
# 370
# 2024-02-20 14:11:28.000000000
# 23
# 371
# 2024-02-20 14:15:24.500000000
# 23
# 372
# 2024-02-20 14:22:08.500000000
# -27
# 373
# 2024-02-20 14:32:39.000000000
# 23
# 374
# 2024-02-20 14:38:20.000000000
# 23
# 375
# 2024-02-20 14:42:34.500000000
# -52
# 376
# 2024-02-20 14:46:45.500000000
# -27
# 377
# 2024-02-20 21:10:49.000000000
# -27
# 378
# 2024-02-20 21:13:52.500000000
# -52
# 379
# 2024-02-20 21:15:34.000000000
# 23
# 380
# 2024-02-20 21:17:08.500000000
# 23
# 381
# 2024-02-20 21:21:09.500000000
# 23
# 382
# 2024-02-20 21:25:23.000000000
# -27
# 383
# 2024-02-20 21:28:58.500000000
# 23
# 384
# 2024-02-20 21:33:02.000000000
# -52
# 385
# 2024-02-20 21:37:47.000000000
# -27
# 386
# 2024-02-20 21:41:43.500000000
# -52
# 387
# 2024-02-20 21:44:38.000000000
# 23
# 388
# 2024-02-20 21:47:44.500000000
# 23
# 389
# 2024-02-20 21:54:12.000000000
# 23
# 390
# 2024-02-20 22:03:46.000000000
# -52
# 391
# 2024-02-20 22:07:19.500000000
# 23
# 392
# 2024-02-20 22:11:41.000000000
# -27
# 393
# 2024-02-20 22:16:45.500000000
# -52
# 394
# 2024-02-20 22:21:19.500000000
# 23
# 395
# 2024-02-20 22:27:48.000000000
# 23
# 396
# 2024-02-20 22:29:46.500000000
# 23
# 397
# 2024-02-20 22:32:46.500000000
# -52
# 398
# 2024-02-20 22:40:31.000000000
# 23
# 399
# 2024-02-20 22:47:57.500000000
# 23
# 400
# 2024-02-20 22:55:43.500000000
# 23
# 401
# 2024-02-20 22:58:07.000000000
# 23
# 402
# 2024-02-20 23:01:01.000000000
# 23
# 403
# 2024-02-20 23:06:02.500000000
# 23
# 404
# 2024-02-20 23:10:47.500000000
# 23
# 405
# 2024-02-20 23:18:57.500000000
# -77
# 406
# 2024-02-20 23:28:43.000000000
# 23
# 407
# 2024-02-20 23:36:39.500000000
# 23
# 408
# 2024-02-20 23:49:06.500000000
# -27
# 409
# 2024-02-21 09:10:19.500000000
# -77
# 410
# 2024-02-21 09:12:12.000000000
# -2
# 411
# 2024-02-21 09:15:10.500000000
# 23
# 412
# 2024-02-21 09:17:27.500000000
# -52
# 413
# 2024-02-21 09:22:17.000000000
# -27
# 414
# 2024-02-21 09:26:37.500000000
# 23
# 415
# 2024-02-21 09:28:53.000000000
# 23
# 416
# 2024-02-21 09:31:04.500000000
# -77
# 417
# 2024-02-21 09:33:29.500000000
# 23
# 418
# 2024-02-21 09:36:03.500000000
# 23
# 419
# 2024-02-21 09:39:31.500000000
# 23
# 420
# 2024-02-21 09:41:23.000000000
# 23
# 421
# 2024-02-21 09:42:35.000000000
# -52
# 422
# 2024-02-21 09:44:43.000000000
# 23
# 423
# 2024-02-21 09:47:32.000000000
# 23
# 424
# 2024-02-21 09:50:21.000000000
# 23
# 425
# 2024-02-21 09:55:34.500000000
# 23
# 426
# 2024-02-21 09:57:57.500000000
# 23
# 427
# 2024-02-21 10:02:00.500000000
# -27
# 428
# 2024-02-21 10:03:58.000000000
# -27
# 429
# 2024-02-21 10:30:45.500000000
# -27
# 430
# 2024-02-21 10:33:47.000000000
# 23
# 431
# 2024-02-21 10:40:10.000000000
# -2
# 432
# 2024-02-21 10:44:51.000000000
# 23
# 433
# 2024-02-21 10:48:39.000000000
# 23
# 434
# 2024-02-21 10:56:44.000000000
# 23
# 435
# 2024-02-21 11:00:19.500000000
# 23
# 436
# 2024-02-21 11:02:54.000000000
# 23
# 437
# 2024-02-21 11:06:35.000000000
# 23
# 438
# 2024-02-21 11:09:38.500000000
# 23
# 439
# 2024-02-21 11:11:19.000000000
# 23
# 440
# 2024-02-21 11:12:33.000000000
# -27
# 441
# 2024-02-21 11:14:46.500000000
# 23
# 442
# 2024-02-21 11:16:46.500000000
# 23
# 443
# 2024-02-21 11:19:50.000000000
# 23
# 444
# 2024-02-21 13:41:48.500000000
# 23
# 445
# 2024-02-21 13:46:50.000000000
# 23
# 446
# 2024-02-21 13:50:01.000000000
# 23
# 447
# 2024-02-21 13:54:01.000000000
# 23
# 448
# 2024-02-21 13:57:33.000000000
# 23
# 449
# 2024-02-21 14:00:00.500000000
# 23
# 450
# 2024-02-21 14:02:34.500000000
# -52
# 451
# 2024-02-21 14:08:56.500000000
# 23
# 452
# 2024-02-21 14:11:09.000001000
# -77
# 453
# 2024-02-21 14:15:45.000001000
# 23
# 454
# 2024-02-21 14:18:11.000001000
# 23
# 455
# 2024-02-21 14:21:04.000001000
# 23
# 456
# 2024-02-21 14:25:48.000000000
# -52
# 457
# 2024-02-21 14:29:03.000000000
# 23
# 458
# 2024-02-21 14:37:59.000001000
# 23
# 459
# 2024-02-21 14:47:12.500000000
# 23
# 460
# 2024-02-21 21:11:46.500000000
# -52
# 461
# 2024-02-21 21:13:11.500000000
# -27
# 462
# 2024-02-21 21:14:55.500000000
# 23
# 463
# 2024-02-21 21:16:53.500000000
# 23
# 464
# 2024-02-21 21:19:11.500000000
# 23
# 465
# 2024-02-21 21:20:56.000000000
# 23
# 466
# 2024-02-21 21:24:24.000000000
# 23
# 467
# 2024-02-21 21:27:56.500000000
# -27
# 468
# 2024-02-21 21:32:12.500000000
# 23
# 469
# 2024-02-21 21:34:02.500000000
# 23
# 470
# 2024-02-21 21:36:48.500000000
# 23
# 471
# 2024-02-21 21:39:26.500000000
# -27
# 472
# 2024-02-21 21:43:31.500000000
# -27
# 473
# 2024-02-21 21:54:33.000000000
# 23
# 474
# 2024-02-21 21:57:17.000000000
# 23
# 475
# 2024-02-21 22:05:34.500000000
# 23
# 476
# 2024-02-21 22:10:38.500000000
# 23
# 477
# 2024-02-21 22:13:44.000000000
# 23
# 478
# 2024-02-21 22:15:21.500000000
# 23
# 479
# 2024-02-21 22:18:28.500000000
# 23
# 480
# 2024-02-21 22:23:23.000000000
# 23
# 481
# 2024-02-21 22:25:46.000000000
# -27
# 482
# 2024-02-21 22:29:56.000000000
# -52
# 483
# 2024-02-21 22:31:12.500000000
# 23
# 484
# 2024-02-21 22:33:52.500000000
# 23
# 485
# 2024-02-21 22:36:42.500000000
# 23
# 486
# 2024-02-21 22:39:46.500000000
# -27
# 487
# 2024-02-21 22:44:01.000000000
# -27
# 488
# 2024-02-21 22:47:08.000000000
# 23
# 489
# 2024-02-21 22:50:42.000000000
# 23
# 490
# 2024-02-21 22:52:55.000000000
# -52
# 491
# 2024-02-21 22:57:15.500000000
# -27
# 492
# 2024-02-21 22:59:26.000000000
# 23
# 493
# 2024-02-21 23:02:01.000000000
# -2
# 494
# 2024-02-21 23:03:59.500000000
# 23
# 495
# 2024-02-21 23:07:54.500000000
# 23
# 496
# 2024-02-21 23:11:25.000000000
# 23
# 497
# 2024-02-21 23:17:11.500000000
# 23
# 498
# 2024-02-21 23:25:32.500000000
# 23
# 499
# 2024-02-21 23:32:13.500000000
# 23
# 500
# 2024-02-21 23:46:10.000000000
# -27
# 501
# 2024-02-22 09:10:43.500000000
# 23
# 502
# 2024-02-22 09:16:36.000000000
# 23
# 503
# 2024-02-22 09:18:41.500000000
# -52
# 504
# 2024-02-22 09:20:49.000000000
# -52
# 505
# 2024-02-22 09:31:00.500000000
# 23
# 506
# 2024-02-22 09:33:59.500000000
# 23
# 507
# 2024-02-22 09:38:01.500000000
# 23
# 508
# 2024-02-22 09:40:01.500000000
# -77
# 509
# 2024-02-22 09:44:06.000000000
# 23
# 510
# 2024-02-22 09:49:05.000000000
# -27
# 511
# 2024-02-22 09:54:40.000000000
# 23
# 512
# 2024-02-22 09:59:55.000000000
# 23
# 513
# 2024-02-22 10:06:57.500000000
# -27
# 514
# 2024-02-22 10:10:31.500000000
# 23
# 515
# 2024-02-22 10:12:58.500000000
# 23
# 516
# 2024-02-22 10:30:52.000000000
# 23
# 517
# 2024-02-22 10:42:07.000000000
# -77
# 518
# 2024-02-22 10:52:27.000000000
# 23
# 519
# 2024-02-22 10:55:15.500000000
# 23
# 520
# 2024-02-22 10:57:22.000000000
# -27
# 521
# 2024-02-22 10:59:58.000000000
# 23
# 522
# 2024-02-22 11:02:14.000000000
# -27
# 523
# 2024-02-22 11:05:04.000000000
# 23
# 524
# 2024-02-22 11:09:06.000000000
# 23
# 525
# 2024-02-22 11:12:25.000000000
# 23
# 526
# 2024-02-22 11:14:56.500000000
# 23
# 527
# 2024-02-22 11:17:22.000000000
# -52
# 528
# 2024-02-22 13:40:14.500000000
# 23
# 529
# 2024-02-22 13:43:11.500000000
# 23
# 530
# 2024-02-22 13:45:42.500000000
# 23
# 531
# 2024-02-22 13:47:47.500000000
# 23
# 532
# 2024-02-22 13:51:30.500000000
# -27
# 533
# 2024-02-22 13:53:47.500000000
# -52
# 534
# 2024-02-22 13:56:09.000000000
# 23
# 535
# 2024-02-22 13:58:17.500000000
# 23
# 536
# 2024-02-22 14:05:21.500000000
# -77
# 537
# 2024-02-22 14:07:53.000000000
# 23
# 538
# 2024-02-22 14:10:13.000000000
# 23
# 539
# 2024-02-22 14:13:00.500000000
# -52
# 540
# 2024-02-22 14:16:42.500000000
# 23
# 541
# 2024-02-22 14:19:30.500000000
# -77
# 542
# 2024-02-22 14:23:47.500000000
# -2
# 543
# 2024-02-22 14:27:50.500000000
# 23
# 544
# 2024-02-22 14:30:56.500000000
# 23
# 545
# 2024-02-22 14:32:32.500000000
# 23
# 546
# 2024-02-22 21:10:07.000000000
# 23
# 547
# 2024-02-22 21:11:45.000000000
# 23
# 548
# 2024-02-22 21:13:44.000000000
# -27
# 549
# 2024-02-22 21:17:51.500000000
# -27
# 550
# 2024-02-22 21:20:30.500000000
# -27
# 551
# 2024-02-22 21:21:44.500000000
# -27
# 552
# 2024-02-22 21:23:47.000000000
# 23
# 553
# 2024-02-22 21:25:14.500000000
# 23
# 554
# 2024-02-22 21:26:43.000000000
# 23
# 555
# 2024-02-22 21:28:04.000000000
# -52
# 556
# 2024-02-22 21:29:35.000000000
# 23
# 557
# 2024-02-22 21:31:56.000000000
# 23
# 558
# 2024-02-22 21:35:13.500000000
# -27
# 559
# 2024-02-22 21:39:00.000000000
# 23
# 560
# 2024-02-22 21:41:25.500000000
# -52
# 561
# 2024-02-22 21:43:21.000000000
# 23
# 562
# 2024-02-22 21:44:35.000000000
# 23
# 563
# 2024-02-22 21:46:38.500000000
# 23
# 564
# 2024-02-22 21:52:44.000000000
# 23
# 565
# 2024-02-22 21:54:41.000000000
# 23
# 566
# 2024-02-22 21:56:45.500000000
# 23
# 567
# 2024-02-22 21:58:21.500000000
# -52
# 568
# 2024-02-22 22:01:39.500000000
# 23
# 569
# 2024-02-22 22:05:24.500000000
# 23
# 570
# 2024-02-22 22:08:33.500000000
# 23
# 571
# 2024-02-22 22:12:11.000000000
# 23
# 572
# 2024-02-22 22:15:35.500000000
# -27
# 573
# 2024-02-22 22:20:49.000000000
# 23
# 574
# 2024-02-22 22:26:54.000000000
# -27
# 575
# 2024-02-22 22:29:55.000000000
# 23
# 576
# 2024-02-22 22:42:30.500000000
# -27
# 577
# 2024-02-22 22:52:06.500000000
# 23
# 578
# 2024-02-22 22:55:18.000000000
# -52
# 579
# 2024-02-22 22:58:31.500000000
# -27
# 580
# 2024-02-22 23:00:50.000000000
# 23
# 581
# 2024-02-22 23:13:57.500000000
# 23
# 582
# 2024-02-22 23:27:03.000000000
# 23
# 583
# 2024-02-22 23:31:40.000000000
# 23
# 584
# 2024-02-22 23:43:20.500000000
# -27
# 585
# 2024-02-22 23:59:17.500000000
# 23
# 586
# 2024-02-23 09:12:53.000000000
# 23
# 587
# 2024-02-23 09:16:48.500000000
# -52
# 588
# 2024-02-23 09:18:13.000000000
# -52
# 589
# 2024-02-23 09:20:34.000000000
# -27
# 590
# 2024-02-23 09:25:40.000000000
# -77
# 591
# 2024-02-23 09:28:25.000000000
# 23
# 592
# 2024-02-23 09:30:06.000000000
# -2
# 593
# 2024-02-23 09:35:13.500000000
# 23
# 594
# 2024-02-23 09:37:01.000000000
# -2
# 595
# 2024-02-23 09:39:00.500000000
# -27
# 596
# 2024-02-23 09:41:47.500000000
# -27
# 597
# 2024-02-23 09:43:43.000000000
# -27
# 598
# 2024-02-23 09:46:15.000000000
# 23
# 599
# 2024-02-23 09:48:17.500000000
# 23
# 600
# 2024-02-23 09:50:58.000000000
# 23
# 601
# 2024-02-23 09:53:56.500000000
# 23
# 602
# 2024-02-23 09:56:24.500000000
# 23
# 603
# 2024-02-23 09:57:34.000000000
# 23
# 604
# 2024-02-23 09:58:33.500000000
# 23
# 605
# 2024-02-23 10:00:02.000000000
# -52
# 606
# 2024-02-23 10:01:23.500000000
# -27
# 607
# 2024-02-23 10:02:58.500000000
# -52
# 608
# 2024-02-23 10:04:02.000000000
# 23
# 609
# 2024-02-23 10:06:06.000000000
# -27
# 610
# 2024-02-23 10:07:54.500000000
# -52
# 611
# 2024-02-23 10:09:55.500000000
# -27
# 612
# 2024-02-23 10:11:15.500000000
# 23
# 613
# 2024-02-23 10:12:33.000000000
# 23
# 614
# 2024-02-23 10:13:41.500000000
# 23
# 615
# 2024-02-23 10:14:59.500000000
# 23
# 616
# 2024-02-23 10:31:35.000000000
# 23
# 617
# 2024-02-23 10:32:49.000000000
# 23
# 618
# 2024-02-23 10:34:53.000000000
# -27
# 619
# 2024-02-23 10:37:03.500000000
# -27
# 620
# 2024-02-23 10:39:20.500000000
# 23
# 621
# 2024-02-23 10:40:45.000000000
# 23
# 622
# 2024-02-23 10:42:35.000000000
# 23
# 623
# 2024-02-23 10:44:04.500000000
# 23
# 624
# 2024-02-23 10:46:45.000000000
# 23
# 625
# 2024-02-23 10:49:11.000000000
# 23
# 626
# 2024-02-23 10:51:33.000000000
# 23
# 627
# 2024-02-23 10:53:34.500000000
# 23
# 628
# 2024-02-23 10:55:34.000000000
# 23
# 629
# 2024-02-23 10:59:08.000000000
# 23
# 630
# 2024-02-23 11:02:51.500000000
# -27
# 631
# 2024-02-23 11:07:01.000000000
# -27
# 632
# 2024-02-23 11:09:18.500000000
# -27
# 633
# 2024-02-23 11:11:19.000000000
# 23
# 634
# 2024-02-23 11:13:53.500000000
# -52
# 635
# 2024-02-23 11:15:40.000000000
# -77
# 636
# 2024-02-23 11:16:31.500000000
# 23
# 637
# 2024-02-23 11:17:34.000000000
# 23
# 638
# 2024-02-23 11:19:01.000000000
# 23
# 639
# 2024-02-23 13:41:50.500000000
# -27
# 640
# 2024-02-23 13:45:10.000000000
# 23
# 641
# 2024-02-23 13:47:17.500000000
# 23
# 642
# 2024-02-23 13:51:13.000000000
# -52
# 643
# 2024-02-23 13:54:51.000000000
# -27
# 644
# 2024-02-23 13:58:05.500000000
# -52
# 645
# 2024-02-23 14:03:17.000000000
# -27
# 646
# 2024-02-23 14:06:22.000000000
# -52
# 647
# 2024-02-23 14:09:19.500000000
# 23
# 648
# 2024-02-23 14:12:24.000000000
# -27
# 649
# 2024-02-23 14:16:10.500000000
# 23
# 650
# 2024-02-23 14:19:27.500000000
# -27
# 651
# 2024-02-23 14:22:44.000000000
# 23
# 652
# 2024-02-23 14:25:57.500000000
# 23
# 653
# 2024-02-23 14:28:04.500000000
# -52
# 654
# 2024-02-23 14:33:56.500000000
# -27
# 655
# 2024-02-23 14:36:48.000000000
# -27
# 656
# 2024-02-23 14:40:49.500000000
# -52
# 657
# 2024-02-23 14:45:57.500000000
# 23
# 658
# 2024-02-23 14:47:44.000000000
# -27
# 659
# 2024-02-23 14:49:37.000000000
# -27
# 660
# 2024-02-23 21:10:09.000000000
# -27
# 661
# 2024-02-23 21:11:46.500000000
# 23
# 662
# 2024-02-23 21:14:17.000000000
# -52
# 663
# 2024-02-23 21:16:13.500000000
# 23
# 664
# 2024-02-23 21:18:21.500000000
# 23
# 665
# 2024-02-23 21:20:00.000000000
# -2
# 666
# 2024-02-23 21:23:25.500000000
# 23
# 667
# 2024-02-23 21:24:35.000000000
# -52
# 668
# 2024-02-23 21:26:22.500000000
# 23
# 669
# 2024-02-23 21:29:40.500000000
# -52
# 670
# 2024-02-23 21:32:44.000000000
# -27
# 671
# 2024-02-23 21:35:02.500000000
# 23
# 672
# 2024-02-23 21:36:40.000000000
# 23
# 673
# 2024-02-23 21:40:21.500000000
# 23
# 674
# 2024-02-23 21:46:17.000000000
# 23
# 675
# 2024-02-23 21:49:27.500000000
# 23
# 676
# 2024-02-23 21:55:00.000000000
# -27
# 677
# 2024-02-23 22:06:21.000000000
# 23
# 678
# 2024-02-23 22:12:23.500000000
# 23
# 679
# 2024-02-23 22:15:59.500000000
# 23
# 680
# 2024-02-23 22:19:56.500000000
# -27
# 681
# 2024-02-23 22:21:41.000000000
# 23
# 682
# 2024-02-23 22:24:05.500000000
# 23
# 683
# 2024-02-23 22:25:35.000000000
# -27
# 684
# 2024-02-23 22:27:54.000000000
# -2
# 685
# 2024-02-23 22:31:39.000000000
# -52
# 686
# 2024-02-23 22:33:56.000000000
# -27
# 687
# 2024-02-23 22:35:53.500000000
# 23
# 688
# 2024-02-23 22:40:15.500000000
# 23
# 689
# 2024-02-23 22:43:41.500000000
# 23
# 690
# 2024-02-23 22:50:42.000000000
# 23
# 691
# 2024-02-23 22:57:33.500000000
# 23
# 692
# 2024-02-23 22:59:52.500000000
# 23
# 693
# 2024-02-23 23:02:29.000000000
# 23
# 694
# 2024-02-23 23:03:34.500000000
# -52
# 695
# 2024-02-23 23:05:01.500000000
# -52
# 696
# 2024-02-23 23:06:14.500000000
# 23
# 697
# 2024-02-23 23:07:59.000000000
# -27
# 698
# 2024-02-23 23:14:26.000000000
# 23
# 699
# 2024-02-23 23:15:55.500000000
# -77
# 700
# 2024-02-23 23:22:03.500000000
# 23
# 701
# 2024-02-23 23:28:01.000000000
# 23
# 702
# 2024-02-23 23:34:15.000000000
# 23
# 703
# 2024-02-23 23:41:10.500000000
# 23
# 704
# 2024-02-23 23:47:42.500000000
# -77
# 705
# 2024-02-23 23:52:50.500000000
# 23
# 706
# 2024-02-23 23:57:27.000000000
# 23
# 707
# 2024-02-23 23:58:42.000000000
# -52
# 708
# 2024-02-23 23:59:55.500000000
# 23
# 709
# 2024-02-26 09:10:10.000000000
# 23
# 710
# 2024-02-26 09:11:59.000000000
# 23
# 711
# 2024-02-26 09:13:59.500000000
# -27
# 712
# 2024-02-26 09:17:08.500000000
# 23
# 713
# 2024-02-26 09:19:07.000000000
# 23
# 714
# 2024-02-26 09:21:08.000000000
# 23
# 715
# 2024-02-26 09:23:26.000000000
# 23
# 716
# 2024-02-26 09:26:08.000000000
# 23
# 717
# 2024-02-26 09:27:49.000000000
# 23
# 718
# 2024-02-26 09:30:51.500000000
# 23
# 719
# 2024-02-26 09:34:31.000000000
# 23
# 720
# 2024-02-26 09:39:00.000000000
# 23
# 721
# 2024-02-26 09:41:26.500000000
# 23
# 722
# 2024-02-26 09:43:12.500000000
# 23
# 723
# 2024-02-26 09:45:52.500000000
# 23
# 724
# 2024-02-26 09:48:08.000000000
# 23
# 725
# 2024-02-26 09:50:10.000000000
# 23
# 726
# 2024-02-26 09:52:53.500000000
# 23
# 727
# 2024-02-26 09:56:22.500000000
# 23
# 728
# 2024-02-26 09:59:23.500000000
# -77
# 729
# 2024-02-26 10:01:22.500000000
# 23
# 730
# 2024-02-26 10:03:39.000000000
# 23
# 731
# 2024-02-26 10:07:16.000000000
# 23
# 732
# 2024-02-26 10:10:17.000000000
# -27
# 733
# 2024-02-26 10:12:18.500000000
# 23
# 734
# 2024-02-26 10:14:23.000000000
# 23
# 735
# 2024-02-26 10:31:51.000000000
# -52
# 736
# 2024-02-26 10:37:17.000000000
# 23
# 737
# 2024-02-26 10:40:59.500000000
# 23
# 738
# 2024-02-26 10:45:12.000000000
# 23
# 739
# 2024-02-26 10:50:23.500000000
# -27
# 740
# 2024-02-26 10:54:26.000000000
# 23
# 741
# 2024-02-26 11:00:08.500000000
# 23
# 742
# 2024-02-26 11:11:46.000000000
# 23
# 743
# 2024-02-26 11:15:03.500000000
# 23
# 744
# 2024-02-26 13:40:12.000000000
# -77
# 745
# 2024-02-26 13:45:55.500000000
# 23
# 746
# 2024-02-26 13:51:10.000000000
# 23
# 747
# 2024-02-26 13:55:03.500000000
# 23
# 748
# 2024-02-26 14:00:44.000000000
# -27
# 749
# 2024-02-26 14:07:03.000000000
# 23
# 750
# 2024-02-26 14:12:42.000000000
# 23
# 751
# 2024-02-26 14:22:25.500000000
# 23
# 752
# 2024-02-26 14:29:09.000000000
# -77
# 753
# 2024-02-26 14:36:37.500000000
# 23
# 754
# 2024-02-26 14:45:56.500000000
# 23
# 755
# 2024-02-26 21:10:01.000000000
# 23
# 756
# 2024-02-26 21:11:11.500000000
# 23
# 757
# 2024-02-26 21:12:59.500000000
# 23
# 758
# 2024-02-26 21:13:58.500000000
# 23
# 759
# 2024-02-26 21:17:32.500000000
# -2
# 760
# 2024-02-26 21:19:58.000000000
# -27
# 761
# 2024-02-26 21:22:31.000000000
# 23
# 762
# 2024-02-26 21:23:42.000000000
# 23
# 763
# 2024-02-26 21:25:43.000000000
# 23
# 764
# 2024-02-26 21:27:31.000000000
# 23
# 765
# 2024-02-26 21:30:27.000000000
# 23
# 766
# 2024-02-26 21:32:33.500000000
# 23
# 767
# 2024-02-26 21:34:35.000000000
# 23
# 768
# 2024-02-26 21:36:28.000000000
# 23
# 769
# 2024-02-26 21:40:28.500000000
# 23
# 770
# 2024-02-26 21:43:56.500000000
# 23
# 771
# 2024-02-26 21:47:12.000000000
# 23
# 772
# 2024-02-26 21:50:29.500000000
# -52
# 773
# 2024-02-26 21:56:31.000000000
# 23
# 774
# 2024-02-26 22:00:23.000000000
# -27
# 775
# 2024-02-26 22:05:17.500000000
# -2
# 776
# 2024-02-26 22:13:09.000000000
# 23
# 777
# 2024-02-26 22:14:53.000000000
# -27
# 778
# 2024-02-26 22:17:44.000000000
# 23
# 779
# 2024-02-26 22:23:10.000000000
# 23
# 780
# 2024-02-26 22:27:31.000000000
# 23
# 781
# 2024-02-26 22:31:17.000000000
# 23
# 782
# 2024-02-26 22:34:02.000000000
# -52
# 783
# 2024-02-26 22:39:07.000000000
# 23
# 784
# 2024-02-26 22:41:17.500000000
# 23
# 785
# 2024-02-26 22:49:04.500000000
# 23
# 786
# 2024-02-26 22:54:04.000000000
# 23
# 787
# 2024-02-26 23:00:28.000000000
# -52
# 788
# 2024-02-26 23:05:38.500000000
# -27
# 789
# 2024-02-26 23:19:09.000000000
# 23
# 790
# 2024-02-26 23:30:05.000000000
# 23
# 791
# 2024-02-26 23:42:50.500000000
# 23
# 792
# 2024-02-26 23:59:37.500000000
# 23
# 793
# 2024-02-27 09:11:32.000000000
# 23
# 794
# 2024-02-27 09:17:31.000000000
# 23
# 795
# 2024-02-27 09:21:07.000000000
# 23
# 796
# 2024-02-27 09:26:06.500000000
# 23
# 797
# 2024-02-27 09:27:56.500000000
# 23
# 798
# 2024-02-27 09:30:08.500000000
# 23
# 799
# 2024-02-27 09:31:23.500000000
# -27
# 800
# 2024-02-27 09:34:32.000000000
# -52
# 801
# 2024-02-27 09:36:25.500000000
# 23
# 802
# 2024-02-27 09:38:02.000000000
# 23
# 803
# 2024-02-27 09:40:09.000000000
# 23
# 804
# 2024-02-27 09:43:29.500000000
# 23
# 805
# 2024-02-27 09:45:01.000000000
# 23
# 806
# 2024-02-27 09:47:39.000000000
# 23
# 807
# 2024-02-27 09:50:49.500000000
# 23
# 808
# 2024-02-27 09:53:15.500000000
# 23
# 809
# 2024-02-27 09:55:25.000000000
# 23
# 810
# 2024-02-27 09:57:16.500000000
# -27
# 811
# 2024-02-27 09:59:13.500000000
# 23
# 812
# 2024-02-27 10:01:07.500000000
# 23
# 813
# 2024-02-27 10:03:39.500000000
# 23
# 814
# 2024-02-27 10:05:49.500000000
# 23
# 815
# 2024-02-27 10:07:07.500000000
# 23
# 816
# 2024-02-27 10:08:44.500000000
# 23
# 817
# 2024-02-27 10:10:01.000000000
# 23
# 818
# 2024-02-27 10:13:13.500000000
# 23
# 819
# 2024-02-27 10:14:55.000000000
# 23
# 820
# 2024-02-27 10:31:44.500000000
# 23
# 821
# 2024-02-27 10:33:43.500000000
# -52
# 822
# 2024-02-27 10:35:20.500000000
# 23
# 823
# 2024-02-27 10:39:09.000000000
# 23
# 824
# 2024-02-27 10:42:30.000000000
# -52
# 825
# 2024-02-27 10:45:24.500000000
# -52
# 826
# 2024-02-27 10:49:38.500000000
# 23
# 827
# 2024-02-27 10:51:03.500000000
# 23
# 828
# 2024-02-27 10:52:57.500000000
# 23
# 829
# 2024-02-27 10:55:47.000000000
# -52
# 830
# 2024-02-27 10:57:31.000000000
# 23
# 831
# 2024-02-27 10:58:51.000000000
# 23
# 832
# 2024-02-27 11:00:45.500000000
# 23
# 833
# 2024-02-27 11:01:49.500000000
# 23
# 834
# 2024-02-27 11:03:28.500000000
# 23
# 835
# 2024-02-27 11:08:08.500000000
# 23
# 836
# 2024-02-27 11:11:13.500000000
# 23
# 837
# 2024-02-27 11:16:00.500000000
# 23
# 838
# 2024-02-27 13:40:03.500000000
# 23
# 839
# 2024-02-27 13:42:14.000000000
# -52
# 840
# 2024-02-27 13:45:13.500000000
# 23
# 841
# 2024-02-27 13:47:15.000000000
# 23
# 842
# 2024-02-27 13:49:05.000000000
# 23
# 843
# 2024-02-27 13:57:17.500000000
# 23
# 844
# 2024-02-27 13:59:32.000000000
# 23
# 845
# 2024-02-27 14:03:03.000000000
# 23
# 846
# 2024-02-27 14:07:45.000000000
# -52
# 847
# 2024-02-27 14:11:06.000000000
# 23
# 848
# 2024-02-27 14:18:13.000000000
# -52
# 849
# 2024-02-27 14:20:32.500000000
# -27
# 850
# 2024-02-27 14:24:10.000000000
# 23
# 851
# 2024-02-27 14:27:26.000000000
# 23
# 852
# 2024-02-27 14:32:47.000000000
# -52
# 853
# 2024-02-27 14:36:08.500000000
# 23
# 854
# 2024-02-27 14:38:32.500000000
# 23
# 855
# 2024-02-27 14:41:47.000000000
# 23
# 856
# 2024-02-27 14:47:11.000000000
# 23
# 857
# 2024-02-27 14:49:17.500000000
# 23
# 858
# 2024-02-27 21:10:35.500000000
# -27
# 859
# 2024-02-27 21:12:46.500000000
# 23
# 860
# 2024-02-27 21:14:25.000000000
# 23
# 861
# 2024-02-27 21:16:00.500000000
# -2
# 862
# 2024-02-27 21:21:43.500000000
# 23
# 863
# 2024-02-27 21:23:52.000000000
# 23
# 864
# 2024-02-27 21:25:18.000000000
# 23
# 865
# 2024-02-27 21:28:33.500000000
# 23
# 866
# 2024-02-27 21:30:24.500000000
# 23
# 867
# 2024-02-27 21:31:44.500000000
# 23
# 868
# 2024-02-27 21:36:01.000000000
# 23
# 869
# 2024-02-27 21:37:14.500000000
# 23
# 870
# 2024-02-27 21:40:26.500000000
# 23
# 871
# 2024-02-27 21:43:06.500000000
# -52
# 872
# 2024-02-27 21:49:20.000000000
# 23
# 873
# 2024-02-27 21:55:30.000000000
# 23
# 874
# 2024-02-27 22:00:02.000000000
# 23
# 875
# 2024-02-27 22:05:26.500000000
# -52
# 876
# 2024-02-27 22:10:44.000000000
# -52
# 877
# 2024-02-27 22:27:22.500000000
# -77
# 878
# 2024-02-27 22:32:37.000000000
# 23
# 879
# 2024-02-27 22:37:24.500000000
# 23
# 880
# 2024-02-27 22:47:20.500000000
# -77
# 881
# 2024-02-27 22:58:15.000000000
# -52
# 882
# 2024-02-27 23:01:15.500000000
# 23
# 883
# 2024-02-27 23:10:36.500000000
# -52
# 884
# 2024-02-27 23:19:19.000000000
# 23
# 885
# 2024-02-27 23:24:48.000000000
# 23
# 886
# 2024-02-27 23:33:22.500000000
# 23
# 887
# 2024-02-27 23:48:01.000000000
# -27
# 888
# 2024-02-28 09:10:54.500000000
# 23
# 889
# 2024-02-28 09:13:33.000000000
# 23
# 890
# 2024-02-28 09:16:47.500000000
# 23
# 891
# 2024-02-28 09:20:10.000000000
# -52
# 892
# 2024-02-28 09:24:03.500000000
# 23
# 893
# 2024-02-28 09:26:10.500000000
# -77
# 894
# 2024-02-28 09:30:35.000000000
# 23
# 895
# 2024-02-28 09:33:42.500000000
# -27
# 896
# 2024-02-28 09:36:05.500000000
# 23
# 897
# 2024-02-28 09:38:38.000000000
# 23
# 898
# 2024-02-28 09:45:12.000000000
# 23
# 899
# 2024-02-28 09:48:38.500000000
# -52
# 900
# 2024-02-28 09:52:31.000000000
# 23
# 901
# 2024-02-28 09:54:56.500000000
# 23
# 902
# 2024-02-28 09:58:12.000000000
# -27
# 903
# 2024-02-28 10:00:06.000000000
# 23
# 904
# 2024-02-28 10:03:08.500000000
# 23
# 905
# 2024-02-28 10:07:18.500000000
# -52
# 906
# 2024-02-28 10:09:43.000000000
# -27
# 907
# 2024-02-28 10:12:10.500000000
# -77
# 908
# 2024-02-28 10:30:22.000000000
# 23
# 909
# 2024-02-28 10:32:34.500000000
# -27
# 910
# 2024-02-28 10:37:10.500000000
# -52
# 911
# 2024-02-28 10:40:31.000000000
# 23
# 912
# 2024-02-28 10:47:07.500000000
# -2
# 913
# 2024-02-28 10:51:57.000000000
# 23
# 914
# 2024-02-28 10:53:11.000000000
# 23
# 915
# 2024-02-28 10:54:27.000000000
# 23
# 916
# 2024-02-28 10:57:46.500000000
# 23
# 917
# 2024-02-28 11:05:07.500000000
# 23
# 918
# 2024-02-28 11:07:08.000000000
# 23
# 919
# 2024-02-28 11:09:04.000000000
# 23
# 920
# 2024-02-28 11:10:35.500000000
# -52
# 921
# 2024-02-28 11:13:09.500000000
# 23
# 922
# 2024-02-28 11:15:45.000000000
# 23
# 923
# 2024-02-28 11:18:54.000000000
# 23
# 924
# 2024-02-28 13:41:17.000000000
# -27
# 925
# 2024-02-28 13:45:05.500000000
# 23
# 926
# 2024-02-28 13:47:38.000000000
# 23
# 927
# 2024-02-28 13:51:20.500000000
# -77
# 928
# 2024-02-28 13:54:58.000000000
# -27
# 929
# 2024-02-28 13:56:29.000000000
# 23
# 930
# 2024-02-28 14:03:25.500000000
# 23
# 931
# 2024-02-28 14:07:41.000000000
# 23
# 932
# 2024-02-28 14:10:24.500000000
# 23
# 933
# 2024-02-28 14:12:03.500000000
# 23
# 934
# 2024-02-28 14:15:10.000000000
# 23
# 935
# 2024-02-28 14:19:53.000000000
# 23
# 936
# 2024-02-28 14:25:52.500000000
# -27
# 937
# 2024-02-28 14:36:43.000000000
# -52
# 938
# 2024-02-28 14:42:27.000000000
# -27
# 939
# 2024-02-28 14:44:53.500000000
# -2
# 940
# 2024-02-05: 286.00
# 2024-02-06: 536.00
# 2024-02-07: 779.00
# 2024-02-08: -101.00
# 2024-02-19: 342.00
# 2024-02-20: -83.00
# 2024-02-21: 516.00
# 2024-02-22: 105.00
# 2024-02-23: -421.00
# 2024-02-26: 882.00
# 2024-02-27: 660.00
# 2024-02-28: -4.00
# Final profit: 3497.00
# 0.7127659574468085
# 940
