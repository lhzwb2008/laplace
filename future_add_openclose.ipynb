# %%
import pandas as pd
from enum import Enum, auto

FILENAME = "future_taobao_ssMain_tick"

class open_interest_delta_forward_enum(Enum):
    NONE = auto()
    UNKNOWN = auto()
    EXCHANGE = auto()
    OPENFWDOUBLE = auto()
    OPEN = auto()
    CLOSEFWDOUBLE = auto()
    CLOSE = auto()

class order_forward_enum(Enum):
    UP = auto()
    DOWN = auto()
    MIDDLE = auto()

class tick_type_key_enum(Enum):
    TICKTYPE = auto()
    TICKCOLOR = auto()

class tick_type_enum(Enum):
    NOCHANGE = '无交易'
    UNKNOWN = '未知'
    EXCHANGELONG = '多换'
    EXCHANGESHORT = '空换'
    EXCHANGEUNKOWN = '未知换'
    OPENDOUBLE = '双开'
    OPENLONG = '多开'
    OPENSHORT = '空开'
    OPENUNKOWN = '未知开'
    CLOSEDOUBLE = '双平'
    CLOSESHORT = '空平'
    CLOSELONG = '多平'
    CLOSEUNKOWN = '未知平'

class tick_color_enum(Enum):
    WHITE = '白色'
    RED = '红色'
    GREEN = '绿色'

tick_type_cal_dict = {
    open_interest_delta_forward_enum.NONE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.EXCHANGE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGELONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGESHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPENFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPEN:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENLONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENSHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSEFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSESHORT,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSELONG,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
}

 # Mapping of openclose and price_direction to open_interest_delta_forward_enum and order_forward_enum
openclose_mapping = {
    '换手': open_interest_delta_forward_enum.EXCHANGE,
    '双开': open_interest_delta_forward_enum.OPENFWDOUBLE,
    '开仓': open_interest_delta_forward_enum.OPEN,
    '双平': open_interest_delta_forward_enum.CLOSEFWDOUBLE,  # Assuming definition for 双平
    '平仓': open_interest_delta_forward_enum.CLOSE,
    '无交易': open_interest_delta_forward_enum.NONE,
    '未知':open_interest_delta_forward_enum.UNKNOWN
}

price_direction_mapping = {
    '向上': order_forward_enum.UP,
    '向下': order_forward_enum.DOWN,
    '不变': order_forward_enum.MIDDLE
}

# 枚举到中文的映射
tick_type_to_chinese = {
    tick_type_enum.NOCHANGE: '无交易',
    tick_type_enum.UNKNOWN: '未知',
    tick_type_enum.EXCHANGELONG: '多换',
    tick_type_enum.EXCHANGESHORT: '空换',
    tick_type_enum.EXCHANGEUNKOWN: '未知换',
    tick_type_enum.OPENDOUBLE: '双开',
    tick_type_enum.OPENLONG: '开多',
    tick_type_enum.OPENSHORT: '开空',
    tick_type_enum.OPENUNKOWN: '未知开',
    tick_type_enum.CLOSEDOUBLE: '双平',
    tick_type_enum.CLOSESHORT: '空平',
    tick_type_enum.CLOSELONG: '多平',
    tick_type_enum.CLOSEUNKOWN: '未知平',
}

tick_color_to_chinese = {
    tick_color_enum.WHITE: '白色',
    tick_color_enum.RED: '红色',
    tick_color_enum.GREEN: '绿色',
}


# Load the tick data
df = pd.read_csv(FILENAME+".csv")

# Calculate the deltas for volume and open interest
df['volume_delta'] = df['volume'].diff()
df['open_interest_delta'] = df['open_interest'].diff()

# Initialize columns for open/close position
df['trade_openclose'] = None
df['trade_color'] = None 
df['close_count'] = df['volume_delta']

# Iterate over the DataFrame to assign open/close positions
for i in range(1, len(df)):
    volume_delta = df.loc[i, 'volume_delta']
    open_interest_delta = df.loc[i, 'open_interest_delta']
    last_price = df.loc[i, 'last_price']
    ask_price1 = df.loc[i, 'ask_price1']
    bid_price1 = df.loc[i, 'bid_price1']
    pre_last_price = df.loc[i-1,'last_price']
    pre_ask_price1 = df.loc[i-1, 'ask_price1']
    pre_bid_price1 = df.loc[i-1, 'bid_price1']
    openclose = ''
    price_direction = ''

    # Determine the open/close position
    if volume_delta == open_interest_delta > 0:
        openclose = '双开'
    elif volume_delta > open_interest_delta > 0:
        openclose = '开仓'
    elif volume_delta > abs(open_interest_delta) > 0 and open_interest_delta < 0:
        openclose = '平仓'
    elif volume_delta > 0 and open_interest_delta == 0:
        openclose = '换手'
    elif volume_delta + open_interest_delta == 0 and volume_delta>0:
        openclose = '双平'
    elif volume_delta == 0 and  open_interest_delta == 0:
        openclose = '无交易'
    else:
        openclose = '未知'
    
    # 判断价格方向
    if last_price >= pre_ask_price1:
        price_direction = '向上'
    elif last_price <= pre_bid_price1:
        price_direction = '向下'
    elif last_price >= ask_price1:
        price_direction = '向上'
    elif last_price <= bid_price1:
        price_direction = '向下'
    else:
        price_direction = '不变'
        
   

    # Convert openclose and price_direction to their corresponding enum values
    delta_enum = openclose_mapping.get(openclose, open_interest_delta_forward_enum.NONE)
    direction_enum = price_direction_mapping.get(price_direction, order_forward_enum.MIDDLE)

    # Retrieve the tick type and color based on the mappings
    tick_info = tick_type_cal_dict.get(delta_enum, {}).get(direction_enum, {})
    tick_type = tick_info.get(tick_type_key_enum.TICKTYPE, tick_type_enum.UNKNOWN)
    tick_color = tick_info.get(tick_type_key_enum.TICKCOLOR, tick_color_enum.WHITE)
    

    # 使用映射转换为中文描述
    tick_type_chinese = tick_type_to_chinese[tick_type]
    tick_color_chinese = tick_color_to_chinese[tick_color]

    # 更新DataFrame
    df.at[i, 'trade_openclose'] = tick_type_chinese
    df.at[i, 'trade_color'] = tick_color_chinese

# Save the modified DataFrame to a new CSV file
df.to_csv(FILENAME+"_withopenclose.csv", index=False)

# %%
import pandas as pd

# 假设已加载并准备好DataFrame df
df = pd.read_csv(FILENAME+"_withopenclose.csv")

df = df.loc[df['volume_delta'] > 0]
# 重置索引以确保从0开始
df.reset_index(drop=True, inplace=True)


guess_tick=100

# 初始化列用于标记交易机会
df['buy_opportunity'] = 0
df['sell_opportunity'] = 0
trade_hand=1

# 为每个tick计算未来100个tick内与当前挂单价格相匹配的成交量
for i in range(len(df)):
    if i + guess_tick >= len(df):  # 确保未来有足够的tick进行分析
        break

    # 当前的买一和卖一价
    current_ask_price1 = df.loc[i, 'ask_price1']
    current_bid_price1 = df.loc[i, 'bid_price1']

    # 初始化对应价格的成交量计数
    matching_buy_volume = 0
    matching_sell_volume = 0
    
    buy_done = 0
    sell_done = 0

    # 遍历未来100个tick
    for j in range(i+1, i+guess_tick+1):
        if df.loc[j, 'bid_price1']<current_bid_price1:
            buy_done = 1 
        if df.loc[j, 'ask_price1']>current_ask_price1:
            sell_done = 1 
        # 如果未来tick的买一价等于当前tick的买一价，累加成交量
        if df.loc[j, 'bid_price1'] == current_bid_price1 and df.loc[j, 'bid_price1'] == df.loc[j, 'last_price']:
            matching_buy_volume += df.loc[j, 'volume_delta']
        # 如果未来tick的卖一价等于当前tick的卖一价，累加成交量
        if df.loc[j, 'ask_price1'] == current_ask_price1 and df.loc[j, 'ask_price1'] == df.loc[j, 'last_price']:
            matching_sell_volume += df.loc[j, 'volume_delta']

    # 判断是否存在买卖机会
    if buy_done==1 or matching_buy_volume >= df.loc[i, 'ask_volume1']+trade_hand:
        df.loc[i, 'buy_opportunity'] = 1
    if sell_done==1 or matching_sell_volume >= df.loc[i, 'bid_volume1']+trade_hand:
        df.loc[i, 'sell_opportunity'] = 1


# 创建一个新列来标记同时为买卖机会的tick
df['dual_opportunity'] = ((df['buy_opportunity'] == 1) & (df['sell_opportunity'] == 1)).astype(int)

# 计算同时为买卖机会的总数
dual_opportunities_count = df['dual_opportunity'].sum()

# 计算比例
total_ticks_analyzed = len(df) - guess_tick
dual_opportunities_ratio = dual_opportunities_count / total_ticks_analyzed

print(f"Dual opportunities count: {dual_opportunities_count}")
print(f"Dual opportunities ratio: {dual_opportunities_ratio:.4f}")

# 保存到新的CSV文件
df.to_csv(FILENAME+"_with_opportunities.csv", index=False)
# Out:
# Dual opportunities count: 310773
# Dual opportunities ratio: 0.5481

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score,precision_score

FILENAME = "future_taobao_ssMain_tick"
# 加载数据
data = pd.read_csv(FILENAME+"_with_opportunities.csv")

data_clean = data.dropna().copy()  # 创建一个副本以避免警告

# features = [
#     'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
#     'bid_price1', 'ask_price1', 'bid_price2', 'ask_price2', 'bid_price3', 'ask_price3',
#     'bid_price4', 'ask_price4', 'bid_price5', 'ask_price5', 'bid_volume1', 'bid_volume2',
#     'bid_volume3', 'bid_volume4', 'bid_volume5', 'ask_volume1', 'ask_volume2', 'ask_volume3',
#     'ask_volume4', 'ask_volume5'
# ]
features = [
    'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
    'bid_price1', 'ask_price1', 'bid_volume1', 'ask_volume1'
]
# 计算短期量价特征

# window_size = 500  # 用于特征计算的窗口大小
# # 特征生成
# data_clean['rolling_mean'] = data_clean['last_price'].rolling(window=window_size).mean()
# data_clean['rolling_std'] = data_clean['last_price'].rolling(window=window_size).std()
# # RSI计算
# delta = data_clean['last_price'].diff()
# gain = (delta.where(delta > 0, 0)).fillna(0)
# loss = (-delta.where(delta < 0, 0)).fillna(0)
# avg_gain = gain.rolling(window=window_size).mean()
# avg_loss = loss.rolling(window=window_size).mean()
# rs = avg_gain / avg_loss
# data_clean['RSI'] = 100 - (100 / (1 + rs))
# # MACD计算
# short_ema = data_clean['last_price'].ewm(span=int(window_size/2), adjust=False).mean()  # 使用窗口大小的一半作为短期EMA
# long_ema = data_clean['last_price'].ewm(span=window_size, adjust=False).mean()  # 使用整个窗口大小作为长期EMA
# data_clean['MACD'] = short_ema - long_ema
# data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=int(window_size/3), adjust=False).mean()  # 使用窗口大小的三分之一作为信号线
# # 删除因计算滚动特征而产生的NaN值
# data_clean.dropna(inplace=True)
# # 添加新特征到特征列表
# features.extend(['rolling_mean', 'rolling_std', 'RSI', 'MACD', 'MACD_signal'])


# 目标列处理
data_clean['successful_trade'] = data_clean.apply(
    lambda row: 1 if row['buy_opportunity'] and row['sell_opportunity'] else 0, axis=1
)

X = data_clean[['datetime'] + features]
y = data_clean['successful_trade']

# 数据切分
split_start = int(len(data_clean) * 0)
split_point = int(len(data_clean) * 0.7)
X_train = X.iloc[split_start:split_point]
y_train = y.iloc[split_start:split_point]
X_test = X.iloc[split_point:]
y_test = y.iloc[split_point:]

# 模型训练
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# 注意：随机森林模型不能直接处理datetime类型的特征，所以在训练前需要去除或转换该特征
X_train_features = X_train.drop(columns=['datetime'])
X_test_features = X_test.drop(columns=['datetime'])
rf_model.fit(X_train_features, y_train)

# 获取属于类别1的概率
y_pred_proba = rf_model.predict_proba(X_test_features)[:, 1]
# 设置交易阈值
trade_threshold = 0.6
# 根据阈值生成预测结果，大于等于阈值预测为1，否则为0
y_pred_threshold = (y_pred_proba >= trade_threshold).astype(int)
# 计算查准率
precision = precision_score(y_test, y_pred_threshold)
print(f"Precision: {precision}")

# 对照组评估（全1预测）
predictions_all_ones = [1] * len(y_test)
print("All Ones Accuracy:", precision_score(y_test, predictions_all_ones))
# Out:
# Precision: 0.689914789307809
# All Ones Accuracy: 0.5026569168008841

# %%
from datetime import datetime, time

guess_tick = 100
profit = 0  # 盈利
trade_threshold = 0.6 # 交易阈值
trade_hand = 1
trade_gap = 5 #每跳多少钱
hand_volume = 5  # 不锈钢1手5吨，1手开仓2元，平今0元
hand_fee = 2
done_count = 0
count = 0
daily_profit = {}  # 新增：用于存储每日盈利

def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False

# 定义时间范围数组
notrade_time = ["09:00-09:10","11:20-11:30","13:30-13:40","14:50-15:00","21:00-21:10","0:00-1:00"]

i = 0
while i < len(X_test) - guess_tick:
    datetime_str = X_test.iloc[i]['datetime']
    date_str = datetime_str.split(' ')[0]  # 新增：提取日期字符串
    if '.' in datetime_str:
        # 如果有小数点，分割为主时间部分和纳秒部分
        time, nano_part = datetime_str.split('.')
    else:
        # 如果没有小数点，则没有纳秒部分
        time = datetime_str
        nano_part = '0'
    if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S").time(), notrade_time):
        i = i+1
        continue
    proba = y_pred_proba[i]
    if proba > trade_threshold:
        current_ask_price1 = X_test.iloc[i]['ask_price1']
        current_bid_price1 = X_test.iloc[i]['bid_price1']
        if current_ask_price1-current_bid_price1!=trade_gap:
            i = i+1
            continue

        matching_buy_volume = 0
        matching_sell_volume = 0
        buy_done = 0
        sell_done = 0
        
        for j in range(i + 1, i + guess_tick+1):
        # j = i+1
        # start_time = datetime.strptime(X_test.iloc[j]['datetime'][:-3], '%Y-%m-%d %H:%M:%S.%f')
        # while True:
        #     end_time = datetime.strptime(X_test.iloc[j]['datetime'][:-3], '%Y-%m-%d %H:%M:%S.%f')
        #     if (end_time - start_time).total_seconds()>300:
        #         break
            
            future_tick = X_test.iloc[j]
            if future_tick['bid_price1'] < current_bid_price1:
                buy_done = 1
            if future_tick['ask_price1'] > current_ask_price1:
                sell_done = 1
            if future_tick['bid_price1'] == current_bid_price1 and future_tick['last_price'] == current_bid_price1:
                matching_sell_volume += future_tick['volume_delta']
            if future_tick['ask_price1'] == current_ask_price1 and future_tick['last_price'] == current_ask_price1:
                matching_buy_volume += future_tick['volume_delta']
            
            j = j+1 

        stop_loss_tick = i + guess_tick
        # stop_loss_tick = j
        stop_loss_price_bid = X_test.iloc[stop_loss_tick]['bid_price1']
        stop_loss_price_ask = X_test.iloc[stop_loss_tick]['ask_price1']
        count = count +1
        # 判断是否存在买卖机会
        if (buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand) and \
        (sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand):
            trade_profit = (current_ask_price1 - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            done_count = done_count + 1
            print(X_test.iloc[i]['datetime'])
            print(trade_profit)
        elif buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand:
            trade_profit = (stop_loss_price_bid - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            print(X_test.iloc[i]['datetime'])
            print(trade_profit)
        elif sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand:
            trade_profit = (current_ask_price1 - stop_loss_price_ask) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            print(X_test.iloc[i]['datetime'])
            print(trade_profit)
        else:
            i = i + 1
        i = stop_loss_tick
        print(X_test.iloc[i]['datetime'])
        
    else:
        i = i + 1

# 打印每一天的盈利
for date, daily_profit in daily_profit.items():
    print(f"{date}: {daily_profit:.2f}")

print(f"Final profit: {profit:.2f}")
print(done_count/count)
print(count)
# Out:
# 2024-02-05 14:34:07.500000000
# 23
# 2024-02-05 14:39:20.500000000
# 2024-02-05 14:39:20.500000000
# 23
# 2024-02-05 14:44:22.000000000
# 2024-02-05 14:44:22.000000000
# 23
# 2024-02-05 14:49:39.500000000
# 2024-02-05 14:49:39.500000000
# 23
# 2024-02-05 14:54:43.500000000
# 2024-02-05 21:10:02.500000000
# 23
# 2024-02-05 21:15:05.000000000
# 2024-02-05 21:15:05.000000000
# 23
# 2024-02-05 21:20:07.000000000
# 2024-02-05 21:20:53.500000000
# 23
# 2024-02-05 21:26:00.500000000
# 2024-02-05 21:26:35.500000000
# 23
# 2024-02-05 21:31:48.500000000
# 2024-02-05 21:34:39.000000000
# -52
# 2024-02-05 21:39:43.500000000
# 2024-02-05 21:40:09.000000000
# 23
# 2024-02-05 21:45:13.000000000
# 2024-02-05 21:45:16.500000000
# 23
# 2024-02-05 21:50:21.500000000
# 2024-02-05 21:51:00.000000000
# -2
# 2024-02-05 21:56:02.000000000
# 2024-02-05 21:56:08.500000000
# 23
# 2024-02-05 22:01:16.000000000
# 2024-02-05 22:02:04.000000000
# 23
# 2024-02-05 22:07:14.500000000
# 2024-02-05 22:08:26.000000000
# 23
# 2024-02-05 22:13:31.500000000
# 2024-02-05 22:15:06.000000000
# 23
# 2024-02-05 22:20:07.000000000
# 2024-02-05 22:20:30.500000000
# -27
# 2024-02-05 22:25:38.000000000
# 2024-02-05 22:26:13.000000000
# 23
# 2024-02-05 22:31:16.000000000
# 2024-02-05 22:31:54.000000000
# 23
# 2024-02-05 22:36:55.500000000
# 2024-02-05 22:39:02.500000000
# 23
# 2024-02-05 22:45:02.000000000
# 2024-02-05 22:45:52.500000000
# -77
# 2024-02-05 22:50:59.500000000
# 2024-02-05 22:51:11.500000000
# 23
# 2024-02-05 22:56:13.500000000
# 2024-02-05 22:57:33.000000000
# 23
# 2024-02-05 23:02:57.000000000
# 2024-02-05 23:04:13.500000000
# -27
# 2024-02-05 23:09:47.000000000
# 2024-02-05 23:16:05.000000000
# 23
# 2024-02-05 23:21:37.000000000
# 2024-02-05 23:22:24.500000000
# 23
# 2024-02-05 23:27:30.500000000
# 2024-02-05 23:30:51.000000000
# 23
# 2024-02-05 23:35:59.000000000
# 2024-02-05 23:36:20.500000000
# -27
# 2024-02-05 23:42:23.500000000
# 2024-02-05 23:44:22.500000000
# -2
# 2024-02-05 23:49:55.000000000
# 2024-02-05 23:59:47.500000000
# -27
# 2024-02-06 00:04:51.000000000
# 2024-02-06 09:10:03.000000000
# 23
# 2024-02-06 09:15:04.000000000
# 2024-02-06 09:15:04.000000000
# 23
# 2024-02-06 09:20:05.000000000
# 2024-02-06 09:21:01.000000000
# 23
# 2024-02-06 09:26:02.000000000
# 2024-02-06 09:26:12.000000000
# 23
# 2024-02-06 09:31:13.500000000
# 2024-02-06 09:32:17.500000000
# 23
# 2024-02-06 09:37:18.500000000
# 2024-02-06 09:37:45.500000000
# 23
# 2024-02-06 09:42:46.500000000
# 2024-02-06 09:43:10.000000000
# 23
# 2024-02-06 09:48:11.500000000
# 2024-02-06 09:48:31.500000000
# 23
# 2024-02-06 09:53:33.500000000
# 2024-02-06 09:53:40.000000000
# 23
# 2024-02-06 09:58:42.500000000
# 2024-02-06 10:00:40.000000000
# 23
# 2024-02-06 10:05:44.000000000
# 2024-02-06 10:06:53.000000000
# 23
# 2024-02-06 10:11:55.000000000
# 2024-02-06 10:12:04.000000000
# 23
# 2024-02-06 10:30:00.500000000
# 2024-02-06 10:30:03.500000000
# 23
# 2024-02-06 10:35:04.500000000
# 2024-02-06 10:35:36.000000000
# 23
# 2024-02-06 10:40:44.000000000
# 2024-02-06 10:41:10.000000000
# 23
# 2024-02-06 10:46:11.500000000
# 2024-02-06 10:46:38.000000000
# 23
# 2024-02-06 10:51:40.500000000
# 2024-02-06 10:51:53.000000000
# -52
# 2024-02-06 10:56:56.000000000
# 2024-02-06 10:57:04.500000000
# 23
# 2024-02-06 11:02:10.000000000
# 2024-02-06 11:03:58.000000000
# 23
# 2024-02-06 11:09:15.000000000
# 2024-02-06 11:09:15.000000000
# -77
# 2024-02-06 11:14:17.500000000
# 2024-02-06 11:14:29.500000000
# 23
# 2024-02-06 11:19:45.000000000
# 2024-02-06 13:40:19.000000000
# -152
# 2024-02-06 13:45:31.500000000
# 2024-02-06 13:45:31.500000000
# 23
# 2024-02-06 13:50:34.000000000
# 2024-02-06 13:51:11.000000000
# 23
# 2024-02-06 13:56:13.000000000
# 2024-02-06 13:56:32.000000000
# 23
# 2024-02-06 14:01:33.500000000
# 2024-02-06 14:01:33.500000000
# 23
# 2024-02-06 14:06:35.000000000
# 2024-02-06 14:07:30.000000000
# 23
# 2024-02-06 14:12:35.000000000
# 2024-02-06 14:12:44.000000000
# 23
# 2024-02-06 14:17:49.500000000
# 2024-02-06 14:17:49.500000000
# 23
# 2024-02-06 14:23:01.500000000
# 2024-02-06 14:23:01.500000000
# 23
# 2024-02-06 14:28:07.000000000
# 2024-02-06 14:28:07.000000000
# -52
# 2024-02-06 14:33:16.000000000
# 2024-02-06 14:33:27.000000000
# 23
# 2024-02-06 14:38:39.000000000
# 2024-02-06 14:38:39.000000000
# 23
# 2024-02-06 14:43:49.000000000
# 2024-02-06 14:43:53.500000000
# 23
# 2024-02-06 14:49:03.500000000
# 2024-02-06 14:49:50.000000000
# 23
# 2024-02-06 14:54:51.000000000
# 2024-02-06 21:10:06.000000000
# 23
# 2024-02-06 21:15:08.000000000
# 2024-02-06 21:15:13.000000000
# -52
# 2024-02-06 21:20:15.500000000
# 2024-02-06 21:21:15.500000000
# 23
# 2024-02-06 21:26:26.500000000
# 2024-02-06 21:26:35.000000000
# 23
# 2024-02-06 21:31:56.000000000
# 2024-02-06 21:32:02.000000000
# 23
# 2024-02-06 21:37:03.500000000
# 2024-02-06 21:38:01.000000000
# -52
# 2024-02-06 21:43:02.000000000
# 2024-02-06 21:43:32.500000000
# -52
# 2024-02-06 21:48:35.000000000
# 2024-02-06 21:49:18.500000000
# -77
# 2024-02-06 21:54:25.500000000
# 2024-02-06 21:54:39.000000000
# 23
# 2024-02-06 21:59:40.000000000
# 2024-02-06 22:00:01.000000000
# 23
# 2024-02-06 22:05:15.000000000
# 2024-02-06 22:06:00.500000000
# 23
# 2024-02-06 22:11:03.500000000
# 2024-02-06 22:12:13.500000000
# 23
# 2024-02-06 22:17:54.000000000
# 2024-02-06 22:18:41.500000000
# 23
# 2024-02-06 22:23:51.500000000
# 2024-02-06 22:24:05.500000000
# -77
# 2024-02-06 22:29:15.500000000
# 2024-02-06 22:29:19.500000000
# 23
# 2024-02-06 22:34:21.500000000
# 2024-02-06 22:34:47.000000000
# 23
# 2024-02-06 22:39:53.000000000
# 2024-02-06 22:41:00.000000000
# 23
# 2024-02-06 22:46:01.000000000
# 2024-02-06 22:46:10.500000000
# 23
# 2024-02-06 22:51:17.000000000
# 2024-02-06 22:51:52.000000000
# 23
# 2024-02-06 22:56:58.500000000
# 2024-02-06 22:58:13.000000000
# 23
# 2024-02-06 23:03:21.500000000
# 2024-02-06 23:03:23.000000000
# 23
# 2024-02-06 23:08:42.500000000
# 2024-02-06 23:08:59.000000000
# 23
# 2024-02-06 23:14:12.500000000
# 2024-02-06 23:14:12.500000000
# 23
# 2024-02-06 23:19:27.500000000
# 2024-02-06 23:19:33.000000000
# -27
# 2024-02-06 23:24:59.500000000
# 2024-02-06 23:27:13.000000000
# 23
# 2024-02-06 23:32:17.000000000
# 2024-02-06 23:32:22.500000000
# -77
# 2024-02-06 23:37:30.500000000
# 2024-02-06 23:38:50.000000000
# 23
# 2024-02-06 23:44:35.500000000
# 2024-02-06 23:50:19.500000000
# 2024-02-06 23:50:19.500000000
# 23
# 2024-02-06 23:55:40.000000000
# 2024-02-06 23:55:40.000000000
# 23
# 2024-02-07 00:01:29.000000000
# 2024-02-07 09:10:22.500000000
# 23
# 2024-02-07 09:15:24.500000000
# 2024-02-07 09:16:10.000000000
# -52
# 2024-02-07 09:21:12.000000000
# 2024-02-07 09:22:01.500000000
# 23
# 2024-02-07 09:27:06.500000000
# 2024-02-07 09:27:10.500000000
# 23
# 2024-02-07 09:32:17.000000000
# 2024-02-07 09:32:17.000000000
# 23
# 2024-02-07 09:37:18.000000000
# 2024-02-07 09:37:46.500000000
# 23
# 2024-02-07 09:42:49.000000000
# 2024-02-07 09:42:52.000000000
# 23
# 2024-02-07 09:48:02.000000000
# 2024-02-07 09:48:02.500000000
# 23
# 2024-02-07 09:53:05.500000000
# 2024-02-07 09:53:13.500000000
# -77
# 2024-02-07 09:58:17.000000000
# 2024-02-07 09:58:31.500000000
# 23
# 2024-02-07 10:03:47.500000000
# 2024-02-07 10:03:51.000000000
# 23
# 2024-02-07 10:08:58.000000000
# 2024-02-07 10:10:07.000000000
# 23
# 2024-02-07 10:30:01.000000000
# 2024-02-07 10:30:01.000000000
# -102
# 2024-02-07 10:35:10.000000000
# 2024-02-07 10:35:11.500000000
# 23
# 2024-02-07 10:40:16.500000000
# 2024-02-07 10:40:16.500000000
# 23
# 2024-02-07 10:45:27.500000000
# 2024-02-07 10:47:05.500000000
# 23
# 2024-02-07 10:52:10.500000000
# 2024-02-07 10:52:39.500000000
# -302
# 2024-02-07 10:57:40.500000000
# 2024-02-07 10:57:41.500000000
# 23
# 2024-02-07 11:02:42.500000000
# 2024-02-07 11:02:42.500000000
# 23
# 2024-02-07 11:07:46.000000000
# 2024-02-07 11:07:46.500000000
# -52
# 2024-02-07 11:12:48.000000000
# 2024-02-07 11:13:02.500000000
# -27
# 2024-02-07 11:18:06.000000000
# 2024-02-07 11:18:06.000000000
# -27
# 2024-02-07 11:23:09.000000000
# 2024-02-07 13:41:00.000000000
# 23
# 2024-02-07 13:46:04.000000000
# 2024-02-07 13:46:04.000000000
# 23
# 2024-02-07 13:51:08.500000000
# 2024-02-07 13:51:12.000000000
# 23
# 2024-02-07 13:56:17.000000000
# 2024-02-07 13:56:56.000000000
# 23
# 2024-02-07 14:01:58.500000000
# 2024-02-07 14:02:20.000000000
# 23
# 2024-02-07 14:07:21.000000000
# 2024-02-07 14:07:47.500000000
# 23
# 2024-02-07 14:12:52.500000000
# 2024-02-07 14:12:52.500000000
# 23
# 2024-02-07 14:18:03.500000000
# 2024-02-07 14:18:05.000000000
# 23
# 2024-02-07 14:23:10.000000000
# 2024-02-07 14:23:13.000000000
# 23
# 2024-02-07 14:28:15.000000000
# 2024-02-07 14:29:19.000000000
# 23
# 2024-02-07 14:34:20.500000000
# 2024-02-07 14:35:12.000000000
# 23
# 2024-02-07 14:40:19.000000000
# 2024-02-07 14:40:24.000000000
# 23
# 2024-02-07 14:45:26.000000000
# 2024-02-07 14:45:26.000000000
# 23
# 2024-02-07 14:50:28.500000000
# 2024-02-07 21:10:06.000000000
# 23
# 2024-02-07 21:15:07.000000000
# 2024-02-07 21:15:08.500000000
# 23
# 2024-02-07 21:20:10.500000000
# 2024-02-07 21:20:27.000000000
# 23
# 2024-02-07 21:25:29.000000000
# 2024-02-07 21:25:29.000000000
# -52
# 2024-02-07 21:30:31.500000000
# 2024-02-07 21:30:32.500000000
# 23
# 2024-02-07 21:35:33.500000000
# 2024-02-07 21:35:36.500000000
# 23
# 2024-02-07 21:41:00.000000000
# 2024-02-07 21:41:00.000000000
# 23
# 2024-02-07 21:46:02.500000000
# 2024-02-07 21:46:02.500000000
# 23
# 2024-02-07 21:51:05.000000000
# 2024-02-07 21:51:05.000000000
# 23
# 2024-02-07 21:56:08.000000000
# 2024-02-07 21:56:08.000000000
# 23
# 2024-02-07 22:01:13.000000000
# 2024-02-07 22:01:13.000000000
# 23
# 2024-02-07 22:06:21.500000000
# 2024-02-07 22:06:23.000000000
# -77
# 2024-02-07 22:11:25.500000000
# 2024-02-07 22:11:49.000000000
# 23
# 2024-02-07 22:16:56.500000000
# 2024-02-07 22:18:16.000000000
# -27
# 2024-02-07 22:23:21.000000000
# 2024-02-07 22:23:21.000000000
# 23
# 2024-02-07 22:28:29.500000000
# 2024-02-07 22:28:29.500000000
# 23
# 2024-02-07 22:33:35.500000000
# 2024-02-07 22:33:40.500000000
# 23
# 2024-02-07 22:39:02.000000000
# 2024-02-07 22:39:09.500000000
# -102
# 2024-02-07 22:44:14.000000000
# 2024-02-07 22:44:35.000000000
# 23
# 2024-02-07 22:49:52.500000000
# 2024-02-07 22:50:24.000000000
# 23
# 2024-02-07 22:55:26.500000000
# 2024-02-07 22:55:26.500000000
# 23
# 2024-02-07 23:00:29.000000000
# 2024-02-07 23:00:40.500000000
# 23
# 2024-02-07 23:05:42.000000000
# 2024-02-07 23:05:42.000000000
# 23
# 2024-02-07 23:10:43.500000000
# 2024-02-07 23:10:43.500000000
# 23
# 2024-02-07 23:15:48.000000000
# 2024-02-07 23:15:48.000000000
# -2
# 2024-02-07 23:20:59.000000000
# 2024-02-07 23:21:17.500000000
# 23
# 2024-02-07 23:26:32.000000000
# 2024-02-07 23:26:32.000000000
# -2
# 2024-02-07 23:31:55.000000000
# 2024-02-07 23:31:55.000000000
# 23
# 2024-02-07 23:37:36.500000000
# 2024-02-07 23:39:04.000000000
# 23
# 2024-02-07 23:44:45.000000000
# 2024-02-07 23:44:53.500000000
# 23
# 2024-02-07 23:49:59.000000000
# 2024-02-07 23:49:59.000000000
# 23
# 2024-02-07 23:55:13.000000000
# 2024-02-07 23:55:13.500000000
# 23
# 2024-02-08 00:00:16.500000000
# 2024-02-08 09:10:04.500000000
# 23
# 2024-02-08 09:15:05.500000000
# 2024-02-08 09:15:05.500000000
# -52
# 2024-02-08 09:20:14.500000000
# 2024-02-08 09:20:14.500000000
# 23
# 2024-02-08 09:25:18.000000000
# 2024-02-08 09:25:18.000000000
# 23
# 2024-02-08 09:30:21.500000000
# 2024-02-08 09:30:33.000000000
# 23
# 2024-02-08 09:35:45.000000000
# 2024-02-08 09:37:03.000000000
# -52
# 2024-02-08 09:42:18.000000000
# 2024-02-08 09:42:56.500000000
# -52
# 2024-02-08 09:47:59.500000000
# 2024-02-08 09:49:38.500000000
# -52
# 2024-02-08 09:54:46.500000000
# 2024-02-08 09:54:46.500000000
# 23
# 2024-02-08 09:59:50.500000000
# 2024-02-08 09:59:57.000000000
# 23
# 2024-02-08 10:05:01.000000000
# 2024-02-08 10:05:05.000000000
# -27
# 2024-02-08 10:10:10.000000000
# 2024-02-08 10:10:49.000000000
# 23
# 2024-02-08 10:30:00.500000000
# 2024-02-08 10:30:01.500000000
# -102
# 2024-02-08 10:35:04.500000000
# 2024-02-08 10:35:30.500000000
# -52
# 2024-02-08 10:40:32.500000000
# 2024-02-08 10:40:52.000000000
# 23
# 2024-02-08 10:45:58.000000000
# 2024-02-08 10:46:00.500000000
# 23
# 2024-02-08 10:51:04.000000000
# 2024-02-08 10:51:57.500000000
# 23
# 2024-02-08 10:56:59.500000000
# 2024-02-08 10:57:07.500000000
# -77
# 2024-02-08 11:02:14.000000000
# 2024-02-08 11:02:14.500000000
# 23
# 2024-02-08 11:07:25.000000000
# 2024-02-08 11:10:01.500000000
# 23
# 2024-02-08 11:15:06.000000000
# 2024-02-08 11:15:08.000000000
# 23
# 2024-02-08 11:20:09.000000000
# 2024-02-08 13:40:01.000000000
# 23
# 2024-02-08 13:45:05.000000000
# 2024-02-08 13:45:23.000000000
# 23
# 2024-02-08 13:50:25.000000000
# 2024-02-08 13:50:25.000000000
# 23
# 2024-02-08 13:55:28.500000000
# 2024-02-08 13:56:21.500000000
# 23
# 2024-02-08 14:01:28.500000000
# 2024-02-08 14:01:55.500000000
# 23
# 2024-02-08 14:06:59.000000000
# 2024-02-08 14:07:03.000000000
# 23
# 2024-02-08 14:12:05.000000000
# 2024-02-08 14:12:18.500000000
# 23
# 2024-02-08 14:17:28.500000000
# 2024-02-08 14:18:08.000000000
# 23
# 2024-02-08 14:23:13.000000000
# 2024-02-08 14:24:03.500000000
# 23
# 2024-02-08 14:29:04.500000000
# 2024-02-08 14:30:03.500000000
# 23
# 2024-02-08 14:35:05.500000000
# 2024-02-08 14:36:33.500000000
# 23
# 2024-02-08 14:41:35.500000000
# 2024-02-08 14:41:45.000000000
# 23
# 2024-02-08 14:46:54.000000000
# 2024-02-08 14:47:55.000000000
# 23
# 2024-02-08 14:52:56.500000000
# 2024-02-19 09:10:25.500000000
# 23
# 2024-02-19 09:15:27.500000000
# 2024-02-19 09:15:37.000000000
# 23
# 2024-02-19 09:20:38.000000000
# 2024-02-19 09:21:06.000000000
# -102
# 2024-02-19 09:26:08.000000000
# 2024-02-19 09:26:16.000000000
# 23
# 2024-02-19 09:31:18.000000000
# 2024-02-19 09:31:59.000000000
# 23
# 2024-02-19 09:37:01.500000000
# 2024-02-19 09:37:19.500000000
# 23
# 2024-02-19 09:42:21.000000000
# 2024-02-19 09:42:53.500000000
# 23
# 2024-02-19 09:47:54.500000000
# 2024-02-19 09:48:04.500000000
# 23
# 2024-02-19 09:53:09.500000000
# 2024-02-19 09:55:55.000000000
# -52
# 2024-02-19 10:00:59.000000000
# 2024-02-19 10:01:06.500000000
# 23
# 2024-02-19 10:06:08.000000000
# 2024-02-19 10:06:14.500000000
# 23
# 2024-02-19 10:11:17.000000000
# 2024-02-19 10:11:19.500000000
# 23
# 2024-02-19 10:30:00.500000000
# 2024-02-19 10:31:06.000000000
# 23
# 2024-02-19 10:36:11.500000000
# 2024-02-19 10:37:06.500000000
# 23
# 2024-02-19 10:42:07.500000000
# 2024-02-19 10:42:33.000000000
# -27
# 2024-02-19 10:47:36.500000000
# 2024-02-19 10:49:03.000000000
# 23
# 2024-02-19 10:54:05.500000000
# 2024-02-19 10:54:13.500000000
# -77
# 2024-02-19 10:59:17.500000000
# 2024-02-19 11:00:38.500000000
# 23
# 2024-02-19 11:05:40.500000000
# 2024-02-19 11:06:21.500000000
# 23
# 2024-02-19 11:11:23.500000000
# 2024-02-19 11:11:26.500000000
# 23
# 2024-02-19 11:16:32.000000000
# 2024-02-19 11:17:12.500000000
# -27
# 2024-02-19 11:22:18.000000000
# 2024-02-19 13:40:03.000000000
# 23
# 2024-02-19 13:45:04.000000000
# 2024-02-19 13:45:23.500000000
# 23
# 2024-02-19 13:50:24.500000000
# 2024-02-19 13:51:09.000000000
# 23
# 2024-02-19 13:56:11.000000000
# 2024-02-19 13:56:27.500000000
# 23
# 2024-02-19 14:01:29.500000000
# 2024-02-19 14:01:42.500000000
# 23
# 2024-02-19 14:06:43.500000000
# 2024-02-19 14:06:47.000000000
# 23
# 2024-02-19 14:11:51.500000000
# 2024-02-19 14:12:02.500000000
# 23
# 2024-02-19 14:17:06.500000000
# 2024-02-19 14:17:23.500000000
# 23
# 2024-02-19 14:22:26.000000000
# 2024-02-19 14:22:27.000000000
# -52
# 2024-02-19 14:27:28.000000000
# 2024-02-19 14:29:46.000000000
# 23
# 2024-02-19 14:34:58.500000000
# 2024-02-19 14:35:58.500000000
# 23
# 2024-02-19 14:41:00.500000000
# 2024-02-19 14:41:30.500000000
# 23
# 2024-02-19 14:46:43.500000000
# 2024-02-19 14:46:46.500000000
# 23
# 2024-02-19 14:51:49.500000000
# 2024-02-19 21:10:01.500000000
# 23
# 2024-02-19 21:15:02.500000000
# 2024-02-19 21:16:48.000000000
# -52
# 2024-02-19 21:21:49.000000000
# 2024-02-19 21:22:04.500000000
# 23
# 2024-02-19 21:27:06.000000000
# 2024-02-19 21:30:36.000000000
# 23
# 2024-02-19 21:35:37.000000000
# 2024-02-19 21:35:43.500000000
# 23
# 2024-02-19 21:40:45.000000000
# 2024-02-19 21:41:18.500000000
# 23
# 2024-02-19 21:46:19.500000000
# 2024-02-19 21:46:30.000000000
# 23
# 2024-02-19 21:51:31.500000000
# 2024-02-19 21:54:42.000000000
# -52
# 2024-02-19 21:59:43.500000000
# 2024-02-19 22:00:03.000000000
# -52
# 2024-02-19 22:05:04.000000000
# 2024-02-19 22:07:55.000000000
# 23
# 2024-02-19 22:12:56.000000000
# 2024-02-19 22:13:24.000000000
# 23
# 2024-02-19 22:18:25.500000000
# 2024-02-19 22:20:41.500000000
# 23
# 2024-02-19 22:25:42.500000000
# 2024-02-19 22:26:09.000000000
# -77
# 2024-02-19 22:31:11.000000000
# 2024-02-19 22:31:58.000000000
# 23
# 2024-02-19 22:36:59.500000000
# 2024-02-19 22:37:15.500000000
# 23
# 2024-02-19 22:42:18.500000000
# 2024-02-19 22:45:07.500000000
# 23
# 2024-02-19 22:50:19.500000000
# 2024-02-19 22:51:24.000000000
# 23
# 2024-02-19 22:56:25.500000000
# 2024-02-19 22:58:28.000000000
# 23
# 2024-02-19 23:03:31.500000000
# 2024-02-19 23:06:09.000000000
# -27
# 2024-02-19 23:11:14.000000000
# 2024-02-19 23:12:30.500000000
# -27
# 2024-02-19 23:17:31.500000000
# 2024-02-19 23:19:23.500000000
# -27
# 2024-02-19 23:24:39.500000000
# 2024-02-19 23:27:24.000000000
# -27
# 2024-02-19 23:32:42.000000000
# 2024-02-19 23:35:02.000000000
# 23
# 2024-02-19 23:40:04.000000000
# 2024-02-19 23:42:50.000000000
# -52
# 2024-02-19 23:47:56.500000000
# 2024-02-19 23:48:49.500000000
# -27
# 2024-02-19 23:53:51.000000000
# 2024-02-20 09:10:23.000000000
# 23
# 2024-02-20 09:15:25.000000000
# 2024-02-20 09:15:25.000000000
# 23
# 2024-02-20 09:20:27.000000000
# 2024-02-20 09:20:44.000000000
# -52
# 2024-02-20 09:25:46.500000000
# 2024-02-20 09:27:05.000000000
# -52
# 2024-02-20 09:32:06.500000000
# 2024-02-20 09:34:01.500000000
# 23
# 2024-02-20 09:39:02.500000000
# 2024-02-20 09:39:24.000000000
# 23
# 2024-02-20 09:44:29.000000000
# 2024-02-20 09:45:05.000000000
# 23
# 2024-02-20 09:50:06.000000000
# 2024-02-20 09:53:03.000000000
# 23
# 2024-02-20 09:58:07.000000000
# 2024-02-20 09:59:10.500000000
# 23
# 2024-02-20 10:04:12.000000000
# 2024-02-20 10:04:41.000000000
# -127
# 2024-02-20 10:09:42.500000000
# 2024-02-20 10:09:45.500000000
# 23
# 2024-02-20 10:14:46.500000000
# 2024-02-20 10:14:57.000000000
# 23
# 2024-02-20 10:30:00.500000000
# 2024-02-20 10:30:41.000000000
# 23
# 2024-02-20 10:35:43.000000000
# 2024-02-20 10:36:25.500000000
# 23
# 2024-02-20 10:41:26.500000000
# 2024-02-20 10:42:57.000000000
# 23
# 2024-02-20 10:47:58.000000000
# 2024-02-20 10:49:48.000000000
# 23
# 2024-02-20 10:54:50.000000000
# 2024-02-20 10:56:42.500000000
# 23
# 2024-02-20 11:01:43.500000000
# 2024-02-20 11:01:55.000000000
# 23
# 2024-02-20 11:06:56.000000000
# 2024-02-20 11:06:56.500000000
# 23
# 2024-02-20 11:11:57.500000000
# 2024-02-20 11:17:24.000000000
# 23
# 2024-02-20 11:22:28.000000000
# 2024-02-20 13:42:29.500000000
# 23
# 2024-02-20 13:47:34.000000000
# 2024-02-20 13:50:49.500000000
# -52
# 2024-02-20 13:55:51.000000000
# 2024-02-20 13:55:53.500000000
# -52
# 2024-02-20 14:00:56.000000000
# 2024-02-20 14:04:52.000000000
# -52
# 2024-02-20 14:09:53.500000000
# 2024-02-20 14:11:28.000000000
# 23
# 2024-02-20 14:16:29.000000000
# 2024-02-20 14:19:24.000000000
# 23
# 2024-02-20 14:24:27.000000000
# 2024-02-20 14:32:39.000000000
# 23
# 2024-02-20 14:37:42.500000000
# 2024-02-20 14:38:20.000000000
# 23
# 2024-02-20 14:43:24.000000000
# 2024-02-20 14:44:44.000000000
# -52
# 2024-02-20 14:49:47.000000000
# 2024-02-20 21:10:49.000000000
# 23
# 2024-02-20 21:15:50.500000000
# 2024-02-20 21:15:55.000000000
# 23
# 2024-02-20 21:20:56.000000000
# 2024-02-20 21:21:09.500000000
# 23
# 2024-02-20 21:26:12.500000000
# 2024-02-20 21:28:58.500000000
# 23
# 2024-02-20 21:34:01.000000000
# 2024-02-20 21:34:31.000000000
# 23
# 2024-02-20 21:39:36.500000000
# 2024-02-20 21:41:43.500000000
# -27
# 2024-02-20 21:46:49.500000000
# 2024-02-20 21:47:44.500000000
# 23
# 2024-02-20 21:52:45.500000000
# 2024-02-20 21:54:12.000000000
# 23
# 2024-02-20 21:59:13.500000000
# 2024-02-20 22:03:46.000000000
# -27
# 2024-02-20 22:08:49.500000000
# 2024-02-20 22:09:45.500000000
# 23
# 2024-02-20 22:14:48.000000000
# 2024-02-20 22:16:45.500000000
# -27
# 2024-02-20 22:21:48.000000000
# 2024-02-20 22:23:04.000000000
# 23
# 2024-02-20 22:28:06.500000000
# 2024-02-20 22:28:48.500000000
# 23
# 2024-02-20 22:33:53.500000000
# 2024-02-20 22:34:46.000000000
# -27
# 2024-02-20 22:39:51.000000000
# 2024-02-20 22:40:31.000000000
# -27
# 2024-02-20 22:45:32.000000000
# 2024-02-20 22:47:57.500000000
# 23
# 2024-02-20 22:52:59.000000000
# 2024-02-20 22:55:43.500000000
# 23
# 2024-02-20 23:00:46.000000000
# 2024-02-20 23:01:01.000000000
# 23
# 2024-02-20 23:06:03.000000000
# 2024-02-20 23:06:04.000000000
# -27
# 2024-02-20 23:11:26.000000000
# 2024-02-20 23:18:26.000000000
# -27
# 2024-02-20 23:23:40.500000000
# 2024-02-20 23:24:54.500000000
# -27
# 2024-02-20 23:29:58.500000000
# 2024-02-20 23:30:28.000000000
# -27
# 2024-02-20 23:35:29.500000000
# 2024-02-20 23:36:39.500000000
# 23
# 2024-02-20 23:41:52.000000000
# 2024-02-20 23:43:04.000000000
# 23
# 2024-02-20 23:48:06.000000000
# 2024-02-20 23:49:06.500000000
# -27
# 2024-02-20 23:54:27.000000000
# 2024-02-20 23:54:39.000000000
# -27
# 2024-02-20 23:59:55.500000000
# 2024-02-21 09:10:19.500000000
# -77
# 2024-02-21 09:15:21.000000000
# 2024-02-21 09:15:28.500000000
# 23
# 2024-02-21 09:20:30.000000000
# 2024-02-21 09:22:17.000000000
# 23
# 2024-02-21 09:27:18.500000000
# 2024-02-21 09:28:00.500000000
# 23
# 2024-02-21 09:33:01.500000000
# 2024-02-21 09:33:29.500000000
# 23
# 2024-02-21 09:38:33.000000000
# 2024-02-21 09:39:31.500000000
# 23
# 2024-02-21 09:44:33.000000000
# 2024-02-21 09:44:43.000000000
# 23
# 2024-02-21 09:49:44.000000000
# 2024-02-21 09:50:21.000000000
# 23
# 2024-02-21 09:55:23.500000000
# 2024-02-21 09:55:34.500000000
# 23
# 2024-02-21 10:00:35.500000000
# 2024-02-21 10:02:00.500000000
# 23
# 2024-02-21 10:07:02.500000000
# 2024-02-21 10:30:45.500000000
# 23
# 2024-02-21 10:35:48.500000000
# 2024-02-21 10:40:10.000000000
# 23
# 2024-02-21 10:45:12.000000000
# 2024-02-21 10:45:19.500000000
# -52
# 2024-02-21 10:50:21.000000000
# 2024-02-21 10:56:44.000000000
# 23
# 2024-02-21 11:01:47.500000000
# 2024-02-21 11:02:54.000000000
# 23
# 2024-02-21 11:07:56.500000000
# 2024-02-21 11:08:38.000000000
# 23
# 2024-02-21 11:13:39.500000000
# 2024-02-21 11:14:46.500000000
# -27
# 2024-02-21 11:19:48.000000000
# 2024-02-21 11:19:50.000000000
# 23
# 2024-02-21 11:24:52.000000000
# 2024-02-21 13:41:48.500000000
# 23
# 2024-02-21 13:46:49.500000000
# 2024-02-21 13:46:50.000000000
# 23
# 2024-02-21 13:51:51.000000000
# 2024-02-21 13:52:03.000001000
# 23
# 2024-02-21 13:57:05.000000000
# 2024-02-21 13:57:33.000000000
# 23
# 2024-02-21 14:02:33.500000000
# 2024-02-21 14:02:34.500000000
# -77
# 2024-02-21 14:07:36.000000000
# 2024-02-21 14:08:56.500000000
# 23
# 2024-02-21 14:13:57.000001000
# 2024-02-21 14:15:45.000001000
# 23
# 2024-02-21 14:20:54.000001000
# 2024-02-21 14:21:01.000001000
# 23
# 2024-02-21 14:26:04.000000000
# 2024-02-21 14:28:00.500000000
# 23
# 2024-02-21 14:33:02.000000000
# 2024-02-21 14:37:59.000001000
# 23
# 2024-02-21 14:43:01.000001000
# 2024-02-21 14:47:12.500000000
# 23
# 2024-02-21 14:52:13.500000000
# 2024-02-21 21:11:46.500000000
# 23
# 2024-02-21 21:16:48.000000000
# 2024-02-21 21:16:53.500000000
# 23
# 2024-02-21 21:21:55.000000000
# 2024-02-21 21:24:24.000000000
# 23
# 2024-02-21 21:29:25.500000000
# 2024-02-21 21:32:12.500000000
# 23
# 2024-02-21 21:37:15.000000000
# 2024-02-21 21:39:26.500000000
# -52
# 2024-02-21 21:44:29.500000000
# 2024-02-21 21:54:33.000000000
# 23
# 2024-02-21 21:59:35.000000000
# 2024-02-21 22:05:34.500000000
# 23
# 2024-02-21 22:10:35.500000000
# 2024-02-21 22:10:38.500000000
# 23
# 2024-02-21 22:15:40.000000000
# 2024-02-21 22:16:07.500000000
# 23
# 2024-02-21 22:21:10.500000000
# 2024-02-21 22:23:23.000000000
# 23
# 2024-02-21 22:28:24.000000000
# 2024-02-21 22:29:56.000000000
# 23
# 2024-02-21 22:34:58.500000000
# 2024-02-21 22:36:42.500000000
# 23
# 2024-02-21 22:41:46.500000000
# 2024-02-21 22:41:48.500000000
# -27
# 2024-02-21 22:46:50.000000000
# 2024-02-21 22:47:00.000000000
# 23
# 2024-02-21 22:52:01.500000000
# 2024-02-21 22:52:55.000000000
# -77
# 2024-02-21 22:57:56.000000000
# 2024-02-21 22:58:07.500000000
# 23
# 2024-02-21 23:03:11.000000000
# 2024-02-21 23:03:59.500000000
# 23
# 2024-02-21 23:09:00.500000000
# 2024-02-21 23:11:25.000000000
# 23
# 2024-02-21 23:16:33.000000000
# 2024-02-21 23:17:11.500000000
# 23
# 2024-02-21 23:22:19.000000000
# 2024-02-21 23:30:56.000000000
# 2024-02-21 23:32:11.000000000
# -27
# 2024-02-21 23:37:22.000000000
# 2024-02-21 23:46:10.000000000
# -27
# 2024-02-21 23:51:12.500000000
# 2024-02-22 09:10:43.500000000
# 23
# 2024-02-22 09:15:48.000000000
# 2024-02-22 09:16:36.000000000
# 23
# 2024-02-22 09:21:38.500000000
# 2024-02-22 09:21:38.500000000
# 23
# 2024-02-22 09:26:42.500000000
# 2024-02-22 09:31:00.500000000
# 23
# 2024-02-22 09:36:09.500000000
# 2024-02-22 09:38:01.500000000
# 23
# 2024-02-22 09:43:03.500000000
# 2024-02-22 09:44:06.000000000
# 23
# 2024-02-22 09:49:07.000000000
# 2024-02-22 09:50:32.500000000
# -77
# 2024-02-22 09:55:34.500000000
# 2024-02-22 09:57:52.000000000
# 23
# 2024-02-22 10:02:53.000000000
# 2024-02-22 10:06:57.500000000
# -127
# 2024-02-22 10:11:59.500000000
# 2024-02-22 10:12:58.500000000
# 23
# 2024-02-22 10:30:00.500000000
# 2024-02-22 10:30:52.000000000
# 23
# 2024-02-22 10:35:55.000000000
# 2024-02-22 10:42:07.000000000
# -52
# 2024-02-22 10:47:10.000000000
# 2024-02-22 10:52:27.000000000
# 23
# 2024-02-22 10:57:28.000000000
# 2024-02-22 10:58:40.500000000
# -52
# 2024-02-22 11:03:50.500000000
# 2024-02-22 11:05:04.000000000
# 23
# 2024-02-22 11:10:12.500000000
# 2024-02-22 11:11:08.500000000
# 23
# 2024-02-22 11:16:09.500000000
# 2024-02-22 11:17:22.000000000
# 23
# 2024-02-22 11:22:23.500000000
# 2024-02-22 13:40:14.500000000
# 23
# 2024-02-22 13:45:16.000000000
# 2024-02-22 13:45:42.500000000
# 23
# 2024-02-22 13:50:46.000000000
# 2024-02-22 13:51:30.500000000
# 23
# 2024-02-22 13:56:32.000000000
# 2024-02-22 13:56:42.500000000
# 23
# 2024-02-22 14:01:43.500000000
# 2024-02-22 14:05:21.500000000
# -127
# 2024-02-22 14:10:26.500000000
# 2024-02-22 14:12:08.500000000
# 23
# 2024-02-22 14:17:12.000000000
# 2024-02-22 14:18:02.000000000
# 23
# 2024-02-22 14:23:04.000000000
# 2024-02-22 14:23:47.500000000
# 23
# 2024-02-22 14:28:51.000000000
# 2024-02-22 14:29:02.000000000
# 23
# 2024-02-22 14:34:06.500000000
# 2024-02-22 21:10:07.000000000
# 23
# 2024-02-22 21:15:08.000000000
# 2024-02-22 21:17:51.500000000
# 23
# 2024-02-22 21:22:53.000000000
# 2024-02-22 21:23:07.000000000
# -102
# 2024-02-22 21:28:08.000000000
# 2024-02-22 21:28:16.000000000
# 23
# 2024-02-22 21:33:17.000000000
# 2024-02-22 21:35:13.500000000
# -52
# 2024-02-22 21:40:14.500000000
# 2024-02-22 21:40:49.000000000
# 23
# 2024-02-22 21:45:50.000000000
# 2024-02-22 21:45:52.500000000
# 23
# 2024-02-22 21:50:53.500000000
# 2024-02-22 21:52:44.000000000
# 23
# 2024-02-22 21:57:45.000000000
# 2024-02-22 21:57:50.000000000
# 23
# 2024-02-22 22:02:52.000000000
# 2024-02-22 22:05:24.500000000
# 23
# 2024-02-22 22:10:26.000000000
# 2024-02-22 22:12:11.000000000
# 23
# 2024-02-22 22:17:22.500000000
# 2024-02-22 22:20:28.500000000
# 23
# 2024-02-22 22:25:36.500000000
# 2024-02-22 22:26:54.000000000
# 23
# 2024-02-22 22:31:56.000000000
# 2024-02-22 22:32:49.500000000
# -27
# 2024-02-22 22:37:51.000000000
# 2024-02-22 22:42:30.500000000
# -52
# 2024-02-22 22:47:32.500000000
# 2024-02-22 22:52:06.500000000
# 23
# 2024-02-22 22:57:07.500000000
# 2024-02-22 22:58:31.500000000
# -52
# 2024-02-22 23:03:45.000000000
# 2024-02-22 23:13:57.500000000
# -27
# 2024-02-22 23:19:04.500000000
# 2024-02-22 23:19:07.000000000
# 23
# 2024-02-22 23:24:08.000000000
# 2024-02-22 23:27:03.000000000
# -52
# 2024-02-22 23:32:06.000000000
# 2024-02-22 23:32:10.500000000
# -27
# 2024-02-22 23:37:17.000000000
# 2024-02-22 23:43:20.500000000
# -27
# 2024-02-22 23:48:39.000000000
# 2024-02-22 23:50:51.000000000
# -27
# 2024-02-22 23:55:58.000000000
# 2024-02-22 23:59:17.500000000
# -2
# 2024-02-23 00:04:24.000000000
# 2024-02-23 09:12:53.000000000
# 23
# 2024-02-23 09:17:54.000000000
# 2024-02-23 09:18:13.000000000
# -27
# 2024-02-23 09:23:15.000000000
# 2024-02-23 09:25:40.000000000
# -127
# 2024-02-23 09:30:41.000000000
# 2024-02-23 09:35:13.500000000
# 23
# 2024-02-23 09:40:15.000000000
# 2024-02-23 09:41:47.500000000
# -77
# 2024-02-23 09:46:48.500000000
# 2024-02-23 09:47:06.000000000
# 23
# 2024-02-23 09:52:09.500000000
# 2024-02-23 09:53:56.500000000
# 23
# 2024-02-23 09:58:57.500000000
# 2024-02-23 09:58:57.500000000
# 23
# 2024-02-23 10:03:58.500000000
# 2024-02-23 10:04:02.000000000
# 23
# 2024-02-23 10:09:04.000000000
# 2024-02-23 10:09:55.500000000
# 23
# 2024-02-23 10:14:56.500000000
# 2024-02-23 10:14:59.500000000
# 23
# 2024-02-23 10:35:01.000000000
# 2024-02-23 10:35:01.500000000
# -102
# 2024-02-23 10:40:02.500000000
# 2024-02-23 10:40:35.000000000
# 23
# 2024-02-23 10:45:36.000000000
# 2024-02-23 10:46:45.000000000
# 23
# 2024-02-23 10:51:50.500000000
# 2024-02-23 10:52:01.500000000
# 23
# 2024-02-23 10:57:02.500000000
# 2024-02-23 10:59:08.000000000
# 23
# 2024-02-23 11:04:09.000000000
# 2024-02-23 11:07:01.000000000
# 23
# 2024-02-23 11:12:02.500000000
# 2024-02-23 11:12:20.000000000
# 23
# 2024-02-23 11:17:21.500000000
# 2024-02-23 11:17:34.000000000
# 23
# 2024-02-23 11:22:35.000000000
# 2024-02-23 13:41:50.500000000
# 23
# 2024-02-23 13:46:51.500000000
# 2024-02-23 13:47:16.000000000
# 23
# 2024-02-23 13:52:17.500000000
# 2024-02-23 13:54:43.500000000
# -52
# 2024-02-23 13:59:44.500000000
# 2024-02-23 14:03:17.000000000
# 23
# 2024-02-23 14:08:18.000000000
# 2024-02-23 14:09:19.500000000
# 23
# 2024-02-23 14:14:22.500000000
# 2024-02-23 14:14:56.000000000
# -52
# 2024-02-23 14:19:57.000000000
# 2024-02-23 14:22:44.000000000
# 23
# 2024-02-23 14:27:45.500000000
# 2024-02-23 14:28:04.500000000
# -52
# 2024-02-23 14:33:05.500000000
# 2024-02-23 14:33:56.500000000
# 23
# 2024-02-23 14:38:59.000000000
# 2024-02-23 14:39:15.000000000
# -52
# 2024-02-23 14:44:18.500000000
# 2024-02-23 14:45:57.500000000
# 23
# 2024-02-23 14:50:58.500000000
# 2024-02-23 21:10:09.000000000
# -52
# 2024-02-23 21:15:10.000000000
# 2024-02-23 21:15:15.500000000
# 23
# 2024-02-23 21:20:19.000000000
# 2024-02-23 21:20:25.500000000
# -102
# 2024-02-23 21:25:26.500000000
# 2024-02-23 21:26:22.500000000
# 23
# 2024-02-23 21:31:23.500000000
# 2024-02-23 21:32:44.000000000
# 23
# 2024-02-23 21:37:45.000000000
# 2024-02-23 21:37:45.000000000
# 23
# 2024-02-23 21:42:50.000000000
# 2024-02-23 21:46:17.000000000
# 23
# 2024-02-23 21:51:18.000000000
# 2024-02-23 21:51:53.000000000
# 23
# 2024-02-23 21:56:55.500000000
# 2024-02-23 21:57:16.000000000
# 23
# 2024-02-23 22:02:18.000000000
# 2024-02-23 22:06:21.000000000
# 23
# 2024-02-23 22:11:22.500000000
# 2024-02-23 22:12:23.500000000
# -27
# 2024-02-23 22:17:25.000000000
# 2024-02-23 22:18:14.000000000
# 23
# 2024-02-23 22:23:17.500000000
# 2024-02-23 22:24:05.500000000
# 23
# 2024-02-23 22:29:07.000000000
# 2024-02-23 22:31:39.000000000
# 23
# 2024-02-23 22:36:46.500000000
# 2024-02-23 22:40:15.500000000
# 23
# 2024-02-23 22:45:22.500000000
# 2024-02-23 22:50:42.000000000
# 23
# 2024-02-23 22:55:43.000000000
# 2024-02-23 22:57:33.500000000
# 23
# 2024-02-23 23:02:34.500000000
# 2024-02-23 23:02:47.000000000
# -102
# 2024-02-23 23:07:50.500000000
# 2024-02-23 23:07:59.000000000
# 23
# 2024-02-23 23:13:03.000000000
# 2024-02-23 23:14:26.000000000
# 23
# 2024-02-23 23:19:27.000000000
# 2024-02-23 23:22:03.500000000
# 23
# 2024-02-23 23:27:06.500000000
# 2024-02-23 23:28:01.000000000
# 23
# 2024-02-23 23:33:08.000000000
# 2024-02-23 23:34:15.000000000
# 23
# 2024-02-23 23:39:21.000000000
# 2024-02-23 23:41:10.500000000
# 23
# 2024-02-23 23:46:32.500000000
# 2024-02-23 23:47:42.500000000
# -127
# 2024-02-23 23:52:44.000000000
# 2024-02-23 23:52:50.500000000
# 23
# 2024-02-23 23:57:52.500000000
# 2024-02-23 23:58:06.000000000
# 23
# 2024-02-24 00:03:08.000000000
# 2024-02-26 09:10:10.000000000
# 23
# 2024-02-26 09:15:11.500000000
# 2024-02-26 09:17:08.500000000
# 23
# 2024-02-26 09:22:10.000000000
# 2024-02-26 09:22:40.500000000
# 23
# 2024-02-26 09:27:41.500000000
# 2024-02-26 09:27:49.000000000
# 23
# 2024-02-26 09:32:52.000000000
# 2024-02-26 09:34:31.000000000
# 23
# 2024-02-26 09:39:41.000000000
# 2024-02-26 09:40:22.500000000
# 23
# 2024-02-26 09:45:24.500000000
# 2024-02-26 09:45:52.500000000
# 23
# 2024-02-26 09:50:58.500000000
# 2024-02-26 09:51:27.000000000
# 23
# 2024-02-26 09:56:28.500000000
# 2024-02-26 09:56:28.500000000
# 23
# 2024-02-26 10:01:29.500000000
# 2024-02-26 10:01:32.500000000
# 23
# 2024-02-26 10:06:37.000000000
# 2024-02-26 10:07:16.000000000
# 23
# 2024-02-26 10:12:23.000000000
# 2024-02-26 10:12:32.500000000
# 23
# 2024-02-26 10:30:00.500000000
# 2024-02-26 10:31:51.000000000
# -102
# 2024-02-26 10:36:53.500000000
# 2024-02-26 10:37:17.000000000
# 23
# 2024-02-26 10:42:19.000000000
# 2024-02-26 10:45:12.000000000
# 23
# 2024-02-26 10:50:13.000000000
# 2024-02-26 10:50:23.500000000
# 23
# 2024-02-26 10:55:28.000000000
# 2024-02-26 10:56:04.000000000
# -52
# 2024-02-26 11:01:08.000000000
# 2024-02-26 11:01:55.500000000
# -27
# 2024-02-26 11:06:59.500000000
# 2024-02-26 11:11:46.000000000
# 23
# 2024-02-26 11:16:47.500000000
# 2024-02-26 13:40:12.000000000
# -77
# 2024-02-26 13:45:15.000000000
# 2024-02-26 13:45:55.500000000
# 23
# 2024-02-26 13:51:03.500000000
# 2024-02-26 13:51:10.000000000
# 23
# 2024-02-26 13:56:12.500000000
# 2024-02-26 14:00:44.000000000
# -27
# 2024-02-26 14:05:45.500000000
# 2024-02-26 14:07:03.000000000
# 23
# 2024-02-26 14:12:11.000000000
# 2024-02-26 14:12:42.000000000
# -27
# 2024-02-26 14:17:47.500000000
# 2024-02-26 14:22:25.500000000
# 23
# 2024-02-26 14:27:27.500000000
# 2024-02-26 14:29:09.000000000
# -102
# 2024-02-26 14:34:18.000000000
# 2024-02-26 14:36:37.500000000
# 23
# 2024-02-26 14:41:42.500000000
# 2024-02-26 14:45:56.500000000
# 23
# 2024-02-26 14:50:58.500000000
# 2024-02-26 21:10:01.000000000
# 23
# 2024-02-26 21:15:02.000000000
# 2024-02-26 21:17:32.500000000
# 23
# 2024-02-26 21:22:33.500000000
# 2024-02-26 21:23:32.500000000
# 23
# 2024-02-26 21:28:33.500000000
# 2024-02-26 21:30:27.000000000
# 23
# 2024-02-26 21:35:28.500000000
# 2024-02-26 21:35:29.500000000
# 23
# 2024-02-26 21:40:31.500000000
# 2024-02-26 21:42:31.000000000
# 23
# 2024-02-26 21:47:32.000000000
# 2024-02-26 21:47:57.500000000
# 23
# 2024-02-26 21:52:59.000000000
# 2024-02-26 21:53:04.500000000
# 23
# 2024-02-26 21:58:06.500000000
# 2024-02-26 22:00:23.000000000
# -52
# 2024-02-26 22:05:24.500000000
# 2024-02-26 22:06:37.000000000
# -52
# 2024-02-26 22:11:39.500000000
# 2024-02-26 22:13:09.000000000
# 23
# 2024-02-26 22:18:11.500000000
# 2024-02-26 22:22:15.000000000
# 23
# 2024-02-26 22:27:19.000000000
# 2024-02-26 22:27:31.000000000
# 23
# 2024-02-26 22:32:36.000000000
# 2024-02-26 22:34:02.000000000
# -52
# 2024-02-26 22:39:04.000000000
# 2024-02-26 22:39:07.000000000
# 23
# 2024-02-26 22:44:08.000000000
# 2024-02-26 22:49:04.500000000
# 23
# 2024-02-26 22:54:06.000000000
# 2024-02-26 22:57:55.500000000
# 23
# 2024-02-26 23:02:59.000000000
# 2024-02-26 23:05:38.500000000
# -27
# 2024-02-26 23:10:42.000000000
# 2024-02-26 23:11:29.500000000
# -2
# 2024-02-26 23:16:31.500000000
# 2024-02-26 23:19:09.000000000
# -27
# 2024-02-26 23:24:20.500000000
# 2024-02-26 23:29:49.000000000
# -52
# 2024-02-26 23:34:52.000000000
# 2024-02-26 23:42:50.500000000
# -27
# 2024-02-26 23:48:09.000000000
# 2024-02-26 23:59:37.500000000
# 23
# 2024-02-27 00:04:41.000000000
# 2024-02-27 09:11:32.000000000
# 23
# 2024-02-27 09:16:33.000000000
# 2024-02-27 09:17:31.000000000
# 23
# 2024-02-27 09:22:32.000000000
# 2024-02-27 09:22:51.000000000
# -227
# 2024-02-27 09:27:52.000000000
# 2024-02-27 09:27:56.500000000
# 23
# 2024-02-27 09:32:57.500000000
# 2024-02-27 09:34:32.000000000
# 23
# 2024-02-27 09:39:34.000000000
# 2024-02-27 09:39:55.000000000
# 23
# 2024-02-27 09:44:56.500000000
# 2024-02-27 09:45:01.000000000
# 23
# 2024-02-27 09:50:02.000000000
# 2024-02-27 09:50:33.500000000
# -152
# 2024-02-27 09:55:34.500000000
# 2024-02-27 09:55:34.500000000
# 23
# 2024-02-27 10:00:35.500000000
# 2024-02-27 10:00:38.500000000
# 23
# 2024-02-27 10:05:39.500000000
# 2024-02-27 10:05:49.500000000
# 23
# 2024-02-27 10:10:50.500000000
# 2024-02-27 10:10:58.500000000
# 23
# 2024-02-27 10:30:00.500000000
# 2024-02-27 10:30:01.000000000
# 23
# 2024-02-27 10:35:02.000000000
# 2024-02-27 10:35:06.500000000
# 23
# 2024-02-27 10:40:09.500000000
# 2024-02-27 10:41:00.000000000
# -52
# 2024-02-27 10:46:01.000000000
# 2024-02-27 10:47:20.500000000
# 23
# 2024-02-27 10:52:22.000000000
# 2024-02-27 10:52:46.000000000
# -152
# 2024-02-27 10:57:47.000000000
# 2024-02-27 10:58:30.500000000
# 23
# 2024-02-27 11:03:31.500000000
# 2024-02-27 11:03:42.000000000
# 23
# 2024-02-27 11:08:43.000000000
# 2024-02-27 11:08:59.500000000
# 23
# 2024-02-27 11:14:02.000000000
# 2024-02-27 11:16:00.500000000
# 23
# 2024-02-27 11:21:06.000000000
# 2024-02-27 13:40:03.500000000
# 23
# 2024-02-27 13:45:04.500000000
# 2024-02-27 13:45:13.500000000
# 23
# 2024-02-27 13:50:20.000000000
# 2024-02-27 13:50:34.500000000
# 23
# 2024-02-27 13:55:39.000000000
# 2024-02-27 13:57:17.500000000
# 23
# 2024-02-27 14:02:20.500000000
# 2024-02-27 14:03:03.000000000
# 23
# 2024-02-27 14:08:05.000000000
# 2024-02-27 14:11:06.000000000
# 23
# 2024-02-27 14:16:07.000000000
# 2024-02-27 14:18:13.000000000
# -52
# 2024-02-27 14:23:15.000000000
# 2024-02-27 14:24:10.000000000
# 23
# 2024-02-27 14:29:11.000000000
# 2024-02-27 14:32:47.000000000
# -77
# 2024-02-27 14:37:50.000000000
# 2024-02-27 14:38:32.500000000
# 23
# 2024-02-27 14:43:34.500000000
# 2024-02-27 14:47:11.000000000
# 23
# 2024-02-27 14:52:12.000000000
# 2024-02-27 21:10:35.500000000
# -52
# 2024-02-27 21:15:37.000000000
# 2024-02-27 21:15:45.500000000
# 23
# 2024-02-27 21:20:46.500000000
# 2024-02-27 21:21:43.500000000
# 23
# 2024-02-27 21:26:47.500000000
# 2024-02-27 21:28:33.500000000
# 23
# 2024-02-27 21:33:34.500000000
# 2024-02-27 21:36:01.000000000
# 23
# 2024-02-27 21:41:02.500000000
# 2024-02-27 21:43:06.500000000
# -77
# 2024-02-27 21:48:07.500000000
# 2024-02-27 21:49:20.000000000
# 23
# 2024-02-27 21:54:29.000000000
# 2024-02-27 21:55:30.000000000
# 23
# 2024-02-27 22:00:32.000000000
# 2024-02-27 22:01:03.500000000
# 23
# 2024-02-27 22:06:10.500000000
# 2024-02-27 22:07:38.000000000
# -27
# 2024-02-27 22:12:39.500000000
# 2024-02-27 22:14:53.000000000
# 23
# 2024-02-27 22:19:54.500000000
# 2024-02-27 22:27:22.500000000
# -77
# 2024-02-27 22:32:24.500000000
# 2024-02-27 22:32:37.000000000
# 23
# 2024-02-27 22:37:38.000000000
# 2024-02-27 22:38:14.500000000
# -52
# 2024-02-27 22:43:15.500000000
# 2024-02-27 22:47:20.500000000
# 23
# 2024-02-27 22:52:23.000000000
# 2024-02-27 22:58:15.000000000
# -52
# 2024-02-27 23:03:22.000000000
# 2024-02-27 23:05:28.500000000
# 23
# 2024-02-27 23:10:33.000000000
# 2024-02-27 23:10:36.500000000
# -52
# 2024-02-27 23:15:41.000000000
# 2024-02-27 23:19:19.000000000
# 23
# 2024-02-27 23:24:20.000000000
# 2024-02-27 23:24:48.000000000
# 23
# 2024-02-27 23:30:00.000000000
# 2024-02-27 23:33:22.500000000
# -2
# 2024-02-27 23:38:37.000000000
# 2024-02-27 23:48:01.000000000
# -27
# 2024-02-27 23:53:04.500000000
# 2024-02-28 09:10:54.500000000
# 23
# 2024-02-28 09:15:57.000000000
# 2024-02-28 09:16:47.500000000
# 23
# 2024-02-28 09:21:53.500000000
# 2024-02-28 09:22:42.500000000
# -152
# 2024-02-28 09:27:43.500000000
# 2024-02-28 09:30:35.000000000
# 23
# 2024-02-28 09:35:39.500000000
# 2024-02-28 09:36:05.500000000
# 23
# 2024-02-28 09:41:09.500000000
# 2024-02-28 09:45:12.000000000
# 23
# 2024-02-28 09:50:13.000000000
# 2024-02-28 09:50:48.500000000
# 23
# 2024-02-28 09:55:52.000000000
# 2024-02-28 09:56:39.500000000
# 23
# 2024-02-28 10:01:43.500000000
# 2024-02-28 10:03:08.500000000
# 23
# 2024-02-28 10:08:10.000000000
# 2024-02-28 10:09:43.000000000
# -77
# 2024-02-28 10:14:44.000000000
# 2024-02-28 10:30:22.000000000
# 23
# 2024-02-28 10:35:23.000000000
# 2024-02-28 10:37:10.500000000
# 23
# 2024-02-28 10:42:12.500000000
# 2024-02-28 10:42:43.500000000
# 23
# 2024-02-28 10:47:46.500000000
# 2024-02-28 10:51:57.000000000
# 23
# 2024-02-28 10:56:58.500000000
# 2024-02-28 10:57:46.500000000
# 23
# 2024-02-28 11:02:48.000000000
# 2024-02-28 11:05:07.500000000
# 23
# 2024-02-28 11:10:09.000000000
# 2024-02-28 11:10:13.500000000
# 23
# 2024-02-28 11:15:14.500000000
# 2024-02-28 11:15:18.000000000
# -77
# 2024-02-28 11:20:19.000000000
# 2024-02-28 13:41:17.000000000
# 23
# 2024-02-28 13:46:18.500000000
# 2024-02-28 13:46:46.000000000
# -52
# 2024-02-28 13:51:48.000000000
# 2024-02-28 13:54:58.000000000
# 23
# 2024-02-28 14:00:01.000000000
# 2024-02-28 14:03:25.500000000
# 23
# 2024-02-28 14:08:27.500000000
# 2024-02-28 14:08:35.000000000
# -77
# 2024-02-28 14:13:37.500000000
# 2024-02-28 14:13:58.500000000
# 23
# 2024-02-28 14:18:59.500000000
# 2024-02-28 14:19:53.000000000
# 23
# 2024-02-28 14:24:55.500000000
# 2024-02-28 14:25:52.500000000
# 23
# 2024-02-28 14:30:56.000000000
# 2024-02-28 14:36:43.000000000
# 23
# 2024-02-28 14:41:44.500000000
# 2024-02-28 14:42:27.000000000
# 23
# 2024-02-28 14:47:28.000000000
# 2024-02-05: 265.00
# 2024-02-06: 472.00
# 2024-02-07: 341.00
# 2024-02-08: 132.00
# 2024-02-19: 232.00
# 2024-02-20: 115.00
# 2024-02-21: 500.00
# 2024-02-22: -100.00
# 2024-02-23: 61.00
# 2024-02-26: 146.00
# 2024-02-27: -233.00
# 2024-02-28: 94.00
# Final profit: 2025.00
# 0.7524916943521595
# 602
