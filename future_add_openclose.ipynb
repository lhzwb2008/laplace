# %%
import pandas as pd
from enum import Enum, auto

FILENAME = "future_taobao_ss2405_tick"

class open_interest_delta_forward_enum(Enum):
    NONE = auto()
    UNKNOWN = auto()
    EXCHANGE = auto()
    OPENFWDOUBLE = auto()
    OPEN = auto()
    CLOSEFWDOUBLE = auto()
    CLOSE = auto()

class order_forward_enum(Enum):
    UP = auto()
    DOWN = auto()
    MIDDLE = auto()

class tick_type_key_enum(Enum):
    TICKTYPE = auto()
    TICKCOLOR = auto()

class tick_type_enum(Enum):
    NOCHANGE = '无交易'
    UNKNOWN = '未知'
    EXCHANGELONG = '多换'
    EXCHANGESHORT = '空换'
    EXCHANGEUNKOWN = '未知换'
    OPENDOUBLE = '双开'
    OPENLONG = '多开'
    OPENSHORT = '空开'
    OPENUNKOWN = '未知开'
    CLOSEDOUBLE = '双平'
    CLOSESHORT = '空平'
    CLOSELONG = '多平'
    CLOSEUNKOWN = '未知平'

class tick_color_enum(Enum):
    WHITE = '白色'
    RED = '红色'
    GREEN = '绿色'

tick_type_cal_dict = {
    open_interest_delta_forward_enum.NONE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.EXCHANGE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGELONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGESHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPENFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPEN:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENLONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENSHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSEFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSESHORT,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSELONG,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
}

 # Mapping of openclose and price_direction to open_interest_delta_forward_enum and order_forward_enum
openclose_mapping = {
    '换手': open_interest_delta_forward_enum.EXCHANGE,
    '双开': open_interest_delta_forward_enum.OPENFWDOUBLE,
    '开仓': open_interest_delta_forward_enum.OPEN,
    '双平': open_interest_delta_forward_enum.CLOSEFWDOUBLE,  # Assuming definition for 双平
    '平仓': open_interest_delta_forward_enum.CLOSE,
    '无交易': open_interest_delta_forward_enum.NONE,
    '未知':open_interest_delta_forward_enum.UNKNOWN
}

price_direction_mapping = {
    '向上': order_forward_enum.UP,
    '向下': order_forward_enum.DOWN,
    '不变': order_forward_enum.MIDDLE
}

# 枚举到中文的映射
tick_type_to_chinese = {
    tick_type_enum.NOCHANGE: '无交易',
    tick_type_enum.UNKNOWN: '未知',
    tick_type_enum.EXCHANGELONG: '多换',
    tick_type_enum.EXCHANGESHORT: '空换',
    tick_type_enum.EXCHANGEUNKOWN: '未知换',
    tick_type_enum.OPENDOUBLE: '双开',
    tick_type_enum.OPENLONG: '开多',
    tick_type_enum.OPENSHORT: '开空',
    tick_type_enum.OPENUNKOWN: '未知开',
    tick_type_enum.CLOSEDOUBLE: '双平',
    tick_type_enum.CLOSESHORT: '空平',
    tick_type_enum.CLOSELONG: '多平',
    tick_type_enum.CLOSEUNKOWN: '未知平',
}

tick_color_to_chinese = {
    tick_color_enum.WHITE: '白色',
    tick_color_enum.RED: '红色',
    tick_color_enum.GREEN: '绿色',
}


# Load the tick data
df = pd.read_csv(FILENAME+".csv")

# Calculate the deltas for volume and open interest
df['volume_delta'] = df['volume'].diff()
df['open_interest_delta'] = df['open_interest'].diff()

# Initialize columns for open/close position
df['trade_openclose'] = None
df['trade_color'] = None 
df['close_count'] = df['volume_delta']

# Iterate over the DataFrame to assign open/close positions
for i in range(1, len(df)):
    volume_delta = df.loc[i, 'volume_delta']
    open_interest_delta = df.loc[i, 'open_interest_delta']
    last_price = df.loc[i, 'last_price']
    ask_price1 = df.loc[i, 'ask_price1']
    bid_price1 = df.loc[i, 'bid_price1']
    pre_last_price = df.loc[i-1,'last_price']
    pre_ask_price1 = df.loc[i-1, 'ask_price1']
    pre_bid_price1 = df.loc[i-1, 'bid_price1']
    openclose = ''
    price_direction = ''

    # Determine the open/close position
    if volume_delta == open_interest_delta > 0:
        openclose = '双开'
    elif volume_delta > open_interest_delta > 0:
        openclose = '开仓'
    elif volume_delta > abs(open_interest_delta) > 0 and open_interest_delta < 0:
        openclose = '平仓'
    elif volume_delta > 0 and open_interest_delta == 0:
        openclose = '换手'
    elif volume_delta + open_interest_delta == 0 and volume_delta>0:
        openclose = '双平'
    elif volume_delta == 0 and  open_interest_delta == 0:
        openclose = '无交易'
    else:
        openclose = '未知'
    
    # 判断价格方向
    if last_price >= pre_ask_price1:
        price_direction = '向上'
    elif last_price <= pre_bid_price1:
        price_direction = '向下'
    elif last_price >= ask_price1:
        price_direction = '向上'
    elif last_price <= bid_price1:
        price_direction = '向下'
    else:
        price_direction = '不变'
        
   

    # Convert openclose and price_direction to their corresponding enum values
    delta_enum = openclose_mapping.get(openclose, open_interest_delta_forward_enum.NONE)
    direction_enum = price_direction_mapping.get(price_direction, order_forward_enum.MIDDLE)

    # Retrieve the tick type and color based on the mappings
    tick_info = tick_type_cal_dict.get(delta_enum, {}).get(direction_enum, {})
    tick_type = tick_info.get(tick_type_key_enum.TICKTYPE, tick_type_enum.UNKNOWN)
    tick_color = tick_info.get(tick_type_key_enum.TICKCOLOR, tick_color_enum.WHITE)
    

    # 使用映射转换为中文描述
    tick_type_chinese = tick_type_to_chinese[tick_type]
    tick_color_chinese = tick_color_to_chinese[tick_color]

    # 更新DataFrame
    df.at[i, 'trade_openclose'] = tick_type_chinese
    df.at[i, 'trade_color'] = tick_color_chinese

# Save the modified DataFrame to a new CSV file
df.to_csv(FILENAME+"_withopenclose.csv", index=False)

# %%
import pandas as pd

# 假设已加载并准备好DataFrame df
df = pd.read_csv(FILENAME+"_withopenclose.csv")

df = df.loc[df['volume_delta'] > 0]
# 重置索引以确保从0开始
df.reset_index(drop=True, inplace=True)


guess_tick=100

# 初始化列用于标记交易机会
df['buy_opportunity'] = 0
df['sell_opportunity'] = 0
trade_hand = 1
trade_slippy = 0

# 为每个tick计算未来100个tick内与当前挂单价格相匹配的成交量
for i in range(len(df)):
    if i + guess_tick >= len(df):  # 确保未来有足够的tick进行分析
        break

    # 当前的买一和卖一价
    current_ask_price1 = df.loc[i, 'ask_price1']
    current_bid_price1 = df.loc[i, 'bid_price1']

    # 初始化对应价格的成交量计数
    matching_buy_volume = 0
    matching_sell_volume = 0
    
    buy_done = 0
    sell_done = 0

    # 遍历未来100个tick
    for j in range(i+1, i+guess_tick+1):
        if df.loc[j, 'bid_price1']<current_bid_price1:
            buy_done = 1 
        if df.loc[j, 'ask_price1']>current_ask_price1:
            sell_done = 1 
        # 如果未来tick的买一价等于当前tick的买一价，累加成交量
        if df.loc[j, 'bid_price1'] == current_bid_price1 and df.loc[j, 'bid_price1'] == df.loc[j, 'last_price']:
            matching_buy_volume += df.loc[j, 'volume_delta']
        # 如果未来tick的卖一价等于当前tick的卖一价，累加成交量
        if df.loc[j, 'ask_price1'] == current_ask_price1 and df.loc[j, 'ask_price1'] == df.loc[j, 'last_price']:
            matching_sell_volume += df.loc[j, 'volume_delta']

    # 判断是否存在买卖机会
    if buy_done==1 or matching_buy_volume >= df.loc[i, 'ask_volume1']+trade_hand+trade_slippy:
        df.loc[i, 'buy_opportunity'] = 1
    if sell_done==1 or matching_sell_volume >= df.loc[i, 'bid_volume1']+trade_hand+trade_slippy:
        df.loc[i, 'sell_opportunity'] = 1


# 创建一个新列来标记同时为买卖机会的tick
df['dual_opportunity'] = ((df['buy_opportunity'] == 1) & (df['sell_opportunity'] == 1)).astype(int)

# 计算同时为买卖机会的总数
dual_opportunities_count = df['dual_opportunity'].sum()

# 计算比例
total_ticks_analyzed = len(df) - guess_tick
dual_opportunities_ratio = dual_opportunities_count / total_ticks_analyzed

print(f"Dual opportunities count: {dual_opportunities_count}")
print(f"Dual opportunities ratio: {dual_opportunities_ratio:.4f}")

# 保存到新的CSV文件
df.to_csv(FILENAME+"_with_opportunities.csv", index=False)

# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score,precision_score

FILENAME = "future_taobao_ssMain_tick"
# FILENAME = "future_taobao_ss2405_tick"

# 加载数据
data = pd.read_csv(FILENAME+"_with_opportunities.csv")

data_clean = data.dropna().copy()  # 创建一个副本以避免警告

# features = [
#     'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
#     'bid_price1', 'ask_price1', 'bid_price2', 'ask_price2', 'bid_price3', 'ask_price3',
#     'bid_price4', 'ask_price4', 'bid_price5', 'ask_price5', 'bid_volume1', 'bid_volume2',
#     'bid_volume3', 'bid_volume4', 'bid_volume5', 'ask_volume1', 'ask_volume2', 'ask_volume3',
#     'ask_volume4', 'ask_volume5'
# ]
features = [
    'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
    'bid_price1', 'ask_price1', 'bid_volume1', 'ask_volume1'
]

# window_size = 500  # 用于特征计算的窗口大小

# # 特征生成
# data_clean['rolling_mean'] = data_clean['last_price'].rolling(window=window_size).mean()
# data_clean['rolling_std'] = data_clean['last_price'].rolling(window=window_size).std()
# data_clean['ask_rolling_mean'] = data_clean['ask_price1'].rolling(window=window_size).mean()
# data_clean['ask_rolling_std'] = data_clean['ask_price1'].rolling(window=window_size).std()
# data_clean['bid_rolling_mean'] = data_clean['bid_price1'].rolling(window=window_size).mean()
# data_clean['bid_rolling_std'] = data_clean['bid_price1'].rolling(window=window_size).std()
# # RSI计算
# delta = data_clean['last_price'].diff()
# gain = (delta.where(delta > 0, 0)).fillna(0)
# loss = (-delta.where(delta < 0, 0)).fillna(0)
# avg_gain = gain.rolling(window=window_size).mean()
# avg_loss = loss.rolling(window=window_size).mean()
# rs = avg_gain / avg_loss
# data_clean['RSI'] = 100 - (100 / (1 + rs))
# # MACD计算
# short_ema = data_clean['last_price'].ewm(span=int(window_size/2), adjust=False).mean()  # 使用窗口大小的一半作为短期EMA
# long_ema = data_clean['last_price'].ewm(span=window_size, adjust=False).mean()  # 使用整个窗口大小作为长期EMA
# data_clean['MACD'] = short_ema - long_ema
# data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=int(window_size/3), adjust=False).mean()  # 使用窗口大小的三分之一作为信号线
# # 删除因计算滚动特征而产生的NaN值
# data_clean.dropna(inplace=True)
# # 添加新特征到特征列表
# features.extend(['rolling_mean', 'rolling_std','ask_rolling_mean', 'ask_rolling_std','bid_rolling_mean', 'bid_rolling_std', 'RSI', 'MACD', 'MACD_signal'])

# 目标列处理
data_clean['successful_trade'] = data_clean.apply(
    lambda row: 1 if row['buy_opportunity'] and row['sell_opportunity'] else 0, axis=1
)

X = data_clean[['datetime'] + features]
y = data_clean['successful_trade']

# 数据切分
split_start = int(len(data_clean) * 0.3)
split_point = int(len(data_clean) * 0.8)
X_train = X.iloc[split_start:split_point]
y_train = y.iloc[split_start:split_point]
X_test = X.iloc[split_point:]
y_test = y.iloc[split_point:]

# # 模型训练
# model = RandomForestClassifier(n_estimators=100, random_state=42)
# # 注意：随机森林模型不能直接处理datetime类型的特征，所以在训练前需要去除或转换该特征
# X_train_features = X_train.drop(columns=['datetime'])
# X_test_features = X_test.drop(columns=['datetime'])
# model.fit(X_train_features, y_train)

# 创建XGBoost模型并调整参数
model = xgb.XGBClassifier(
    n_estimators=100,  # 树的个数
    max_depth=6,  # 树的深度
    learning_rate=0.1,  # 学习率
    subsample=0.8,  # 训练每棵树时使用的样本比例
    colsample_bytree=0.8,  # 构建树时的列采样比例
    random_state=42,  # 随机种子
    use_label_encoder=False,  # 避免使用标签编码器的警告
    eval_metric='logloss'  # 评估指标
)
X_train_features = X_train.drop(columns=['datetime'])
X_test_features = X_test.drop(columns=['datetime'])
# 模型训练
model.fit(X_train_features, y_train)


# 获取属于类别1的概率
y_pred_proba = model.predict_proba(X_test_features)[:, 1]
# 设置交易阈值
trade_threshold = 0.65
# 根据阈值生成预测结果，大于等于阈值预测为1，否则为0
y_pred_threshold = (y_pred_proba >= trade_threshold).astype(int)
# 计算查准率
precision = precision_score(y_test, y_pred_threshold)
print(f"Precision: {precision}")
predicted_ones_count = np.sum(y_pred_threshold == 1)
total_count = len(y_pred_threshold)
print(f"Predicted as 1: {predicted_ones_count} / Total: {total_count}")

# 对照组评估（全1预测）
predictions_all_ones = [1] * len(y_test)
print("All Ones Accuracy:", precision_score(y_test, predictions_all_ones))
# Out:
# Precision: 0.6650688579471963
# Predicted as 1: 13143 / Total: 113415
# All Ones Accuracy: 0.4672926861526253

# %%
from datetime import datetime, time
import numpy as np

guess_tick = 100
profit = 0  # 盈利
trade_threshold = 0.65 # 交易阈值
trade_hand = 1
trade_slippy = 0

trade_gap = 5 #每跳多少钱
hand_volume = 5  # 不锈钢1手5吨，1手开仓2元，平今0元
hand_fee = 2
done_count = 0
count = 0
daily_profit = {}  # 新增：用于存储每日盈利
daily_trade = {}

last_date_str=''
stop = False


def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False

# 定义时间范围数组
notrade_time = ["09:00-09:20","11:20-11:30","13:30-13:40","14:50-15:00","21:00-21:10","0:00-1:00"]

i = 100
while i < len(X_test) - 100:  # 留出100个tick进行预测
    
    datetime_str = X_test.iloc[i]['datetime']
    date_str = datetime_str.split(' ')[0]  # 新增：提取日期字符串
    
    if last_date_str!= date_str: 
        daily_fail_count = 0
        daily_count = 0
        last_date_str = date_str
        stop = False
    
    if stop:
        i = i + 1
        continue
    
    if daily_profit.get(date_str, 0)  < -120:
        last_date_str = date_str
        stop = True
   
    
    
    if '.' in datetime_str:
        # 如果有小数点，分割为主时间部分和纳秒部分
        time, nano_part = datetime_str.split('.')
    else:
        # 如果没有小数点，则没有纳秒部分
        time = datetime_str
        nano_part = '0'
    if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S").time(), notrade_time):
        i = i+1
        continue
    
    
    proba = y_pred_proba[i]
    if proba < trade_threshold:
        i = i+1
        continue
    
    # 计算前100个tick的最高价和最低价差值
    price_difference = X_test['ask_price1'].iloc[i] - X_test['ask_price1'].iloc[i-20]
        
    # 如果差值大于10，跳过当前循环迭代
    if price_difference >= 15 or price_difference <= -15:
        i += 100
        continue
    
    current_ask_price1 = X_test.iloc[i]['ask_price1']
    current_bid_price1 = X_test.iloc[i]['bid_price1']
    if current_ask_price1-current_bid_price1!=trade_gap:
        i = i + 1
        continue

    matching_buy_volume = 0
    matching_sell_volume = 0
    buy_done = 0
    sell_done = 0
    
    for j in range(i + 1, i + guess_tick+1): 
        future_tick = X_test.iloc[j]
        if future_tick['bid_price1'] < current_bid_price1:
            buy_done = 1
        if future_tick['ask_price1'] > current_ask_price1:
            sell_done = 1
        if future_tick['bid_price1'] == current_bid_price1 and future_tick['last_price'] == current_bid_price1:
            matching_sell_volume += future_tick['volume_delta']
        if future_tick['ask_price1'] == current_ask_price1 and future_tick['last_price'] == current_ask_price1:
            matching_buy_volume += future_tick['volume_delta']
        j = j+1 

    stop_loss_tick = i + guess_tick
    stop_loss_price_bid = X_test.iloc[stop_loss_tick]['bid_price1']
    stop_loss_price_ask = X_test.iloc[stop_loss_tick]['ask_price1']
    count = count + 1
    daily_trade[date_str] = daily_trade.get(date_str,0)+1
    
    # 判断是否存在买卖机会
    if (buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand+trade_slippy) and \
    (sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand+trade_slippy):
        trade_profit = (current_ask_price1 - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        done_count += 1
        print(X_test.iloc[i]['datetime'])
        print(trade_profit)
    elif buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand+trade_slippy:
        trade_profit = (stop_loss_price_bid - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        print(X_test.iloc[i]['datetime'])
        # print(stop_loss_price_bid)
        # print(current_bid_price1)
        # print(price_difference)
        daily_fail_count += 1
        print(trade_profit)
    elif sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand+trade_slippy:
        trade_profit = (current_ask_price1 - stop_loss_price_ask) * trade_hand * hand_volume-hand_fee*trade_hand
        profit += trade_profit
        daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
        print(X_test.iloc[i]['datetime'])
        # print(current_ask_price1)
        # print(stop_loss_price_ask)
        # print(price_difference)
        print(trade_profit)
    else:
        i = i + 1
    i = stop_loss_tick
    print(X_test.iloc[i]['datetime'])
        

# 打印每一天的盈利
for date, daily_profit in daily_profit.items():
    print(f"{date}: {daily_profit:.2f}")
for date, daily_trade in daily_trade.items():
    print(f"{date}: {daily_trade}")

print(f"Final profit: {profit:.2f}")
print(done_count)
print(count)
print(done_count/count)
# Out:
# 2024-02-20 14:12:03.000000000
# 23
# 2024-02-20 14:15:14.000000000
# 2024-02-20 14:15:24.500000000
# 23
# 2024-02-20 14:20:00.500000000
# 2024-02-20 14:22:06.500000000
# 23
# 2024-02-20 14:26:03.000000000
# 2024-02-20 14:26:55.500000000
# -2
# 2024-02-20 14:31:02.000000000
# 2024-02-20 14:32:37.500000000
# 23
# 2024-02-20 14:34:35.000000000
# 2024-02-20 14:36:20.500000000
# -52
# 2024-02-20 14:40:14.000000000
# 2024-02-20 14:40:18.500000000
# 23
# 2024-02-20 14:44:07.500000000
# 2024-02-20 14:44:44.000000000
# -27
# 2024-02-20 14:47:36.500000000
# 2024-02-20 14:48:04.000000000
# 23
# 2024-02-20 14:50:10.500000000
# 2024-02-20 21:10:47.500000000
# 23
# 2024-02-20 21:12:33.000000000
# 2024-02-20 21:14:48.500000000
# -77
# 2024-02-20 21:16:12.000000000
# 2024-02-20 21:16:13.500000000
# 23
# 2024-02-20 21:17:16.500000000
# 2024-02-20 21:18:09.500000000
# 23
# 2024-02-20 21:19:48.500000000
# 2024-02-20 21:22:47.500000000
# 23
# 2024-02-20 21:25:39.500000000
# 2024-02-20 21:28:58.500000000
# 23
# 2024-02-20 21:30:37.500000000
# 2024-02-20 21:31:06.000000000
# 23
# 2024-02-20 21:33:33.500000000
# 2024-02-20 21:34:03.500000000
# -27
# 2024-02-20 21:37:03.500000000
# 2024-02-20 21:44:38.000000000
# 23
# 2024-02-20 21:47:08.500000000
# 2024-02-20 21:55:31.500000000
# -27
# 2024-02-20 21:59:35.500000000
# 2024-02-20 22:16:45.500000000
# -52
# 2024-02-20 22:20:00.000000000
# 2024-02-20 22:28:49.500000000
# -52
# 2024-02-20 22:30:08.500000000
# 2024-02-20 22:32:01.000000000
# 23
# 2024-02-20 22:34:51.500000000
# 2024-02-20 22:35:08.500000000
# -27
# 2024-02-20 22:40:18.000000000
# 2024-02-20 22:40:42.000000000
# -27
# 2024-02-20 22:44:43.000000000
# 2024-02-20 22:49:41.500000000
# -52
# 2024-02-20 22:54:43.000000000
# 2024-02-20 22:55:43.500000000
# 23
# 2024-02-20 22:58:06.500000000
# 2024-02-20 22:58:08.500000000
# -27
# 2024-02-20 23:00:15.000000000
# 2024-02-20 23:04:23.500000000
# -52
# 2024-02-20 23:09:18.500000000
# 2024-02-21 09:22:12.500000000
# 23
# 2024-02-21 09:24:00.000000000
# 2024-02-21 09:24:14.500000000
# 23
# 2024-02-21 09:26:16.000000000
# 2024-02-21 09:26:29.000000000
# 23
# 2024-02-21 09:28:42.000000000
# 2024-02-21 09:28:49.000000000
# -2
# 2024-02-21 09:30:44.500000000
# 2024-02-21 09:32:04.000000000
# 23
# 2024-02-21 09:33:29.500000000
# 2024-02-21 09:34:36.500000000
# 23
# 2024-02-21 09:36:47.000000000
# 2024-02-21 09:38:58.500000000
# 23
# 2024-02-21 09:40:46.000000000
# 2024-02-21 09:40:50.500000000
# 23
# 2024-02-21 09:41:46.500000000
# 2024-02-21 09:41:46.500000000
# 23
# 2024-02-21 09:42:53.000000000
# 2024-02-21 09:42:59.000000000
# 23
# 2024-02-21 09:44:25.000000000
# 2024-02-21 09:45:01.500000000
# 23
# 2024-02-21 09:46:22.500000000
# 2024-02-21 09:46:33.500000000
# -27
# 2024-02-21 09:47:53.000000000
# 2024-02-21 09:47:56.500000000
# 23
# 2024-02-21 09:49:21.000000000
# 2024-02-21 09:49:21.500000000
# 23
# 2024-02-21 09:51:02.500000000
# 2024-02-21 09:51:11.500000000
# 23
# 2024-02-21 09:53:20.500000000
# 2024-02-21 09:53:25.000000000
# 23
# 2024-02-21 09:55:36.000000000
# 2024-02-21 09:57:33.500000000
# 23
# 2024-02-21 09:59:41.000000000
# 2024-02-21 10:02:00.500000000
# -27
# 2024-02-21 10:03:11.500000000
# 2024-02-21 10:03:58.000000000
# -27
# 2024-02-21 10:05:13.500000000
# 2024-02-21 10:08:42.500000000
# 23
# 2024-02-21 10:10:36.500000000
# 2024-02-21 10:10:36.500000000
# 23
# 2024-02-21 10:13:05.500000000
# 2024-02-21 10:13:08.500000000
# 23
# 2024-02-21 10:30:25.000000000
# 2024-02-21 10:30:45.500000000
# -27
# 2024-02-21 10:33:39.500000000
# 2024-02-21 10:33:47.000000000
# 23
# 2024-02-21 10:37:05.500000000
# 2024-02-21 10:37:39.000000000
# 23
# 2024-02-21 10:40:35.000000000
# 2024-02-21 10:40:36.500000000
# 23
# 2024-02-21 10:42:52.500000000
# 2024-02-21 10:42:59.000000000
# 23
# 2024-02-21 10:44:54.500000000
# 2024-02-21 10:45:01.500000000
# -52
# 2024-02-21 10:46:52.000000000
# 2024-02-21 10:47:08.500000000
# 23
# 2024-02-21 10:49:06.500000000
# 2024-02-21 10:49:06.500000000
# 23
# 2024-02-21 10:50:56.500000000
# 2024-02-21 10:51:15.500000000
# 23
# 2024-02-21 10:53:25.500000000
# 2024-02-21 10:53:41.000000000
# -52
# 2024-02-21 10:55:56.500000000
# 2024-02-21 10:56:44.000000000
# 23
# 2024-02-21 10:59:05.000000000
# 2024-02-21 11:00:18.500000000
# 23
# 2024-02-21 11:02:49.500000000
# 2024-02-21 11:02:54.000000000
# 23
# 2024-02-21 11:04:19.500000000
# 2024-02-21 11:04:31.000000000
# 23
# 2024-02-21 11:06:05.000000000
# 2024-02-21 11:06:26.500000000
# 23
# 2024-02-21 11:08:39.500000000
# 2024-02-21 11:08:40.500000000
# -52
# 2024-02-21 11:09:42.500000000
# 2024-02-21 11:09:48.500000000
# 23
# 2024-02-21 11:11:13.000000000
# 2024-02-21 11:11:15.000000000
# 23
# 2024-02-21 11:12:22.000000000
# 2024-02-21 11:12:29.000000000
# 23
# 2024-02-21 11:14:07.000000000
# 2024-02-21 11:14:28.500000000
# 23
# 2024-02-21 11:15:39.500000000
# 2024-02-21 11:15:40.500000000
# -52
# 2024-02-21 11:17:15.000000000
# 2024-02-21 11:17:16.000000000
# -52
# 2024-02-21 11:19:08.000000000
# 2024-02-21 11:19:19.500000000
# 23
# 2024-02-21 11:21:35.500000000
# 2024-02-21 13:40:21.500000000
# 23
# 2024-02-21 13:42:12.000000000
# 2024-02-21 13:42:14.500000000
# 23
# 2024-02-21 13:44:13.500000000
# 2024-02-21 13:45:01.500000000
# 23
# 2024-02-21 13:47:00.500000000
# 2024-02-21 13:47:01.500000000
# 23
# 2024-02-21 13:49:20.000001000
# 2024-02-21 13:49:33.500000000
# 23
# 2024-02-21 13:52:21.000001000
# 2024-02-21 13:52:48.000001000
# 23
# 2024-02-21 13:54:41.000001000
# 2024-02-21 13:55:08.000000000
# 23
# 2024-02-21 13:57:28.000001000
# 2024-02-21 13:57:33.000000000
# 23
# 2024-02-21 13:59:35.500000000
# 2024-02-21 13:59:38.500000000
# 23
# 2024-02-21 14:01:55.500000000
# 2024-02-21 14:01:55.500000000
# 23
# 2024-02-21 14:03:37.500000000
# 2024-02-21 14:03:37.500000000
# 23
# 2024-02-21 14:06:34.500000000
# 2024-02-21 14:06:41.000000000
# 23
# 2024-02-21 14:09:14.500000000
# 2024-02-21 14:09:16.500000000
# 23
# 2024-02-21 14:11:12.000001000
# 2024-02-21 14:11:12.000001000
# 23
# 2024-02-21 14:13:59.000001000
# 2024-02-21 14:13:59.000001000
# -27
# 2024-02-21 14:15:12.000001000
# 2024-02-21 14:15:31.000000000
# 23
# 2024-02-21 14:17:29.000001000
# 2024-02-21 14:17:32.000000000
# 23
# 2024-02-21 14:19:39.000001000
# 2024-02-21 14:20:02.000000000
# 23
# 2024-02-21 14:23:45.000000000
# 2024-02-21 14:24:11.000000000
# 23
# 2024-02-21 14:27:51.000000000
# 2024-02-21 14:27:52.000000000
# 23
# 2024-02-21 14:31:08.000000000
# 2024-02-21 14:31:09.500000000
# -77
# 2024-02-21 14:34:02.000000000
# 2024-02-21 14:35:10.000000000
# 23
# 2024-02-21 14:39:56.000000000
# 2024-02-21 14:40:08.000000000
# 23
# 2024-02-21 14:44:35.000001000
# 2024-02-21 14:45:00.000000000
# 23
# 2024-02-21 14:47:23.500000000
# 2024-02-21 14:48:28.000000000
# -27
# 2024-02-21 14:50:42.000000000
# 2024-02-21 21:10:01.000000000
# -27
# 2024-02-21 21:11:06.500000000
# 2024-02-21 21:12:06.500000000
# 23
# 2024-02-21 21:13:15.500000000
# 2024-02-21 21:13:20.000000000
# -27
# 2024-02-21 21:14:43.500000000
# 2024-02-21 21:14:55.500000000
# 23
# 2024-02-21 21:16:23.000000000
# 2024-02-21 21:16:53.500000000
# 23
# 2024-02-21 21:18:10.500000000
# 2024-02-21 21:18:40.500000000
# 23
# 2024-02-21 21:20:11.500000000
# 2024-02-21 21:20:55.500000000
# -27
# 2024-02-21 21:22:30.000000000
# 2024-02-21 21:23:07.000000000
# 23
# 2024-02-21 21:25:09.500000000
# 2024-02-21 21:28:44.500000000
# -27
# 2024-02-21 21:30:51.000000000
# 2024-02-21 21:32:19.500000000
# 23
# 2024-02-21 21:34:16.500000000
# 2024-02-21 21:35:12.500000000
# 23
# 2024-02-21 21:37:07.500000000
# 2024-02-21 21:38:03.000000000
# 23
# 2024-02-21 21:40:01.000000000
# 2024-02-21 21:43:23.500000000
# -27
# 2024-02-21 21:46:47.500000000
# 2024-02-21 21:54:33.000000000
# 23
# 2024-02-21 21:57:10.000000000
# 2024-02-21 21:57:17.000000000
# 23
# 2024-02-21 22:01:03.500000000
# 2024-02-21 22:02:13.500000000
# -27
# 2024-02-21 22:05:46.500000000
# 2024-02-21 22:06:12.000000000
# 23
# 2024-02-21 22:11:07.000000000
# 2024-02-21 22:11:26.500000000
# 23
# 2024-02-21 22:14:08.500000000
# 2024-02-21 22:14:27.500000000
# 23
# 2024-02-21 22:15:36.500000000
# 2024-02-21 22:16:07.500000000
# 23
# 2024-02-21 22:19:03.500000000
# 2024-02-21 22:19:47.500000000
# 23
# 2024-02-21 22:23:16.000000000
# 2024-02-21 22:23:23.000000000
# 23
# 2024-02-21 22:25:41.500000000
# 2024-02-21 22:25:47.500000000
# 23
# 2024-02-21 22:29:05.500000000
# 2024-02-21 22:29:54.000000000
# 23
# 2024-02-21 22:31:10.000000000
# 2024-02-21 22:31:11.500000000
# -2
# 2024-02-21 22:33:06.000000000
# 2024-02-21 22:33:44.000000000
# -2
# 2024-02-21 22:36:06.500000000
# 2024-02-21 22:36:43.000000000
# -52
# 2024-02-21 22:39:03.500000000
# 2024-02-21 22:41:34.500000000
# 23
# 2024-02-21 22:44:23.000000000
# 2024-02-21 22:47:01.500000000
# 23
# 2024-02-21 22:49:44.500000000
# 2024-02-21 22:50:42.000000000
# 23
# 2024-02-21 22:52:52.500000000
# 2024-02-21 22:52:54.000000000
# -52
# 2024-02-21 22:55:59.500000000
# 2024-02-21 22:57:15.500000000
# -27
# 2024-02-21 22:59:21.500000000
# 2024-02-21 22:59:26.000000000
# 23
# 2024-02-21 23:01:36.000000000
# 2024-02-21 23:02:01.000000000
# -2
# 2024-02-21 23:03:44.000000000
# 2024-02-21 23:03:59.500000000
# 23
# 2024-02-21 23:06:13.500000000
# 2024-02-21 23:06:13.500000000
# 23
# 2024-02-21 23:09:29.500000000
# 2024-02-21 23:11:25.000000000
# 23
# 2024-02-21 23:16:06.000000000
# 2024-02-21 23:17:11.000000000
# 23
# 2024-02-21 23:23:16.500000000
# 2024-02-21 23:25:32.500000000
# 23
# 2024-02-21 23:32:13.000000000
# 2024-02-21 23:32:13.000000000
# 23
# 2024-02-21 23:42:27.000000000
# 2024-02-21 23:42:27.000000000
# 23
# 2024-02-21 23:48:10.000000000
# 2024-02-21 23:50:09.000000000
# -27
# 2024-02-22 00:00:14.500000000
# 2024-02-22 09:20:14.500000000
# 23
# 2024-02-22 09:22:20.500000000
# 2024-02-22 09:22:21.500000000
# -27
# 2024-02-22 09:25:16.000000000
# 2024-02-22 09:25:16.000000000
# -102
# 2024-02-22 09:27:24.000000000
# 2024-02-22 09:27:24.500000000
# -27
# 2024-02-22 09:29:46.000000000
# 2024-02-23 09:20:04.000000000
# 23
# 2024-02-23 09:21:59.500000000
# 2024-02-23 09:21:59.500000000
# 23
# 2024-02-23 09:24:21.000000000
# 2024-02-23 09:25:06.500000000
# 23
# 2024-02-23 09:26:41.500000000
# 2024-02-23 09:27:22.500000000
# 23
# 2024-02-23 09:28:39.000000000
# 2024-02-23 09:28:49.000000000
# 23
# 2024-02-23 09:29:55.000000000
# 2024-02-23 09:29:56.000000000
# 23
# 2024-02-23 09:30:56.500000000
# 2024-02-23 09:31:04.500000000
# -52
# 2024-02-23 09:32:28.500000000
# 2024-02-23 09:33:06.500000000
# 23
# 2024-02-23 09:34:49.500000000
# 2024-02-23 09:35:12.000000000
# 23
# 2024-02-23 09:36:41.500000000
# 2024-02-23 09:36:58.000000000
# -2
# 2024-02-23 09:38:38.000000000
# 2024-02-23 09:39:00.500000000
# -27
# 2024-02-23 09:40:28.000000000
# 2024-02-23 09:41:10.500000000
# -27
# 2024-02-23 09:42:50.000000000
# 2024-02-23 09:44:50.500000000
# -52
# 2024-02-23 09:46:32.000000000
# 2024-02-23 09:47:06.000000000
# -27
# 2024-02-23 09:48:46.000000000
# 2024-02-23 09:50:58.000000000
# 23
# 2024-02-23 09:53:12.500000000
# 2024-02-23 09:53:17.000000000
# 23
# 2024-02-23 09:55:37.500000000
# 2024-02-23 09:55:37.500000000
# -152
# 2024-02-23 09:57:09.500000000
# 2024-02-23 09:57:09.500000000
# 23
# 2024-02-23 09:58:02.000000000
# 2024-02-23 09:58:04.500000000
# 23
# 2024-02-23 09:59:09.500000000
# 2024-02-23 09:59:09.500000000
# 23
# 2024-02-23 10:00:27.500000000
# 2024-02-23 10:00:35.000000000
# -27
# 2024-02-23 10:01:45.000000000
# 2024-02-23 10:01:51.000000000
# 23
# 2024-02-23 10:03:06.500000000
# 2024-02-23 10:03:06.500000000
# -27
# 2024-02-23 10:04:02.000000000
# 2024-02-23 10:04:02.000000000
# 23
# 2024-02-23 10:05:10.500000000
# 2024-02-23 10:06:06.000000000
# -27
# 2024-02-23 10:07:44.500000000
# 2024-02-23 10:07:45.000000000
# 23
# 2024-02-23 10:09:23.000000000
# 2024-02-23 10:09:59.000000000
# 23
# 2024-02-23 10:11:02.000000000
# 2024-02-23 10:11:10.000000000
# 23
# 2024-02-23 10:12:25.500000000
# 2024-02-23 10:12:26.500000000
# 23
# 2024-02-23 10:13:32.500000000
# 2024-02-23 10:13:34.000000000
# 23
# 2024-02-23 10:14:54.000000000
# 2024-02-23 10:14:54.000000000
# 23
# 2024-02-23 10:30:58.000000000
# 2024-02-23 10:31:07.500000000
# 23
# 2024-02-23 10:32:23.500000000
# 2024-02-23 10:32:32.000000000
# 23
# 2024-02-23 10:34:15.000000000
# 2024-02-23 10:34:15.500000000
# 23
# 2024-02-23 10:36:00.000000000
# 2024-02-23 10:36:00.000000000
# 23
# 2024-02-23 10:37:35.500000000
# 2024-02-23 10:37:39.000000000
# 23
# 2024-02-23 10:39:22.000000000
# 2024-02-23 10:39:22.000000000
# 23
# 2024-02-23 10:40:38.500000000
# 2024-02-23 10:40:45.000000000
# 23
# 2024-02-23 10:42:25.000000000
# 2024-02-23 10:42:46.000000000
# 23
# 2024-02-23 10:44:10.000000000
# 2024-02-23 10:44:44.500000000
# 23
# 2024-02-23 10:46:45.000000000
# 2024-02-23 10:47:01.000000000
# 23
# 2024-02-23 10:49:18.500000000
# 2024-02-23 10:49:18.500000000
# 23
# 2024-02-23 10:51:39.000000000
# 2024-02-23 10:52:01.500000000
# -52
# 2024-02-23 10:53:46.500000000
# 2024-02-23 10:53:47.500000000
# -27
# 2024-02-23 10:55:54.500000000
# 2024-02-23 10:57:08.500000000
# 23
# 2024-02-23 10:59:03.000000000
# 2024-02-23 10:59:08.000000000
# 23
# 2024-02-23 11:01:14.000000000
# 2024-02-23 11:01:14.500000000
# -27
# 2024-02-23 11:03:05.000000000
# 2024-02-23 11:03:06.500000000
# -27
# 2024-02-23 11:05:31.000000000
# 2024-02-23 11:07:00.500000000
# -27
# 2024-02-23 11:08:58.000000000
# 2024-02-23 11:09:18.000000000
# 23
# 2024-02-23 11:11:17.000000000
# 2024-02-23 11:11:17.000000000
# 23
# 2024-02-23 11:13:07.500000000
# 2024-02-23 11:13:53.500000000
# -52
# 2024-02-23 11:15:20.000000000
# 2024-02-23 11:15:27.500000000
# -102
# 2024-02-23 11:16:20.500000000
# 2024-02-23 11:16:26.000000000
# 23
# 2024-02-23 11:17:23.500000000
# 2024-02-23 11:17:26.000000000
# 23
# 2024-02-23 11:18:41.000000000
# 2024-02-23 11:19:00.500000000
# 23
# 2024-02-23 11:19:58.500000000
# 2024-02-23 11:19:59.000000000
# 23
# 2024-02-23 11:21:02.500000000
# 2024-02-23 13:41:48.000000000
# -27
# 2024-02-23 13:44:03.500000000
# 2024-02-23 13:45:10.000000000
# 23
# 2024-02-23 13:47:17.500000000
# 2024-02-23 13:47:18.000000000
# 23
# 2024-02-23 13:49:54.000000000
# 2024-02-23 13:50:46.500000000
# -27
# 2024-02-23 13:54:32.500000000
# 2024-02-23 13:54:43.500000000
# -27
# 2024-02-23 13:57:15.500000000
# 2024-02-23 13:58:04.500000000
# 23
# 2024-02-23 14:01:18.500000000
# 2024-02-23 14:03:17.500000000
# -27
# 2024-02-23 14:05:45.500000000
# 2024-02-23 14:06:22.500000000
# -27
# 2024-02-23 14:08:44.500000000
# 2024-02-23 14:09:13.500000000
# 23
# 2024-02-23 14:10:50.500000000
# 2024-02-23 14:11:40.000000000
# -27
# 2024-02-23 14:13:28.500000000
# 2024-02-23 14:14:55.500000000
# -27
# 2024-02-23 14:17:04.500000000
# 2024-02-23 14:17:13.000000000
# 23
# 2024-02-23 14:19:37.500000000
# 2024-02-23 14:22:43.500000000
# -52
# 2024-02-23 14:25:11.500000000
# 2024-02-23 14:25:11.500000000
# -77
# 2024-02-23 14:27:02.500000000
# 2024-02-23 14:27:18.500000000
# -27
# 2024-02-23 14:30:48.500000000
# 2024-02-23 14:31:44.000000000
# 23
# 2024-02-23 14:34:19.000000000
# 2024-02-23 14:35:46.500000000
# -27
# 2024-02-23 14:37:54.000000000
# 2024-02-23 14:37:58.000000000
# -27
# 2024-02-23 14:41:11.500000000
# 2024-02-23 14:41:13.000000000
# -27
# 2024-02-23 14:43:36.000000000
# 2024-02-23 14:45:56.000000000
# 23
# 2024-02-23 14:47:23.500000000
# 2024-02-23 14:47:52.000000000
# 23
# 2024-02-23 14:49:41.000000000
# 2024-02-23 14:49:50.500000000
# 23
# 2024-02-23 14:52:05.500000000
# 2024-02-23 21:10:33.500000000
# 23
# 2024-02-23 21:12:12.500000000
# 2024-02-23 21:13:08.000000000
# 23
# 2024-02-23 21:14:45.000000000
# 2024-02-23 21:15:13.500000000
# 23
# 2024-02-23 21:17:14.500000000
# 2024-02-23 21:17:16.000000000
# -52
# 2024-02-23 21:19:12.500000000
# 2024-02-23 21:19:39.500000000
# 23
# 2024-02-23 21:21:27.000000000
# 2024-02-23 21:23:25.000000000
# 23
# 2024-02-23 21:24:32.000000000
# 2024-02-23 21:24:35.000000000
# -52
# 2024-02-23 21:25:56.000000000
# 2024-02-23 21:26:22.500000000
# 23
# 2024-02-23 21:28:05.500000000
# 2024-02-23 21:29:39.500000000
# -77
# 2024-02-23 21:31:22.000000000
# 2024-02-23 21:34:07.500000000
# -27
# 2024-02-23 21:35:43.000000000
# 2024-02-23 21:36:29.000000000
# -52
# 2024-02-23 21:38:05.500000000
# 2024-02-26 09:20:17.000000000
# 23
# 2024-02-26 09:21:54.000000000
# 2024-02-26 09:22:06.000000000
# 23
# 2024-02-26 09:24:28.500000000
# 2024-02-26 09:24:32.000000000
# -77
# 2024-02-26 09:26:56.500000000
# 2024-02-26 09:27:11.000000000
# -27
# 2024-02-26 09:28:33.500000000
# 2024-02-26 09:28:53.500000000
# 23
# 2024-02-26 09:30:58.000000000
# 2024-02-26 09:31:30.000000000
# 23
# 2024-02-26 09:33:34.000000000
# 2024-02-26 09:34:26.500000000
# 23
# 2024-02-26 09:36:41.000000000
# 2024-02-26 09:36:41.000000000
# -27
# 2024-02-26 09:38:59.000000000
# 2024-02-26 09:39:00.000000000
# 23
# 2024-02-26 09:41:05.500000000
# 2024-02-26 09:41:05.500000000
# -52
# 2024-02-26 09:42:58.000000000
# 2024-02-26 09:42:58.000000000
# 23
# 2024-02-26 09:44:31.500000000
# 2024-02-26 09:44:35.000000000
# 23
# 2024-02-26 09:46:28.500000000
# 2024-02-26 09:46:29.500000000
# 23
# 2024-02-26 09:48:03.000000000
# 2024-02-26 09:48:03.000000000
# 23
# 2024-02-26 09:50:01.000000000
# 2024-02-26 09:50:03.000000000
# 23
# 2024-02-26 09:51:50.500000000
# 2024-02-26 09:52:51.500000000
# 23
# 2024-02-26 09:55:08.500000000
# 2024-02-26 09:56:08.500000000
# -27
# 2024-02-26 09:57:33.500000000
# 2024-02-26 09:57:37.500000000
# 23
# 2024-02-26 09:59:47.500000000
# 2024-02-26 09:59:58.000000000
# 23
# 2024-02-26 10:01:36.500000000
# 2024-02-26 10:01:36.500000000
# 23
# 2024-02-26 10:04:08.000000000
# 2024-02-26 10:04:15.000000000
# -77
# 2024-02-26 10:06:47.500000000
# 2024-02-26 10:08:19.500000000
# 23
# 2024-02-26 10:10:36.500000000
# 2024-02-26 10:10:37.000000000
# -52
# 2024-02-26 10:12:20.000000000
# 2024-02-26 10:12:20.000000000
# 23
# 2024-02-26 10:14:24.500000000
# 2024-02-26 10:14:25.500000000
# -27
# 2024-02-26 10:31:37.500000000
# 2024-02-26 10:31:42.500000000
# 23
# 2024-02-26 10:34:18.500000000
# 2024-02-26 10:35:24.500000000
# 23
# 2024-02-26 10:37:31.000000000
# 2024-02-26 10:37:36.500000000
# 23
# 2024-02-26 10:40:19.500000000
# 2024-02-26 10:40:19.500000000
# -2
# 2024-02-26 10:43:35.500000000
# 2024-02-26 10:43:40.500000000
# 23
# 2024-02-26 10:47:06.500000000
# 2024-02-26 10:47:06.500000000
# -2
# 2024-02-26 10:51:04.500000000
# 2024-02-26 10:52:17.500000000
# -27
# 2024-02-26 10:54:59.000000000
# 2024-02-26 10:56:45.500000000
# 23
# 2024-02-26 10:59:46.500000000
# 2024-02-26 11:00:05.500000000
# -27
# 2024-02-26 11:02:38.500000000
# 2024-02-26 11:08:34.500000000
# 23
# 2024-02-26 11:11:49.500000000
# 2024-02-26 11:11:49.500000000
# -27
# 2024-02-26 11:14:43.500000000
# 2024-02-26 11:14:53.500000000
# -27
# 2024-02-26 11:18:21.000000000
# 2024-02-26 13:40:36.500000000
# -52
# 2024-02-26 13:43:00.000000000
# 2024-02-26 13:45:55.500000000
# 23
# 2024-02-26 13:49:28.000000000
# 2024-02-26 13:51:10.000000000
# 23
# 2024-02-26 13:54:42.500000000
# 2024-02-26 13:54:44.500000000
# 23
# 2024-02-26 13:57:36.000000000
# 2024-02-26 13:57:39.500000000
# 23
# 2024-02-26 14:01:06.000000000
# 2024-02-26 14:01:49.500000000
# 23
# 2024-02-26 14:07:15.500000000
# 2024-02-26 14:07:15.500000000
# -27
# 2024-02-26 14:11:59.500000000
# 2024-02-26 14:12:11.000000000
# -77
# 2024-02-26 14:14:13.500000000
# 2024-02-26 14:14:28.500000000
# -27
# 2024-02-26 14:17:15.500000000
# 2024-02-26 14:19:19.000000000
# -52
# 2024-02-26 14:21:15.500000000
# 2024-02-26 14:21:34.000000000
# -27
# 2024-02-26 14:23:37.500000000
# 2024-02-26 14:23:44.500000000
# 23
# 2024-02-26 14:26:03.000000000
# 2024-02-26 14:28:20.000000000
# 23
# 2024-02-26 14:30:12.000000000
# 2024-02-26 14:30:12.500000000
# 23
# 2024-02-26 14:32:42.500000000
# 2024-02-26 14:32:45.000000000
# 23
# 2024-02-26 14:37:01.000000000
# 2024-02-26 14:37:07.500000000
# 23
# 2024-02-26 14:41:01.000000000
# 2024-02-26 14:41:31.000000000
# 23
# 2024-02-26 14:43:57.000000000
# 2024-02-26 14:44:13.500000000
# 23
# 2024-02-26 14:46:58.000000000
# 2024-02-26 14:47:07.000000000
# 23
# 2024-02-26 14:50:13.000000000
# 2024-02-26 21:10:13.000000000
# 23
# 2024-02-26 21:11:14.000000000
# 2024-02-26 21:11:14.000000000
# 23
# 2024-02-26 21:12:12.000000000
# 2024-02-26 21:13:54.000000000
# 23
# 2024-02-26 21:14:53.500000000
# 2024-02-26 21:22:31.000000000
# 23
# 2024-02-26 21:23:38.500000000
# 2024-02-26 21:23:47.500000000
# 23
# 2024-02-26 21:25:20.000000000
# 2024-02-26 21:25:43.000000000
# 23
# 2024-02-26 21:27:27.000000000
# 2024-02-26 21:30:27.000000000
# 23
# 2024-02-26 21:32:00.500000000
# 2024-02-26 21:32:33.500000000
# 23
# 2024-02-26 21:34:34.500000000
# 2024-02-26 21:35:02.000000000
# -27
# 2024-02-26 21:36:39.000000000
# 2024-02-26 21:39:16.000000000
# 23
# 2024-02-26 21:41:06.000000000
# 2024-02-26 21:42:05.000000000
# 23
# 2024-02-26 21:43:54.000000000
# 2024-02-26 21:43:57.000000000
# 23
# 2024-02-26 21:45:52.000000000
# 2024-02-26 21:46:24.000000000
# -27
# 2024-02-26 21:49:13.000000000
# 2024-02-26 21:50:31.000000000
# -52
# 2024-02-26 21:53:14.500000000
# 2024-02-26 21:56:36.000000000
# -52
# 2024-02-26 21:59:10.000000000
# 2024-02-26 22:05:18.500000000
# 23
# 2024-02-26 22:09:31.000000000
# 2024-02-26 22:13:38.500000000
# -52
# 2024-02-26 22:15:11.500000000
# 2024-02-26 22:17:46.000000000
# -27
# 2024-02-26 22:22:40.500000000
# 2024-02-26 22:23:10.000000000
# 23
# 2024-02-26 22:26:19.000000000
# 2024-02-26 22:26:31.000000000
# 23
# 2024-02-26 22:29:12.500000000
# 2024-02-26 22:33:59.000000000
# 23
# 2024-02-26 22:36:16.000000000
# 2024-02-26 22:39:07.000000000
# 23
# 2024-02-26 22:41:11.000000000
# 2024-02-26 22:41:16.500000000
# 23
# 2024-02-26 22:44:22.500000000
# 2024-02-26 22:48:52.000000000
# 23
# 2024-02-26 22:53:28.000000000
# 2024-02-26 22:53:41.500000000
# 23
# 2024-02-26 22:58:14.000000000
# 2024-02-26 22:58:14.500000000
# 23
# 2024-02-26 23:00:36.000000000
# 2024-02-26 23:05:38.500000000
# -27
# 2024-02-26 23:12:29.500000000
# 2024-02-26 23:20:03.500000000
# 23
# 2024-02-26 23:31:32.500000000
# 2024-02-26 23:31:37.500000000
# 23
# 2024-02-26 23:41:03.500000000
# 2024-02-26 23:44:40.000000000
# 23
# 2024-02-26 23:59:06.000000000
# 2024-02-26 23:59:56.000000000
# 23
# 2024-02-27 00:09:35.500000000
# 2024-02-27 09:20:15.500000000
# 23
# 2024-02-27 09:22:23.000000000
# 2024-02-27 09:22:26.500000000
# 23
# 2024-02-27 09:25:12.500000000
# 2024-02-27 09:25:15.500000000
# -77
# 2024-02-27 09:26:51.000000000
# 2024-02-27 09:27:56.500000000
# 23
# 2024-02-27 09:29:20.500000000
# 2024-02-27 09:29:22.000000000
# -52
# 2024-02-27 09:30:35.500000000
# 2024-02-27 09:30:41.500000000
# 23
# 2024-02-27 09:31:48.500000000
# 2024-02-27 09:31:58.500000000
# 23
# 2024-02-27 09:33:33.000000000
# 2024-02-27 09:33:43.000000000
# 23
# 2024-02-27 09:35:14.000000000
# 2024-02-27 09:35:41.000000000
# 23
# 2024-02-27 09:37:10.000000000
# 2024-02-27 09:39:54.500000000
# -52
# 2024-02-27 09:41:43.000000000
# 2024-02-27 09:43:21.000000000
# 23
# 2024-02-27 09:44:33.500000000
# 2024-02-27 09:44:38.000000000
# 23
# 2024-02-27 09:46:05.000000000
# 2024-02-27 09:46:11.500000000
# 23
# 2024-02-27 09:49:02.500000000
# 2024-02-27 09:49:03.500000000
# 23
# 2024-02-27 09:51:22.000000000
# 2024-02-27 09:51:53.500000000
# 23
# 2024-02-27 09:53:53.500000000
# 2024-02-27 09:54:49.500000000
# -52
# 2024-02-27 09:56:01.000000000
# 2024-02-27 09:57:24.500000000
# 23
# 2024-02-27 09:59:04.000000000
# 2024-02-27 09:59:12.500000000
# 23
# 2024-02-27 10:01:07.000000000
# 2024-02-27 10:01:49.000000000
# 23
# 2024-02-27 10:03:49.000000000
# 2024-02-27 10:05:04.500000000
# 23
# 2024-02-27 10:06:14.500000000
# 2024-02-27 10:06:19.000000000
# -27
# 2024-02-27 10:07:40.500000000
# 2024-02-27 10:07:40.500000000
# 23
# 2024-02-27 10:08:56.500000000
# 2024-02-27 10:09:25.000000000
# -52
# 2024-02-27 10:10:40.500000000
# 2024-02-27 10:10:56.000000000
# 23
# 2024-02-27 10:12:38.500000000
# 2024-02-27 10:12:50.500000000
# 23
# 2024-02-27 10:14:35.000000000
# 2024-02-27 10:14:35.000000000
# 23
# 2024-02-27 10:30:47.000000000
# 2024-02-27 10:30:47.000000000
# 23
# 2024-02-27 10:32:31.000000000
# 2024-02-27 10:33:12.500000000
# 23
# 2024-02-27 10:34:55.500000000
# 2024-02-27 10:35:02.500000000
# 23
# 2024-02-27 10:36:39.500000000
# 2024-02-27 10:38:07.500000000
# 23
# 2024-02-27 10:40:55.000000000
# 2024-02-27 10:40:59.500000000
# 23
# 2024-02-27 10:43:56.000000000
# 2024-02-27 10:43:57.500000000
# -27
# 2024-02-27 10:46:45.000000000
# 2024-02-27 10:46:49.000000000
# -27
# 2024-02-27 10:48:43.500000000
# 2024-02-27 10:49:30.500000000
# 23
# 2024-02-27 10:50:56.000000000
# 2024-02-27 10:51:02.500000000
# 23
# 2024-02-27 10:52:47.500000000
# 2024-02-27 10:52:47.500000000
# 23
# 2024-02-27 10:54:59.500000000
# 2024-02-27 10:55:03.000000000
# 23
# 2024-02-27 10:56:24.500000000
# 2024-02-27 10:56:24.500000000
# -27
# 2024-02-27 10:57:26.000000000
# 2024-02-27 10:57:29.000000000
# 23
# 2024-02-27 10:58:33.000000000
# 2024-02-27 10:58:50.000000000
# 23
# 2024-02-27 10:59:41.000000000
# 2024-02-27 10:59:41.000000000
# 23
# 2024-02-27 11:00:42.500000000
# 2024-02-27 11:00:45.500000000
# 23
# 2024-02-27 11:01:45.500000000
# 2024-02-27 11:01:48.000000000
# 23
# 2024-02-27 11:02:53.500000000
# 2024-02-27 11:03:02.000000000
# 23
# 2024-02-27 11:03:56.500000000
# 2024-02-27 11:04:01.000000000
# -27
# 2024-02-27 11:05:02.500000000
# 2024-02-27 11:05:08.500000000
# -2
# 2024-02-27 11:06:11.000000000
# 2024-02-27 11:07:05.500000000
# -27
# 2024-02-27 11:08:08.000000000
# 2024-02-27 11:08:08.500000000
# 23
# 2024-02-27 11:09:19.000000000
# 2024-02-27 11:10:59.500000000
# 23
# 2024-02-27 11:12:35.000000000
# 2024-02-27 11:14:10.000000000
# -52
# 2024-02-27 11:15:35.500000000
# 2024-02-27 11:15:50.500000000
# -27
# 2024-02-27 11:18:29.000000000
# 2024-02-27 11:19:11.500000000
# 23
# 2024-02-27 11:22:05.000000000
# 2024-02-27 13:40:04.500000000
# -52
# 2024-02-27 13:41:36.500000000
# 2024-02-27 13:42:13.500000000
# 23
# 2024-02-27 13:43:55.000000000
# 2024-02-27 13:45:05.000000000
# 23
# 2024-02-27 13:46:56.500000000
# 2024-02-27 13:47:00.500000000
# 23
# 2024-02-27 13:48:23.000000000
# 2024-02-27 13:49:05.000000000
# 23
# 2024-02-27 13:51:38.000000000
# 2024-02-27 13:53:55.000000000
# -27
# 2024-02-27 13:56:37.500000000
# 2024-02-27 13:57:16.500000000
# 23
# 2024-02-27 13:59:31.000000000
# 2024-02-27 13:59:32.000000000
# 23
# 2024-02-27 14:01:18.500000000
# 2024-02-27 14:01:22.000000000
# 23
# 2024-02-27 14:03:49.000000000
# 2024-02-27 14:03:49.500000000
# 23
# 2024-02-27 14:07:20.000000000
# 2024-02-27 14:07:44.500000000
# 23
# 2024-02-27 14:10:30.500000000
# 2024-02-27 14:10:32.000000000
# 23
# 2024-02-27 14:14:33.000000000
# 2024-02-27 14:15:24.500000000
# 23
# 2024-02-27 14:18:21.500000000
# 2024-02-27 14:18:57.500000000
# 23
# 2024-02-27 14:21:17.000000000
# 2024-02-27 14:21:17.000000000
# -52
# 2024-02-27 14:24:14.500000000
# 2024-02-27 14:24:16.000000000
# 23
# 2024-02-27 14:26:20.500000000
# 2024-02-27 14:27:24.000000000
# 23
# 2024-02-27 14:29:22.000000000
# 2024-02-27 14:29:47.500000000
# 23
# 2024-02-27 14:33:52.000000000
# 2024-02-27 14:34:39.500000000
# 23
# 2024-02-27 14:36:25.500000000
# 2024-02-27 14:36:26.000000000
# 23
# 2024-02-27 14:38:24.000000000
# 2024-02-27 14:38:32.500000000
# 23
# 2024-02-27 14:41:23.500000000
# 2024-02-27 14:41:47.000000000
# 23
# 2024-02-27 14:44:28.500000000
# 2024-02-27 14:45:05.000000000
# 23
# 2024-02-27 14:47:06.000000000
# 2024-02-27 14:47:07.000000000
# -52
# 2024-02-27 14:49:00.500000000
# 2024-02-27 14:49:14.500000000
# 23
# 2024-02-27 14:50:51.500000000
# 2024-02-27 21:10:30.000000000
# -27
# 2024-02-27 21:11:39.000000000
# 2024-02-27 21:12:08.500000000
# -52
# 2024-02-27 21:13:25.000000000
# 2024-02-27 21:14:25.000000000
# 23
# 2024-02-27 21:15:58.000000000
# 2024-02-27 21:18:29.000000000
# -52
# 2024-02-27 21:20:36.000000000
# 2024-02-27 21:21:44.500000000
# 23
# 2024-02-27 21:23:53.000000000
# 2024-02-27 21:23:53.000000000
# 23
# 2024-02-27 21:24:57.500000000
# 2024-02-27 21:25:01.500000000
# -27
# 2024-02-27 21:26:31.000000000
# 2024-02-27 21:27:22.500000000
# 23
# 2024-02-27 21:28:48.000000000
# 2024-02-27 21:29:02.500000000
# 23
# 2024-02-27 21:30:42.000000000
# 2024-02-27 21:31:00.000000000
# 23
# 2024-02-27 21:32:23.000000000
# 2024-02-27 21:36:01.500000000
# -52
# 2024-02-27 21:37:15.000000000
# 2024-02-27 21:37:15.500000000
# 23
# 2024-02-27 21:38:56.500000000
# 2024-02-27 21:40:12.500000000
# 23
# 2024-02-27 21:42:31.000000000
# 2024-02-27 21:46:08.000000000
# 23
# 2024-02-27 21:48:31.000000000
# 2024-02-27 21:49:20.000000000
# 23
# 2024-02-27 21:52:16.000000000
# 2024-02-27 21:52:57.000000000
# 23
# 2024-02-27 21:57:20.500000000
# 2024-02-27 21:58:30.000000000
# -102
# 2024-02-27 22:00:01.000000000
# 2024-02-27 22:00:02.000000000
# 23
# 2024-02-27 22:01:58.500000000
# 2024-02-27 22:04:00.000000000
# 23
# 2024-02-27 22:07:03.000000000
# 2024-02-27 22:07:03.500000000
# 23
# 2024-02-27 22:09:38.000000000
# 2024-02-27 22:10:43.500000000
# 23
# 2024-02-27 22:14:54.500000000
# 2024-02-27 22:17:50.500000000
# 23
# 2024-02-27 22:23:01.000000000
# 2024-02-27 22:25:56.000000000
# 23
# 2024-02-27 22:29:56.000000000
# 2024-02-27 22:29:57.000000000
# 23
# 2024-02-27 22:33:38.500000000
# 2024-02-27 22:34:24.500000000
# 23
# 2024-02-27 22:37:25.000000000
# 2024-02-27 22:37:31.000000000
# 23
# 2024-02-27 22:41:42.000000000
# 2024-02-27 22:45:53.000000000
# 23
# 2024-02-27 22:49:14.000000000
# 2024-02-27 22:49:33.500000000
# 23
# 2024-02-27 22:52:38.500000000
# 2024-02-27 22:56:02.000000000
# -52
# 2024-02-27 22:57:49.500000000
# 2024-02-27 22:58:15.000000000
# -52
# 2024-02-27 23:00:05.500000000
# 2024-02-27 23:00:27.000000000
# -27
# 2024-02-27 23:03:31.000000000
# 2024-02-27 23:03:57.500000000
# 23
# 2024-02-27 23:09:37.000000000
# 2024-02-27 23:09:39.000000000
# 23
# 2024-02-27 23:15:04.500000000
# 2024-02-27 23:15:07.500000000
# -52
# 2024-02-27 23:21:27.000000000
# 2024-02-27 23:23:54.500000000
# 23
# 2024-02-27 23:29:01.000000000
# 2024-02-27 23:33:22.000000000
# -52
# 2024-02-27 23:40:56.000000000
# 2024-02-27 23:45:12.000000000
# 23
# 2024-02-27 23:55:33.500000000
# 2024-02-28 09:20:08.500000000
# 23
# 2024-02-28 09:22:39.500000000
# 2024-02-28 09:22:42.500000000
# -52
# 2024-02-28 09:25:00.500000000
# 2024-02-28 09:25:00.500000000
# 23
# 2024-02-28 09:26:45.500000000
# 2024-02-28 09:27:04.500000000
# 23
# 2024-02-28 09:28:40.500000000
# 2024-02-28 09:29:10.500000000
# 23
# 2024-02-28 09:30:57.500000000
# 2024-02-28 09:33:19.000000000
# -52
# 2024-02-28 09:34:56.000000000
# 2024-02-28 09:35:56.500000000
# 23
# 2024-02-28 09:37:53.000000000
# 2024-02-28 09:37:58.000000000
# 23
# 2024-02-28 09:41:01.500000000
# 2024-02-28 09:41:13.500000000
# -27
# 2024-02-28 09:43:40.500000000
# 2024-02-28 09:44:32.500000000
# 23
# 2024-02-28 09:46:40.500000000
# 2024-02-28 09:47:09.500000000
# 23
# 2024-02-28 09:48:46.500000000
# 2024-02-28 09:48:46.500000000
# 23
# 2024-02-28 09:51:14.000000000
# 2024-02-28 09:51:15.000000000
# 23
# 2024-02-28 09:52:45.000000000
# 2024-02-28 09:53:21.500000000
# 23
# 2024-02-28 09:55:43.000000000
# 2024-02-28 09:56:11.500000000
# 23
# 2024-02-28 09:58:41.500000000
# 2024-02-28 09:59:00.500000000
# 23
# 2024-02-28 10:00:38.000000000
# 2024-02-28 10:03:05.000000000
# 23
# 2024-02-28 10:05:48.500000000
# 2024-02-28 10:05:52.000000000
# 23
# 2024-02-28 10:07:52.000000000
# 2024-02-28 10:07:52.000000000
# 23
# 2024-02-28 10:09:18.500000000
# 2024-02-28 10:09:42.000000000
# 23
# 2024-02-28 10:12:02.500000000
# 2024-02-28 10:12:08.000000000
# 23
# 2024-02-28 10:30:03.500000000
# 2024-02-28 10:30:17.000000000
# -52
# 2024-02-28 10:32:31.000000000
# 2024-02-28 10:32:34.000000000
# 23
# 2024-02-28 10:35:10.500000000
# 2024-02-28 10:35:39.000000000
# 23
# 2024-02-28 10:38:09.500000000
# 2024-02-28 10:39:18.500000000
# 23
# 2024-02-28 10:41:43.500000000
# 2024-02-28 10:41:43.500000000
# 23
# 2024-02-28 10:44:19.500000000
# 2024-02-28 10:44:22.000000000
# -52
# 2024-02-28 10:47:01.500000000
# 2024-02-28 10:47:04.000000000
# 23
# 2024-02-28 10:49:54.500000000
# 2024-02-28 10:50:04.500000000
# 23
# 2024-02-28 10:51:47.500000000
# 2024-02-28 10:51:47.500000000
# 23
# 2024-02-28 10:53:05.000000000
# 2024-02-28 10:53:14.000000000
# 23
# 2024-02-28 10:54:25.000000000
# 2024-02-28 10:54:27.000000000
# 23
# 2024-02-28 10:56:28.500000000
# 2024-02-28 10:57:02.500000000
# -27
# 2024-02-28 10:58:35.000000000
# 2024-02-28 10:58:50.000000000
# 23
# 2024-02-28 11:01:12.500000000
# 2024-02-28 11:01:12.500000000
# -52
# 2024-02-28 11:04:33.000000000
# 2024-02-28 11:05:09.000000000
# -52
# 2024-02-28 11:06:45.000000000
# 2024-02-28 11:07:00.500000000
# 23
# 2024-02-28 11:08:55.500000000
# 2024-02-28 11:09:04.000000000
# 23
# 2024-02-28 11:10:16.000000000
# 2024-02-28 11:10:35.500000000
# -52
# 2024-02-28 11:12:09.000000000
# 2024-02-28 11:12:22.000000000
# 23
# 2024-02-28 11:14:24.000000000
# 2024-02-28 11:14:24.500000000
# 23
# 2024-02-28 11:16:53.000000000
# 2024-02-28 11:16:58.000000000
# 23
# 2024-02-28 11:18:48.500000000
# 2024-02-28 11:18:48.500000000
# 23
# 2024-02-28 11:20:01.000000000
# 2024-02-28 13:40:44.500000000
# 23
# 2024-02-28 13:42:38.500000000
# 2024-02-28 13:44:27.500000000
# -52
# 2024-02-28 13:46:44.500000000
# 2024-02-28 13:46:46.000000000
# -52
# 2024-02-28 13:48:56.000000000
# 2024-02-28 13:49:15.000000000
# 23
# 2024-02-28 13:51:50.500000000
# 2024-02-28 13:52:56.000000000
# -102
# 2024-02-28 13:55:10.000000000
# 2024-02-28 13:55:19.500000000
# -27
# 2024-02-28 13:56:36.000000000
# 2024-02-28 13:57:13.500000000
# 23
# 2024-02-28 14:00:42.500000000
# 2024-02-28 14:03:00.000000000
# -52
# 2024-02-28 14:06:12.000000000
# 2024-02-28 14:07:41.000000000
# 23
# 2024-02-28 14:10:23.000000000
# 2024-02-28 14:10:24.500000000
# 23
# 2024-02-28 14:11:50.000000000
# 2024-02-28 14:12:02.000000000
# 23
# 2024-02-28 14:14:05.000000000
# 2024-02-28 14:15:10.000000000
# 23
# 2024-02-28 14:18:39.000000000
# 2024-02-28 14:18:39.500000000
# 23
# 2024-02-28 14:21:48.000000000
# 2024-02-28 14:21:49.000000000
# 23
# 2024-02-28 14:24:48.500000000
# 2024-02-28 14:25:00.500000000
# 23
# 2024-02-28 14:27:42.500000000
# 2024-02-28 14:28:02.000000000
# -102
# 2024-02-28 14:31:00.500000000
# 2024-02-28 14:31:25.000000000
# -52
# 2024-02-28 14:35:03.500000000
# 2024-02-28 14:36:43.000000000
# -52
# 2024-02-28 14:40:32.500000000
# 2024-02-28 14:42:27.000000000
# -27
# 2024-02-28 14:44:53.500000000
# 2024-02-28 14:44:53.500000000
# -2
# 2024-02-28 14:47:37.500000000
# 2024-02-28 14:48:16.000000000
# 23
# 2024-02-28 14:50:41.500000000
# 2024-02-20: -156.00
# 2024-02-21: 1151.00
# 2024-02-22: -133.00
# 2024-02-23: -155.00
# 2024-02-26: 376.00
# 2024-02-27: 697.00
# 2024-02-28: 97.00
# 2024-02-20: 28
# 2024-02-21: 112
# 2024-02-22: 4
# 2024-02-23: 90
# 2024-02-26: 87
# 2024-02-27: 114
# 2024-02-28: 64
# Final profit: 1877.00
# 347
# 499
# 0.6953907815631263
