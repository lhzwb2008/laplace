# %%
import pandas as pd
from enum import Enum, auto

FILENAME = "future_taobao_ssMain_tick"

class open_interest_delta_forward_enum(Enum):
    NONE = auto()
    UNKNOWN = auto()
    EXCHANGE = auto()
    OPENFWDOUBLE = auto()
    OPEN = auto()
    CLOSEFWDOUBLE = auto()
    CLOSE = auto()

class order_forward_enum(Enum):
    UP = auto()
    DOWN = auto()
    MIDDLE = auto()

class tick_type_key_enum(Enum):
    TICKTYPE = auto()
    TICKCOLOR = auto()

class tick_type_enum(Enum):
    NOCHANGE = '无交易'
    UNKNOWN = '未知'
    EXCHANGELONG = '多换'
    EXCHANGESHORT = '空换'
    EXCHANGEUNKOWN = '未知换'
    OPENDOUBLE = '双开'
    OPENLONG = '多开'
    OPENSHORT = '空开'
    OPENUNKOWN = '未知开'
    CLOSEDOUBLE = '双平'
    CLOSESHORT = '空平'
    CLOSELONG = '多平'
    CLOSEUNKOWN = '未知平'

class tick_color_enum(Enum):
    WHITE = '白色'
    RED = '红色'
    GREEN = '绿色'

tick_type_cal_dict = {
    open_interest_delta_forward_enum.NONE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.NOCHANGE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.EXCHANGE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGELONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGESHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.EXCHANGEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPENFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.OPEN:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENLONG,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENSHORT,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.OPENUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSEFWDOUBLE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEDOUBLE,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
    open_interest_delta_forward_enum.CLOSE:
        {
            order_forward_enum.UP: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSESHORT,
                                    tick_type_key_enum.TICKCOLOR: tick_color_enum.RED},
            order_forward_enum.DOWN: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSELONG,
                                      tick_type_key_enum.TICKCOLOR: tick_color_enum.GREEN},
            order_forward_enum.MIDDLE: {tick_type_key_enum.TICKTYPE: tick_type_enum.CLOSEUNKOWN,
                                        tick_type_key_enum.TICKCOLOR: tick_color_enum.WHITE}
        },
}

 # Mapping of openclose and price_direction to open_interest_delta_forward_enum and order_forward_enum
openclose_mapping = {
    '换手': open_interest_delta_forward_enum.EXCHANGE,
    '双开': open_interest_delta_forward_enum.OPENFWDOUBLE,
    '开仓': open_interest_delta_forward_enum.OPEN,
    '双平': open_interest_delta_forward_enum.CLOSEFWDOUBLE,  # Assuming definition for 双平
    '平仓': open_interest_delta_forward_enum.CLOSE,
    '无交易': open_interest_delta_forward_enum.NONE,
    '未知':open_interest_delta_forward_enum.UNKNOWN
}

price_direction_mapping = {
    '向上': order_forward_enum.UP,
    '向下': order_forward_enum.DOWN,
    '不变': order_forward_enum.MIDDLE
}

# 枚举到中文的映射
tick_type_to_chinese = {
    tick_type_enum.NOCHANGE: '无交易',
    tick_type_enum.UNKNOWN: '未知',
    tick_type_enum.EXCHANGELONG: '多换',
    tick_type_enum.EXCHANGESHORT: '空换',
    tick_type_enum.EXCHANGEUNKOWN: '未知换',
    tick_type_enum.OPENDOUBLE: '双开',
    tick_type_enum.OPENLONG: '开多',
    tick_type_enum.OPENSHORT: '开空',
    tick_type_enum.OPENUNKOWN: '未知开',
    tick_type_enum.CLOSEDOUBLE: '双平',
    tick_type_enum.CLOSESHORT: '空平',
    tick_type_enum.CLOSELONG: '多平',
    tick_type_enum.CLOSEUNKOWN: '未知平',
}

tick_color_to_chinese = {
    tick_color_enum.WHITE: '白色',
    tick_color_enum.RED: '红色',
    tick_color_enum.GREEN: '绿色',
}


# Load the tick data
df = pd.read_csv(FILENAME+".csv")

# Calculate the deltas for volume and open interest
df['volume_delta'] = df['volume'].diff()
df['open_interest_delta'] = df['open_interest'].diff()

# Initialize columns for open/close position
df['trade_openclose'] = None
df['trade_color'] = None 
df['close_count'] = df['volume_delta']

# Iterate over the DataFrame to assign open/close positions
for i in range(1, len(df)):
    volume_delta = df.loc[i, 'volume_delta']
    open_interest_delta = df.loc[i, 'open_interest_delta']
    last_price = df.loc[i, 'last_price']
    ask_price1 = df.loc[i, 'ask_price1']
    bid_price1 = df.loc[i, 'bid_price1']
    pre_last_price = df.loc[i-1,'last_price']
    pre_ask_price1 = df.loc[i-1, 'ask_price1']
    pre_bid_price1 = df.loc[i-1, 'bid_price1']
    openclose = ''
    price_direction = ''

    # Determine the open/close position
    if volume_delta == open_interest_delta > 0:
        openclose = '双开'
    elif volume_delta > open_interest_delta > 0:
        openclose = '开仓'
    elif volume_delta > abs(open_interest_delta) > 0 and open_interest_delta < 0:
        openclose = '平仓'
    elif volume_delta > 0 and open_interest_delta == 0:
        openclose = '换手'
    elif volume_delta + open_interest_delta == 0 and volume_delta>0:
        openclose = '双平'
    elif volume_delta == 0 and  open_interest_delta == 0:
        openclose = '无交易'
    else:
        openclose = '未知'
    
    # 判断价格方向
    if last_price >= pre_ask_price1:
        price_direction = '向上'
    elif last_price <= pre_bid_price1:
        price_direction = '向下'
    elif last_price >= ask_price1:
        price_direction = '向上'
    elif last_price <= bid_price1:
        price_direction = '向下'
    else:
        price_direction = '不变'
        
   

    # Convert openclose and price_direction to their corresponding enum values
    delta_enum = openclose_mapping.get(openclose, open_interest_delta_forward_enum.NONE)
    direction_enum = price_direction_mapping.get(price_direction, order_forward_enum.MIDDLE)

    # Retrieve the tick type and color based on the mappings
    tick_info = tick_type_cal_dict.get(delta_enum, {}).get(direction_enum, {})
    tick_type = tick_info.get(tick_type_key_enum.TICKTYPE, tick_type_enum.UNKNOWN)
    tick_color = tick_info.get(tick_type_key_enum.TICKCOLOR, tick_color_enum.WHITE)
    

    # 使用映射转换为中文描述
    tick_type_chinese = tick_type_to_chinese[tick_type]
    tick_color_chinese = tick_color_to_chinese[tick_color]

    # 更新DataFrame
    df.at[i, 'trade_openclose'] = tick_type_chinese
    df.at[i, 'trade_color'] = tick_color_chinese

# Save the modified DataFrame to a new CSV file
df.to_csv(FILENAME+"_withopenclose.csv", index=False)

# %%
import pandas as pd

# 假设已加载并准备好DataFrame df
df = pd.read_csv(FILENAME+"_withopenclose.csv")

df = df.loc[df['volume_delta'] > 0]
# 重置索引以确保从0开始
df.reset_index(drop=True, inplace=True)


guess_tick=100

# 初始化列用于标记交易机会
df['buy_opportunity'] = 0
df['sell_opportunity'] = 0
trade_hand=1

# 为每个tick计算未来100个tick内与当前挂单价格相匹配的成交量
for i in range(len(df)):
    if i + guess_tick >= len(df):  # 确保未来有足够的tick进行分析
        break

    # 当前的买一和卖一价
    current_ask_price1 = df.loc[i, 'ask_price1']
    current_bid_price1 = df.loc[i, 'bid_price1']

    # 初始化对应价格的成交量计数
    matching_buy_volume = 0
    matching_sell_volume = 0
    
    buy_done = 0
    sell_done = 0

    # 遍历未来100个tick
    for j in range(i+1, i+guess_tick+1):
        if df.loc[j, 'bid_price1']<current_bid_price1:
            buy_done = 1 
        if df.loc[j, 'ask_price1']>current_ask_price1:
            sell_done = 1 
        # 如果未来tick的买一价等于当前tick的买一价，累加成交量
        if df.loc[j, 'bid_price1'] == current_bid_price1 and df.loc[j, 'bid_price1'] == df.loc[j, 'last_price']:
            matching_buy_volume += df.loc[j, 'volume_delta']
        # 如果未来tick的卖一价等于当前tick的卖一价，累加成交量
        if df.loc[j, 'ask_price1'] == current_ask_price1 and df.loc[j, 'ask_price1'] == df.loc[j, 'last_price']:
            matching_sell_volume += df.loc[j, 'volume_delta']

    # 判断是否存在买卖机会
    if buy_done==1 or matching_buy_volume >= df.loc[i, 'ask_volume1']+trade_hand:
        df.loc[i, 'buy_opportunity'] = 1
    if sell_done==1 or matching_sell_volume >= df.loc[i, 'bid_volume1']+trade_hand:
        df.loc[i, 'sell_opportunity'] = 1


# 创建一个新列来标记同时为买卖机会的tick
df['dual_opportunity'] = ((df['buy_opportunity'] == 1) & (df['sell_opportunity'] == 1)).astype(int)

# 计算同时为买卖机会的总数
dual_opportunities_count = df['dual_opportunity'].sum()

# 计算比例
total_ticks_analyzed = len(df) - guess_tick
dual_opportunities_ratio = dual_opportunities_count / total_ticks_analyzed

print(f"Dual opportunities count: {dual_opportunities_count}")
print(f"Dual opportunities ratio: {dual_opportunities_ratio:.4f}")

# 保存到新的CSV文件
df.to_csv(FILENAME+"_with_opportunities.csv", index=False)
# Out:
# Dual opportunities count: 310773
# Dual opportunities ratio: 0.5481

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score,precision_score

FILENAME = "future_taobao_ssMain_tick"
# 加载数据
data = pd.read_csv(FILENAME+"_with_opportunities.csv")

data_clean = data.dropna().copy()  # 创建一个副本以避免警告

# features = [
#     'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
#     'bid_price1', 'ask_price1', 'bid_price2', 'ask_price2', 'bid_price3', 'ask_price3',
#     'bid_price4', 'ask_price4', 'bid_price5', 'ask_price5', 'bid_volume1', 'bid_volume2',
#     'bid_volume3', 'bid_volume4', 'bid_volume5', 'ask_volume1', 'ask_volume2', 'ask_volume3',
#     'ask_volume4', 'ask_volume5'
# ]
features = [
    'last_price','highest','lowest', 'volume', 'open_interest', 'volume_delta', 'open_interest_delta',
    'bid_price1', 'ask_price1', 'bid_volume1', 'ask_volume1'
]
# 计算短期量价特征

# window_size = 500  # 用于特征计算的窗口大小
# # 特征生成
# data_clean['rolling_mean'] = data_clean['last_price'].rolling(window=window_size).mean()
# data_clean['rolling_std'] = data_clean['last_price'].rolling(window=window_size).std()
# # RSI计算
# delta = data_clean['last_price'].diff()
# gain = (delta.where(delta > 0, 0)).fillna(0)
# loss = (-delta.where(delta < 0, 0)).fillna(0)
# avg_gain = gain.rolling(window=window_size).mean()
# avg_loss = loss.rolling(window=window_size).mean()
# rs = avg_gain / avg_loss
# data_clean['RSI'] = 100 - (100 / (1 + rs))
# # MACD计算
# short_ema = data_clean['last_price'].ewm(span=int(window_size/2), adjust=False).mean()  # 使用窗口大小的一半作为短期EMA
# long_ema = data_clean['last_price'].ewm(span=window_size, adjust=False).mean()  # 使用整个窗口大小作为长期EMA
# data_clean['MACD'] = short_ema - long_ema
# data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=int(window_size/3), adjust=False).mean()  # 使用窗口大小的三分之一作为信号线
# # 删除因计算滚动特征而产生的NaN值
# data_clean.dropna(inplace=True)
# # 添加新特征到特征列表
# features.extend(['rolling_mean', 'rolling_std', 'RSI', 'MACD', 'MACD_signal'])


# 目标列处理
data_clean['successful_trade'] = data_clean.apply(
    lambda row: 1 if row['buy_opportunity'] and row['sell_opportunity'] else 0, axis=1
)

X = data_clean[['datetime'] + features]
y = data_clean['successful_trade']

# 数据切分
split_start = int(len(data_clean) * 0.4)
split_point = int(len(data_clean) * 0.9)
X_train = X.iloc[split_start:split_point]
y_train = y.iloc[split_start:split_point]
X_test = X.iloc[split_point:]
y_test = y.iloc[split_point:]

# 模型训练
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# 注意：随机森林模型不能直接处理datetime类型的特征，所以在训练前需要去除或转换该特征
X_train_features = X_train.drop(columns=['datetime'])
X_test_features = X_test.drop(columns=['datetime'])
rf_model.fit(X_train_features, y_train)

# 获取属于类别1的概率
y_pred_proba = rf_model.predict_proba(X_test_features)[:, 1]
# 设置交易阈值
trade_threshold = 0.6
# 根据阈值生成预测结果，大于等于阈值预测为1，否则为0
y_pred_threshold = (y_pred_proba >= trade_threshold).astype(int)
# 计算查准率
precision = precision_score(y_test, y_pred_threshold)
print(f"Precision: {precision}")

# 对照组评估（全1预测）
predictions_all_ones = [1] * len(y_test)
print("All Ones Accuracy:", precision_score(y_test, predictions_all_ones))

# %%
from datetime import datetime, time

guess_tick = 100
profit = 0  # 盈利
trade_threshold = 0.6 # 交易阈值
trade_hand = 1
trade_gap = 5 #每跳多少钱
hand_volume = 5  # 不锈钢1手5吨，1手开仓2元，平今0元
hand_fee = 2
done_count = 0
count = 0
daily_profit = {}  # 新增：用于存储每日盈利
daily_trade = {}

def parse_time_range(time_range_str):
    """解析时间范围字符串并返回时间对象的开始和结束时间"""
    start_str, end_str = time_range_str.split('-')
    start_time = datetime.strptime(start_str, "%H:%M").time()
    end_time = datetime.strptime(end_str, "%H:%M").time()
    return start_time, end_time

def is_time_in_ranges(time_to_check, time_ranges):
    """判断给定时间是否在时间范围数组内"""
    for time_range in time_ranges:
        start_time, end_time = parse_time_range(time_range)
        if start_time <= time_to_check <= end_time:
            return True
    return False

# 定义时间范围数组
notrade_time = ["09:00-09:10","11:20-11:30","13:30-13:40","14:50-15:00","21:00-21:10","0:00-1:00"]

i = 0
while i < len(X_test) - guess_tick:
    datetime_str = X_test.iloc[i]['datetime']
    date_str = datetime_str.split(' ')[0]  # 新增：提取日期字符串
    if '.' in datetime_str:
        # 如果有小数点，分割为主时间部分和纳秒部分
        time, nano_part = datetime_str.split('.')
    else:
        # 如果没有小数点，则没有纳秒部分
        time = datetime_str
        nano_part = '0'
    if is_time_in_ranges(datetime.strptime(time, "%Y-%m-%d %H:%M:%S").time(), notrade_time):
        i = i+1
        continue
    proba = y_pred_proba[i]
    if proba > trade_threshold:
        current_ask_price1 = X_test.iloc[i]['ask_price1']
        current_bid_price1 = X_test.iloc[i]['bid_price1']
        if current_ask_price1-current_bid_price1!=trade_gap:
            i = i+1
            continue

        matching_buy_volume = 0
        matching_sell_volume = 0
        buy_done = 0
        sell_done = 0
        
        for j in range(i + 1, i + guess_tick+1): 
            future_tick = X_test.iloc[j]
            if future_tick['bid_price1'] < current_bid_price1:
                buy_done = 1
            if future_tick['ask_price1'] > current_ask_price1:
                sell_done = 1
            if future_tick['bid_price1'] == current_bid_price1 and future_tick['last_price'] == current_bid_price1:
                matching_sell_volume += future_tick['volume_delta']
            if future_tick['ask_price1'] == current_ask_price1 and future_tick['last_price'] == current_ask_price1:
                matching_buy_volume += future_tick['volume_delta']
            
            j = j+1 

        stop_loss_tick = i + guess_tick
        stop_loss_price_bid = X_test.iloc[stop_loss_tick]['bid_price1']
        stop_loss_price_ask = X_test.iloc[stop_loss_tick]['ask_price1']
        count = count +1
        daily_trade[date_str] = daily_trade.get(date_str,0)+1
        
        # 判断是否存在买卖机会
        if (buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand) and \
        (sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand):
            trade_profit = (current_ask_price1 - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            done_count = done_count + 1
            print(X_test.iloc[i]['datetime'])
            print(trade_profit)
        elif buy_done == 1 or matching_buy_volume >= X_test.iloc[stop_loss_tick]['ask_volume1']+trade_hand:
            trade_profit = (stop_loss_price_bid - current_bid_price1) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            # stop_loss_tick = stop_loss_tick + 10*guess_tick
            print(X_test.iloc[i]['datetime'])
            print(trade_profit)
        elif sell_done == 1 or matching_sell_volume >= X_test.iloc[stop_loss_tick]['bid_volume1']+trade_hand:
            trade_profit = (current_ask_price1 - stop_loss_price_ask) * trade_hand * hand_volume-hand_fee*trade_hand
            profit += trade_profit
            daily_profit[date_str] = daily_profit.get(date_str, 0) + trade_profit  # 更新每日盈利
            # stop_loss_tick = stop_loss_tick + 10*guess_tick
            print(X_test.iloc[i]['datetime'])
            print(trade_profit)
        else:
            i = i + 1
        i = stop_loss_tick
        print(X_test.iloc[i]['datetime'])
        
    else:
        i = i + 1

# 打印每一天的盈利
for date, daily_profit in daily_profit.items():
    print(f"{date}: {daily_profit:.2f}")
for date, daily_trade in daily_trade.items():
    print(f"{date}: {daily_trade}")

print(f"Final profit: {profit:.2f}")
print(done_count/count)
print(count)
# Out:
# 2024-02-05 14:34:07.500000000
# 23
# 2024-02-05 14:39:21.500000000
# 2024-02-05 14:39:21.500000000
# 23
# 2024-02-05 14:44:09.000000000
# 2024-02-05 14:44:09.000000000
# 23
# 2024-02-05 14:47:01.500000000
# 2024-02-05 14:47:14.500000000
# 23
# 2024-02-05 14:50:47.000000000
# 2024-02-05 21:10:34.500000000
# 23
# 2024-02-05 21:11:49.000000000
# 2024-02-05 21:11:58.500000000
# -27
# 2024-02-05 21:13:32.000000000
# 2024-02-05 21:14:37.500000000
# -2
# 2024-02-05 21:16:21.000000000
# 2024-02-05 21:17:35.000000000
# 23
# 2024-02-05 21:21:51.500000000
# 2024-02-05 21:27:55.500000000
# 23
# 2024-02-05 21:29:25.000000000
# 2024-02-05 21:30:54.500000000
# 23
# 2024-02-05 21:34:01.000000000
# 2024-02-05 21:36:41.000000000
# 23
# 2024-02-05 21:40:38.500000000
# 2024-02-05 21:42:01.000000000
# 23
# 2024-02-05 21:45:33.000000000
# 2024-02-05 21:47:33.500000000
# 23
# 2024-02-05 21:51:30.500000000
# 2024-02-05 21:52:26.500000000
# 23
# 2024-02-05 21:56:22.500000000
# 2024-02-05 21:57:07.000000000
# 23
# 2024-02-05 22:00:34.500000000
# 2024-02-05 22:00:35.000000000
# 23
# 2024-02-05 22:05:02.000000000
# 2024-02-05 22:08:26.000000000
# 23
# 2024-02-05 22:12:54.500000000
# 2024-02-05 22:15:07.000000000
# 23
# 2024-02-05 22:19:53.500000000
# 2024-02-05 22:20:30.500000000
# 23
# 2024-02-05 22:27:09.000000000
# 2024-02-05 22:28:28.500000000
# 23
# 2024-02-05 22:35:00.000000000
# 2024-02-05 22:35:51.000000000
# -52
# 2024-02-05 22:43:25.000000000
# 2024-02-05 22:46:56.500000000
# 23
# 2024-02-05 22:53:29.500000000
# 2024-02-05 22:58:40.000000000
# 23
# 2024-02-05 23:02:04.000000000
# 2024-02-05 23:39:06.500000000
# 23
# 2024-02-06 00:04:05.500000000
# 2024-02-06 09:10:01.500000000
# 23
# 2024-02-06 09:12:52.000000000
# 2024-02-06 09:13:25.000000000
# 23
# 2024-02-06 09:15:45.500000000
# 2024-02-06 09:16:15.000000000
# 23
# 2024-02-06 09:19:11.000000000
# 2024-02-06 09:19:17.000000000
# 23
# 2024-02-06 09:21:54.000000000
# 2024-02-06 09:22:21.500000000
# 23
# 2024-02-06 09:23:48.500000000
# 2024-02-06 09:24:04.000000000
# 23
# 2024-02-06 09:26:20.000000000
# 2024-02-06 09:26:34.000000000
# 23
# 2024-02-06 09:27:39.500000000
# 2024-02-06 09:28:28.500000000
# -52
# 2024-02-06 09:29:39.000000000
# 2024-02-06 09:29:44.500000000
# 23
# 2024-02-06 09:31:22.500000000
# 2024-02-06 09:33:02.000000000
# 23
# 2024-02-06 09:35:35.000000000
# 2024-02-06 09:36:10.500000000
# -77
# 2024-02-06 09:38:15.000000000
# 2024-02-06 09:39:40.000000000
# 23
# 2024-02-06 09:44:49.500000000
# 2024-02-06 09:45:16.500000000
# -127
# 2024-02-06 09:48:34.500000000
# 2024-02-06 09:49:30.500000000
# -52
# 2024-02-06 09:52:19.000000000
# 2024-02-06 09:52:33.000000000
# 23
# 2024-02-06 09:54:33.000000000
# 2024-02-06 09:54:33.000000000
# 23
# 2024-02-06 09:57:38.500000000
# 2024-02-06 09:57:38.500000000
# 23
# 2024-02-06 10:01:05.000000000
# 2024-02-06 10:01:05.000000000
# 23
# 2024-02-06 10:06:03.500000000
# 2024-02-06 10:06:52.500000000
# 23
# 2024-02-06 10:11:12.000000000
# 2024-02-06 10:12:48.500000000
# -52
# 2024-02-06 10:31:42.500000000
# 2024-02-06 10:32:04.000000000
# 23
# 2024-02-06 10:36:27.500000000
# 2024-02-06 10:37:45.000000000
# 23
# 2024-02-06 10:44:07.000000000
# 2024-02-06 10:46:38.000000000
# 23
# 2024-02-06 10:49:05.000000000
# 2024-02-06 10:49:10.500000000
# 23
# 2024-02-06 10:50:42.000000000
# 2024-02-06 10:51:04.000000000
# -77
# 2024-02-06 10:53:24.000000000
# 2024-02-06 10:55:20.000000000
# 23
# 2024-02-06 11:02:50.500000000
# 2024-02-06 11:03:58.000000000
# 23
# 2024-02-06 11:09:49.500000000
# 2024-02-06 11:12:36.000000000
# -77
# 2024-02-06 11:16:32.500000000
# 2024-02-06 13:41:03.000000000
# 23
# 2024-02-06 13:42:40.000000000
# 2024-02-06 13:44:13.000000000
# 23
# 2024-02-06 13:46:20.500000000
# 2024-02-06 13:47:28.500000000
# -102
# 2024-02-06 13:50:34.000000000
# 2024-02-06 13:51:11.000000000
# 23
# 2024-02-06 13:53:58.500000000
# 2024-02-06 13:58:19.500000000
# 23
# 2024-02-06 14:01:29.500000000
# 2024-02-06 14:03:12.500000000
# 23
# 2024-02-06 14:08:17.000000000
# 2024-02-06 14:08:34.500000000
# 23
# 2024-02-06 14:12:36.000000000
# 2024-02-06 14:12:36.000000000
# 23
# 2024-02-06 14:16:40.500000000
# 2024-02-06 14:16:40.500000000
# 23
# 2024-02-06 14:21:10.500000000
# 2024-02-06 14:22:31.500000000
# 23
# 2024-02-06 14:27:02.500000000
# 2024-02-06 14:27:02.500000000
# -77
# 2024-02-06 14:31:30.000000000
# 2024-02-06 14:32:32.000000000
# 23
# 2024-02-06 14:38:26.000000000
# 2024-02-06 14:38:31.000000000
# 23
# 2024-02-06 14:45:20.000000000
# 2024-02-06 14:45:22.000000000
# 23
# 2024-02-06 14:49:51.500000000
# 2024-02-06 14:49:52.000000000
# 23
# 2024-02-06 14:53:27.000000000
# 2024-02-06 21:10:01.000000000
# 23
# 2024-02-06 21:11:50.500000000
# 2024-02-06 21:11:52.000000000
# 23
# 2024-02-06 21:13:51.000000000
# 2024-02-06 21:13:51.000000000
# 23
# 2024-02-06 21:15:51.500000000
# 2024-02-06 21:16:03.000000000
# 23
# 2024-02-06 21:18:01.500000000
# 2024-02-06 21:18:06.000000000
# 23
# 2024-02-06 21:21:29.500000000
# 2024-02-06 21:21:29.500000000
# 23
# 2024-02-06 21:25:27.500000000
# 2024-02-06 21:25:52.500000000
# 23
# 2024-02-06 21:28:15.500000000
# 2024-02-06 21:31:21.500000000
# 23
# 2024-02-06 21:36:24.000000000
# 2024-02-06 21:38:25.500000000
# 23
# 2024-02-06 21:40:02.500000000
# 2024-02-06 21:40:17.500000000
# 23
# 2024-02-06 21:43:47.500000000
# 2024-02-06 21:44:41.000000000
# 23
# 2024-02-06 21:48:31.000000000
# 2024-02-06 21:49:45.000000000
# 23
# 2024-02-06 21:53:50.000000000
# 2024-02-06 21:54:36.000000000
# 23
# 2024-02-06 22:00:13.500000000
# 2024-02-06 22:01:03.500000000
# 23
# 2024-02-06 22:06:45.000000000
# 2024-02-06 22:06:54.500000000
# 23
# 2024-02-06 22:15:40.500000000
# 2024-02-06 22:15:49.500000000
# 23
# 2024-02-06 22:25:02.500000000
# 2024-02-06 22:25:22.000000000
# 23
# 2024-02-06 22:27:45.500000000
# 2024-02-06 22:27:48.500000000
# 23
# 2024-02-06 22:30:56.500000000
# 2024-02-06 22:31:39.500000000
# -27
# 2024-02-06 22:35:53.500000000
# 2024-02-06 22:35:56.500000000
# 23
# 2024-02-06 22:40:16.000000000
# 2024-02-06 22:41:00.000000000
# 23
# 2024-02-06 22:44:59.000000000
# 2024-02-06 22:49:18.500000000
# -27
# 2024-02-06 22:50:39.500000000
# 2024-02-06 22:50:53.000000000
# 23
# 2024-02-06 22:54:58.500000000
# 2024-02-06 22:59:36.000000000
# -27
# 2024-02-06 23:04:43.500000000
# 2024-02-06 23:06:11.500000000
# 23
# 2024-02-06 23:13:41.000000000
# 2024-02-06 23:19:56.000000000
# 23
# 2024-02-06 23:33:12.500000000
# 2024-02-06 23:38:59.000000000
# 23
# 2024-02-06 23:58:06.500000000
# 2024-02-07 09:10:09.000000000
# 23
# 2024-02-07 09:13:07.500000000
# 2024-02-07 09:13:07.500000000
# 23
# 2024-02-07 09:17:30.500000000
# 2024-02-07 09:17:38.500000000
# 23
# 2024-02-07 09:24:30.500000000
# 2024-02-07 09:25:15.000000000
# -102
# 2024-02-07 09:30:53.500000000
# 2024-02-07 09:31:04.000000000
# 23
# 2024-02-07 09:34:04.000000000
# 2024-02-07 09:34:27.000000000
# -127
# 2024-02-07 09:38:41.000000000
# 2024-02-07 09:39:22.000000000
# 23
# 2024-02-07 09:42:49.500000000
# 2024-02-07 09:42:52.000000000
# 23
# 2024-02-07 09:47:15.000000000
# 2024-02-07 09:50:09.500000000
# 23
# 2024-02-07 09:53:33.000000000
# 2024-02-07 09:57:50.000000000
# 23
# 2024-02-07 10:04:21.000000000
# 2024-02-07 10:04:21.000000000
# 23
# 2024-02-07 10:12:05.500000000
# 2024-02-07 10:12:09.000000000
# 23
# 2024-02-07 10:33:33.500000000
# 2024-02-07 10:36:26.000000000
# 23
# 2024-02-07 10:40:28.000000000
# 2024-02-07 10:42:09.000000000
# -52
# 2024-02-07 10:47:24.000000000
# 2024-02-07 10:47:26.500000000
# 23
# 2024-02-07 10:55:10.500000000
# 2024-02-07 10:57:07.500000000
# 23
# 2024-02-07 10:58:20.000000000
# 2024-02-07 10:59:05.500000000
# 23
# 2024-02-07 11:00:08.000000000
# 2024-02-07 11:00:09.500000000
# -52
# 2024-02-07 11:01:59.000000000
# 2024-02-07 11:02:43.500000000
# 23
# 2024-02-07 11:05:41.000000000
# 2024-02-07 11:05:41.000000000
# 23
# 2024-02-07 11:07:57.500000000
# 2024-02-07 11:11:22.000000000
# 23
# 2024-02-07 11:15:11.000000000
# 2024-02-07 11:19:43.500000000
# 23
# 2024-02-07 11:24:42.500000000
# 2024-02-07 13:41:00.000000000
# 23
# 2024-02-07 13:43:01.500000000
# 2024-02-07 13:43:39.500000000
# 23
# 2024-02-07 13:45:17.500000000
# 2024-02-07 13:45:22.500000000
# 23
# 2024-02-07 13:47:57.500000000
# 2024-02-07 13:48:56.000000000
# 23
# 2024-02-07 13:52:15.000000000
# 2024-02-07 13:52:43.000000000
# 23
# 2024-02-07 13:57:25.000000000
# 2024-02-07 14:04:58.500000000
# 23
# 2024-02-07 14:09:43.500000000
# 2024-02-07 14:13:47.000000000
# -52
# 2024-02-07 14:21:38.000000000
# 2024-02-07 14:22:30.500000000
# 23
# 2024-02-07 14:25:48.500000000
# 2024-02-07 14:26:58.500000000
# -52
# 2024-02-07 14:29:47.000000000
# 2024-02-07 14:31:04.000000000
# 23
# 2024-02-07 14:35:09.500000000
# 2024-02-07 14:38:48.500000000
# 23
# 2024-02-07 14:42:45.500000000
# 2024-02-07 14:43:07.000000000
# 23
# 2024-02-07 14:46:10.000000000
# 2024-02-07 14:48:52.000000000
# 23
# 2024-02-07 14:51:14.500000000
# 2024-02-07 21:11:07.500000000
# 23
# 2024-02-07 21:13:23.000000000
# 2024-02-07 21:13:43.500000000
# 23
# 2024-02-07 21:15:39.000000000
# 2024-02-07 21:16:22.000000000
# 23
# 2024-02-07 21:19:27.500000000
# 2024-02-07 21:19:51.000000000
# -77
# 2024-02-07 21:22:55.000000000
# 2024-02-07 21:43:24.500000000
# 23
# 2024-02-07 21:49:20.500000000
# 2024-02-07 21:58:19.000000000
# 23
# 2024-02-07 22:04:54.000000000
# 2024-02-07 22:06:21.500000000
# 23
# 2024-02-07 22:10:15.500000000
# 2024-02-07 22:12:20.500000000
# 23
# 2024-02-07 22:18:39.500000000
# 2024-02-07 22:22:17.500000000
# 23
# 2024-02-07 22:26:24.500000000
# 2024-02-07 22:35:01.500000000
# 23
# 2024-02-07 22:41:43.000000000
# 2024-02-07 22:44:41.500000000
# 23
# 2024-02-07 22:48:29.500000000
# 2024-02-07 22:49:13.500000000
# 23
# 2024-02-07 22:56:07.500000000
# 2024-02-07 22:59:25.000000000
# 23
# 2024-02-07 23:03:06.000000000
# 2024-02-07 23:03:07.500000000
# -52
# 2024-02-07 23:08:26.000000000
# 2024-02-07 23:18:10.000000000
# -27
# 2024-02-07 23:37:36.500000000
# 2024-02-07 23:49:59.500000000
# 23
# 2024-02-08 00:11:11.500000000
# 2024-02-08 09:10:40.000000000
# 23
# 2024-02-08 09:11:43.000000000
# 2024-02-08 09:13:58.500000000
# -52
# 2024-02-08 09:19:11.500000000
# 2024-02-08 09:30:18.500000000
# 23
# 2024-02-08 09:33:51.000000000
# 2024-02-08 09:39:52.500000000
# 23
# 2024-02-08 09:43:03.500000000
# 2024-02-08 09:45:08.500000000
# 23
# 2024-02-08 09:50:33.500000000
# 2024-02-08 09:50:34.000000000
# 23
# 2024-02-08 09:54:24.000000000
# 2024-02-08 09:57:38.000000000
# 23
# 2024-02-08 10:03:27.000000000
# 2024-02-08 10:06:00.500000000
# 23
# 2024-02-08 10:11:57.500000000
# 2024-02-08 10:58:24.000000000
# 23
# 2024-02-08 11:01:20.000000000
# 2024-02-08 11:11:08.000000000
# 23
# 2024-02-08 11:18:48.000000000
# 2024-02-08 13:45:23.000000000
# 23
# 2024-02-08 13:50:34.500000000
# 2024-02-08 13:52:15.000000000
# 23
# 2024-02-08 13:57:17.000000000
# 2024-02-08 13:57:25.500000000
# 23
# 2024-02-08 14:00:45.500000000
# 2024-02-08 14:00:55.000000000
# 23
# 2024-02-08 14:05:29.000000000
# 2024-02-08 14:11:19.000000000
# 23
# 2024-02-08 14:16:37.500000000
# 2024-02-08 14:18:08.000000000
# 23
# 2024-02-08 14:24:06.000000000
# 2024-02-08 14:24:13.000000000
# 23
# 2024-02-08 14:29:24.500000000
# 2024-02-08 14:30:09.000000000
# -77
# 2024-02-08 14:34:21.000000000
# 2024-02-08 14:36:39.500000000
# 23
# 2024-02-08 14:40:19.500000000
# 2024-02-08 14:41:06.500000000
# 23
# 2024-02-08 14:43:39.500000000
# 2024-02-08 14:43:40.000000000
# 23
# 2024-02-08 14:45:59.500000000
# 2024-02-08 14:46:03.000000000
# 23
# 2024-02-08 14:48:28.500000000
# 2024-02-08 14:48:39.500000000
# 23
# 2024-02-08 14:50:29.500000000
# 2024-02-19 09:10:07.500000000
# -2
# 2024-02-19 09:11:18.500000000
# 2024-02-19 09:11:23.500000000
# 23
# 2024-02-19 09:12:47.500000000
# 2024-02-19 09:12:51.000000000
# 23
# 2024-02-19 09:13:52.000000000
# 2024-02-19 09:14:03.000000000
# 23
# 2024-02-19 09:15:13.000000000
# 2024-02-19 09:15:13.500000000
# 23
# 2024-02-19 09:16:28.500000000
# 2024-02-19 09:16:34.000000000
# 23
# 2024-02-19 09:18:04.000000000
# 2024-02-19 09:18:25.000000000
# -27
# 2024-02-19 09:20:02.000000000
# 2024-02-19 09:21:06.500000000
# -52
# 2024-02-19 09:22:26.500000000
# 2024-02-19 09:22:55.000000000
# 23
# 2024-02-19 09:24:28.000000000
# 2024-02-19 09:25:04.000000000
# -77
# 2024-02-19 09:26:46.000000000
# 2024-02-19 09:26:48.500000000
# -77
# 2024-02-19 09:29:08.000000000
# 2024-02-19 09:29:25.000000000
# 23
# 2024-02-19 09:31:29.000000000
# 2024-02-19 09:32:57.500000000
# 23
# 2024-02-19 09:34:37.500000000
# 2024-02-19 09:36:08.000000000
# 23
# 2024-02-19 09:38:17.500000000
# 2024-02-19 09:38:18.500000000
# 23
# 2024-02-19 09:40:34.500000000
# 2024-02-19 09:40:53.500000000
# 23
# 2024-02-19 09:42:54.500000000
# 2024-02-19 09:42:55.000000000
# 23
# 2024-02-19 09:44:57.500000000
# 2024-02-19 09:44:59.000000000
# 23
# 2024-02-19 09:47:38.500000000
# 2024-02-19 09:47:38.500000000
# -27
# 2024-02-19 09:52:13.000000000
# 2024-02-19 09:55:39.500000000
# -52
# 2024-02-19 09:59:03.500000000
# 2024-02-19 09:59:04.000000000
# 23
# 2024-02-19 10:01:02.500000000
# 2024-02-19 10:01:48.500000000
# 23
# 2024-02-19 10:05:18.000000000
# 2024-02-19 10:05:19.500000000
# 23
# 2024-02-19 10:08:32.000000000
# 2024-02-19 10:10:34.000000000
# 23
# 2024-02-19 10:13:47.000000000
# 2024-02-19 10:14:56.000000000
# -77
# 2024-02-19 10:31:36.000000000
# 2024-02-19 10:34:14.000000000
# 23
# 2024-02-19 10:36:29.000000000
# 2024-02-19 10:36:30.500000000
# 23
# 2024-02-19 10:38:01.500000000
# 2024-02-19 10:38:15.000000000
# 23
# 2024-02-19 10:40:52.500000000
# 2024-02-19 10:40:52.500000000
# 23
# 2024-02-19 10:43:11.500000000
# 2024-02-19 10:43:38.000000000
# 23
# 2024-02-19 10:47:51.500000000
# 2024-02-19 10:49:02.500000000
# 23
# 2024-02-19 10:52:39.000000000
# 2024-02-19 10:53:47.500000000
# 23
# 2024-02-19 10:57:28.500000000
# 2024-02-19 11:00:38.500000000
# 23
# 2024-02-19 11:04:32.000000000
# 2024-02-19 11:05:03.000000000
# -27
# 2024-02-19 11:07:10.500000000
# 2024-02-19 11:08:02.000000000
# -52
# 2024-02-19 11:12:23.000000000
# 2024-02-19 11:14:04.500000000
# 23
# 2024-02-19 11:17:43.000000000
# 2024-02-19 11:18:00.000000000
# 23
# 2024-02-19 11:22:29.500000000
# 2024-02-19 13:41:31.000000000
# 23
# 2024-02-19 13:44:03.500000000
# 2024-02-19 13:45:25.500000000
# 23
# 2024-02-19 13:47:58.000000000
# 2024-02-19 13:49:48.000000000
# 23
# 2024-02-19 13:52:33.000000000
# 2024-02-19 13:54:05.500000000
# -77
# 2024-02-19 13:55:50.000000000
# 2024-02-19 13:56:11.000000000
# 23
# 2024-02-19 13:58:32.000000000
# 2024-02-19 13:58:33.500000000
# 23
# 2024-02-19 14:00:27.500000000
# 2024-02-19 14:00:33.000000000
# 23
# 2024-02-19 14:02:50.500000000
# 2024-02-19 14:02:50.500000000
# -52
# 2024-02-19 14:05:36.000000000
# 2024-02-19 14:05:43.000000000
# 23
# 2024-02-19 14:07:31.000000000
# 2024-02-19 14:07:57.000000000
# 23
# 2024-02-19 14:10:34.000000000
# 2024-02-19 14:11:09.500000000
# 23
# 2024-02-19 14:13:29.500000000
# 2024-02-19 14:13:53.500000000
# 23
# 2024-02-19 14:15:25.500000000
# 2024-02-19 14:15:30.000000000
# 23
# 2024-02-19 14:18:07.000000000
# 2024-02-19 14:18:07.500000000
# 23
# 2024-02-19 14:20:09.000000000
# 2024-02-19 14:20:09.000000000
# -102
# 2024-02-19 14:21:50.500000000
# 2024-02-19 14:22:01.500000000
# 23
# 2024-02-19 14:23:21.500000000
# 2024-02-19 14:23:23.500000000
# 23
# 2024-02-19 14:25:04.500000000
# 2024-02-19 14:25:07.500000000
# 23
# 2024-02-19 14:27:21.500000000
# 2024-02-19 14:28:09.000000000
# 23
# 2024-02-19 14:30:45.000000000
# 2024-02-19 14:31:25.000000000
# -77
# 2024-02-19 14:33:29.500000000
# 2024-02-19 14:34:16.500000000
# 23
# 2024-02-19 14:37:59.500000000
# 2024-02-19 14:38:08.500000000
# -52
# 2024-02-19 14:40:55.500000000
# 2024-02-19 14:41:00.500000000
# -52
# 2024-02-19 14:43:41.000000000
# 2024-02-19 14:44:01.500000000
# -77
# 2024-02-19 14:46:15.000000000
# 2024-02-19 14:46:15.000000000
# 23
# 2024-02-19 14:47:29.500000000
# 2024-02-19 14:47:29.500000000
# -77
# 2024-02-19 14:49:16.500000000
# 2024-02-19 14:49:42.500000000
# 23
# 2024-02-19 14:51:17.500000000
# 2024-02-19 21:10:02.000000000
# 23
# 2024-02-19 21:11:22.000000000
# 2024-02-19 21:11:49.000000000
# 23
# 2024-02-19 21:13:00.500000000
# 2024-02-19 21:13:20.500000000
# 23
# 2024-02-19 21:14:58.000000000
# 2024-02-19 21:16:05.000000000
# 23
# 2024-02-19 21:17:43.000000000
# 2024-02-19 21:17:52.500000000
# -27
# 2024-02-19 21:19:38.500000000
# 2024-02-19 21:20:30.500000000
# 23
# 2024-02-19 21:22:23.500000000
# 2024-02-19 21:24:22.500000000
# 23
# 2024-02-19 21:26:12.500000000
# 2024-02-19 21:28:23.500000000
# -2
# 2024-02-19 21:30:06.500000000
# 2024-02-19 21:30:34.500000000
# -52
# 2024-02-19 21:32:55.500000000
# 2024-02-19 21:32:56.500000000
# -27
# 2024-02-19 21:34:36.500000000
# 2024-02-19 21:34:50.500000000
# 23
# 2024-02-19 21:36:33.000000000
# 2024-02-19 21:36:48.500000000
# -52
# 2024-02-19 21:38:03.500000000
# 2024-02-19 21:38:10.500000000
# 23
# 2024-02-19 21:39:16.000000000
# 2024-02-19 21:39:18.500000000
# -77
# 2024-02-19 21:40:30.000000000
# 2024-02-19 21:41:02.500000000
# -27
# 2024-02-19 21:43:08.000000000
# 2024-02-19 21:43:31.000000000
# -27
# 2024-02-19 21:45:35.500000000
# 2024-02-19 21:46:11.000000000
# -52
# 2024-02-19 21:47:24.000000000
# 2024-02-19 21:49:08.500000000
# 23
# 2024-02-19 21:52:24.000000000
# 2024-02-19 21:54:43.000000000
# -27
# 2024-02-19 21:56:24.000000000
# 2024-02-19 21:57:33.000000000
# -77
# 2024-02-19 22:00:03.000000000
# 2024-02-19 22:00:03.500000000
# 23
# 2024-02-19 22:02:14.000000000
# 2024-02-19 22:02:21.500000000
# 23
# 2024-02-19 22:05:10.000000000
# 2024-02-19 22:06:27.500000000
# 23
# 2024-02-19 22:10:22.000000000
# 2024-02-19 22:10:46.000000000
# 23
# 2024-02-19 22:12:49.500000000
# 2024-02-19 22:13:24.000000000
# 23
# 2024-02-19 22:14:18.000000000
# 2024-02-19 22:14:56.500000000
# 23
# 2024-02-19 22:17:08.500000000
# 2024-02-19 22:19:17.500000000
# 23
# 2024-02-19 22:21:57.000000000
# 2024-02-19 22:22:59.000000000
# -27
# 2024-02-19 22:26:01.000000000
# 2024-02-19 22:26:38.500000000
# 23
# 2024-02-19 22:28:32.000000000
# 2024-02-19 22:28:32.000000000
# 23
# 2024-02-19 22:30:30.500000000
# 2024-02-19 22:30:35.000000000
# 23
# 2024-02-19 22:33:07.500000000
# 2024-02-19 22:35:29.500000000
# 23
# 2024-02-19 22:37:20.500000000
# 2024-02-19 22:37:23.500000000
# 23
# 2024-02-19 22:41:01.000000000
# 2024-02-19 22:45:07.500000000
# 23
# 2024-02-19 22:49:09.000000000
# 2024-02-19 22:51:25.000000000
# 23
# 2024-02-19 22:57:05.000000000
# 2024-02-19 22:58:17.500000000
# 23
# 2024-02-19 23:00:58.000000000
# 2024-02-19 23:07:05.000000000
# 23
# 2024-02-19 23:12:29.500000000
# 2024-02-19 23:12:30.500000000
# -27
# 2024-02-19 23:15:09.000000000
# 2024-02-19 23:15:23.500000000
# 23
# 2024-02-19 23:21:03.000000000
# 2024-02-19 23:22:46.000000000
# 23
# 2024-02-19 23:31:28.000000000
# 2024-02-19 23:31:28.500000000
# 23
# 2024-02-19 23:40:05.500000000
# 2024-02-19 23:42:58.500000000
# 23
# 2024-02-19 23:48:12.500000000
# 2024-02-19 23:50:51.000000000
# -52
# 2024-02-20 00:05:40.000000000
# 2024-02-20 09:10:30.000000000
# 23
# 2024-02-20 09:12:48.500000000
# 2024-02-20 09:14:27.000000000
# 23
# 2024-02-20 09:15:51.500000000
# 2024-02-20 09:15:58.500000000
# 23
# 2024-02-20 09:18:13.500000000
# 2024-02-20 09:18:17.500000000
# 23
# 2024-02-20 09:21:09.000000000
# 2024-02-20 09:21:29.500000000
# 23
# 2024-02-20 09:23:18.500000000
# 2024-02-20 09:23:18.500000000
# 23
# 2024-02-20 09:24:46.500000000
# 2024-02-20 09:25:12.500000000
# -52
# 2024-02-20 09:27:30.500000000
# 2024-02-20 09:27:47.500000000
# 23
# 2024-02-20 09:29:23.500000000
# 2024-02-20 09:29:50.000000000
# 23
# 2024-02-20 09:31:25.500000000
# 2024-02-20 09:31:53.000000000
# 23
# 2024-02-20 09:33:33.000000000
# 2024-02-20 09:34:27.000000000
# 23
# 2024-02-20 09:36:07.000000000
# 2024-02-20 09:36:23.000000000
# 23
# 2024-02-20 09:39:06.500000000
# 2024-02-20 09:39:27.500000000
# 23
# 2024-02-20 09:42:18.500000000
# 2024-02-20 09:44:54.000000000
# 23
# 2024-02-20 09:47:27.500000000
# 2024-02-20 09:47:27.500000000
# 23
# 2024-02-20 09:50:14.000000000
# 2024-02-20 09:52:15.500000000
# 23
# 2024-02-20 09:55:29.000000000
# 2024-02-20 09:56:33.000000000
# 23
# 2024-02-20 09:59:56.000000000
# 2024-02-20 10:00:34.000000000
# -27
# 2024-02-20 10:05:31.500000000
# 2024-02-20 10:06:01.500000000
# 23
# 2024-02-20 10:09:05.000000000
# 2024-02-20 10:09:28.500000000
# 23
# 2024-02-20 10:12:17.500000000
# 2024-02-20 10:12:25.500000000
# 23
# 2024-02-20 10:13:52.000000000
# 2024-02-20 10:14:40.500000000
# -27
# 2024-02-20 10:31:15.500000000
# 2024-02-20 10:31:51.000000000
# 23
# 2024-02-20 10:33:14.000000000
# 2024-02-20 10:34:40.500000000
# 23
# 2024-02-20 10:36:56.000000000
# 2024-02-20 10:37:14.000000000
# 23
# 2024-02-20 10:39:59.500000000
# 2024-02-20 10:41:05.000000000
# 23
# 2024-02-20 10:42:56.000000000
# 2024-02-20 10:42:57.000000000
# 23
# 2024-02-20 10:45:18.500000000
# 2024-02-20 10:49:28.000000000
# 23
# 2024-02-20 10:52:10.500000000
# 2024-02-20 10:52:56.000000000
# -52
# 2024-02-20 10:54:13.500000000
# 2024-02-20 10:54:37.000000000
# 23
# 2024-02-20 10:56:21.500000000
# 2024-02-20 10:56:43.000000000
# -52
# 2024-02-20 10:58:24.500000000
# 2024-02-20 10:58:25.000000000
# 23
# 2024-02-20 10:59:56.500000000
# 2024-02-20 11:00:00.000000000
# -27
# 2024-02-20 11:01:45.000000000
# 2024-02-20 11:01:54.500000000
# 23
# 2024-02-20 11:02:57.000000000
# 2024-02-20 11:03:48.500000000
# -27
# 2024-02-20 11:05:07.000000000
# 2024-02-20 11:05:09.500000000
# 23
# 2024-02-20 11:08:07.500000000
# 2024-02-20 11:08:09.500000000
# -52
# 2024-02-20 11:10:52.500000000
# 2024-02-20 11:11:04.500000000
# -27
# 2024-02-20 11:13:20.500000000
# 2024-02-20 11:16:17.500000000
# 23
# 2024-02-20 11:18:11.500000000
# 2024-02-20 11:18:30.000000000
# -27
# 2024-02-20 11:20:00.500000000
# 2024-02-20 13:40:37.500000000
# 23
# 2024-02-20 13:42:04.000000000
# 2024-02-20 13:42:19.000000000
# -2
# 2024-02-20 13:44:12.000000000
# 2024-02-20 13:45:32.000000000
# 23
# 2024-02-20 13:46:58.500000000
# 2024-02-20 13:47:01.000000000
# 23
# 2024-02-20 13:49:19.000000000
# 2024-02-20 13:53:15.500000000
# -27
# 2024-02-20 13:55:15.500000000
# 2024-02-20 13:55:53.000000000
# 23
# 2024-02-20 13:57:57.500000000
# 2024-02-20 14:03:46.500000000
# 23
# 2024-02-20 14:06:40.500000000
# 2024-02-20 14:07:07.000000000
# 23
# 2024-02-20 14:10:05.500000000
# 2024-02-20 14:12:03.500000000
# 23
# 2024-02-20 14:15:17.500000000
# 2024-02-20 14:15:56.000000000
# 23
# 2024-02-20 14:21:17.000000000
# 2024-02-20 14:22:08.000000000
# -27
# 2024-02-20 14:26:21.000000000
# 2024-02-20 14:26:56.000000000
# -27
# 2024-02-20 14:31:04.000000000
# 2024-02-20 14:32:39.000000000
# 23
# 2024-02-20 14:34:36.500000000
# 2024-02-20 14:36:23.500000000
# 23
# 2024-02-20 14:40:16.500000000
# 2024-02-20 14:40:18.500000000
# 23
# 2024-02-20 14:44:07.500000000
# 2024-02-20 14:44:07.500000000
# 23
# 2024-02-20 14:46:56.000000000
# 2024-02-20 14:48:08.000000000
# -27
# 2024-02-20 14:50:24.500000000
# 2024-02-20 21:10:47.000000000
# -27
# 2024-02-20 21:12:32.500000000
# 2024-02-20 21:14:50.500000000
# -102
# 2024-02-20 21:16:14.000000000
# 2024-02-20 21:16:38.000000000
# 23
# 2024-02-20 21:17:47.500000000
# 2024-02-20 21:22:31.500000000
# 23
# 2024-02-20 21:25:14.500000000
# 2024-02-20 21:33:01.500000000
# -52
# 2024-02-20 21:35:09.000000000
# 2024-02-20 21:35:17.000000000
# 23
# 2024-02-20 21:38:51.000000000
# 2024-02-20 21:41:52.000000000
# 23
# 2024-02-20 21:44:38.000000000
# 2024-02-20 21:44:38.500000000
# 23
# 2024-02-20 21:47:12.000000000
# 2024-02-20 21:47:52.000000000
# -27
# 2024-02-20 21:50:17.000000000
# 2024-02-20 21:55:32.500000000
# -27
# 2024-02-20 21:59:36.500000000
# 2024-02-20 22:07:21.500000000
# 23
# 2024-02-20 22:10:45.500000000
# 2024-02-20 22:11:43.000000000
# -27
# 2024-02-20 22:16:12.000000000
# 2024-02-20 22:16:46.500000000
# -52
# 2024-02-20 22:20:01.000000000
# 2024-02-20 22:27:48.500000000
# 23
# 2024-02-20 22:29:38.000000000
# 2024-02-20 22:47:37.500000000
# 2024-02-20 23:06:20.500000000
# -27
# 2024-02-20 23:11:11.000000000
# 2024-02-20 23:18:46.000000000
# 23
# 2024-02-20 23:24:51.000000000
# 2024-02-20 23:28:43.500000000
# 23
# 2024-02-20 23:34:59.000000000
# 2024-02-20 23:43:25.500000000
# -27
# 2024-02-20 23:52:49.500000000
# 2024-02-21 09:12:16.500000000
# 23
# 2024-02-21 09:14:38.500000000
# 2024-02-21 09:17:27.000000000
# 23
# 2024-02-21 09:19:47.500000000
# 2024-02-21 09:23:13.000000000
# 23
# 2024-02-21 09:25:21.500000000
# 2024-02-21 09:26:39.500000000
# 23
# 2024-02-21 09:28:57.000000000
# 2024-02-21 09:34:37.000000000
# 23
# 2024-02-21 09:36:48.500000000
# 2024-02-21 09:41:36.000000000
# 23
# 2024-02-21 09:42:40.000000000
# 2024-02-21 09:45:02.500000000
# 23
# 2024-02-21 09:46:23.500000000
# 2024-02-21 09:47:02.500000000
# 23
# 2024-02-21 09:48:33.000000000
# 2024-02-21 09:50:21.500000000
# 23
# 2024-02-21 09:52:35.500000000
# 2024-02-21 10:02:01.000000000
# -27
# 2024-02-21 10:03:14.000000000
# 2024-02-21 10:14:23.500000000
# -2
# 2024-02-21 10:32:08.000000000
# 2024-02-21 10:32:21.500000000
# -52
# 2024-02-21 10:35:08.500000000
# 2024-02-21 10:38:16.500000000
# -52
# 2024-02-21 10:41:02.000000000
# 2024-02-21 10:42:59.000000000
# 23
# 2024-02-21 10:44:54.500000000
# 2024-02-21 10:54:01.500000000
# -52
# 2024-02-21 10:56:20.000000000
# 2024-02-21 11:03:46.500000000
# -27
# 2024-02-21 11:05:08.500000000
# 2024-02-21 11:07:00.000000000
# 23
# 2024-02-21 11:08:54.500000000
# 2024-02-21 11:09:37.500000000
# 23
# 2024-02-21 11:10:58.500000000
# 2024-02-21 11:13:17.500000000
# 23
# 2024-02-21 11:14:49.500000000
# 2024-02-21 11:16:46.500000000
# 23
# 2024-02-21 11:18:36.500000000
# 2024-02-21 14:02:31.000000000
# -52
# 2024-02-21 14:04:39.000000000
# 2024-02-21 14:17:40.000000000
# 23
# 2024-02-21 14:19:46.000001000
# 2024-02-21 14:28:55.000000000
# 23
# 2024-02-21 14:32:24.000001000
# 2024-02-21 14:33:00.000001000
# 23
# 2024-02-21 14:37:52.000000000
# 2024-02-21 14:39:47.000000000
# -27
# 2024-02-21 14:43:59.000000000
# 2024-02-21 14:49:06.000000000
# 23
# 2024-02-21 14:50:59.500000000
# 2024-02-21 21:10:01.000000000
# 23
# 2024-02-21 21:11:06.500000000
# 2024-02-21 21:11:07.000000000
# -27
# 2024-02-21 21:12:19.000000000
# 2024-02-21 21:13:07.500000000
# 23
# 2024-02-21 21:14:23.000000000
# 2024-02-21 21:14:57.000000000
# 23
# 2024-02-21 21:16:25.500000000
# 2024-02-21 21:19:38.500000000
# -52
# 2024-02-21 21:21:12.500000000
# 2024-02-21 21:21:52.500000000
# -52
# 2024-02-21 21:23:29.000000000
# 2024-02-21 21:24:25.000000000
# 23
# 2024-02-21 21:26:22.500000000
# 2024-02-21 21:26:47.000000000
# 23
# 2024-02-21 21:28:53.500000000
# 2024-02-21 21:32:17.500000000
# 23
# 2024-02-21 21:34:07.500000000
# 2024-02-21 21:34:22.000000000
# -52
# 2024-02-21 21:36:35.500000000
# 2024-02-21 21:37:03.000000000
# 23
# 2024-02-21 21:39:22.000000000
# 2024-02-21 21:39:22.500000000
# -27
# 2024-02-21 21:42:40.000000000
# 2024-02-21 21:43:34.500000000
# -27
# 2024-02-21 21:47:22.000000000
# 2024-02-21 21:54:37.500000000
# 23
# 2024-02-21 21:57:22.500000000
# 2024-02-21 21:57:22.500000000
# 23
# 2024-02-21 22:01:07.000000000
# 2024-02-21 22:05:58.500000000
# 23
# 2024-02-21 22:10:57.500000000
# 2024-02-21 22:13:11.000000000
# 23
# 2024-02-21 22:14:46.500000000
# 2024-02-21 22:16:07.500000000
# 23
# 2024-02-21 22:19:03.500000000
# 2024-02-21 22:20:36.000000000
# 23
# 2024-02-21 22:24:02.500000000
# 2024-02-21 22:25:09.000000000
# 23
# 2024-02-21 22:27:40.000000000
# 2024-02-21 22:27:41.000000000
# 23
# 2024-02-21 22:30:13.000000000
# 2024-02-21 22:31:11.500000000
# -2
# 2024-02-21 22:33:06.000000000
# 2024-02-21 22:34:14.000000000
# 23
# 2024-02-21 22:36:42.000000000
# 2024-02-21 22:36:45.000000000
# 23
# 2024-02-21 22:39:06.500000000
# 2024-02-21 22:44:04.000000000
# -27
# 2024-02-21 22:47:08.500000000
# 2024-02-21 22:50:42.000000000
# 23
# 2024-02-21 22:52:52.500000000
# 2024-02-21 22:53:01.500000000
# -27
# 2024-02-21 22:56:29.500000000
# 2024-02-21 22:59:26.000000000
# 23
# 2024-02-21 23:01:36.000000000
# 2024-02-21 23:02:11.500000000
# -2
# 2024-02-21 23:03:58.000000000
# 2024-02-21 23:04:04.000000000
# 23
# 2024-02-21 23:06:23.000000000
# 2024-02-21 23:08:15.500000000
# 23
# 2024-02-21 23:11:41.000000000
# 2024-02-21 23:18:52.000000000
# -27
# 2024-02-21 23:27:20.000000000
# 2024-02-21 23:32:13.500000000
# 23
# 2024-02-21 23:42:28.500000000
# 2024-02-22 09:11:17.000000000
# 23
# 2024-02-22 09:12:39.000000000
# 2024-02-22 09:24:22.000000000
# 23
# 2024-02-22 09:26:54.000000000
# 2024-02-22 09:37:55.500000000
# -27
# 2024-02-22 09:39:43.000000000
# 2024-02-22 09:44:06.000000000
# 23
# 2024-02-22 09:46:03.500000000
# 2024-02-22 09:50:37.500000000
# -77
# 2024-02-22 09:53:52.500000000
# 2024-02-22 10:00:06.500000000
# 23
# 2024-02-22 10:03:02.000000000
# 2024-02-22 10:10:31.500000000
# 23
# 2024-02-22 10:11:52.500000000
# 2024-02-22 10:30:02.000000000
# 23
# 2024-02-22 10:32:45.500000000
# 2024-02-22 10:32:50.000000000
# 23
# 2024-02-22 10:36:03.000000000
# 2024-02-22 10:37:23.500000000
# -2
# 2024-02-22 10:40:43.500000000
# 2024-02-22 10:42:48.500000000
# -27
# 2024-02-22 10:47:18.500000000
# 2024-02-22 10:52:27.000000000
# 23
# 2024-02-22 10:54:09.000000000
# 2024-02-22 10:59:51.000000000
# 23
# 2024-02-22 11:00:58.500000000
# 2024-02-22 11:08:53.500000000
# 23
# 2024-02-22 11:12:10.500000000
# 2024-02-22 11:17:56.000000000
# -52
# 2024-02-22 11:20:15.500000000
# 2024-02-22 13:41:31.500000000
# 23
# 2024-02-22 13:43:31.000000000
# 2024-02-22 13:47:47.500000000
# 23
# 2024-02-22 13:50:21.000000000
# 2024-02-22 13:53:47.500000000
# -52
# 2024-02-22 13:55:51.000000000
# 2024-02-22 13:56:29.000000000
# 23
# 2024-02-22 13:58:22.000000000
# 2024-02-22 14:03:18.000000000
# 23
# 2024-02-22 14:05:45.000000000
# 2024-02-22 14:06:16.000000000
# 23
# 2024-02-22 14:08:12.000000000
# 2024-02-22 14:10:12.000000000
# 23
# 2024-02-22 14:12:29.500000000
# 2024-02-22 14:13:18.500000000
# -27
# 2024-02-22 14:16:19.000000000
# 2024-02-22 14:18:09.500000000
# -52
# 2024-02-22 14:21:02.000000000
# 2024-02-22 14:27:47.000000000
# 23
# 2024-02-22 14:29:59.000000000
# 2024-02-22 14:30:08.500000000
# -2
# 2024-02-22 14:32:06.500000000
# 2024-02-22 14:38:36.500000000
# 23
# 2024-02-22 14:41:06.000000000
# 2024-02-22 21:10:18.000000000
# -27
# 2024-02-22 21:11:42.500000000
# 2024-02-22 21:11:45.500000000
# 23
# 2024-02-22 21:13:22.000000000
# 2024-02-22 21:13:23.500000000
# -27
# 2024-02-22 21:15:16.500000000
# 2024-02-22 21:20:30.500000000
# -27
# 2024-02-22 21:21:37.000000000
# 2024-02-22 21:22:23.500000000
# 23
# 2024-02-22 21:23:52.000000000
# 2024-02-22 21:24:33.000000000
# 23
# 2024-02-22 21:25:53.500000000
# 2024-02-22 21:26:40.000000000
# 23
# 2024-02-22 21:27:52.000000000
# 2024-02-22 21:28:04.000000000
# -52
# 2024-02-22 21:29:23.500000000
# 2024-02-22 21:29:29.000000000
# -2
# 2024-02-22 21:31:08.500000000
# 2024-02-22 21:33:12.500000000
# 23
# 2024-02-22 21:35:12.500000000
# 2024-02-22 21:35:14.500000000
# 23
# 2024-02-22 21:37:30.500000000
# 2024-02-22 21:38:58.000000000
# 23
# 2024-02-22 21:41:17.000000000
# 2024-02-22 21:41:25.000000000
# 23
# 2024-02-22 21:43:15.500000000
# 2024-02-22 21:43:22.000000000
# -52
# 2024-02-22 21:44:34.500000000
# 2024-02-22 21:45:47.000000000
# 23
# 2024-02-22 21:48:02.000000000
# 2024-02-22 21:52:47.000000000
# 23
# 2024-02-22 21:54:42.000000000
# 2024-02-22 21:54:45.500000000
# 23
# 2024-02-22 21:56:34.000000000
# 2024-02-22 21:57:52.000000000
# -27
# 2024-02-22 21:59:43.000000000
# 2024-02-22 22:00:00.000000000
# 23
# 2024-02-22 22:01:33.000000000
# 2024-02-22 22:05:22.000000000
# 23
# 2024-02-22 22:08:17.000000000
# 2024-02-22 22:08:54.500000000
# 23
# 2024-02-22 22:12:40.000000000
# 2024-02-22 22:15:35.500000000
# -27
# 2024-02-22 22:20:46.500000000
# 2024-02-22 22:20:47.000000000
# 23
# 2024-02-22 22:26:04.500000000
# 2024-02-22 22:27:36.500000000
# 23
# 2024-02-22 22:31:24.500000000
# 2024-02-22 22:32:44.500000000
# 23
# 2024-02-22 22:38:53.500000000
# 2024-02-22 22:42:27.500000000
# -27
# 2024-02-22 22:45:27.500000000
# 2024-02-22 22:46:34.000000000
# 23
# 2024-02-22 22:49:48.500000000
# 2024-02-22 22:52:19.000000000
# 23
# 2024-02-22 22:55:27.000000000
# 2024-02-22 22:56:43.000000000
# -77
# 2024-02-22 22:58:32.500000000
# 2024-02-22 22:58:41.000000000
# 23
# 2024-02-22 23:00:31.000000000
# 2024-02-22 23:00:49.000000000
# -27
# 2024-02-22 23:03:05.500000000
# 2024-02-22 23:03:16.000000000
# 23
# 2024-02-22 23:09:56.500000000
# 2024-02-22 23:13:48.500000000
# -27
# 2024-02-22 23:19:44.500000000
# 2024-02-22 23:25:41.500000000
# 23
# 2024-02-22 23:31:04.000000000
# 2024-02-22 23:31:13.500000000
# 23
# 2024-02-22 23:36:13.000000000
# 2024-02-22 23:43:19.000000000
# -27
# 2024-02-22 23:50:54.500000000
# 2024-02-22 23:51:12.000000000
# -27
# 2024-02-23 00:01:57.000000000
# 2024-02-23 09:10:08.500000000
# 23
# 2024-02-23 09:12:45.500000000
# 2024-02-23 09:17:13.500000000
# 23
# 2024-02-23 09:18:43.500000000
# 2024-02-23 09:20:09.000000000
# -27
# 2024-02-23 09:22:04.500000000
# 2024-02-23 09:25:44.000000000
# -77
# 2024-02-23 09:27:07.500000000
# 2024-02-23 09:27:26.500000000
# 23
# 2024-02-23 09:28:44.000000000
# 2024-02-23 09:29:49.500000000
# 23
# 2024-02-23 09:30:48.500000000
# 2024-02-23 09:30:50.000000000
# -52
# 2024-02-23 09:32:01.000000000
# 2024-02-23 09:34:03.500000000
# -52
# 2024-02-23 09:35:47.500000000
# 2024-02-23 09:36:01.500000000
# 23
# 2024-02-23 09:37:30.000000000
# 2024-02-23 09:37:38.000000000
# -77
# 2024-02-23 09:39:14.000000000
# 2024-02-23 09:39:45.500000000
# 23
# 2024-02-23 09:41:33.000000000
# 2024-02-23 09:41:51.000000000
# 23
# 2024-02-23 09:43:27.500000000
# 2024-02-23 09:44:44.500000000
# 23
# 2024-02-23 09:46:26.000000000
# 2024-02-23 09:47:02.000000000
# 23
# 2024-02-23 09:48:35.000000000
# 2024-02-23 09:51:43.500000000
# 23
# 2024-02-23 09:53:56.500000000
# 2024-02-23 09:53:56.500000000
# 23
# 2024-02-23 09:56:24.500000000
# 2024-02-23 09:56:27.500000000
# 23
# 2024-02-23 09:57:27.500000000
# 2024-02-23 09:57:48.500000000
# 23
# 2024-02-23 09:58:48.500000000
# 2024-02-23 09:59:01.500000000
# 23
# 2024-02-23 10:00:19.000000000
# 2024-02-23 10:00:38.500000000
# -2
# 2024-02-23 10:01:49.000000000
# 2024-02-23 10:02:22.500000000
# 23
# 2024-02-23 10:03:26.500000000
# 2024-02-23 10:04:02.000000000
# 23
# 2024-02-23 10:05:10.500000000
# 2024-02-23 10:06:15.000000000
# 23
# 2024-02-23 10:07:54.500000000
# 2024-02-23 10:09:13.500000000
# 23
# 2024-02-23 10:10:19.500000000
# 2024-02-23 10:10:29.500000000
# 23
# 2024-02-23 10:11:35.500000000
# 2024-02-23 10:11:41.500000000
# 23
# 2024-02-23 10:12:53.500000000
# 2024-02-23 10:13:16.000000000
# 23
# 2024-02-23 10:14:40.000000000
# 2024-02-23 10:14:51.000000000
# 23
# 2024-02-23 10:30:53.500000000
# 2024-02-23 10:31:07.000000000
# 23
# 2024-02-23 10:32:22.500000000
# 2024-02-23 10:32:39.000000000
# -27
# 2024-02-23 10:34:20.500000000
# 2024-02-23 10:34:24.500000000
# -52
# 2024-02-23 10:36:08.500000000
# 2024-02-23 10:37:04.000000000
# -27
# 2024-02-23 10:38:47.500000000
# 2024-02-23 10:39:21.500000000
# 23
# 2024-02-23 10:40:38.000000000
# 2024-02-23 10:40:45.000000000
# 23
# 2024-02-23 10:42:25.000000000
# 2024-02-23 10:42:59.000000000
# 23
# 2024-02-23 10:44:29.000000000
# 2024-02-23 10:44:34.000000000
# 23
# 2024-02-23 10:46:33.500000000
# 2024-02-23 10:46:35.000000000
# 23
# 2024-02-23 10:49:07.000000000
# 2024-02-23 10:49:11.000000000
# 23
# 2024-02-23 10:51:30.000000000
# 2024-02-23 10:52:02.000000000
# 23
# 2024-02-23 10:53:47.500000000
# 2024-02-23 10:53:47.500000000
# -27
# 2024-02-23 10:55:54.500000000
# 2024-02-23 10:56:28.500000000
# 23
# 2024-02-23 10:58:13.000000000
# 2024-02-23 11:02:43.500000000
# -27
# 2024-02-23 11:04:54.000000000
# 2024-02-23 11:08:07.000000000
# 23
# 2024-02-23 11:09:47.500000000
# 2024-02-23 11:11:10.000000000
# 23
# 2024-02-23 11:13:03.500000000
# 2024-02-23 11:13:53.500000000
# -52
# 2024-02-23 11:15:20.000000000
# 2024-02-23 11:15:39.000000000
# -102
# 2024-02-23 11:16:30.500000000
# 2024-02-23 11:16:32.500000000
# 23
# 2024-02-23 11:17:33.000000000
# 2024-02-23 11:17:46.000000000
# 23
# 2024-02-23 11:18:58.000000000
# 2024-02-23 11:19:01.500000000
# 23
# 2024-02-23 11:20:00.000000000
# 2024-02-23 13:41:54.000000000
# -27
# 2024-02-23 13:44:17.500000000
# 2024-02-23 13:45:09.000000000
# 23
# 2024-02-23 13:47:16.500000000
# 2024-02-23 13:47:16.500000000
# 23
# 2024-02-23 13:49:47.500000000
# 2024-02-23 13:49:50.500000000
# -27
# 2024-02-23 13:53:42.500000000
# 2024-02-23 13:54:43.500000000
# -27
# 2024-02-23 13:57:15.500000000
# 2024-02-23 13:58:04.500000000
# 23
# 2024-02-23 14:01:18.500000000
# 2024-02-23 14:03:24.500000000
# 23
# 2024-02-23 14:06:12.500000000
# 2024-02-23 14:06:21.500000000
# -52
# 2024-02-23 14:08:33.500000000
# 2024-02-23 14:09:16.500000000
# 23
# 2024-02-23 14:10:54.000000000
# 2024-02-23 14:11:55.000000000
# -27
# 2024-02-23 14:14:09.500000000
# 2024-02-23 14:14:56.000000000
# -27
# 2024-02-23 14:17:05.500000000
# 2024-02-23 14:17:13.500000000
# -27
# 2024-02-23 14:19:38.000000000
# 2024-02-23 14:22:49.500000000
# -52
# 2024-02-23 14:25:16.000000000
# 2024-02-23 14:26:02.000000000
# 23
# 2024-02-23 14:28:04.000000000
# 2024-02-23 14:34:00.500000000
# -27
# 2024-02-23 14:36:47.500000000
# 2024-02-23 14:36:48.000000000
# -27
# 2024-02-23 14:39:30.000000000
# 2024-02-23 14:40:41.000000000
# -52
# 2024-02-23 14:42:58.000000000
# 2024-02-23 14:45:57.500000000
# 23
# 2024-02-23 14:47:26.500000000
# 2024-02-23 14:47:44.000000000
# -27
# 2024-02-23 14:49:30.000000000
# 2024-02-23 14:49:37.000000000
# -27
# 2024-02-23 14:51:51.000000000
# 2024-02-23 21:10:09.000000000
# -27
# 2024-02-23 21:11:46.500000000
# 2024-02-23 21:11:52.000000000
# 23
# 2024-02-23 21:13:38.500000000
# 2024-02-23 21:14:18.000000000
# 23
# 2024-02-23 21:16:07.000000000
# 2024-02-23 21:16:14.500000000
# -27
# 2024-02-23 21:18:19.500000000
# 2024-02-23 21:19:42.000000000
# 23
# 2024-02-23 21:21:33.500000000
# 2024-02-23 21:21:39.500000000
# 23
# 2024-02-23 21:23:13.000000000
# 2024-02-23 21:24:12.500000000
# 23
# 2024-02-23 21:25:26.500000000
# 2024-02-23 21:26:21.000000000
# -27
# 2024-02-23 21:28:03.500000000
# 2024-02-23 21:31:06.000000000
# -2
# 2024-02-23 21:32:19.500000000
# 2024-02-23 21:32:39.000000000
# -27
# 2024-02-23 21:34:30.500000000
# 2024-02-23 21:35:02.000000000
# 23
# 2024-02-23 21:36:32.500000000
# 2024-02-23 21:36:43.000000000
# -77
# 2024-02-23 21:38:25.000000000
# 2024-02-23 21:39:54.000000000
# 23
# 2024-02-23 21:41:49.500000000
# 2024-02-23 21:42:47.500000000
# -27
# 2024-02-23 21:46:11.000000000
# 2024-02-23 21:46:17.000000000
# 23
# 2024-02-23 21:49:22.000000000
# 2024-02-23 21:52:55.000000000
# -52
# 2024-02-23 21:56:45.500000000
# 2024-02-23 21:57:16.000000000
# 23
# 2024-02-23 22:00:29.500000000
# 2024-02-23 22:06:21.500000000
# -52
# 2024-02-23 22:09:57.000000000
# 2024-02-23 22:10:02.000000000
# -52
# 2024-02-23 22:13:30.500000000
# 2024-02-23 22:13:39.000000000
# 23
# 2024-02-23 22:18:12.500000000
# 2024-02-23 22:18:13.000000000
# -27
# 2024-02-23 22:20:19.500000000
# 2024-02-23 22:21:40.500000000
# 23
# 2024-02-23 22:23:17.500000000
# 2024-02-23 22:23:34.000000000
# 23
# 2024-02-23 22:25:07.000000000
# 2024-02-23 22:25:34.500000000
# -27
# 2024-02-23 22:27:32.000000000
# 2024-02-23 22:30:59.500000000
# 23
# 2024-02-23 22:32:57.000000000
# 2024-02-23 22:32:58.000000000
# -52
# 2024-02-23 22:34:57.500000000
# 2024-02-23 22:36:13.000000000
# 23
# 2024-02-23 22:38:55.000000000
# 2024-02-23 22:41:59.500000000
# 23
# 2024-02-23 22:44:07.500000000
# 2024-02-23 22:44:08.500000000
# -52
# 2024-02-23 22:47:34.500000000
# 2024-02-23 22:50:46.500000000
# -27
# 2024-02-23 22:54:01.500000000
# 2024-02-23 22:54:46.500000000
# -52
# 2024-02-23 22:57:16.000000000
# 2024-02-23 22:58:52.500000000
# 23
# 2024-02-23 23:00:04.000000000
# 2024-02-23 23:00:23.000000000
# -27
# 2024-02-23 23:02:17.000000000
# 2024-02-23 23:02:40.500000000
# 23
# 2024-02-23 23:03:38.500000000
# 2024-02-23 23:03:39.500000000
# 23
# 2024-02-23 23:04:50.500000000
# 2024-02-23 23:05:19.000000000
# 23
# 2024-02-23 23:06:31.000000000
# 2024-02-23 23:06:33.000000000
# 23
# 2024-02-23 23:08:16.500000000
# 2024-02-23 23:08:55.000000000
# 23
# 2024-02-23 23:11:25.000000000
# 2024-02-23 23:13:44.500000000
# 23
# 2024-02-23 23:15:25.500000000
# 2024-02-23 23:15:27.500000000
# 23
# 2024-02-23 23:18:08.000000000
# 2024-02-23 23:18:49.000000000
# 23
# 2024-02-23 23:22:11.000000000
# 2024-02-23 23:22:23.000000000
# 23
# 2024-02-23 23:27:11.500000000
# 2024-02-23 23:27:50.000000000
# 23
# 2024-02-23 23:31:40.000000000
# 2024-02-23 23:32:50.000000000
# 23
# 2024-02-23 23:37:55.500000000
# 2024-02-23 23:37:58.500000000
# 23
# 2024-02-23 23:44:14.000000000
# 2024-02-23 23:44:33.000000000
# 23
# 2024-02-23 23:49:16.500000000
# 2024-02-23 23:51:54.500000000
# 23
# 2024-02-23 23:53:03.500000000
# 2024-02-23 23:57:42.000000000
# -127
# 2024-02-23 23:58:39.500000000
# 2024-02-23 23:59:19.500000000
# 23
# 2024-02-24 00:00:29.500000000
# 2024-02-26 09:10:10.000000000
# 23
# 2024-02-26 09:11:32.500000000
# 2024-02-26 09:11:32.500000000
# 23
# 2024-02-26 09:13:11.500000000
# 2024-02-26 09:13:11.500000000
# 23
# 2024-02-26 09:15:01.000000000
# 2024-02-26 09:17:08.000000000
# 23
# 2024-02-26 09:18:56.500000000
# 2024-02-26 09:19:09.500000000
# -52
# 2024-02-26 09:20:55.500000000
# 2024-02-26 09:21:11.500000000
# 23
# 2024-02-26 09:23:26.000000000
# 2024-02-26 09:23:28.000000000
# 23
# 2024-02-26 09:26:09.500000000
# 2024-02-26 09:27:44.000000000
# 23
# 2024-02-26 09:29:37.500000000
# 2024-02-26 09:31:19.000000000
# 23
# 2024-02-26 09:33:22.000000000
# 2024-02-26 09:35:15.000000000
# -52
# 2024-02-26 09:37:28.500000000
# 2024-02-26 09:39:05.500000000
# 23
# 2024-02-26 09:41:16.500000000
# 2024-02-26 09:41:26.500000000
# 23
# 2024-02-26 09:43:12.500000000
# 2024-02-26 09:43:12.500000000
# 23
# 2024-02-26 09:44:42.500000000
# 2024-02-26 09:44:45.000000000
# -77
# 2024-02-26 09:46:35.500000000
# 2024-02-26 09:46:40.000000000
# 23
# 2024-02-26 09:48:33.000000000
# 2024-02-26 09:49:20.500000000
# -27
# 2024-02-26 09:50:45.000000000
# 2024-02-26 09:51:26.500000000
# 23
# 2024-02-26 09:53:30.000000000
# 2024-02-26 09:56:51.000000000
# -52
# 2024-02-26 09:58:36.000000000
# 2024-02-26 10:00:02.500000000
# 23
# 2024-02-26 10:01:42.500000000
# 2024-02-26 10:02:15.500000000
# 23
# 2024-02-26 10:04:46.500000000
# 2024-02-26 10:08:28.000000000
# -102
# 2024-02-26 10:10:43.000000000
# 2024-02-26 10:11:56.000000000
# 23
# 2024-02-26 10:13:49.000000000
# 2024-02-26 10:14:22.500000000
# -27
# 2024-02-26 10:31:24.000000000
# 2024-02-26 10:32:21.000000000
# -52
# 2024-02-26 10:35:13.500000000
# 2024-02-26 10:35:26.000000000
# -52
# 2024-02-26 10:37:36.500000000
# 2024-02-26 10:39:53.500000000
# -27
# 2024-02-26 10:43:08.500000000
# 2024-02-26 10:45:18.500000000
# 23
# 2024-02-26 10:48:51.000000000
# 2024-02-26 10:54:26.500000000
# -2
# 2024-02-26 10:57:34.000000000
# 2024-02-26 11:00:06.000000000
# 23
# 2024-02-26 11:02:39.000000000
# 2024-02-26 11:11:44.500000000
# 23
# 2024-02-26 11:14:37.500000000
# 2024-02-26 11:14:54.500000000
# 23
# 2024-02-26 11:18:28.500000000
# 2024-02-26 13:45:55.500000000
# 23
# 2024-02-26 13:49:28.000000000
# 2024-02-26 13:51:15.000000000
# 23
# 2024-02-26 13:54:58.000000000
# 2024-02-26 14:00:03.500000000
# 23
# 2024-02-26 14:05:11.500000000
# 2024-02-26 14:07:03.000000000
# 23
# 2024-02-26 14:11:30.500000000
# 2024-02-26 14:14:37.500000000
# -27
# 2024-02-26 14:17:40.500000000
# 2024-02-26 14:22:16.500000000
# -52
# 2024-02-26 14:24:36.000000000
# 2024-02-26 14:25:20.000000000
# 23
# 2024-02-26 14:27:40.000000000
# 2024-02-26 14:30:21.500000000
# -77
# 2024-02-26 14:32:56.000000000
# 2024-02-26 14:37:02.500000000
# 23
# 2024-02-26 14:40:46.000000000
# 2024-02-26 14:43:33.000000000
# -52
# 2024-02-26 14:45:54.500000000
# 2024-02-26 21:10:01.000000000
# 23
# 2024-02-26 21:11:02.500000000
# 2024-02-26 21:11:03.500000000
# 23
# 2024-02-26 21:12:00.000000000
# 2024-02-26 21:13:54.000000000
# 23
# 2024-02-26 21:14:53.500000000
# 2024-02-26 21:19:53.000000000
# 23
# 2024-02-26 21:21:30.000000000
# 2024-02-26 21:22:31.000000000
# 23
# 2024-02-26 21:23:38.500000000
# 2024-02-26 21:23:42.000000000
# 23
# 2024-02-26 21:25:12.500000000
# 2024-02-26 21:25:43.000000000
# 23
# 2024-02-26 21:27:27.000000000
# 2024-02-26 21:30:27.000000000
# 23
# 2024-02-26 21:32:00.500000000
# 2024-02-26 21:32:33.500000000
# 23
# 2024-02-26 21:34:34.500000000
# 2024-02-26 21:34:55.500000000
# 23
# 2024-02-26 21:36:29.500000000
# 2024-02-26 21:43:56.500000000
# 23
# 2024-02-26 21:45:51.000000000
# 2024-02-26 21:46:24.000000000
# -27
# 2024-02-26 21:49:13.000000000
# 2024-02-26 21:50:31.000000000
# -52
# 2024-02-26 21:53:14.500000000
# 2024-02-26 21:56:31.000000000
# 23
# 2024-02-26 21:59:00.000000000
# 2024-02-26 22:05:18.000000000
# -2
# 2024-02-26 22:09:25.500000000
# 2024-02-26 22:14:21.500000000
# 23
# 2024-02-26 22:16:18.000000000
# 2024-02-26 22:17:59.500000000
# -27
# 2024-02-26 22:22:57.500000000
# 2024-02-26 22:26:33.000000000
# 23
# 2024-02-26 22:29:18.500000000
# 2024-02-26 22:41:17.500000000
# 23
# 2024-02-26 22:44:27.500000000
# 2024-02-26 22:44:52.500000000
# -27
# 2024-02-26 22:48:38.500000000
# 2024-02-26 22:48:52.000000000
# 23
# 2024-02-26 22:53:28.000000000
# 2024-02-26 22:57:58.000000000
# 23
# 2024-02-26 23:00:26.000000000
# 2024-02-26 23:00:28.000000000
# -52
# 2024-02-26 23:04:35.500000000
# 2024-02-26 23:05:38.500000000
# -27
# 2024-02-26 23:12:29.500000000
# 2024-02-26 23:19:09.500000000
# 23
# 2024-02-26 23:30:05.500000000
# 2024-02-26 23:30:05.500000000
# 23
# 2024-02-26 23:38:02.000000000
# 2024-02-26 23:44:40.000000000
# 23
# 2024-02-26 23:59:06.000000000
# 2024-02-27 09:10:32.500000000
# -52
# 2024-02-27 09:12:08.000000000
# 2024-02-27 09:17:31.000000000
# 23
# 2024-02-27 09:19:45.500000000
# 2024-02-27 09:20:15.500000000
# 23
# 2024-02-27 09:22:23.000000000
# 2024-02-27 09:22:28.000000000
# 23
# 2024-02-27 09:25:15.500000000
# 2024-02-27 09:26:10.500000000
# -102
# 2024-02-27 09:27:26.500000000
# 2024-02-27 09:29:17.500000000
# -77
# 2024-02-27 09:30:30.500000000
# 2024-02-27 09:30:48.500000000
# 23
# 2024-02-27 09:31:57.500000000
# 2024-02-27 09:31:57.500000000
# 23
# 2024-02-27 09:33:32.000000000
# 2024-02-27 09:34:49.500000000
# -77
# 2024-02-27 09:36:28.500000000
# 2024-02-27 09:36:55.000000000
# 23
# 2024-02-27 09:38:27.500000000
# 2024-02-27 09:40:09.500000000
# 23
# 2024-02-27 09:42:30.000000000
# 2024-02-27 09:43:21.000000000
# 23
# 2024-02-27 09:44:33.500000000
# 2024-02-27 09:44:55.000000000
# 23
# 2024-02-27 09:46:22.500000000
# 2024-02-27 09:47:10.500000000
# -52
# 2024-02-27 09:50:07.500000000
# 2024-02-27 09:50:39.500000000
# -52
# 2024-02-27 09:52:09.500000000
# 2024-02-27 09:53:15.500000000
# 23
# 2024-02-27 09:55:08.500000000
# 2024-02-27 09:55:48.500000000
# 23
# 2024-02-27 09:57:25.000000000
# 2024-02-27 09:57:25.500000000
# 23
# 2024-02-27 09:59:05.500000000
# 2024-02-27 09:59:13.500000000
# 23
# 2024-02-27 10:01:07.500000000
# 2024-02-27 10:01:34.000000000
# -52
# 2024-02-27 10:03:40.000000000
# 2024-02-27 10:05:04.500000000
# 23
# 2024-02-27 10:06:14.500000000
# 2024-02-27 10:07:05.000000000
# 23
# 2024-02-27 10:08:30.000000000
# 2024-02-27 10:09:49.500000000
# 23
# 2024-02-27 10:11:01.000000000
# 2024-02-27 10:11:01.500000000
# -27
# 2024-02-27 10:12:48.000000000
# 2024-02-27 10:13:15.000000000
# 23
# 2024-02-27 10:14:43.500000000
# 2024-02-27 10:14:54.000000000
# -27
# 2024-02-27 10:31:12.500000000
# 2024-02-27 10:31:40.000000000
# -52
# 2024-02-27 10:33:36.500000000
# 2024-02-27 10:33:43.000000000
# -52
# 2024-02-27 10:35:20.000000000
# 2024-02-27 10:35:20.000000000
# 23
# 2024-02-27 10:37:09.500000000
# 2024-02-27 10:39:44.000000000
# 23
# 2024-02-27 10:43:00.000000000
# 2024-02-27 10:43:57.500000000
# -27
# 2024-02-27 10:46:45.000000000
# 2024-02-27 10:49:31.500000000
# 23
# 2024-02-27 10:50:57.000000000
# 2024-02-27 10:51:07.500000000
# 23
# 2024-02-27 10:52:57.000000000
# 2024-02-27 10:52:57.500000000
# 23
# 2024-02-27 10:55:04.500000000
# 2024-02-27 10:56:06.000000000
# 23
# 2024-02-27 10:57:07.000000000
# 2024-02-27 10:59:07.000000000
# 23
# 2024-02-27 10:59:58.500000000
# 2024-02-27 11:01:32.000000000
# 23
# 2024-02-27 11:02:38.000000000
# 2024-02-27 11:03:07.500000000
# -102
# 2024-02-27 11:04:02.000000000
# 2024-02-27 11:04:17.500000000
# 23
# 2024-02-27 11:05:20.000000000
# 2024-02-27 11:08:08.500000000
# 23
# 2024-02-27 11:09:19.000000000
# 2024-02-27 11:11:53.000000000
# 23
# 2024-02-27 11:14:30.000000000
# 2024-02-27 11:16:00.500000000
# 23
# 2024-02-27 11:18:55.500000000
# 2024-02-27 11:19:11.500000000
# 23
# 2024-02-27 11:22:05.000000000
# 2024-02-27 13:40:22.500000000
# 23
# 2024-02-27 13:42:10.500000000
# 2024-02-27 13:42:14.000000000
# -52
# 2024-02-27 13:43:56.000000000
# 2024-02-27 13:45:13.000000000
# -52
# 2024-02-27 13:46:59.500000000
# 2024-02-27 13:47:23.000000000
# 23
# 2024-02-27 13:49:12.500000000
# 2024-02-27 13:53:55.000000000
# -27
# 2024-02-27 13:56:37.500000000
# 2024-02-27 13:59:36.000000000
# 23
# 2024-02-27 14:01:22.000000000
# 2024-02-27 14:02:51.500000000
# -52
# 2024-02-27 14:05:56.000000000
# 2024-02-27 14:08:02.500000000
# 23
# 2024-02-27 14:10:54.000000000
# 2024-02-27 14:14:23.500000000
# 23
# 2024-02-27 14:17:35.000000000
# 2024-02-27 14:18:57.500000000
# 23
# 2024-02-27 14:21:17.000000000
# 2024-02-27 14:21:17.000000000
# -52
# 2024-02-27 14:24:14.500000000
# 2024-02-27 14:24:16.000000000
# 23
# 2024-02-27 14:26:20.500000000
# 2024-02-27 14:27:37.500000000
# -27
# 2024-02-27 14:30:42.000000000
# 2024-02-27 14:32:47.000000000
# -52
# 2024-02-27 14:35:37.000000000
# 2024-02-27 14:36:08.500000000
# 23
# 2024-02-27 14:37:39.000000000
# 2024-02-27 14:38:32.500000000
# 23
# 2024-02-27 14:41:23.500000000
# 2024-02-27 14:47:02.000000000
# -77
# 2024-02-27 14:48:56.500000000
# 2024-02-27 21:10:35.500000000
# -27
# 2024-02-27 21:11:47.500000000
# 2024-02-27 21:12:50.000000000
# 23
# 2024-02-27 21:14:03.000000000
# 2024-02-27 21:14:25.000000000
# 23
# 2024-02-27 21:15:58.000000000
# 2024-02-27 21:16:00.500000000
# -2
# 2024-02-27 21:17:40.000000000
# 2024-02-27 21:21:44.500000000
# 23
# 2024-02-27 21:23:53.000000000
# 2024-02-27 21:23:53.000000000
# 23
# 2024-02-27 21:24:57.500000000
# 2024-02-27 21:25:18.000000000
# 23
# 2024-02-27 21:27:01.500000000
# 2024-02-27 21:28:33.500000000
# 23
# 2024-02-27 21:30:24.500000000
# 2024-02-27 21:30:44.500000000
# 23
# 2024-02-27 21:32:05.500000000
# 2024-02-27 21:34:22.000000000
# 2024-02-27 21:36:01.000000000
# 23
# 2024-02-27 21:37:14.500000000
# 2024-02-27 21:37:15.500000000
# 23
# 2024-02-27 21:38:56.500000000
# 2024-02-27 21:49:35.000000000
# 23
# 2024-02-27 21:52:56.500000000
# 2024-02-27 21:52:57.000000000
# 23
# 2024-02-27 21:57:20.500000000
# 2024-02-27 21:58:16.500000000
# 23
# 2024-02-27 21:59:54.000000000
# 2024-02-27 22:00:02.000000000
# 23
# 2024-02-27 22:01:58.500000000
# 2024-02-27 22:05:34.500000000
# 23
# 2024-02-27 22:08:10.000000000
# 2024-02-27 22:09:15.500000000
# 23
# 2024-02-27 22:13:09.500000000
# 2024-02-27 22:22:04.500000000
# 23
# 2024-02-27 22:26:32.500000000
# 2024-02-27 22:28:10.500000000
# -52
# 2024-02-27 22:31:33.000000000
# 2024-02-27 22:34:25.000000000
# -2
# 2024-02-27 22:37:28.500000000
# 2024-02-27 22:38:14.500000000
# -52
# 2024-02-27 22:42:49.000000000
# 2024-02-27 22:52:31.000000000
# 23
# 2024-02-27 22:56:46.000000000
# 2024-02-27 22:58:15.000000000
# -52
# 2024-02-27 23:00:05.500000000
# 2024-02-27 23:01:15.500000000
# 23
# 2024-02-27 23:05:47.500000000
# 2024-02-27 23:09:39.000000000
# 23
# 2024-02-27 23:15:04.500000000
# 2024-02-27 23:17:39.500000000
# 23
# 2024-02-27 23:23:36.000000000
# 2024-02-27 23:24:19.500000000
# 23
# 2024-02-27 23:30:46.000000000
# 2024-02-27 23:30:46.000000000
# 23
# 2024-02-27 23:40:22.500000000
# 2024-02-27 23:52:36.500000000
# -2
# 2024-02-28 00:07:43.000000000
# 2024-02-28 09:11:01.000000000
# 23
# 2024-02-28 09:12:23.500000000
# 2024-02-28 09:13:33.000000000
# 23
# 2024-02-28 09:15:48.000000000
# 2024-02-28 09:19:24.000000000
# 23
# 2024-02-28 09:21:22.500000000
# 2024-02-28 09:24:03.500000000
# 23
# 2024-02-28 09:26:05.000000000
# 2024-02-28 09:26:10.500000000
# -77
# 2024-02-28 09:27:27.000000000
# 2024-02-28 09:28:08.500000000
# 23
# 2024-02-28 09:29:42.500000000
# 2024-02-28 09:31:02.500000000
# 23
# 2024-02-28 09:33:27.000000000
# 2024-02-28 09:33:42.500000000
# -27
# 2024-02-28 09:35:26.000000000
# 2024-02-28 09:36:05.500000000
# 23
# 2024-02-28 09:38:06.500000000
# 2024-02-28 09:45:13.000000000
# 23
# 2024-02-28 09:47:24.500000000
# 2024-02-28 09:48:38.500000000
# -52
# 2024-02-28 09:51:03.000000000
# 2024-02-28 09:51:25.000000000
# 23
# 2024-02-28 09:53:06.000000000
# 2024-02-28 09:54:36.500000000
# 23
# 2024-02-28 09:56:50.500000000
# 2024-02-28 09:56:54.000000000
# -52
# 2024-02-28 09:59:22.500000000
# 2024-02-28 10:00:31.500000000
# 23
# 2024-02-28 10:03:17.000000000
# 2024-02-28 10:04:16.500000000
# 23
# 2024-02-28 10:06:44.000000000
# 2024-02-28 10:07:19.500000000
# 23
# 2024-02-28 10:08:52.000000000
# 2024-02-28 10:09:43.000000000
# -27
# 2024-02-28 10:12:03.500000000
# 2024-02-28 10:12:10.500000000
# -77
# 2024-02-28 10:30:15.500000000
# 2024-02-28 10:30:28.500000000
# 23
# 2024-02-28 10:32:36.000000000
# 2024-02-28 10:32:36.000000000
# -27
# 2024-02-28 10:35:17.000000000
# 2024-02-28 10:35:39.500000000
# -52
# 2024-02-28 10:38:10.000000000
# 2024-02-28 10:40:42.500000000
# 23
# 2024-02-28 10:43:02.000000000
# 2024-02-28 10:46:40.500000000
# -52
# 2024-02-28 10:48:23.000000000
# 2024-02-28 10:50:06.000000000
# -52
# 2024-02-28 10:51:48.500000000
# 2024-02-28 10:52:43.500000000
# -52
# 2024-02-28 10:53:40.500000000
# 2024-02-28 10:54:31.000000000
# 23
# 2024-02-28 10:56:40.000000000
# 2024-02-28 10:57:41.000000000
# 23
# 2024-02-28 10:59:08.000000000
# 2024-02-28 11:01:01.500000000
# -52
# 2024-02-28 11:03:56.500000000
# 2024-02-28 11:05:09.500000000
# 23
# 2024-02-28 11:06:45.500000000
# 2024-02-28 11:07:08.000000000
# 23
# 2024-02-28 11:09:01.500000000
# 2024-02-28 11:09:04.000000000
# 23
# 2024-02-28 11:10:16.000000000
# 2024-02-28 11:13:08.000000000
# 23
# 2024-02-28 11:15:17.500000000
# 2024-02-28 11:17:38.000000000
# 23
# 2024-02-28 11:19:00.000000000
# 2024-02-28 11:19:01.500000000
# 23
# 2024-02-28 11:20:14.000000000
# 2024-02-28 13:41:17.000000000
# -27
# 2024-02-28 13:43:33.500000000
# 2024-02-28 13:45:06.000000000
# 23
# 2024-02-28 13:47:17.500000000
# 2024-02-28 13:47:31.000000000
# 23
# 2024-02-28 13:50:06.000000000
# 2024-02-28 13:51:18.000000000
# -77
# 2024-02-28 13:54:07.500000000
# 2024-02-28 13:55:16.000000000
# 23
# 2024-02-28 13:56:31.500000000
# 2024-02-28 13:57:23.000000000
# -77
# 2024-02-28 14:00:53.500000000
# 2024-02-28 14:03:25.500000000
# 23
# 2024-02-28 14:06:46.000000000
# 2024-02-28 14:07:41.500000000
# 23
# 2024-02-28 14:10:23.500000000
# 2024-02-28 14:10:24.500000000
# 23
# 2024-02-28 14:11:50.000000000
# 2024-02-28 14:12:04.000000000
# 23
# 2024-02-28 14:14:08.500000000
# 2024-02-28 14:18:38.500000000
# 23
# 2024-02-28 14:21:46.000000000
# 2024-02-28 14:21:47.500000000
# -52
# 2024-02-28 14:24:46.500000000
# 2024-02-28 14:25:01.000000000
# 23
# 2024-02-28 14:27:43.500000000
# 2024-02-28 14:28:02.000000000
# -102
# 2024-02-28 14:31:00.500000000
# 2024-02-28 14:31:27.500000000
# -52
# 2024-02-28 14:35:08.500000000
# 2024-02-28 14:36:43.000000000
# -52
# 2024-02-28 14:40:32.500000000
# 2024-02-28 14:44:34.500000000
# 23
# 2024-02-28 14:47:27.500000000
# 2024-02-28 14:48:16.000000000
# 23
# 2024-02-28 14:50:41.500000000
# 2024-02-05: 402.00
# 2024-02-06: 560.00
# 2024-02-07: 373.00
# 2024-02-08: 354.00
# 2024-02-19: 136.00
# 2024-02-20: 325.00
# 2024-02-21: 307.00
# 2024-02-22: 172.00
# 2024-02-23: -86.00
# 2024-02-26: 114.00
# 2024-02-27: 72.00
# 2024-02-28: -256.00
# 2024-02-05: 24
# 2024-02-06: 70
# 2024-02-07: 51
# 2024-02-08: 23
# 2024-02-19: 107
# 2024-02-20: 76
# 2024-02-21: 59
# 2024-02-22: 64
# 2024-02-23: 118
# 2024-02-26: 68
# 2024-02-27: 90
# 2024-02-28: 53
# Final profit: 2473.00
# 0.7023661270236613
# 803
