# %%
import os
import glob
import pandas as pd

def read_csv_with_encoding(file, encodings):
    for encoding in encodings:
        try:
            return pd.read_csv(file, encoding=encoding)
        except UnicodeDecodeError:
            continue
    raise ValueError(f"None of the encodings worked for file: {file}")

def combine_csv_in_folder(folder_path, file_pattern, combined_csv):
    os.chdir(folder_path)
    file_list = glob.glob(file_pattern)
    print(file_list)

    for file in file_list:
        df = read_csv_with_encoding(file, ['utf-8', 'gb2312', 'gbk'])
        combined_csv = combined_csv.append(df, ignore_index=True)

    return combined_csv

# List of folders to combine CSV files from
folders = ['/Users/zhangwenbo/Downloads/1']  # Update with your folder paths
file_pattern = "ss2401.csv"

# Create an empty DataFrame to store combined data
combined_csv = pd.DataFrame()

# Process each folder
for folder in folders:
    combined_csv = combine_csv_in_folder(folder, file_pattern, combined_csv)

# Save the combined data to a new CSV file
combined_csv.to_csv("/Users/zhangwenbo/testProjects/laplace/combined_csv.csv", index=False, encoding='utf-8', errors='ignore')

print("All files combined successfully!")
# Out:
#                            datetime        datetime_nano  \
# 0     2024-01-04 20:59:00.500000000  1704373140500000000
# 1     2024-01-04 21:00:00.500004000  1704373200500004000
# 2     2024-01-04 21:00:01.000000000  1704373201000000000
# 3     2024-01-04 21:00:01.500000000  1704373201500000000
# 4     2024-01-04 21:00:02.000000000  1704373202000000000
# ...                             ...                  ...
# 5403  2024-01-05 14:54:19.000000000  1704437659000000000
# 5404  2024-01-05 14:57:18.500000000  1704437838500000000
# 5405  2024-01-05 14:59:19.500000000  1704437959500000000
# 5406  2024-01-05 14:59:34.500000000  1704437974500000000
# 5407  2024-01-05 14:59:59.000001000  1704437999000001000
#
#       SHFE.ss2401.last_price  SHFE.ss2401.highest  SHFE.ss2401.lowest  \
# 0                        NaN                  NaN                 NaN
# 1                        NaN                  NaN                 NaN
# 2                        NaN                  NaN                 NaN
# 3                        NaN                  NaN                 NaN
# 4                        NaN                  NaN                 NaN
# ...                      ...                  ...                 ...
# 5403                 13530.0              13775.0             13505.0
# 5404                 13550.0              13775.0             13505.0
# 5405                 13550.0              13775.0             13505.0
# 5406                 13550.0              13775.0             13505.0
# 5407                 13550.0              13775.0             13505.0
#
#       SHFE.ss2401.average  SHFE.ss2401.volume  SHFE.ss2401.amount  \
# 0                     NaN                   0                   0
# 1                     NaN                   0                   0
# 2                     NaN                   0                   0
# 3                     NaN                   0                   0
# 4                     NaN                   0                   0
# ...                   ...                 ...                 ...
# 5403              13643.3                 348            23739300
# 5404              13640.2                 360            24552300
# 5405              13640.2                 360            24552300
# 5406              13640.2                 360            24552300
# 5407              13640.2                 360            24552300
#
#       SHFE.ss2401.open_interest  SHFE.ss2401.bid_price1  ...  \
# 0                          2028                   13560  ...
# 1                          2028                   13570  ...
# 2                          2028                   13755  ...
# 3                          2028                   13760  ...
# 4                          2028                   13765  ...
# ...                         ...                     ...  ...
# 5403                       1800                   13510  ...
# 5404                       1788                   13510  ...
# 5405                       1788                   13505  ...
# 5406                       1788                   13510  ...
# 5407                       1788                   13510  ...
#
#       SHFE.ss2401.ask_price3  SHFE.ss2401.ask_volume3  SHFE.ss2401.bid_price4  \
# 0                        NaN                        0                     NaN
# 1                    14180.0                       12                     NaN
# 2                    13955.0                       12                 13725.0
# 3                    14180.0                       12                 13560.0
# 4                    14380.0                       12                 13360.0
# ...                      ...                      ...                     ...
# 5403                 13580.0                       12                 13450.0
# 5404                 13600.0                       12                 13450.0
# 5405                 13600.0                       12                 13400.0
# 5406                 13600.0                       12                 13450.0
# 5407                 13600.0                       12                 13450.0
#
#       SHFE.ss2401.bid_volume4  SHFE.ss2401.ask_price4  \
# 0                           0                     NaN
# 1                           0                 14380.0
# 2                          12                 14180.0
# 3                          12                 14380.0
# 4                          12                     NaN
# ...                       ...                     ...
# 5403                       24                 13600.0
# 5404                       24                 13625.0
# 5405                       24                 13625.0
# 5406                       24                 13625.0
# 5407                       24                 13625.0
#
#       SHFE.ss2401.ask_volume4  SHFE.ss2401.bid_price5  \
# 0                           0                     NaN
# 1                          12                     NaN
# 2                          12                 13575.0
# 3                          12                 13360.0
# 4                           0                     NaN
# ...                       ...                     ...
# 5403                       12                 13400.0
# 5404                       12                 13400.0
# 5405                       12                 13320.0
# 5406                       12                 13400.0
# 5407                       12                 13400.0
#
#       SHFE.ss2401.bid_volume5  SHFE.ss2401.ask_price5  SHFE.ss2401.ask_volume5
# 0                           0                     NaN                        0
# 1                           0                     NaN                        0
# 2                          36                 14380.0                       12
# 3                          12                     NaN                        0
# 4                           0                     NaN                        0
# ...                       ...                     ...                      ...
# 5403                       24                 13625.0                       12
# 5404                       24                 13700.0                       24
# 5405                       12                 13700.0                       24
# 5406                       24                 13700.0                       24
# 5407                       24                 13700.0                       24
#
# [5408 rows x 29 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 31>()
#      30 # Process each folder
#      31 for folder in folders:
# ---> 32     combined_csv = combine_csv_in_folder(folder, file_pattern, combined_csv)
#      34 # Save the combined data to a new CSV file
#      35 combined_csv.to_csv("/Users/zhangwenbo/testProjects/laplace/combined_csv.csv", index=False, encoding='utf-8', errors='ignore')
#
# Input In [6], in combine_csv_in_folder(folder_path, file_pattern, combined_csv)
#      18             df = read_csv_with_encoding(file_path, ['utf-8', 'gb2312', 'gbk'])
#      19             print(df)
# ---> 20             combined_csv = combined_csv.append(df, ignore_index=True)
#      21 return combined_csv
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
data = pd.read_csv("/Users/zhangwenbo/testProjects/laplace/combined_csv.csv")
data['close'] = data['最新价']
data['time'] = data['最后修改时间']
data['trade_time'] = pd.to_datetime(data['交易日'].astype(str) + ' ' + data['最后修改时间'])
data = data.sort_values(by='trade_time')
data.to_csv("future_ssmain_tick.csv")
