# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# 1. 数据加载和预处理
data = pd.read_csv("merged_sorted_file1.csv")

data_clean = data.dropna(subset=['current']).copy()


# 2. 特征生成
# Calculate rolling mean and standard deviation
data_clean['rolling_mean'] = data_clean['current'].rolling(window=5).mean()
data_clean['rolling_std'] = data_clean['current'].rolling(window=5).std()
data_clean = data_clean.fillna(data_clean.median())

# Calculate RSI
delta = data_clean['current'].diff()
gain = (delta.where(delta > 0, 0)).fillna(0)
loss = (-delta.where(delta < 0, 0)).fillna(0)
avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()
rs = avg_gain / avg_loss
data_clean['RSI'] = 100 - (100 / (1 + rs))

# Calculate MACD
short_ema = data_clean['current'].ewm(span=12, adjust=False).mean()
long_ema = data_clean['current'].ewm(span=26, adjust=False).mean()
data_clean['MACD'] = short_ema - long_ema
data_clean['MACD_signal'] = data_clean['MACD'].ewm(span=9, adjust=False).mean()

# Shift RSI and MACD to use them as features for next timestep
data_clean['RSI_shifted'] = data_clean['RSI'].shift(1)
data_clean['MACD_shifted'] = data_clean['MACD'].shift(1)
data_clean['MACD_signal_shifted'] = data_clean['MACD_signal'].shift(1)

# Define label
data_clean['label'] = (data_clean['current'].shift(-120) > data_clean['current']).astype(int)
# data_clean['label'] = data_clean['current'].shift(-200) - data_clean['current']



# 3. 分割数据
data_clean['date_only'] = pd.to_datetime(data_clean['time']).dt.date
# Updated the data split to use 'date_only'
first_date = data_clean['date_only'].iloc[0]
# first_month_data = data_clean[data_clean['date_only'] <= first_date + pd.Timedelta(days=10)]
first_month_data = data_clean[(data_clean['date_only'] > first_date + pd.Timedelta(days=20)) & 
                               (data_clean['date_only'] <= first_date + pd.Timedelta(days=30))]
features = ['current', 'rolling_mean', 'rolling_std', 'RSI_shifted', 'MACD_shifted', 'MACD_signal_shifted']
X_first_month = first_month_data[features]
y_first_month = first_month_data['label']

X_train_month_clean = X_first_month.dropna()
y_train_month_clean = y_first_month[X_train_month_clean.index]


# 4. 模型训练
rf = RandomForestClassifier(n_estimators=100, random_state=42)
# rf = RandomForestRegressor(n_estimators=100, random_state=42)

rf.fit(X_train_month_clean, y_train_month_clean)  # Use the cleaned data for training
# Out:
# RandomForestClassifier(random_state=42)

# %%
#涨跌预测
# 5. 使用第二个月的数据进行预测
second_month_data = data_clean[(data_clean['date_only'] > first_date + pd.Timedelta(days=30)) & 
                               (data_clean['date_only'] <= first_date + pd.Timedelta(days=40))]

# 预测的初始化
probabilities_second_month = []

initial_funds = 100000
funds = initial_funds
stock_quantity = 0
stock_price = 0
threshold = 0.95
transactions = []

# 在逐行预测和模拟交易部分，初始化买入价格为0
buy_price = 0
minute_count = 0
for idx, row in second_month_data.iterrows():
    current_row = row[features].fillna(method='ffill')
    current_probability = rf.predict_proba([current_row])[0][1]
    current_price = row['current']
    minute_count = minute_count + 1
    # print(current_probability)
    flag = 1
    time_string = row['time'][-8:]  # 获取时间部分，例如 "22:59:10"
    if time_string.startswith("11:29:") or time_string.startswith("14:59:") or time_string.startswith("22:59:"):
        flag = 0
        
    if current_probability > threshold and stock_quantity == 0 and flag==1:
        print(current_probability)
        stock_quantity = funds // current_price
        funds -= stock_quantity * current_price
        stock_price = current_price
        # fee = max(stock_quantity * current_price * 0.0003, 5)
        # funds -= fee
        buy_price = current_price  # 记录买入价格
        print(f"Time: {row['time']} - Action: BUY at {current_price}, Quantity: {stock_quantity},Funds:{funds}")
        transactions.append({
            'action': 'buy',
            'time': row['time'],
            'price': current_price,
            'quantity': stock_quantity,
            'funds_remaining': funds
        })
        minute_count = 0
    # elif minute_count >= 120 and stock_quantity > 0 :
    elif current_probability < 1-threshold and stock_quantity > 0 and minute_count>120:
        print(current_probability)
        funds += stock_quantity * current_price
        # fee = max(stock_quantity * current_price * 0.0003, 5)
        # funds -= fee
        price_diff = current_price - buy_price  # 计算价格差异
        # 判断价格差异是涨、跌还是平
        if price_diff > 0:
            direction = '涨'
        elif price_diff < 0:
            direction = '跌'
        else:
            direction = '平'
        print(f"Time: {row['time']} - Action: SELL at {current_price}, Quantity: {stock_quantity},Funds:{funds}, Price Change: {direction}")
        transactions.append({
            'action': 'sell',
            'time': row['time'],
            'price': current_price,
            'quantity': stock_quantity,
            'funds_remaining': funds,
            'price_change': direction
        })
        stock_quantity = 0
        buy_price = 0  # 重置买入价格为0
    
    

transactions_df = pd.DataFrame(transactions)
print(transactions_df['price_change'].value_counts())
transactions_df.to_csv('transactions1.csv')
# Out:
# 1.0
# Time: 2023-08-03 09:00:20 - Action: BUY at 3742.0, Quantity: 26.0,Funds:2708.0
# 0.04
# Time: 2023-08-03 09:08:36 - Action: SELL at 3759.0, Quantity: 26.0,Funds:100442.0, Price Change: 涨
# 0.97
# Time: 2023-08-03 09:09:40 - Action: BUY at 3756.0, Quantity: 26.0,Funds:2786.0
# 0.02
# Time: 2023-08-03 09:12:24 - Action: SELL at 3758.0, Quantity: 26.0,Funds:100494.0, Price Change: 涨
# 0.99
# Time: 2023-08-03 09:13:35 - Action: BUY at 3754.0, Quantity: 26.0,Funds:2890.0
# 0.05
# Time: 2023-08-03 09:18:51 - Action: SELL at 3755.0, Quantity: 26.0,Funds:100520.0, Price Change: 涨
# 0.97
# Time: 2023-08-03 09:19:05 - Action: BUY at 3757.0, Quantity: 26.0,Funds:2838.0
# 0.03
# Time: 2023-08-03 09:23:28 - Action: SELL at 3760.0, Quantity: 26.0,Funds:100598.0, Price Change: 涨
# 1.0
# Time: 2023-08-03 09:24:07 - Action: BUY at 3759.0, Quantity: 26.0,Funds:2864.0
# 0.03
# Time: 2023-08-03 09:27:56 - Action: SELL at 3760.0, Quantity: 26.0,Funds:100624.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 09:43:47 - Action: BUY at 3763.0, Quantity: 26.0,Funds:2786.0
# 0.01
# Time: 2023-08-03 09:45:54 - Action: SELL at 3765.0, Quantity: 26.0,Funds:100676.0, Price Change: 涨
# 0.97
# Time: 2023-08-03 10:02:20 - Action: BUY at 3762.0, Quantity: 26.0,Funds:2864.0
# 0.03
# Time: 2023-08-03 10:33:42 - Action: SELL at 3759.0, Quantity: 26.0,Funds:100598.0, Price Change: 跌
# 0.97
# Time: 2023-08-03 10:35:44 - Action: BUY at 3761.0, Quantity: 26.0,Funds:2812.0
# 0.04
# Time: 2023-08-03 10:38:18 - Action: SELL at 3760.0, Quantity: 26.0,Funds:100572.0, Price Change: 跌
# 0.96
# Time: 2023-08-03 10:51:30 - Action: BUY at 3754.0, Quantity: 26.0,Funds:2968.0
# 0.04
# Time: 2023-08-03 10:52:46 - Action: SELL at 3756.0, Quantity: 26.0,Funds:100624.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 10:52:58 - Action: BUY at 3754.0, Quantity: 26.0,Funds:3020.0
# 0.04
# Time: 2023-08-03 10:56:53 - Action: SELL at 3755.0, Quantity: 26.0,Funds:100650.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 10:57:46 - Action: BUY at 3754.0, Quantity: 26.0,Funds:3046.0
# 0.01
# Time: 2023-08-03 11:01:27 - Action: SELL at 3758.0, Quantity: 26.0,Funds:100754.0, Price Change: 涨
# 0.97
# Time: 2023-08-03 11:04:36 - Action: BUY at 3760.0, Quantity: 26.0,Funds:2994.0
# 0.04
# Time: 2023-08-03 11:09:42 - Action: SELL at 3763.0, Quantity: 26.0,Funds:100832.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 11:11:48 - Action: BUY at 3762.0, Quantity: 26.0,Funds:3020.0
# 0.05
# Time: 2023-08-03 11:14:45 - Action: SELL at 3764.0, Quantity: 26.0,Funds:100884.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 11:20:09 - Action: BUY at 3758.0, Quantity: 26.0,Funds:3176.0
# 0.05
# Time: 2023-08-03 11:24:22 - Action: SELL at 3755.0, Quantity: 26.0,Funds:100806.0, Price Change: 跌
# 0.96
# Time: 2023-08-03 11:24:33 - Action: BUY at 3756.0, Quantity: 26.0,Funds:3150.0
# 0.04
# Time: 2023-08-03 11:25:52 - Action: SELL at 3759.0, Quantity: 26.0,Funds:100884.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 11:27:15 - Action: BUY at 3751.0, Quantity: 26.0,Funds:3358.0
# 0.05
# Time: 2023-08-03 13:30:12 - Action: SELL at 3767.0, Quantity: 26.0,Funds:101300.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 13:33:35 - Action: BUY at 3782.0, Quantity: 26.0,Funds:2968.0
# 0.05
# Time: 2023-08-03 13:34:45 - Action: SELL at 3787.0, Quantity: 26.0,Funds:101430.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 13:37:32 - Action: BUY at 3790.0, Quantity: 26.0,Funds:2890.0
# 0.05
# Time: 2023-08-03 13:39:41 - Action: SELL at 3785.0, Quantity: 26.0,Funds:101300.0, Price Change: 跌
# 0.99
# Time: 2023-08-03 13:39:52 - Action: BUY at 3784.0, Quantity: 26.0,Funds:2916.0
# 0.02
# Time: 2023-08-03 13:42:18 - Action: SELL at 3775.0, Quantity: 26.0,Funds:101066.0, Price Change: 跌
# 0.99
# Time: 2023-08-03 13:44:44 - Action: BUY at 3782.0, Quantity: 26.0,Funds:2734.0
# 0.04
# Time: 2023-08-03 13:47:32 - Action: SELL at 3778.0, Quantity: 26.0,Funds:100962.0, Price Change: 跌
# 0.97
# Time: 2023-08-03 13:47:41 - Action: BUY at 3780.0, Quantity: 26.0,Funds:2682.0
# 0.05
# Time: 2023-08-03 13:49:17 - Action: SELL at 3776.0, Quantity: 26.0,Funds:100858.0, Price Change: 跌
# 0.96
# Time: 2023-08-03 13:51:13 - Action: BUY at 3780.0, Quantity: 26.0,Funds:2578.0
# 0.02
# Time: 2023-08-03 13:56:52 - Action: SELL at 3779.0, Quantity: 26.0,Funds:100832.0, Price Change: 跌
# 0.98
# Time: 2023-08-03 13:57:58 - Action: BUY at 3777.0, Quantity: 26.0,Funds:2630.0
# 0.05
# Time: 2023-08-03 13:59:03 - Action: SELL at 3776.0, Quantity: 26.0,Funds:100806.0, Price Change: 跌
# 0.98
# Time: 2023-08-03 14:00:54 - Action: BUY at 3773.0, Quantity: 26.0,Funds:2708.0
# 0.04
# Time: 2023-08-03 14:02:11 - Action: SELL at 3774.0, Quantity: 26.0,Funds:100832.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 14:06:32 - Action: BUY at 3768.0, Quantity: 26.0,Funds:2864.0
# 0.04
# Time: 2023-08-03 14:08:00 - Action: SELL at 3770.0, Quantity: 26.0,Funds:100884.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 14:08:33 - Action: BUY at 3772.0, Quantity: 26.0,Funds:2812.0
# 0.05
# Time: 2023-08-03 14:10:21 - Action: SELL at 3771.0, Quantity: 26.0,Funds:100858.0, Price Change: 跌
# 0.99
# Time: 2023-08-03 14:12:37 - Action: BUY at 3768.0, Quantity: 26.0,Funds:2890.0
# 0.05
# Time: 2023-08-03 14:14:35 - Action: SELL at 3767.0, Quantity: 26.0,Funds:100832.0, Price Change: 跌
# 0.96
# Time: 2023-08-03 14:15:06 - Action: BUY at 3767.0, Quantity: 26.0,Funds:2890.0
# 0.05
# Time: 2023-08-03 14:16:27 - Action: SELL at 3765.0, Quantity: 26.0,Funds:100780.0, Price Change: 跌
# 0.97
# Time: 2023-08-03 14:19:23 - Action: BUY at 3750.0, Quantity: 26.0,Funds:3280.0
# 0.03
# Time: 2023-08-03 14:36:54 - Action: SELL at 3756.0, Quantity: 26.0,Funds:100936.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 14:38:12 - Action: BUY at 3754.0, Quantity: 26.0,Funds:3332.0
# 0.04
# Time: 2023-08-03 14:39:48 - Action: SELL at 3754.0, Quantity: 26.0,Funds:100936.0, Price Change: 平
# 0.96
# Time: 2023-08-03 14:40:24 - Action: BUY at 3752.0, Quantity: 26.0,Funds:3384.0
# 0.05
# Time: 2023-08-03 21:01:53 - Action: SELL at 3805.0, Quantity: 26.0,Funds:102314.0, Price Change: 涨
# 0.97
# Time: 2023-08-03 21:03:07 - Action: BUY at 3795.0, Quantity: 26.0,Funds:3644.0
# 0.01
# Time: 2023-08-03 21:15:33 - Action: SELL at 3799.0, Quantity: 26.0,Funds:102418.0, Price Change: 涨
# 0.96
# Time: 2023-08-03 21:16:13 - Action: BUY at 3799.0, Quantity: 26.0,Funds:3644.0
# 0.05
# Time: 2023-08-03 21:18:01 - Action: SELL at 3802.0, Quantity: 26.0,Funds:102496.0, Price Change: 涨
# 0.99
# Time: 2023-08-03 21:18:29 - Action: BUY at 3800.0, Quantity: 26.0,Funds:3696.0
# 0.03
# Time: 2023-08-03 21:41:13 - Action: SELL at 3787.0, Quantity: 26.0,Funds:102158.0, Price Change: 跌
# 0.98
# Time: 2023-08-03 21:41:45 - Action: BUY at 3789.0, Quantity: 26.0,Funds:3644.0
# 0.02
# Time: 2023-08-03 21:48:26 - Action: SELL at 3787.0, Quantity: 26.0,Funds:102106.0, Price Change: 跌
# 0.97
# Time: 2023-08-03 21:49:52 - Action: BUY at 3788.0, Quantity: 26.0,Funds:3618.0
# 0.05
# Time: 2023-08-03 21:53:20 - Action: SELL at 3787.0, Quantity: 26.0,Funds:102080.0, Price Change: 跌
# 0.96
# Time: 2023-08-03 21:56:24 - Action: BUY at 3784.0, Quantity: 26.0,Funds:3696.0
# 0.01
# Time: 2023-08-03 22:06:48 - Action: SELL at 3772.0, Quantity: 26.0,Funds:101768.0, Price Change: 跌
# 0.97
# Time: 2023-08-03 22:18:55 - Action: BUY at 3773.0, Quantity: 26.0,Funds:3670.0
# 0.04
# Time: 2023-08-03 22:20:55 - Action: SELL at 3770.0, Quantity: 26.0,Funds:101690.0, Price Change: 跌
# 0.97
# Time: 2023-08-03 22:33:23 - Action: BUY at 3768.0, Quantity: 26.0,Funds:3722.0
# 0.03
# Time: 2023-08-03 22:35:32 - Action: SELL at 3765.0, Quantity: 26.0,Funds:101612.0, Price Change: 跌
# 0.98
# Time: 2023-08-03 22:37:24 - Action: BUY at 3759.0, Quantity: 27.0,Funds:119.0
# 0.04
# Time: 2023-08-03 22:39:26 - Action: SELL at 3764.0, Quantity: 27.0,Funds:101747.0, Price Change: 涨
# 0.98
# Time: 2023-08-03 22:42:33 - Action: BUY at 3754.0, Quantity: 27.0,Funds:389.0
# 0.05
# Time: 2023-08-03 22:45:53 - Action: SELL at 3761.0, Quantity: 27.0,Funds:101936.0, Price Change: 涨
# 0.98
# Time: 2023-08-03 22:46:40 - Action: BUY at 3759.0, Quantity: 27.0,Funds:443.0
# 0.03
# Time: 2023-08-03 22:48:21 - Action: SELL at 3758.0, Quantity: 27.0,Funds:101909.0, Price Change: 跌
# 0.98
# Time: 2023-08-03 22:49:16 - Action: BUY at 3754.0, Quantity: 27.0,Funds:551.0
# 0.04
# Time: 2023-08-04 09:10:37 - Action: SELL at 3787.0, Quantity: 27.0,Funds:102800.0, Price Change: 涨
# 0.96
# Time: 2023-08-04 09:12:02 - Action: BUY at 3784.0, Quantity: 27.0,Funds:632.0
# 0.05
# Time: 2023-08-04 09:13:39 - Action: SELL at 3788.0, Quantity: 27.0,Funds:102908.0, Price Change: 涨
# 0.98
# Time: 2023-08-04 09:14:23 - Action: BUY at 3783.0, Quantity: 27.0,Funds:767.0
# 0.0
# Time: 2023-08-04 09:52:37 - Action: SELL at 3776.0, Quantity: 27.0,Funds:102719.0, Price Change: 跌
# 0.97
# Time: 2023-08-04 09:53:01 - Action: BUY at 3777.0, Quantity: 27.0,Funds:740.0
# 0.05
# Time: 2023-08-04 09:54:17 - Action: SELL at 3779.0, Quantity: 27.0,Funds:102773.0, Price Change: 涨
# 0.97
# Time: 2023-08-04 09:55:16 - Action: BUY at 3780.0, Quantity: 27.0,Funds:713.0
# 0.03
# Time: 2023-08-04 09:57:42 - Action: SELL at 3774.0, Quantity: 27.0,Funds:102611.0, Price Change: 跌
# 0.97
# Time: 2023-08-04 10:01:10 - Action: BUY at 3777.0, Quantity: 27.0,Funds:632.0
# 0.05
# Time: 2023-08-04 10:03:12 - Action: SELL at 3774.0, Quantity: 27.0,Funds:102530.0, Price Change: 跌
# 0.98
# Time: 2023-08-04 10:13:30 - Action: BUY at 3767.0, Quantity: 27.0,Funds:821.0
# 0.05
# Time: 2023-08-04 10:34:41 - Action: SELL at 3771.0, Quantity: 27.0,Funds:102638.0, Price Change: 涨
# 1.0
# Time: 2023-08-04 10:36:06 - Action: BUY at 3767.0, Quantity: 27.0,Funds:929.0
# 0.02
# Time: 2023-08-04 10:37:35 - Action: SELL at 3770.0, Quantity: 27.0,Funds:102719.0, Price Change: 涨
# 0.96
# Time: 2023-08-04 10:55:06 - Action: BUY at 3758.0, Quantity: 27.0,Funds:1253.0
# 0.04
# Time: 2023-08-04 10:56:54 - Action: SELL at 3754.0, Quantity: 27.0,Funds:102611.0, Price Change: 跌
# 0.96
# Time: 2023-08-04 10:57:42 - Action: BUY at 3754.0, Quantity: 27.0,Funds:1253.0
# 0.05
# Time: 2023-08-04 10:58:59 - Action: SELL at 3758.0, Quantity: 27.0,Funds:102719.0, Price Change: 涨
# 0.97
# Time: 2023-08-04 11:00:55 - Action: BUY at 3751.0, Quantity: 27.0,Funds:1442.0
# 0.04
# Time: 2023-08-04 11:02:23 - Action: SELL at 3758.0, Quantity: 27.0,Funds:102908.0, Price Change: 涨
# 1.0
# Time: 2023-08-04 11:16:57 - Action: BUY at 3762.0, Quantity: 27.0,Funds:1334.0
# 0.03
# Time: 2023-08-04 11:18:36 - Action: SELL at 3759.0, Quantity: 27.0,Funds:102827.0, Price Change: 跌
# 0.96
# Time: 2023-08-04 11:24:47 - Action: BUY at 3758.0, Quantity: 27.0,Funds:1361.0
# 0.03
# Time: 2023-08-04 11:29:45 - Action: SELL at 3758.0, Quantity: 27.0,Funds:102827.0, Price Change: 平
# 0.99
# Time: 2023-08-04 13:38:25 - Action: BUY at 3760.0, Quantity: 27.0,Funds:1307.0
# 0.05
# Time: 2023-08-04 13:41:33 - Action: SELL at 3759.0, Quantity: 27.0,Funds:102800.0, Price Change: 跌
# 0.99
# Time: 2023-08-04 13:41:49 - Action: BUY at 3760.0, Quantity: 27.0,Funds:1280.0
# 0.01
# Time: 2023-08-04 13:43:52 - Action: SELL at 3760.0, Quantity: 27.0,Funds:102800.0, Price Change: 平
# 0.98
# Time: 2023-08-04 13:48:18 - Action: BUY at 3761.0, Quantity: 27.0,Funds:1253.0
# 0.05
# Time: 2023-08-04 13:51:14 - Action: SELL at 3763.0, Quantity: 27.0,Funds:102854.0, Price Change: 涨
# 0.98
# Time: 2023-08-04 14:01:33 - Action: BUY at 3754.0, Quantity: 27.0,Funds:1496.0
# 0.05
# Time: 2023-08-04 14:50:19 - Action: SELL at 3754.0, Quantity: 27.0,Funds:102854.0, Price Change: 平
# 0.98
# Time: 2023-08-04 14:50:23 - Action: BUY at 3753.0, Quantity: 27.0,Funds:1523.0
# 0.05
# Time: 2023-08-04 21:02:20 - Action: SELL at 3760.0, Quantity: 27.0,Funds:103043.0, Price Change: 涨
# 0.97
# Time: 2023-08-04 21:04:12 - Action: BUY at 3754.0, Quantity: 27.0,Funds:1685.0
# 0.05
# Time: 2023-08-04 21:05:53 - Action: SELL at 3758.0, Quantity: 27.0,Funds:103151.0, Price Change: 涨
# 0.97
# Time: 2023-08-04 21:13:02 - Action: BUY at 3763.0, Quantity: 27.0,Funds:1550.0
# 0.03
# Time: 2023-08-04 21:16:27 - Action: SELL at 3766.0, Quantity: 27.0,Funds:103232.0, Price Change: 涨
# 0.96
# Time: 2023-08-04 21:19:11 - Action: BUY at 3769.0, Quantity: 27.0,Funds:1469.0
# 0.05
# Time: 2023-08-04 21:20:59 - Action: SELL at 3765.0, Quantity: 27.0,Funds:103124.0, Price Change: 跌
# 0.96
# Time: 2023-08-04 21:30:05 - Action: BUY at 3754.0, Quantity: 27.0,Funds:1766.0
# 0.04
# Time: 2023-08-04 21:31:10 - Action: SELL at 3755.0, Quantity: 27.0,Funds:103151.0, Price Change: 涨
# 0.96
# Time: 2023-08-04 21:31:46 - Action: BUY at 3754.0, Quantity: 27.0,Funds:1793.0
# 0.0
# Time: 2023-08-04 21:32:56 - Action: SELL at 3757.0, Quantity: 27.0,Funds:103232.0, Price Change: 涨
# 0.98
# Time: 2023-08-04 21:33:36 - Action: BUY at 3754.0, Quantity: 27.0,Funds:1874.0
# 0.04
# Time: 2023-08-04 21:35:54 - Action: SELL at 3758.0, Quantity: 27.0,Funds:103340.0, Price Change: 涨
# 0.97
# Time: 2023-08-04 21:48:43 - Action: BUY at 3763.0, Quantity: 27.0,Funds:1739.0
# 0.04
# Time: 2023-08-04 21:50:07 - Action: SELL at 3763.0, Quantity: 27.0,Funds:103340.0, Price Change: 平
# 0.96
# Time: 2023-08-04 21:52:52 - Action: BUY at 3767.0, Quantity: 27.0,Funds:1631.0
# 0.03
# Time: 2023-08-04 21:54:38 - Action: SELL at 3765.0, Quantity: 27.0,Funds:103286.0, Price Change: 跌
# 0.97
# Time: 2023-08-04 21:56:30 - Action: BUY at 3763.0, Quantity: 27.0,Funds:1685.0
# 0.02
# Time: 2023-08-04 21:58:15 - Action: SELL at 3762.0, Quantity: 27.0,Funds:103259.0, Price Change: 跌
# 0.98
# Time: 2023-08-04 21:58:51 - Action: BUY at 3763.0, Quantity: 27.0,Funds:1658.0
# 0.02
# Time: 2023-08-04 22:01:06 - Action: SELL at 3763.0, Quantity: 27.0,Funds:103259.0, Price Change: 平
# 0.97
# Time: 2023-08-04 22:02:39 - Action: BUY at 3762.0, Quantity: 27.0,Funds:1685.0
# 0.04
# Time: 2023-08-04 22:04:06 - Action: SELL at 3764.0, Quantity: 27.0,Funds:103313.0, Price Change: 涨
# 0.96
# Time: 2023-08-04 22:06:48 - Action: BUY at 3766.0, Quantity: 27.0,Funds:1631.0
# 0.05
# Time: 2023-08-04 22:08:31 - Action: SELL at 3767.0, Quantity: 27.0,Funds:103340.0, Price Change: 涨
# 0.98
# Time: 2023-08-04 22:09:30 - Action: BUY at 3767.0, Quantity: 27.0,Funds:1631.0
# 0.0
# Time: 2023-08-04 22:13:51 - Action: SELL at 3764.0, Quantity: 27.0,Funds:103259.0, Price Change: 跌
# 0.97
# Time: 2023-08-04 22:18:48 - Action: BUY at 3762.0, Quantity: 27.0,Funds:1685.0
# 0.02
# Time: 2023-08-04 22:20:44 - Action: SELL at 3763.0, Quantity: 27.0,Funds:103286.0, Price Change: 涨
# 0.97
# Time: 2023-08-04 22:22:38 - Action: BUY at 3762.0, Quantity: 27.0,Funds:1712.0
# 0.04
# Time: 2023-08-04 22:24:26 - Action: SELL at 3761.0, Quantity: 27.0,Funds:103259.0, Price Change: 跌
# 0.97
# Time: 2023-08-04 22:24:45 - Action: BUY at 3762.0, Quantity: 27.0,Funds:1685.0
# 0.04
# Time: 2023-08-04 22:27:06 - Action: SELL at 3761.0, Quantity: 27.0,Funds:103232.0, Price Change: 跌
# 0.96
# Time: 2023-08-04 22:38:19 - Action: BUY at 3768.0, Quantity: 27.0,Funds:1496.0
# 0.02
# Time: 2023-08-04 22:40:45 - Action: SELL at 3772.0, Quantity: 27.0,Funds:103340.0, Price Change: 涨
# 0.98
# Time: 2023-08-04 22:51:24 - Action: BUY at 3772.0, Quantity: 27.0,Funds:1496.0
# 0.04
# Time: 2023-08-04 22:53:24 - Action: SELL at 3770.0, Quantity: 27.0,Funds:103286.0, Price Change: 跌
# 0.96
# Time: 2023-08-07 09:00:13 - Action: BUY at 3725.0, Quantity: 27.0,Funds:2711.0
# 0.04
# Time: 2023-08-08 09:02:06 - Action: SELL at 3754.0, Quantity: 27.0,Funds:104069.0, Price Change: 涨
# 0.97
# Time: 2023-08-08 09:02:42 - Action: BUY at 3751.0, Quantity: 27.0,Funds:2792.0
# 0.01
# Time: 2023-08-08 09:04:30 - Action: SELL at 3754.0, Quantity: 27.0,Funds:104150.0, Price Change: 涨
# 0.96
# Time: 2023-08-08 09:08:09 - Action: BUY at 3753.0, Quantity: 27.0,Funds:2819.0
# 0.03
# Time: 2023-08-08 09:10:43 - Action: SELL at 3754.0, Quantity: 27.0,Funds:104177.0, Price Change: 涨
# 1.0
# Time: 2023-08-08 09:11:44 - Action: BUY at 3753.0, Quantity: 27.0,Funds:2846.0
# 0.03
# Time: 2023-08-08 09:14:22 - Action: SELL at 3754.0, Quantity: 27.0,Funds:104204.0, Price Change: 涨
# 0.96
# Time: 2023-08-08 09:15:04 - Action: BUY at 3752.0, Quantity: 27.0,Funds:2900.0
# 0.01
# Time: 2023-08-08 21:12:31 - Action: SELL at 3754.0, Quantity: 27.0,Funds:104258.0, Price Change: 涨
# 0.96
# Time: 2023-08-08 21:14:19 - Action: BUY at 3756.0, Quantity: 27.0,Funds:2846.0
# 0.04
# Time: 2023-08-08 21:17:22 - Action: SELL at 3754.0, Quantity: 27.0,Funds:104204.0, Price Change: 跌
# 0.97
# Time: 2023-08-08 21:18:10 - Action: BUY at 3754.0, Quantity: 27.0,Funds:2846.0
# 涨    45
# 跌    33
# 平     6
# Name: price_change, dtype: int64
